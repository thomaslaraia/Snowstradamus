# %% [markdown]
# # Parallel regression

# %% [markdown]
# #### Arctan loss, f_scale = .1

# %%
from scripts.parallel_phoreal import *

# %matplotlib ipympl

dirpath = '../data_store/data/sodankyla_full/'

# data = []

all_ATL03, all_ATL08 = track_pairs(dirpath)
N = len(all_ATL03)

sodankyla_coords = (26.634154, 67.361833)

# for i in range(N):
for i in [8]:
    data = pvpg_parallel(all_ATL03[i], all_ATL08[i], coords=sodankyla_coords, width=.05,height=.05,\
                         graph_detail=3, loss='arctan',file_index=i, keep_flagged=1, opsys='bad',f_scale=.1)
    # data = pvpg_parallel(all_ATL03[i], all_ATL08[i], coords=sodankyla_coords, width=.5,height=.5,\
    #                      graph_detail=2, loss='linear',file_index=i, keep_flagged=1, opsys='bad',f_scale=.1)
    
    # print(data)
# Out:
# Beam 3 in file 8 has insufficient data.
# Beam 4 in file 8 has insufficient data.
# Beam 5 in file 8 has insufficient data.
# Beam 6 in file 8 has insufficient data.
# /scratch/s1803229/.conda/envs/snow_env/lib/python3.11/site-packages/traitlets/traitlets.py:1385: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
