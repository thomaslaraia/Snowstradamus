# %%
from scripts.parallel_blocks import *

dirpath = '../scratch/data/willowcreek/'

all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
N = len(all_ATL03)
print(N-1)

# coords = (-90.0791, 45.8060)
coords = [(-90.111409,45.774468),(-90.111409,45.810505),(-90.059714,45.828523),(-90.059714,45.837532)]

for i in [3]:#range(N):
    for c in coords:
        data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=c, width=.5,height=.5,file_index=i, alt_thresh=80,\
                             altitude=521, threshold=3, small_box=1, graph_detail=1, loss='linear', rebinned=30, f_scale=.05,\
                             outlier_removal=0.22,method='normal', landcover='forest', trim_atmospheric=True, sat_flag=True)
        # print(data)
# Out:
# 20
# Beam 1, box 1 in willowcreek file 3 has no data.
# Beam 2, box 1 in willowcreek file 3 has no data.
# Nothing in rebinned section for willowcreek file 3's beam 3.
# Nothing in rebinned section for willowcreek file 3's beam 4.
# Nothing in rebinned section for willowcreek file 3's beam 5.
# Nothing in rebinned section for willowcreek file 3's beam 6.
# Beam 1, box 1 in willowcreek file 3 has no data.
# Beam 2, box 1 in willowcreek file 3 has no data.
# Nothing in rebinned section for willowcreek file 3's beam 3.
# Nothing in rebinned section for willowcreek file 3's beam 4.
# Nothing in rebinned section for willowcreek file 3's beam 5.
# Nothing in rebinned section for willowcreek file 3's beam 6.
# Nothing in rebinned section for willowcreek file 3's beam 1.
# Nothing in rebinned section for willowcreek file 3's beam 2.
# Beam 3, box 1 in willowcreek file 3 has no data.
# Beam 4, box 1 in willowcreek file 3 has no data.
# Nothing in rebinned section for willowcreek file 3's beam 5.
# Nothing in rebinned section for willowcreek file 3's beam 6.
# Nothing in rebinned section for willowcreek file 3's beam 1.
# Nothing in rebinned section for willowcreek file 3's beam 2.
# Beam 3, box 1 in willowcreek file 3 has no data.
# Beam 4, box 1 in willowcreek file 3 has no data.
# Nothing in rebinned section for willowcreek file 3's beam 5.
# Nothing in rebinned section for willowcreek file 3's beam 6.

# %%
from scripts.parallel_blocks import *

dirpath = '../scratch/data/willowcreek/'

all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
N = len(all_ATL03)
print(N-1)

coords = (-90.0791, 45.8060)

for i in [3]:#range(N):
    data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=coords, width=4,height=4,file_index=i, alt_thresh=80,\
                         altitude=521, threshold=3, small_box=1, graph_detail=1, loss='linear', rebinned=30, f_scale=.05,\
                         outlier_removal=0.22,method='normal', landcover='forest', trim_atmospheric=True, sat_flag=True)
    # print(data)
# Out:
# 20
# 232
# 223
# Beam 1, box 0 in willowcreek file 3 has no data.
# Beam 1, box 2 in willowcreek file 3 has no data.
# Beam 1, box 3 in willowcreek file 3 has no data.
# Beam 1, box 4 in willowcreek file 3 has no data.
# Beam 1, box 5 in willowcreek file 3 has no data.
# Beam 1, box 6 in willowcreek file 3 has no data.
# Beam 1, box 7 in willowcreek file 3 has no data.
# Beam 1, box 8 in willowcreek file 3 has no data.
# Beam 1, box 10 in willowcreek file 3 has no data.
# Beam 1, box 11 in willowcreek file 3 has no data.
# Beam 1, box 12 in willowcreek file 3 has no data.
# Beam 1, box 13 in willowcreek file 3 has no data.
# Beam 1, box 14 in willowcreek file 3 has no data.
# Beam 1, box 15 in willowcreek file 3 has no data.
# Beam 1, box 16 in willowcreek file 3 has no data.
# Beam 1, box 18 in willowcreek file 3 has no data.
# Beam 1, box 19 in willowcreek file 3 has no data.
# Beam 1, box 20 in willowcreek file 3 has no data.
# Beam 1, box 21 in willowcreek file 3 has no data.
# Beam 1, box 22 in willowcreek file 3 has no data.
# Beam 1, box 23 in willowcreek file 3 has no data.
# Beam 1, box 24 in willowcreek file 3 has no data.
# Beam 1, box 26 in willowcreek file 3 has no data.
# Beam 1, box 27 in willowcreek file 3 has no data.
# Beam 1, box 28 in willowcreek file 3 has no data.
# Beam 1, box 29 in willowcreek file 3 has no data.
# Beam 1, box 30 in willowcreek file 3 has no data.
# Beam 1, box 31 in willowcreek file 3 has no data.
# Beam 1, box 32 in willowcreek file 3 has no data.
# Beam 1, box 34 in willowcreek file 3 has no data.
# Beam 1, box 35 in willowcreek file 3 has no data.
# Beam 1, box 36 in willowcreek file 3 has no data.
# Beam 1, box 37 in willowcreek file 3 has no data.
# Beam 1, box 38 in willowcreek file 3 has no data.
# Beam 1, box 39 in willowcreek file 3 has no data.
# Beam 1, box 40 in willowcreek file 3 has no data.
# Beam 1, box 41 in willowcreek file 3 has insufficient data.
# Beam 1, box 43 in willowcreek file 3 has no data.
# Beam 1, box 44 in willowcreek file 3 has no data.
# Beam 1, box 45 in willowcreek file 3 has no data.
# Beam 1, box 46 in willowcreek file 3 has no data.
# Beam 1, box 47 in willowcreek file 3 has no data.
# Beam 1, box 48 in willowcreek file 3 has no data.
# Beam 1, box 49 in willowcreek file 3 has no data.
# Beam 1, box 51 in willowcreek file 3 has no data.
# Beam 1, box 52 in willowcreek file 3 has no data.
# Beam 1, box 53 in willowcreek file 3 has no data.
# Beam 1, box 54 in willowcreek file 3 has no data.
# Beam 1, box 55 in willowcreek file 3 has no data.
# Beam 1, box 56 in willowcreek file 3 has no data.
# Beam 1, box 57 in willowcreek file 3 has no data.
# Beam 1, box 59 in willowcreek file 3 has no data.
# Beam 1, box 60 in willowcreek file 3 has no data.
# Beam 1, box 61 in willowcreek file 3 has no data.
# Beam 1, box 62 in willowcreek file 3 has no data.
# Beam 1, box 63 in willowcreek file 3 has no data.
# Beam 1, box 64 in willowcreek file 3 has no data.
# Beam 1, box 65 in willowcreek file 3 has no data.
# Beam 1, box 66 in willowcreek file 3 has no data.
# Beam 1, box 67 in willowcreek file 3 has no data.
# Beam 1, box 68 in willowcreek file 3 has no data.
# Beam 1, box 69 in willowcreek file 3 has no data.
# Beam 1, box 70 in willowcreek file 3 has no data.
# Beam 1, box 71 in willowcreek file 3 has no data.
# 168
# 158
# Beam 2, box 0 in willowcreek file 3 has no data.
# Beam 2, box 2 in willowcreek file 3 has no data.
# Beam 2, box 3 in willowcreek file 3 has no data.
# Beam 2, box 4 in willowcreek file 3 has no data.
# Beam 2, box 5 in willowcreek file 3 has no data.
# Beam 2, box 6 in willowcreek file 3 has no data.
# Beam 2, box 7 in willowcreek file 3 has no data.
# Beam 2, box 8 in willowcreek file 3 has no data.
# Beam 2, box 10 in willowcreek file 3 has no data.
# Beam 2, box 11 in willowcreek file 3 has no data.
# Beam 2, box 12 in willowcreek file 3 has no data.
# Beam 2, box 13 in willowcreek file 3 has no data.
# Beam 2, box 14 in willowcreek file 3 has no data.
# Beam 2, box 15 in willowcreek file 3 has no data.
# Beam 2, box 16 in willowcreek file 3 has no data.
# Beam 2, box 18 in willowcreek file 3 has no data.
# Beam 2, box 19 in willowcreek file 3 has no data.
# Beam 2, box 20 in willowcreek file 3 has no data.
# Beam 2, box 21 in willowcreek file 3 has no data.
# Beam 2, box 22 in willowcreek file 3 has no data.
# Beam 2, box 23 in willowcreek file 3 has no data.
# Beam 2, box 24 in willowcreek file 3 has no data.
# Beam 2, box 26 in willowcreek file 3 has no data.
# Beam 2, box 27 in willowcreek file 3 has no data.
# Beam 2, box 28 in willowcreek file 3 has no data.
# Beam 2, box 29 in willowcreek file 3 has no data.
# Beam 2, box 30 in willowcreek file 3 has no data.
# Beam 2, box 31 in willowcreek file 3 has no data.
# Beam 2, box 32 in willowcreek file 3 has no data.
# Beam 2, box 34 in willowcreek file 3 has no data.
# Beam 2, box 35 in willowcreek file 3 has no data.
# Beam 2, box 36 in willowcreek file 3 has no data.
# Beam 2, box 37 in willowcreek file 3 has no data.
# Beam 2, box 38 in willowcreek file 3 has no data.
# Beam 2, box 39 in willowcreek file 3 has no data.
# Beam 2, box 40 in willowcreek file 3 has no data.
# Beam 2, box 42 in willowcreek file 3 has insufficient data.
# Beam 2, box 43 in willowcreek file 3 has no data.
# Beam 2, box 44 in willowcreek file 3 has no data.
# Beam 2, box 45 in willowcreek file 3 has no data.
# Beam 2, box 46 in willowcreek file 3 has no data.
# Beam 2, box 47 in willowcreek file 3 has no data.
# Beam 2, box 48 in willowcreek file 3 has no data.
# Beam 2, box 49 in willowcreek file 3 has no data.
# Beam 2, box 51 in willowcreek file 3 has no data.
# Beam 2, box 52 in willowcreek file 3 has no data.
# Beam 2, box 53 in willowcreek file 3 has no data.
# Beam 2, box 54 in willowcreek file 3 has no data.
# Beam 2, box 55 in willowcreek file 3 has no data.
# Beam 2, box 56 in willowcreek file 3 has no data.
# Beam 2, box 57 in willowcreek file 3 has no data.
# Beam 2, box 59 in willowcreek file 3 has no data.
# Beam 2, box 60 in willowcreek file 3 has no data.
# Beam 2, box 61 in willowcreek file 3 has no data.
# Beam 2, box 62 in willowcreek file 3 has no data.
# Beam 2, box 63 in willowcreek file 3 has no data.
# Beam 2, box 64 in willowcreek file 3 has no data.
# Beam 2, box 65 in willowcreek file 3 has no data.
# Beam 2, box 66 in willowcreek file 3 has no data.
# Beam 2, box 67 in willowcreek file 3 has no data.
# Beam 2, box 68 in willowcreek file 3 has no data.
# Beam 2, box 69 in willowcreek file 3 has no data.
# Beam 2, box 70 in willowcreek file 3 has no data.
# Beam 2, box 71 in willowcreek file 3 has no data.
# 180
# 177
# Beam 3, box 0 in willowcreek file 3 has no data.
# Beam 3, box 1 in willowcreek file 3 has no data.
# Beam 3, box 2 in willowcreek file 3 has no data.
# Beam 3, box 3 in willowcreek file 3 has no data.
# Beam 3, box 5 in willowcreek file 3 has no data.
# Beam 3, box 6 in willowcreek file 3 has no data.
# Beam 3, box 7 in willowcreek file 3 has no data.
# Beam 3, box 8 in willowcreek file 3 has no data.
# Beam 3, box 9 in willowcreek file 3 has no data.
# Beam 3, box 10 in willowcreek file 3 has no data.
# Beam 3, box 11 in willowcreek file 3 has no data.
# Beam 3, box 13 in willowcreek file 3 has no data.
# Beam 3, box 14 in willowcreek file 3 has no data.
# Beam 3, box 15 in willowcreek file 3 has no data.
# Beam 3, box 16 in willowcreek file 3 has no data.
# Beam 3, box 17 in willowcreek file 3 has no data.
# Beam 3, box 18 in willowcreek file 3 has no data.
# Beam 3, box 19 in willowcreek file 3 has no data.
# Beam 3, box 22 in willowcreek file 3 has no data.
# Beam 3, box 23 in willowcreek file 3 has no data.
# Beam 3, box 24 in willowcreek file 3 has no data.
# Beam 3, box 25 in willowcreek file 3 has no data.
# Beam 3, box 26 in willowcreek file 3 has no data.
# Beam 3, box 27 in willowcreek file 3 has no data.
# Beam 3, box 28 in willowcreek file 3 has no data.
# Beam 3, box 30 in willowcreek file 3 has no data.
# Beam 3, box 31 in willowcreek file 3 has no data.
# Beam 3, box 32 in willowcreek file 3 has no data.
# Beam 3, box 33 in willowcreek file 3 has no data.
# Beam 3, box 34 in willowcreek file 3 has no data.
# Beam 3, box 35 in willowcreek file 3 has no data.
# Beam 3, box 36 in willowcreek file 3 has no data.
# Beam 3, box 38 in willowcreek file 3 has no data.
# Beam 3, box 39 in willowcreek file 3 has no data.
# Beam 3, box 40 in willowcreek file 3 has no data.
# Beam 3, box 41 in willowcreek file 3 has no data.
# Beam 3, box 42 in willowcreek file 3 has no data.
# Beam 3, box 43 in willowcreek file 3 has no data.
# Beam 3, box 44 in willowcreek file 3 has no data.
# Beam 3, box 46 in willowcreek file 3 has no data.
# Beam 3, box 47 in willowcreek file 3 has no data.
# Beam 3, box 48 in willowcreek file 3 has no data.
# Beam 3, box 49 in willowcreek file 3 has no data.
# Beam 3, box 50 in willowcreek file 3 has no data.
# Beam 3, box 51 in willowcreek file 3 has no data.
# Beam 3, box 52 in willowcreek file 3 has no data.
# Beam 3, box 54 in willowcreek file 3 has no data.
# Beam 3, box 55 in willowcreek file 3 has no data.
# Beam 3, box 56 in willowcreek file 3 has no data.
# Beam 3, box 57 in willowcreek file 3 has no data.
# Beam 3, box 58 in willowcreek file 3 has no data.
# Beam 3, box 59 in willowcreek file 3 has no data.
# Beam 3, box 60 in willowcreek file 3 has no data.
# Beam 3, box 62 in willowcreek file 3 has no data.
# Beam 3, box 63 in willowcreek file 3 has no data.
# Beam 3, box 64 in willowcreek file 3 has no data.
# Beam 3, box 65 in willowcreek file 3 has no data.
# Beam 3, box 66 in willowcreek file 3 has no data.
# Beam 3, box 67 in willowcreek file 3 has no data.
# Beam 3, box 68 in willowcreek file 3 has no data.
# Beam 3, box 69 in willowcreek file 3 has no data.
# Beam 3, box 70 in willowcreek file 3 has no data.
# Beam 3, box 71 in willowcreek file 3 has no data.
# 37
# 32
# Beam 4, box 0 in willowcreek file 3 has no data.
# Beam 4, box 1 in willowcreek file 3 has no data.
# Beam 4, box 2 in willowcreek file 3 has no data.
# Beam 4, box 3 in willowcreek file 3 has no data.
# Beam 4, box 5 in willowcreek file 3 has no data.
# Beam 4, box 6 in willowcreek file 3 has no data.
# Beam 4, box 7 in willowcreek file 3 has no data.
# Beam 4, box 8 in willowcreek file 3 has no data.
# Beam 4, box 9 in willowcreek file 3 has no data.
# Beam 4, box 10 in willowcreek file 3 has no data.
# Beam 4, box 11 in willowcreek file 3 has no data.
# Beam 4, box 12 in willowcreek file 3 has no data.
# Beam 4, box 13 in willowcreek file 3 has no data.
# Beam 4, box 14 in willowcreek file 3 has no data.
# Beam 4, box 15 in willowcreek file 3 has no data.
# Beam 4, box 16 in willowcreek file 3 has no data.
# Beam 4, box 17 in willowcreek file 3 has no data.
# Beam 4, box 18 in willowcreek file 3 has no data.
# Beam 4, box 19 in willowcreek file 3 has no data.
# Beam 4, box 21 in willowcreek file 3 has no data.
# Beam 4, box 22 in willowcreek file 3 has no data.
# Beam 4, box 23 in willowcreek file 3 has no data.
# Beam 4, box 24 in willowcreek file 3 has no data.
# Beam 4, box 25 in willowcreek file 3 has no data.
# Beam 4, box 26 in willowcreek file 3 has no data.
# Beam 4, box 27 in willowcreek file 3 has no data.
# Beam 4, box 28 in willowcreek file 3 has insufficient data.
# Beam 4, box 29 in willowcreek file 3 has no data.
# Beam 4, box 30 in willowcreek file 3 has no data.
# Beam 4, box 31 in willowcreek file 3 has no data.
# Beam 4, box 32 in willowcreek file 3 has no data.
# Beam 4, box 33 in willowcreek file 3 has no data.
# Beam 4, box 34 in willowcreek file 3 has no data.
# Beam 4, box 35 in willowcreek file 3 has no data.
# Beam 4, box 36 in willowcreek file 3 has no data.
# Beam 4, box 38 in willowcreek file 3 has no data.
# Beam 4, box 39 in willowcreek file 3 has no data.
# Beam 4, box 40 in willowcreek file 3 has no data.
# Beam 4, box 41 in willowcreek file 3 has no data.
# Beam 4, box 42 in willowcreek file 3 has no data.
# Beam 4, box 43 in willowcreek file 3 has no data.
# Beam 4, box 44 in willowcreek file 3 has no data.
# Beam 4, box 46 in willowcreek file 3 has no data.
# Beam 4, box 47 in willowcreek file 3 has no data.
# Beam 4, box 48 in willowcreek file 3 has no data.
# Beam 4, box 49 in willowcreek file 3 has no data.
# Beam 4, box 50 in willowcreek file 3 has no data.
# Beam 4, box 51 in willowcreek file 3 has no data.
# Beam 4, box 52 in willowcreek file 3 has no data.
# Beam 4, box 54 in willowcreek file 3 has no data.
# Beam 4, box 55 in willowcreek file 3 has no data.
# Beam 4, box 56 in willowcreek file 3 has no data.
# Beam 4, box 57 in willowcreek file 3 has no data.
# Beam 4, box 58 in willowcreek file 3 has no data.
# Beam 4, box 59 in willowcreek file 3 has no data.
# Beam 4, box 60 in willowcreek file 3 has no data.
# Beam 4, box 62 in willowcreek file 3 has no data.
# Beam 4, box 63 in willowcreek file 3 has no data.
# Beam 4, box 64 in willowcreek file 3 has no data.
# Beam 4, box 65 in willowcreek file 3 has no data.
# Beam 4, box 66 in willowcreek file 3 has no data.
# Beam 4, box 67 in willowcreek file 3 has no data.
# Beam 4, box 68 in willowcreek file 3 has no data.
# Beam 4, box 69 in willowcreek file 3 has no data.
# Beam 4, box 70 in willowcreek file 3 has no data.
# Beam 4, box 71 in willowcreek file 3 has no data.
# 11
# 11
# Beam 5, box 0 in willowcreek file 3 has no data.
# Beam 5, box 1 in willowcreek file 3 has no data.
# Beam 5, box 2 in willowcreek file 3 has no data.
# Beam 5, box 3 in willowcreek file 3 has no data.
# Beam 5, box 4 in willowcreek file 3 has no data.
# Beam 5, box 5 in willowcreek file 3 has no data.
# Beam 5, box 6 in willowcreek file 3 has no data.
# Beam 5, box 8 in willowcreek file 3 has no data.
# Beam 5, box 9 in willowcreek file 3 has no data.
# Beam 5, box 10 in willowcreek file 3 has no data.
# Beam 5, box 11 in willowcreek file 3 has no data.
# Beam 5, box 12 in willowcreek file 3 has no data.
# Beam 5, box 13 in willowcreek file 3 has no data.
# Beam 5, box 14 in willowcreek file 3 has no data.
# Beam 5, box 15 in willowcreek file 3 has no data.
# Beam 5, box 16 in willowcreek file 3 has no data.
# Beam 5, box 17 in willowcreek file 3 has no data.
# Beam 5, box 18 in willowcreek file 3 has no data.
# Beam 5, box 19 in willowcreek file 3 has no data.
# Beam 5, box 20 in willowcreek file 3 has no data.
# Beam 5, box 21 in willowcreek file 3 has no data.
# Beam 5, box 22 in willowcreek file 3 has no data.
# Beam 5, box 23 in willowcreek file 3 has no data.
# Beam 5, box 24 in willowcreek file 3 has no data.
# Beam 5, box 25 in willowcreek file 3 has no data.
# Beam 5, box 26 in willowcreek file 3 has no data.
# Beam 5, box 27 in willowcreek file 3 has no data.
# Beam 5, box 28 in willowcreek file 3 has no data.
# Beam 5, box 29 in willowcreek file 3 has no data.
# Beam 5, box 30 in willowcreek file 3 has no data.
# Beam 5, box 31 in willowcreek file 3 has no data.
# Beam 5, box 32 in willowcreek file 3 has no data.
# Beam 5, box 33 in willowcreek file 3 has no data.
# Beam 5, box 34 in willowcreek file 3 has no data.
# Beam 5, box 35 in willowcreek file 3 has no data.
# Beam 5, box 36 in willowcreek file 3 has no data.
# Beam 5, box 37 in willowcreek file 3 has no data.
# Beam 5, box 38 in willowcreek file 3 has no data.
# Beam 5, box 39 in willowcreek file 3 has no data.
# Beam 5, box 40 in willowcreek file 3 has no data.
# Beam 5, box 41 in willowcreek file 3 has no data.
# Beam 5, box 42 in willowcreek file 3 has no data.
# Beam 5, box 43 in willowcreek file 3 has no data.
# Beam 5, box 44 in willowcreek file 3 has no data.
# Beam 5, box 45 in willowcreek file 3 has no data.
# Beam 5, box 46 in willowcreek file 3 has no data.
# Beam 5, box 47 in willowcreek file 3 has no data.
# Beam 5, box 48 in willowcreek file 3 has no data.
# Beam 5, box 49 in willowcreek file 3 has no data.
# Beam 5, box 50 in willowcreek file 3 has no data.
# Beam 5, box 51 in willowcreek file 3 has no data.
# Beam 5, box 52 in willowcreek file 3 has no data.
# Beam 5, box 53 in willowcreek file 3 has no data.
# Beam 5, box 54 in willowcreek file 3 has no data.
# Beam 5, box 55 in willowcreek file 3 has no data.
# Beam 5, box 56 in willowcreek file 3 has no data.
# Beam 5, box 57 in willowcreek file 3 has no data.
# Beam 5, box 58 in willowcreek file 3 has no data.
# Beam 5, box 59 in willowcreek file 3 has no data.
# Beam 5, box 60 in willowcreek file 3 has no data.
# Beam 5, box 61 in willowcreek file 3 has no data.
# Beam 5, box 62 in willowcreek file 3 has no data.
# Beam 5, box 63 in willowcreek file 3 has no data.
# Beam 5, box 64 in willowcreek file 3 has no data.
# Beam 5, box 65 in willowcreek file 3 has no data.
# Beam 5, box 66 in willowcreek file 3 has no data.
# Beam 5, box 67 in willowcreek file 3 has no data.
# Beam 5, box 68 in willowcreek file 3 has no data.
# Beam 5, box 69 in willowcreek file 3 has no data.
# Beam 5, box 70 in willowcreek file 3 has no data.
# Beam 5, box 71 in willowcreek file 3 has no data.
# 14
# 13
# Beam 6, box 0 in willowcreek file 3 has no data.
# Beam 6, box 1 in willowcreek file 3 has no data.
# Beam 6, box 2 in willowcreek file 3 has no data.
# Beam 6, box 3 in willowcreek file 3 has no data.
# Beam 6, box 4 in willowcreek file 3 has no data.
# Beam 6, box 5 in willowcreek file 3 has no data.
# Beam 6, box 6 in willowcreek file 3 has no data.
# Beam 6, box 8 in willowcreek file 3 has no data.
# Beam 6, box 9 in willowcreek file 3 has no data.
# Beam 6, box 10 in willowcreek file 3 has no data.
# Beam 6, box 11 in willowcreek file 3 has no data.
# Beam 6, box 12 in willowcreek file 3 has no data.
# Beam 6, box 13 in willowcreek file 3 has no data.
# Beam 6, box 14 in willowcreek file 3 has no data.
# Beam 6, box 15 in willowcreek file 3 has insufficient data.
# Beam 6, box 16 in willowcreek file 3 has no data.
# Beam 6, box 17 in willowcreek file 3 has no data.
# Beam 6, box 18 in willowcreek file 3 has no data.
# Beam 6, box 19 in willowcreek file 3 has no data.
# Beam 6, box 20 in willowcreek file 3 has no data.
# Beam 6, box 21 in willowcreek file 3 has no data.
# Beam 6, box 22 in willowcreek file 3 has no data.
# Beam 6, box 23 in willowcreek file 3 has no data.
# Beam 6, box 24 in willowcreek file 3 has no data.
# Beam 6, box 25 in willowcreek file 3 has no data.
# Beam 6, box 26 in willowcreek file 3 has no data.
# Beam 6, box 27 in willowcreek file 3 has no data.
# Beam 6, box 28 in willowcreek file 3 has no data.
# Beam 6, box 29 in willowcreek file 3 has no data.
# Beam 6, box 30 in willowcreek file 3 has no data.
# Beam 6, box 31 in willowcreek file 3 has no data.
# Beam 6, box 32 in willowcreek file 3 has no data.
# Beam 6, box 33 in willowcreek file 3 has no data.
# Beam 6, box 34 in willowcreek file 3 has no data.
# Beam 6, box 35 in willowcreek file 3 has no data.
# Beam 6, box 36 in willowcreek file 3 has no data.
# Beam 6, box 37 in willowcreek file 3 has no data.
# Beam 6, box 38 in willowcreek file 3 has no data.
# Beam 6, box 39 in willowcreek file 3 has no data.
# Beam 6, box 40 in willowcreek file 3 has no data.
# Beam 6, box 41 in willowcreek file 3 has no data.
# Beam 6, box 42 in willowcreek file 3 has no data.
# Beam 6, box 43 in willowcreek file 3 has no data.
# Beam 6, box 44 in willowcreek file 3 has no data.
# Beam 6, box 45 in willowcreek file 3 has no data.
# Beam 6, box 46 in willowcreek file 3 has no data.
# Beam 6, box 47 in willowcreek file 3 has no data.
# Beam 6, box 48 in willowcreek file 3 has no data.
# Beam 6, box 49 in willowcreek file 3 has no data.
# Beam 6, box 50 in willowcreek file 3 has no data.
# Beam 6, box 51 in willowcreek file 3 has no data.
# Beam 6, box 52 in willowcreek file 3 has no data.
# Beam 6, box 53 in willowcreek file 3 has no data.
# Beam 6, box 54 in willowcreek file 3 has no data.
# Beam 6, box 55 in willowcreek file 3 has no data.
# Beam 6, box 56 in willowcreek file 3 has no data.
# Beam 6, box 57 in willowcreek file 3 has no data.
# Beam 6, box 58 in willowcreek file 3 has no data.
# Beam 6, box 59 in willowcreek file 3 has no data.
# Beam 6, box 60 in willowcreek file 3 has no data.
# Beam 6, box 61 in willowcreek file 3 has no data.
# Beam 6, box 62 in willowcreek file 3 has no data.
# Beam 6, box 63 in willowcreek file 3 has no data.
# Beam 6, box 64 in willowcreek file 3 has no data.
# Beam 6, box 65 in willowcreek file 3 has no data.
# Beam 6, box 66 in willowcreek file 3 has no data.
# Beam 6, box 67 in willowcreek file 3 has no data.
# Beam 6, box 68 in willowcreek file 3 has no data.
# Beam 6, box 69 in willowcreek file 3 has no data.
# Beam 6, box 70 in willowcreek file 3 has no data.
# Beam 6, box 71 in willowcreek file 3 has no data.

# %%
from scripts.parallel_blocks import *

dirpath = '../scratch/data/willowcreek/'

all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
N = len(all_ATL03)
print(N-1)

coords = (-90.0791, 45.8060)

for i in [17]:#range(N):
    data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=coords, width=4,height=4,file_index=i, alt_thresh=80,\
                         altitude=521, threshold=3, small_box=1, graph_detail=1, loss='linear', rebinned=30, f_scale=.05,\
                         outlier_removal=0.22,method='normal', landcover='forest', trim_atmospheric=True, sat_flag=True,\
                         show_me_the_good_ones=True)
    # print(data)
# Out:
# 20
# Beam 1, box 0 in willowcreek file 17 has no data.
# Beam 1, box 1 in willowcreek file 17 has no data.
# Beam 1, box 2 in willowcreek file 17 has no data.
# Beam 1, box 3 in willowcreek file 17 has no data.
# Beam 1, box 5 in willowcreek file 17 has no data.
# Beam 1, box 6 in willowcreek file 17 has no data.
# Beam 1, box 7 in willowcreek file 17 has no data.
# Beam 1, box 8 in willowcreek file 17 has no data.
# Beam 1, box 9 in willowcreek file 17 has no data.
# Beam 1, box 10 in willowcreek file 17 has no data.
# Beam 1, box 11 in willowcreek file 17 has no data.
# Beam 1, box 13 in willowcreek file 17 has no data.
# Beam 1, box 14 in willowcreek file 17 has no data.
# Beam 1, box 15 in willowcreek file 17 has no data.
# Beam 1, box 16 in willowcreek file 17 has no data.
# Beam 1, box 17 in willowcreek file 17 has no data.
# Beam 1, box 18 in willowcreek file 17 has no data.
# Beam 1, box 21 in willowcreek file 17 has no data.
# Beam 1, box 22 in willowcreek file 17 has no data.
# Beam 1, box 23 in willowcreek file 17 has no data.
# Beam 1, box 24 in willowcreek file 17 has no data.
# Beam 1, box 25 in willowcreek file 17 has no data.
# Beam 1, box 26 in willowcreek file 17 has no data.
# Beam 1, box 28 in willowcreek file 17 has no data.
# Beam 1, box 29 in willowcreek file 17 has no data.
# Beam 1, box 30 in willowcreek file 17 has no data.
# Beam 1, box 31 in willowcreek file 17 has no data.
# Beam 1, box 32 in willowcreek file 17 has no data.
# Beam 1, box 33 in willowcreek file 17 has no data.
# Beam 1, box 34 in willowcreek file 17 has no data.
# Beam 1, box 36 in willowcreek file 17 has no data.
# Beam 1, box 37 in willowcreek file 17 has no data.
# Beam 1, box 38 in willowcreek file 17 has no data.
# Beam 1, box 39 in willowcreek file 17 has no data.
# Beam 1, box 40 in willowcreek file 17 has no data.
# Beam 1, box 41 in willowcreek file 17 has no data.
# Beam 1, box 42 in willowcreek file 17 has no data.
# Beam 1, box 44 in willowcreek file 17 has no data.
# Beam 1, box 45 in willowcreek file 17 has no data.
# Beam 1, box 46 in willowcreek file 17 has no data.
# Beam 1, box 47 in willowcreek file 17 has no data.
# Beam 1, box 48 in willowcreek file 17 has no data.
# Beam 1, box 49 in willowcreek file 17 has no data.
# Beam 1, box 50 in willowcreek file 17 has no data.
# Beam 1, box 52 in willowcreek file 17 has no data.
# Beam 1, box 53 in willowcreek file 17 has no data.
# Beam 1, box 54 in willowcreek file 17 has no data.
# Beam 1, box 55 in willowcreek file 17 has no data.
# Beam 1, box 56 in willowcreek file 17 has no data.
# Beam 1, box 57 in willowcreek file 17 has no data.
# Beam 1, box 58 in willowcreek file 17 has no data.
# Beam 1, box 60 in willowcreek file 17 has no data.
# Beam 1, box 61 in willowcreek file 17 has no data.
# Beam 1, box 62 in willowcreek file 17 has no data.
# Beam 1, box 63 in willowcreek file 17 has no data.
# Beam 1, box 64 in willowcreek file 17 has no data.
# Beam 1, box 65 in willowcreek file 17 has no data.
# Beam 1, box 66 in willowcreek file 17 has no data.
# Beam 1, box 67 in willowcreek file 17 has no data.
# Beam 1, box 68 in willowcreek file 17 has no data.
# Beam 1, box 69 in willowcreek file 17 has no data.
# Beam 1, box 70 in willowcreek file 17 has no data.
# Beam 1, box 71 in willowcreek file 17 has no data.
# Beam 2, box 0 in willowcreek file 17 has no data.
# Beam 2, box 1 in willowcreek file 17 has no data.
# Beam 2, box 2 in willowcreek file 17 has no data.
# Beam 2, box 3 in willowcreek file 17 has no data.
# Beam 2, box 5 in willowcreek file 17 has no data.
# Beam 2, box 6 in willowcreek file 17 has no data.
# Beam 2, box 7 in willowcreek file 17 has no data.
# Beam 2, box 8 in willowcreek file 17 has no data.
# Beam 2, box 9 in willowcreek file 17 has no data.
# Beam 2, box 10 in willowcreek file 17 has no data.
# Beam 2, box 13 in willowcreek file 17 has no data.
# Beam 2, box 14 in willowcreek file 17 has no data.
# Beam 2, box 15 in willowcreek file 17 has no data.
# Beam 2, box 16 in willowcreek file 17 has no data.
# Beam 2, box 17 in willowcreek file 17 has no data.
# Beam 2, box 18 in willowcreek file 17 has no data.
# Beam 2, box 20 in willowcreek file 17 has no data.
# Beam 2, box 21 in willowcreek file 17 has no data.
# Beam 2, box 22 in willowcreek file 17 has no data.
# Beam 2, box 23 in willowcreek file 17 has no data.
# Beam 2, box 24 in willowcreek file 17 has no data.
# Beam 2, box 25 in willowcreek file 17 has no data.
# Beam 2, box 26 in willowcreek file 17 has no data.
# Beam 2, box 28 in willowcreek file 17 has no data.
# Beam 2, box 29 in willowcreek file 17 has no data.
# Beam 2, box 30 in willowcreek file 17 has no data.
# Beam 2, box 31 in willowcreek file 17 has no data.
# Beam 2, box 32 in willowcreek file 17 has no data.
# Beam 2, box 33 in willowcreek file 17 has no data.
# Beam 2, box 34 in willowcreek file 17 has no data.
# Beam 2, box 36 in willowcreek file 17 has no data.
# Beam 2, box 37 in willowcreek file 17 has no data.
# Beam 2, box 38 in willowcreek file 17 has no data.
# Beam 2, box 39 in willowcreek file 17 has no data.
# Beam 2, box 40 in willowcreek file 17 has no data.
# Beam 2, box 41 in willowcreek file 17 has no data.
# Beam 2, box 42 in willowcreek file 17 has no data.
# Beam 2, box 44 in willowcreek file 17 has no data.
# Beam 2, box 45 in willowcreek file 17 has no data.
# Beam 2, box 46 in willowcreek file 17 has no data.
# Beam 2, box 47 in willowcreek file 17 has no data.
# Beam 2, box 48 in willowcreek file 17 has no data.
# Beam 2, box 49 in willowcreek file 17 has no data.
# Beam 2, box 50 in willowcreek file 17 has no data.
# Beam 2, box 52 in willowcreek file 17 has no data.
# Beam 2, box 53 in willowcreek file 17 has no data.
# Beam 2, box 54 in willowcreek file 17 has no data.
# Beam 2, box 55 in willowcreek file 17 has no data.
# Beam 2, box 56 in willowcreek file 17 has no data.
# Beam 2, box 57 in willowcreek file 17 has no data.
# Beam 2, box 58 in willowcreek file 17 has no data.
# Beam 2, box 60 in willowcreek file 17 has no data.
# Beam 2, box 61 in willowcreek file 17 has no data.
# Beam 2, box 62 in willowcreek file 17 has no data.
# Beam 2, box 63 in willowcreek file 17 has no data.
# Beam 2, box 64 in willowcreek file 17 has no data.
# Beam 2, box 65 in willowcreek file 17 has no data.
# Beam 2, box 66 in willowcreek file 17 has no data.
# Beam 2, box 67 in willowcreek file 17 has no data.
# Beam 2, box 68 in willowcreek file 17 has no data.
# Beam 2, box 69 in willowcreek file 17 has no data.
# Beam 2, box 70 in willowcreek file 17 has no data.
# Beam 2, box 71 in willowcreek file 17 has no data.
# Beam 3, box 0 in willowcreek file 17 has no data.
# Beam 3, box 1 in willowcreek file 17 has no data.
# Beam 3, box 2 in willowcreek file 17 has no data.
# Beam 3, box 3 in willowcreek file 17 has no data.
# Beam 3, box 4 in willowcreek file 17 has no data.
# Beam 3, box 5 in willowcreek file 17 has no data.
# Beam 3, box 6 in willowcreek file 17 has no data.
# Beam 3, box 8 in willowcreek file 17 has no data.
# Beam 3, box 9 in willowcreek file 17 has no data.
# Beam 3, box 10 in willowcreek file 17 has no data.
# Beam 3, box 11 in willowcreek file 17 has no data.
# Beam 3, box 12 in willowcreek file 17 has no data.
# Beam 3, box 13 in willowcreek file 17 has no data.
# Beam 3, box 14 in willowcreek file 17 has no data.
# Beam 3, box 16 in willowcreek file 17 has no data.
# Beam 3, box 17 in willowcreek file 17 has no data.
# Beam 3, box 18 in willowcreek file 17 has no data.
# Beam 3, box 19 in willowcreek file 17 has no data.
# Beam 3, box 20 in willowcreek file 17 has no data.
# Beam 3, box 21 in willowcreek file 17 has no data.
# Beam 3, box 22 in willowcreek file 17 has no data.
# Beam 3, box 24 in willowcreek file 17 has no data.
# Beam 3, box 25 in willowcreek file 17 has no data.
# Beam 3, box 26 in willowcreek file 17 has no data.
# Beam 3, box 27 in willowcreek file 17 has no data.
# Beam 3, box 28 in willowcreek file 17 has no data.
# Beam 3, box 29 in willowcreek file 17 has no data.
# Beam 3, box 30 in willowcreek file 17 has no data.
# Beam 3, box 32 in willowcreek file 17 has no data.
# Beam 3, box 33 in willowcreek file 17 has no data.
# Beam 3, box 34 in willowcreek file 17 has no data.
# Beam 3, box 35 in willowcreek file 17 has no data.
# Beam 3, box 36 in willowcreek file 17 has no data.
# Beam 3, box 37 in willowcreek file 17 has no data.
# Beam 3, box 40 in willowcreek file 17 has no data.
# Beam 3, box 41 in willowcreek file 17 has no data.
# Beam 3, box 42 in willowcreek file 17 has no data.
# Beam 3, box 43 in willowcreek file 17 has no data.
# Beam 3, box 44 in willowcreek file 17 has no data.
# Beam 3, box 45 in willowcreek file 17 has no data.
# Beam 3, box 47 in willowcreek file 17 has no data.
# Beam 3, box 48 in willowcreek file 17 has no data.
# Beam 3, box 49 in willowcreek file 17 has no data.
# Beam 3, box 50 in willowcreek file 17 has no data.
# Beam 3, box 51 in willowcreek file 17 has no data.
# Beam 3, box 52 in willowcreek file 17 has no data.
# Beam 3, box 53 in willowcreek file 17 has no data.
# Beam 3, box 55 in willowcreek file 17 has no data.
# Beam 3, box 56 in willowcreek file 17 has no data.
# Beam 3, box 57 in willowcreek file 17 has no data.
# Beam 3, box 58 in willowcreek file 17 has no data.
# Beam 3, box 59 in willowcreek file 17 has no data.
# Beam 3, box 60 in willowcreek file 17 has no data.
# Beam 3, box 61 in willowcreek file 17 has no data.
# Beam 3, box 63 in willowcreek file 17 has no data.
# Beam 3, box 64 in willowcreek file 17 has no data.
# Beam 3, box 65 in willowcreek file 17 has no data.
# Beam 3, box 66 in willowcreek file 17 has no data.
# Beam 3, box 67 in willowcreek file 17 has no data.
# Beam 3, box 68 in willowcreek file 17 has no data.
# Beam 3, box 69 in willowcreek file 17 has no data.
# Beam 3, box 70 in willowcreek file 17 has no data.
# Beam 3, box 71 in willowcreek file 17 has no data.
# Beam 4, box 0 in willowcreek file 17 has no data.
# Beam 4, box 1 in willowcreek file 17 has no data.
# Beam 4, box 2 in willowcreek file 17 has no data.
# Beam 4, box 3 in willowcreek file 17 has no data.
# Beam 4, box 4 in willowcreek file 17 has no data.
# Beam 4, box 5 in willowcreek file 17 has no data.
# Beam 4, box 6 in willowcreek file 17 has no data.
# Beam 4, box 8 in willowcreek file 17 has no data.
# Beam 4, box 9 in willowcreek file 17 has no data.
# Beam 4, box 10 in willowcreek file 17 has no data.
# Beam 4, box 11 in willowcreek file 17 has no data.
# Beam 4, box 12 in willowcreek file 17 has no data.
# Beam 4, box 13 in willowcreek file 17 has no data.
# Beam 4, box 14 in willowcreek file 17 has no data.
# Beam 4, box 16 in willowcreek file 17 has no data.
# Beam 4, box 17 in willowcreek file 17 has no data.
# Beam 4, box 18 in willowcreek file 17 has no data.
# Beam 4, box 19 in willowcreek file 17 has no data.
# Beam 4, box 20 in willowcreek file 17 has no data.
# Beam 4, box 21 in willowcreek file 17 has no data.
# Beam 4, box 22 in willowcreek file 17 has no data.
# Beam 4, box 24 in willowcreek file 17 has no data.
# Beam 4, box 25 in willowcreek file 17 has no data.
# Beam 4, box 26 in willowcreek file 17 has no data.
# Beam 4, box 27 in willowcreek file 17 has no data.
# Beam 4, box 28 in willowcreek file 17 has no data.
# Beam 4, box 29 in willowcreek file 17 has no data.
# Beam 4, box 32 in willowcreek file 17 has no data.
# Beam 4, box 33 in willowcreek file 17 has no data.
# Beam 4, box 34 in willowcreek file 17 has no data.
# Beam 4, box 35 in willowcreek file 17 has no data.
# Beam 4, box 36 in willowcreek file 17 has no data.
# Beam 4, box 37 in willowcreek file 17 has no data.
# Beam 4, box 39 in willowcreek file 17 has no data.
# Beam 4, box 40 in willowcreek file 17 has no data.
# Beam 4, box 41 in willowcreek file 17 has no data.
# Beam 4, box 42 in willowcreek file 17 has no data.
# Beam 4, box 43 in willowcreek file 17 has no data.
# Beam 4, box 44 in willowcreek file 17 has no data.
# Beam 4, box 45 in willowcreek file 17 has no data.
# Beam 4, box 47 in willowcreek file 17 has no data.
# Beam 4, box 48 in willowcreek file 17 has no data.
# Beam 4, box 49 in willowcreek file 17 has no data.
# Beam 4, box 50 in willowcreek file 17 has no data.
# Beam 4, box 51 in willowcreek file 17 has no data.
# Beam 4, box 52 in willowcreek file 17 has no data.
# Beam 4, box 53 in willowcreek file 17 has no data.
# Beam 4, box 55 in willowcreek file 17 has no data.
# Beam 4, box 56 in willowcreek file 17 has no data.
# Beam 4, box 57 in willowcreek file 17 has no data.
# Beam 4, box 58 in willowcreek file 17 has no data.
# Beam 4, box 59 in willowcreek file 17 has no data.
# Beam 4, box 60 in willowcreek file 17 has no data.
# Beam 4, box 61 in willowcreek file 17 has no data.
# Beam 4, box 63 in willowcreek file 17 has no data.
# Beam 4, box 64 in willowcreek file 17 has no data.
# Beam 4, box 65 in willowcreek file 17 has no data.
# Beam 4, box 66 in willowcreek file 17 has no data.
# Beam 4, box 67 in willowcreek file 17 has no data.
# Beam 4, box 68 in willowcreek file 17 has no data.
# Beam 4, box 69 in willowcreek file 17 has no data.
# Beam 4, box 70 in willowcreek file 17 has no data.
# Beam 4, box 71 in willowcreek file 17 has no data.
# Nothing in rebinned section for willowcreek file 17's beam 5.
# Nothing in rebinned section for willowcreek file 17's beam 6.
