# %%
from scripts.imports import *

import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)


# ===========================================================
# LOAD AND GROUP DATA
# ===========================================================

df = pd.read_pickle(
    'dataset_lcforest_noLOF_bin15_th3_80m_1kmsmallbox_noprior_ta_wc1_v7.pkl'
)

df['Eg_strong'] = np.where(
    (df['beam_str'] == 'strong') & (df['outlier'] == 1),
    df['Eg'],
    np.nan
)
df['Ev_strong'] = np.where(
    (df['beam_str'] == 'strong') & (df['outlier'] == 1),
    df['Ev'],
    np.nan
)
df['Eg_weak'] = np.where(
    (df['beam_str'] == 'weak') & (df['outlier'] == 1),
    df['Eg'],
    np.nan
)
df['Ev_weak'] = np.where(
    (df['beam_str'] == 'weak') & (df['outlier'] == 1),
    df['Ev'],
    np.nan
)

df['forest_type'] = np.where(df['segment_landcover'] < 119, 'closed', 'open')

df_grouped = df.groupby(['camera', 'date', 'lat', 'lon']).agg({
    'pvpg': 'mean',
    'pv': 'max',
    'pg': 'max',
    'Eg_strong': 'median',
    'Ev_strong': 'median',
    'Eg_weak': 'median',
    'Ev_weak': 'median',
    'data_quantity': 'max',
    'snr': 'mean',
    'FSC': 'mean',
    'TreeSnow': 'mean',
    'layer_flag': 'mean',
    'file_index': 'mean',
    'msw_flag': 'mean',
    'pv_ratio_mean': 'mean',
    'pv_ratio_max': 'mean',
    'forest_type': lambda x: pd.Series.mode(x).iloc[0],
}).reset_index()

df_grouped = df_grouped[df_grouped['Eg_strong'] >= 0].copy()
df_grouped['JointSnow'] = df_grouped['FSC'] + df_grouped['TreeSnow']


# ===========================================================
# CONFIG
# ===========================================================

N_BOOT = 1000
N_SPLITS_CV = 5
TOL_NEAR = 0.003
RNG = np.random.RandomState(42)

FEATURES = ['Eg_strong', 'Ev_strong']
TARGET_COL = 'JointSnowRounded'

RATIO_GRID = np.round(np.arange(1.05, 1.30 + 1e-9, 0.01), 2)
DQ_GRID = np.arange(12, 36)

CLASS_LABELS = [0, 1, 2]
CLASS_NAMES = [
    "No Snow",
    "Ground Snow",
    "Ground + Canopy Snow"
]


# ===========================================================
# FILTERING AND MULTINOMIAL DATASET HELPERS
# ===========================================================

def base_conditions_multinomial(df):
    """
    Base conditions for the multinomial regression.

    This uses only binary endpoint observations:
        FSC approximately 0 or 1
        TreeSnow exactly 0 or 1

    JointSnow = FSC + TreeSnow gives classes:
        0 = no snow
        1 = ground snow
        2 = ground + canopy snow
    """

    return (
        ((df['FSC'] <= 0.005) | (df['FSC'] >= 0.995)) &
        ((df['TreeSnow'] == 0) | (df['TreeSnow'] == 1)) &
        np.isfinite(df['Eg_strong']) &
        np.isfinite(df['Ev_strong']) &
        np.isfinite(df['Eg_weak']) &
        (df['Eg_weak'] > 0) &
        np.isfinite(df['data_quantity'])
    )


def apply_thresholds_for_multinomial(df, ratio_thresh, dq_thresh):
    """
    Applies base multinomial conditions plus the threshold pair being tested.
    """

    cond = (
        base_conditions_multinomial(df) &
        ((df['Eg_strong'] / df['Eg_weak']) >= ratio_thresh) &
        (df['data_quantity'] >= dq_thresh)
    )

    out = df.loc[cond].copy()

    out['JointSnow'] = out['FSC'] + out['TreeSnow']
    out['JointSnowRounded'] = np.round(out['JointSnow']).astype(int)

    out = out[out['JointSnowRounded'].isin(CLASS_LABELS)].copy()

    return out


# ===========================================================
# CV HELPERS FOR THRESHOLD SEARCH
# ===========================================================

def assign_folds_by_camera(df, n_splits=5):
    """
    Round-robin assignment by camera frequency.
    Returns fold indices aligned with df rows.
    """

    counts = df['camera'].value_counts()
    cams_sorted = counts.index.tolist()
    cam2fold = {
        cam: i % n_splits
        for i, cam in enumerate(cams_sorted)
    }

    return df['camera'].map(cam2fold).to_numpy()


def cv_multinomial_metrics(df, features=FEATURES, n_splits=N_SPLITS_CV):
    """
    Camera-grouped CV for the 3-class multinomial target.

    Returns:
        multiclass accuracy
        3x3 confusion matrix
        binary accuracy with classes {1,2} collapsed to 1
    """

    if len(df) == 0:
        return np.nan, None, np.nan

    if df[TARGET_COL].nunique() < 2:
        return np.nan, None, np.nan

    n_unique_cams = df['camera'].nunique()

    if n_unique_cams < 2:
        return np.nan, None, np.nan

    n_splits_eff = max(2, min(n_splits, n_unique_cams))

    grp = assign_folds_by_camera(df, n_splits_eff)

    X = df.loc[:, list(features)].to_numpy()
    y = df[TARGET_COL].to_numpy()

    valid = np.isfinite(X).all(axis=1) & np.isfinite(y)

    X = X[valid]
    y = y[valid]
    grp = grp[valid]

    if len(y) == 0:
        return np.nan, None, np.nan

    if np.unique(y).size < 2:
        return np.nan, None, np.nan

    all_true = []
    all_pred = []

    for f in range(n_splits_eff):

        test_mask = grp == f
        train_mask = ~test_mask

        if not np.any(test_mask) or not np.any(train_mask):
            continue

        X_train = X[train_mask]
        y_train = y[train_mask]
        X_test = X[test_mask]
        y_test = y[test_mask]

        if np.unique(y_train).size < 2:
            continue

        model = LogisticRegression(
            solver='lbfgs',
            max_iter=1000,
            random_state=0
        )

        model.fit(X_train, y_train)

        y_hat = model.predict(X_test)

        all_true.extend(y_test.tolist())
        all_pred.extend(y_hat.tolist())

    if len(all_true) == 0:
        return np.nan, None, np.nan

    all_true = np.asarray(all_true)
    all_pred = np.asarray(all_pred)

    acc = accuracy_score(all_true, all_pred)

    cm = confusion_matrix(
        all_true,
        all_pred,
        labels=CLASS_LABELS
    )

    y_true_bin = (all_true >= 1).astype(int)
    y_pred_bin = (all_pred >= 1).astype(int)

    bin_acc = accuracy_score(y_true_bin, y_pred_bin)

    return acc, cm, bin_acc


def grid_search_thresholds(dedup_train, ratio_grid, dq_grid):
    """
    Searches over Eg_strong/Eg_weak and data_quantity thresholds.

    This is done on the deduplicated bootstrap training cameras,
    as in your original code.
    """

    rows = []

    for ratio_thresh in ratio_grid:

        for dq_thresh in dq_grid:

            df_f = apply_thresholds_for_multinomial(
                dedup_train,
                ratio_thresh,
                dq_thresh
            )

            acc, cm, bin_acc = cv_multinomial_metrics(df_f)

            rows.append({
                'ratio': float(ratio_thresh),
                'dq': int(dq_thresh),
                'accuracy': acc,
                'bin_acc': bin_acc,
                'n_rows': int(len(df_f)),
                'conf_mat': cm
            })

    res = pd.DataFrame(rows)
    res = res.dropna(subset=['accuracy']).reset_index(drop=True)

    return res


def choose_best_thresholds(res, tol=TOL_NEAR):
    """
    Choose among threshold combinations within tol of the best CV accuracy.

    Priority:
        1. largest retained n_rows
        2. higher accuracy
        3. smaller ratio threshold
        4. smaller data_quantity threshold
    """

    if res.empty:
        return None, pd.DataFrame(columns=res.columns)

    best = res['accuracy'].max()

    near = res[res['accuracy'] >= best - tol].copy()

    near = near.sort_values(
        ['n_rows', 'accuracy', 'ratio', 'dq'],
        ascending=[False, False, True, True]
    ).reset_index(drop=True)

    return near.iloc[0].to_dict(), near


# ===========================================================
# FINAL MULTINOMIAL MODEL HELPERS
# ===========================================================

def fit_multinomial_model(train_df):
    """
    Fits final multinomial logistic regression after chosen thresholds.
    """

    X_train = train_df[FEATURES].to_numpy()
    y_train = train_df[TARGET_COL].to_numpy()

    model = LogisticRegression(
        solver='lbfgs',
        max_iter=1000,
        random_state=0
    )

    model.fit(X_train, y_train)

    return model


def predict_multinomial(model, test_df):
    X_test = test_df[FEATURES].to_numpy()
    return model.predict(X_test)


def binary_accuracy_from_multiclass(y_true, y_pred):
    """
    Collapses classes {1, 2} into snow-present and compares against class 0.
    """

    y_true_bin = (np.asarray(y_true) >= 1).astype(int)
    y_pred_bin = (np.asarray(y_pred) >= 1).astype(int)

    return accuracy_score(y_true_bin, y_pred_bin)


# ===========================================================
# BOOTSTRAP LOOP
# ===========================================================

all_cameras = sorted(df_grouped['camera'].unique())

print(f"Number of cameras: {len(all_cameras)}")
print(f"Cameras: {all_cameras}")

bootstrap_rows = []

all_oob_y_true = []
all_oob_y_pred = []

cumulative_cv_conf_mat = np.zeros((3, 3), dtype=int)
cumulative_oob_conf_mat = np.zeros((3, 3), dtype=int)

for b in range(N_BOOT):

    start = time.time()

    sampled_cams = RNG.choice(
        all_cameras,
        size=len(all_cameras),
        replace=True
    )

    sampled_unique = sorted(set(sampled_cams))
    oob_cams = sorted(set(all_cameras) - set(sampled_unique))

    # Duplicated bootstrap training set:
    # if a camera is drawn multiple times, its rows are included multiple times.
    boot_concat = pd.concat(
        [
            df_grouped[df_grouped['camera'] == cam]
            for cam in sampled_cams
        ],
        ignore_index=True
    )

    # Deduplicated training set for threshold search
    dedup_train = df_grouped[
        df_grouped['camera'].isin(sampled_unique)
    ].copy()

    print(f"\n=== Bootstrap {b + 1}/{N_BOOT} ===")

    # -------------------------------------------------------
    # 1. Search thresholds on deduplicated bootstrap train set
    # -------------------------------------------------------

    res = grid_search_thresholds(
        dedup_train,
        RATIO_GRID,
        DQ_GRID
    )

    chosen, near = choose_best_thresholds(
        res,
        tol=TOL_NEAR
    )

    if chosen is None:

        print("No valid threshold combination produced a trainable dataset.")

        bootstrap_rows.append({
            'bootstrap': b + 1,
            'ratio': np.nan,
            'dq': np.nan,
            'n_rows_search': 0,
            'n_rows_boot_train': 0,
            'n_rows_oob': 0,
            'n_oob_cameras': len(oob_cams),
            'cv_acc': np.nan,
            'cv_bin_acc': np.nan,
            'oob_acc': np.nan,
            'oob_bin_acc': np.nan
        })

        continue

    print(
        f"Chosen filter -> "
        f"Eg_strong/Eg_weak >= {chosen['ratio']:.2f}, "
        f"data_quantity >= {int(chosen['dq'])} | "
        f"CV acc={chosen['accuracy']:.4f}, "
        f"CV bin acc={chosen['bin_acc']:.4f}, "
        f"n_rows(dedup)={int(chosen['n_rows'])}"
    )

    if isinstance(chosen.get('conf_mat', None), np.ndarray):
        cumulative_cv_conf_mat += chosen['conf_mat'].astype(int)

    # -------------------------------------------------------
    # 2. Apply chosen thresholds to duplicated bootstrap train
    # -------------------------------------------------------

    boot_train = apply_thresholds_for_multinomial(
        boot_concat,
        chosen['ratio'],
        int(chosen['dq'])
    )

    # -------------------------------------------------------
    # 3. Apply chosen thresholds to OOB cameras
    # -------------------------------------------------------

    oob_df = df_grouped[
        df_grouped['camera'].isin(oob_cams)
    ].copy()

    oob_df = apply_thresholds_for_multinomial(
        oob_df,
        chosen['ratio'],
        int(chosen['dq'])
    )

    if len(boot_train) == 0:

        print("Bootstrapped training set empty after chosen thresholds; skipping.")

        bootstrap_rows.append({
            'bootstrap': b + 1,
            'ratio': float(chosen['ratio']),
            'dq': int(chosen['dq']),
            'n_rows_search': int(chosen['n_rows']),
            'n_rows_boot_train': 0,
            'n_rows_oob': len(oob_df),
            'n_oob_cameras': len(oob_cams),
            'cv_acc': float(chosen['accuracy']),
            'cv_bin_acc': float(chosen['bin_acc']),
            'oob_acc': np.nan,
            'oob_bin_acc': np.nan
        })

        continue

    if boot_train[TARGET_COL].nunique() < 2:

        print("Bootstrapped training set has fewer than 2 classes; skipping.")

        bootstrap_rows.append({
            'bootstrap': b + 1,
            'ratio': float(chosen['ratio']),
            'dq': int(chosen['dq']),
            'n_rows_search': int(chosen['n_rows']),
            'n_rows_boot_train': len(boot_train),
            'n_rows_oob': len(oob_df),
            'n_oob_cameras': len(oob_cams),
            'cv_acc': float(chosen['accuracy']),
            'cv_bin_acc': float(chosen['bin_acc']),
            'oob_acc': np.nan,
            'oob_bin_acc': np.nan
        })

        continue

    if len(oob_df) == 0:

        print("No OOB rows after chosen thresholds.")

        bootstrap_rows.append({
            'bootstrap': b + 1,
            'ratio': float(chosen['ratio']),
            'dq': int(chosen['dq']),
            'n_rows_search': int(chosen['n_rows']),
            'n_rows_boot_train': len(boot_train),
            'n_rows_oob': 0,
            'n_oob_cameras': len(oob_cams),
            'cv_acc': float(chosen['accuracy']),
            'cv_bin_acc': float(chosen['bin_acc']),
            'oob_acc': np.nan,
            'oob_bin_acc': np.nan
        })

        continue

    # -------------------------------------------------------
    # 4. Fit multinomial regression and predict OOB cameras
    # -------------------------------------------------------

    model = fit_multinomial_model(boot_train)

    y_true = oob_df[TARGET_COL].to_numpy()
    y_pred = predict_multinomial(model, oob_df)

    oob_acc = accuracy_score(y_true, y_pred)
    oob_bin_acc = binary_accuracy_from_multiclass(y_true, y_pred)

    oob_cm = confusion_matrix(
        y_true,
        y_pred,
        labels=CLASS_LABELS
    )

    cumulative_oob_conf_mat += oob_cm

    all_oob_y_true.append(y_true.copy())
    all_oob_y_pred.append(y_pred.copy())

    print(f"OOB cameras: {oob_cams if len(oob_cams) else 'none'}")
    print(f"OOB n={len(oob_df)}")
    print(f"OOB multiclass accuracy={oob_acc:.4f}")
    print(f"OOB binary accuracy 0 vs {{1,2}}={oob_bin_acc:.4f}")

    bootstrap_rows.append({
        'bootstrap': b + 1,
        'ratio': float(chosen['ratio']),
        'dq': int(chosen['dq']),
        'n_rows_search': int(chosen['n_rows']),
        'n_rows_boot_train': int(len(boot_train)),
        'n_rows_oob': int(len(oob_df)),
        'n_oob_cameras': int(len(oob_cams)),
        'cv_acc': float(chosen['accuracy']),
        'cv_bin_acc': float(chosen['bin_acc']),
        'oob_acc': float(oob_acc),
        'oob_bin_acc': float(oob_bin_acc)
    })

    end = time.time()
    print(f"{round(end - start, 2)}s")


# ===========================================================
# SUMMARY TABLES
# ===========================================================

bootstrap_df = pd.DataFrame(bootstrap_rows)

print("\n====================")
print("BOOTSTRAP SUMMARY")
print("====================")

def mean_std(series):
    return f"{np.nanmean(series):.4f} � {np.nanstd(series):.4f}"


print("\nFilter choice frequency across bootstraps:")

freq = (
    bootstrap_df
    .dropna(subset=['ratio', 'dq'])
    .value_counts(subset=['ratio', 'dq'])
    .reset_index(name='count')
    .sort_values('count', ascending=False)
)

print(freq.to_string(index=False))


print("\nCV metrics from chosen thresholds:")
print("Multiclass accuracy: ", mean_std(bootstrap_df['cv_acc']))
print("Binary accuracy:     ", mean_std(bootstrap_df['cv_bin_acc']))


print("\nOOB metrics after final multinomial regression:")
print("Multiclass accuracy: ", mean_std(bootstrap_df['oob_acc']))
print("Binary accuracy:     ", mean_std(bootstrap_df['oob_bin_acc']))


print("\nOOB row/camera counts:")
print("Mean OOB rows:       ", f"{np.nanmean(bootstrap_df['n_rows_oob']):.1f}")
print("Mean OOB cameras:    ", f"{np.nanmean(bootstrap_df['n_oob_cameras']):.1f}")


print("\nBootstrap results:")
print(bootstrap_df.to_string(index=False))


# ===========================================================
# PLOT HELPER
# ===========================================================

def plot_confusion_matrix(cm_counts, title):
    """
    Plots row-normalized confusion matrix with counts and percentages.
    """

    cm = cm_counts.astype(float)

    row_sums = cm.sum(axis=1, keepdims=True)

    pct = np.divide(
        cm,
        row_sums,
        out=np.zeros_like(cm),
        where=row_sums != 0
    ) * 100.0

    fig, ax = plt.subplots(figsize=(7.5, 6))

    im = ax.imshow(
        pct,
        cmap="Blues",
        vmin=0,
        vmax=100
    )

    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):

            count = int(cm[i, j])
            perc = pct[i, j]

            ax.text(
                j,
                i,
                f"{count}\n({perc:.1f}%)",
                ha="center",
                va="center",
                fontsize=12,
                color="white" if perc > 50 else "black",
                fontweight="bold" if perc > 50 else "normal"
            )

    ax.set_xticks(np.arange(3))
    ax.set_yticks(np.arange(3))

    ax.set_xticklabels(
        CLASS_NAMES,
        rotation=20,
        ha="right"
    )

    ax.set_yticklabels(CLASS_NAMES)

    ax.set_xlabel("Predicted", fontsize=12)
    ax.set_ylabel("Observed", fontsize=12)
    ax.set_title(title, fontsize=14, weight="bold")

    cbar = fig.colorbar(im, ax=ax)
    cbar.set_label("% of Observed Class", rotation=90)

    ax.set_xticks(np.arange(-0.5, 3, 1), minor=True)
    ax.set_yticks(np.arange(-0.5, 3, 1), minor=True)

    ax.grid(
        which="minor",
        color="white",
        linestyle="-",
        linewidth=1.5,
        alpha=0.8
    )

    ax.tick_params(
        which="minor",
        bottom=False,
        left=False
    )

    plt.tight_layout()
    plt.show()


# ===========================================================
# CONFUSION MATRICES
# ===========================================================

plot_confusion_matrix(
    cumulative_cv_conf_mat,
    "Cumulative CV Confusion Matrix for Chosen Thresholds"
)

plot_confusion_matrix(
    cumulative_oob_conf_mat,
    "Cumulative OOB Multinomial Regression Confusion Matrix"
)


# ===========================================================
# CUMULATIVE CLASSIFICATION REPORT
# ===========================================================

if len(all_oob_y_true) > 0:

    y_true_all = np.concatenate(all_oob_y_true)
    y_pred_all = np.concatenate(all_oob_y_pred)

    print("\n====================")
    print("CUMULATIVE OOB CLASSIFICATION REPORT")
    print("====================")

    print(
        classification_report(
            y_true_all,
            y_pred_all,
            labels=CLASS_LABELS,
            target_names=CLASS_NAMES,
            zero_division=0
        )
    )

else:
    print("\nNo valid OOB predictions were produced.")
# Out:
# Number of cameras: 18
# Cameras: ['bartlett', 'delta_junction', 'glees', 'hyytiala', 'kenttarova', 'lacclair', 'marcell_MN', 'old_jack_pine', 'oregon_yp', 'queens', 'sodankyla_full', 'tammela', 'torgnon', 'underc', 'underhill', 'varrio', 'willowcreek', 'wslcreek']
#
# === Bootstrap 1/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.21, data_quantity >= 25 | CV acc=0.9426, CV bin acc=0.9723, n_rows(dedup)=505
# OOB cameras: ['kenttarova', 'oregon_yp', 'queens', 'torgnon', 'underc', 'varrio', 'wslcreek']
# OOB n=301
# OOB multiclass accuracy=0.9468
# OOB binary accuracy 0 vs {1,2}=1.0000
# 10.15s
#
# === Bootstrap 2/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.28, data_quantity >= 22 | CV acc=0.9491, CV bin acc=0.9915, n_rows(dedup)=589
# OOB cameras: ['bartlett', 'lacclair', 'old_jack_pine', 'sodankyla_full', 'torgnon', 'willowcreek']
# OOB n=254
# OOB multiclass accuracy=0.9173
# OOB binary accuracy 0 vs {1,2}=0.9567
# 10.55s
#
# === Bootstrap 3/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.15, data_quantity >= 28 | CV acc=0.9209, CV bin acc=0.9581, n_rows(dedup)=430
# OOB cameras: ['bartlett', 'kenttarova', 'marcell_MN', 'oregon_yp', 'sodankyla_full', 'torgnon', 'varrio']
# OOB n=341
# OOB multiclass accuracy=0.9619
# OOB binary accuracy 0 vs {1,2}=0.9912
# 9.26s
#
# === Bootstrap 4/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 26 | CV acc=0.9420, CV bin acc=0.9834, n_rows(dedup)=483
# OOB cameras: ['delta_junction', 'glees', 'kenttarova', 'lacclair', 'queens', 'sodankyla_full', 'tammela', 'willowcreek']
# OOB n=345
# OOB multiclass accuracy=0.9246
# OOB binary accuracy 0 vs {1,2}=0.9536
# 10.0s
#
# === Bootstrap 5/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 25 | CV acc=0.9508, CV bin acc=0.9738, n_rows(dedup)=610
# OOB cameras: ['hyytiala', 'lacclair', 'torgnon', 'underc', 'underhill', 'varrio', 'wslcreek']
# OOB n=239
# OOB multiclass accuracy=0.9205
# OOB binary accuracy 0 vs {1,2}=0.9833
# 10.84s
#
# === Bootstrap 6/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 33 | CV acc=0.9520, CV bin acc=0.9880, n_rows(dedup)=417
# OOB cameras: ['delta_junction', 'hyytiala', 'lacclair', 'queens', 'sodankyla_full', 'torgnon', 'willowcreek', 'wslcreek']
# OOB n=248
# OOB multiclass accuracy=0.9395
# OOB binary accuracy 0 vs {1,2}=0.9718
# 10.05s
#
# === Bootstrap 7/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.10, data_quantity >= 28 | CV acc=0.9316, CV bin acc=0.9715, n_rows(dedup)=351
# OOB cameras: ['bartlett', 'glees', 'lacclair', 'old_jack_pine', 'oregon_yp', 'tammela', 'underc', 'varrio', 'wslcreek']
# OOB n=431
# OOB multiclass accuracy=0.9211
# OOB binary accuracy 0 vs {1,2}=0.9698
# 9.17s
#
# === Bootstrap 8/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 32 | CV acc=0.9670, CV bin acc=0.9882, n_rows(dedup)=424
# OOB cameras: ['delta_junction', 'hyytiala', 'underc', 'underhill', 'varrio', 'willowcreek', 'wslcreek']
# OOB n=289
# OOB multiclass accuracy=0.9170
# OOB binary accuracy 0 vs {1,2}=0.9689
# 10.08s
#
# === Bootstrap 9/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 15 | CV acc=0.9504, CV bin acc=0.9773, n_rows(dedup)=484
# OOB cameras: ['hyytiala', 'lacclair', 'old_jack_pine', 'queens', 'sodankyla_full', 'torgnon', 'underc', 'varrio', 'wslcreek']
# OOB n=495
# OOB multiclass accuracy=0.8929
# OOB binary accuracy 0 vs {1,2}=0.9636
# 9.21s
#
# === Bootstrap 10/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 28 | CV acc=0.9542, CV bin acc=0.9763, n_rows(dedup)=590
# OOB cameras: ['marcell_MN', 'old_jack_pine', 'queens', 'torgnon', 'underc', 'underhill', 'wslcreek']
# OOB n=204
# OOB multiclass accuracy=0.9167
# OOB binary accuracy 0 vs {1,2}=0.9902
# 10.25s
#
# === Bootstrap 11/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.09, data_quantity >= 17 | CV acc=0.9571, CV bin acc=0.9751, n_rows(dedup)=723
# OOB cameras: ['delta_junction', 'kenttarova', 'lacclair', 'tammela', 'torgnon', 'underc', 'underhill']
# OOB n=259
# OOB multiclass accuracy=0.8880
# OOB binary accuracy 0 vs {1,2}=0.9846
# 10.52s
#
# === Bootstrap 12/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.15, data_quantity >= 28 | CV acc=0.9575, CV bin acc=0.9803, n_rows(dedup)=659
# OOB cameras: ['marcell_MN', 'queens', 'torgnon', 'underc', 'underhill', 'wslcreek']
# OOB n=112
# OOB multiclass accuracy=0.8571
# OOB binary accuracy 0 vs {1,2}=0.9821
# 11.01s
#
# === Bootstrap 13/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 28 | CV acc=0.9405, CV bin acc=0.9841, n_rows(dedup)=504
# OOB cameras: ['kenttarova', 'lacclair', 'marcell_MN', 'queens', 'sodankyla_full', 'tammela', 'torgnon', 'underhill', 'willowcreek']
# OOB n=290
# OOB multiclass accuracy=0.9414
# OOB binary accuracy 0 vs {1,2}=0.9724
# 9.77s
#
# === Bootstrap 14/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 18 | CV acc=0.9351, CV bin acc=0.9799, n_rows(dedup)=647
# OOB cameras: ['oregon_yp', 'queens', 'sodankyla_full', 'wslcreek']
# OOB n=290
# OOB multiclass accuracy=0.9552
# OOB binary accuracy 0 vs {1,2}=1.0000
# 9.77s
#
# === Bootstrap 15/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 18 | CV acc=0.9051, CV bin acc=0.9684, n_rows(dedup)=474
# OOB cameras: ['delta_junction', 'hyytiala', 'marcell_MN', 'old_jack_pine', 'sodankyla_full', 'torgnon', 'underhill', 'varrio']
# OOB n=513
# OOB multiclass accuracy=0.9045
# OOB binary accuracy 0 vs {1,2}=0.9903
# 8.92s
#
# === Bootstrap 16/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.25, data_quantity >= 19 | CV acc=0.9333, CV bin acc=0.9816, n_rows(dedup)=705
# OOB cameras: ['hyytiala', 'kenttarova', 'lacclair', 'tammela']
# OOB n=199
# OOB multiclass accuracy=0.9598
# OOB binary accuracy 0 vs {1,2}=0.9648
# 10.93s
#
# === Bootstrap 17/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 33 | CV acc=0.9359, CV bin acc=0.9670, n_rows(dedup)=546
# OOB cameras: ['glees', 'oregon_yp', 'wslcreek']
# OOB n=150
# OOB multiclass accuracy=0.9467
# OOB binary accuracy 0 vs {1,2}=0.9933
# 11.2s
#
# === Bootstrap 18/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 20 | CV acc=0.9419, CV bin acc=0.9734, n_rows(dedup)=602
# OOB cameras: ['delta_junction', 'oregon_yp', 'sodankyla_full', 'underc']
# OOB n=350
# OOB multiclass accuracy=0.9371
# OOB binary accuracy 0 vs {1,2}=1.0000
# 10.42s
#
# === Bootstrap 19/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 18 | CV acc=0.9482, CV bin acc=0.9906, n_rows(dedup)=637
# OOB cameras: ['hyytiala', 'lacclair', 'queens', 'sodankyla_full', 'willowcreek', 'wslcreek']
# OOB n=300
# OOB multiclass accuracy=0.9300
# OOB binary accuracy 0 vs {1,2}=0.9667
# 10.85s
#
# === Bootstrap 20/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.09, data_quantity >= 28 | CV acc=0.9497, CV bin acc=0.9840, n_rows(dedup)=437
# OOB cameras: ['glees', 'lacclair', 'old_jack_pine', 'oregon_yp', 'sodankyla_full', 'torgnon', 'wslcreek']
# OOB n=347
# OOB multiclass accuracy=0.9337
# OOB binary accuracy 0 vs {1,2}=0.9769
# 9.77s
#
# === Bootstrap 21/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.25, data_quantity >= 28 | CV acc=0.9427, CV bin acc=0.9780, n_rows(dedup)=454
# OOB cameras: ['lacclair', 'marcell_MN', 'old_jack_pine', 'oregon_yp', 'queens', 'underc', 'underhill']
# OOB n=293
# OOB multiclass accuracy=0.9556
# OOB binary accuracy 0 vs {1,2}=0.9898
# 10.5s
#
# === Bootstrap 22/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.06, data_quantity >= 26 | CV acc=0.9460, CV bin acc=0.9781, n_rows(dedup)=685
# OOB cameras: ['bartlett', 'kenttarova', 'lacclair', 'underhill', 'varrio']
# OOB n=139
# OOB multiclass accuracy=0.8777
# OOB binary accuracy 0 vs {1,2}=0.9281
# 11.71s
#
# === Bootstrap 23/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.06, data_quantity >= 24 | CV acc=0.9546, CV bin acc=0.9812, n_rows(dedup)=639
# OOB cameras: ['bartlett', 'delta_junction', 'lacclair', 'old_jack_pine', 'underc', 'underhill']
# OOB n=226
# OOB multiclass accuracy=0.8673
# OOB binary accuracy 0 vs {1,2}=0.9381
# 11.26s
#
# === Bootstrap 24/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 19 | CV acc=0.9382, CV bin acc=0.9805, n_rows(dedup)=615
# OOB cameras: ['bartlett', 'delta_junction', 'lacclair', 'old_jack_pine', 'queens', 'sodankyla_full', 'wslcreek']
# OOB n=350
# OOB multiclass accuracy=0.9257
# OOB binary accuracy 0 vs {1,2}=0.9686
# 10.51s
#
# === Bootstrap 25/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 32 | CV acc=0.9539, CV bin acc=0.9885, n_rows(dedup)=521
# OOB cameras: ['bartlett', 'delta_junction', 'lacclair', 'old_jack_pine', 'willowcreek']
# OOB n=192
# OOB multiclass accuracy=0.8854
# OOB binary accuracy 0 vs {1,2}=0.9115
# 11.17s
#
# === Bootstrap 26/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.09, data_quantity >= 18 | CV acc=0.9398, CV bin acc=0.9776, n_rows(dedup)=714
# OOB cameras: ['glees', 'hyytiala', 'sodankyla_full', 'underhill']
# OOB n=258
# OOB multiclass accuracy=0.9147
# OOB binary accuracy 0 vs {1,2}=0.9806
# 10.89s
#
# === Bootstrap 27/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.10, data_quantity >= 26 | CV acc=0.9522, CV bin acc=0.9732, n_rows(dedup)=523
# OOB cameras: ['delta_junction', 'kenttarova', 'sodankyla_full', 'underc', 'underhill', 'varrio']
# OOB n=292
# OOB multiclass accuracy=0.9212
# OOB binary accuracy 0 vs {1,2}=0.9966
# 10.2s
#
# === Bootstrap 28/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 35 | CV acc=0.9538, CV bin acc=0.9727, n_rows(dedup)=476
# OOB cameras: ['delta_junction', 'marcell_MN', 'old_jack_pine', 'queens', 'underc']
# OOB n=175
# OOB multiclass accuracy=0.9200
# OOB binary accuracy 0 vs {1,2}=0.9943
# 10.8s
#
# === Bootstrap 29/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.07, data_quantity >= 18 | CV acc=0.9405, CV bin acc=0.9737, n_rows(dedup)=723
# OOB cameras: ['delta_junction', 'marcell_MN', 'oregon_yp', 'torgnon']
# OOB n=254
# OOB multiclass accuracy=0.9449
# OOB binary accuracy 0 vs {1,2}=1.0000
# 10.8s
#
# === Bootstrap 30/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.11, data_quantity >= 18 | CV acc=0.9203, CV bin acc=0.9703, n_rows(dedup)=640
# OOB cameras: ['marcell_MN', 'old_jack_pine', 'sodankyla_full', 'tammela']
# OOB n=327
# OOB multiclass accuracy=0.9725
# OOB binary accuracy 0 vs {1,2}=0.9969
# 10.44s
#
# === Bootstrap 31/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 35 | CV acc=0.9202, CV bin acc=0.9626, n_rows(dedup)=401
# OOB cameras: ['hyytiala', 'marcell_MN', 'old_jack_pine', 'queens', 'tammela', 'underc']
# OOB n=250
# OOB multiclass accuracy=0.9640
# OOB binary accuracy 0 vs {1,2}=0.9960
# 10.28s
#
# === Bootstrap 32/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 35 | CV acc=0.9360, CV bin acc=0.9655, n_rows(dedup)=406
# OOB cameras: ['delta_junction', 'marcell_MN', 'sodankyla_full', 'tammela', 'underhill', 'varrio', 'wslcreek']
# OOB n=245
# OOB multiclass accuracy=0.9673
# OOB binary accuracy 0 vs {1,2}=0.9959
# 10.12s
#
# === Bootstrap 33/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.28, data_quantity >= 28 | CV acc=0.9379, CV bin acc=0.9774, n_rows(dedup)=531
# OOB cameras: ['hyytiala', 'lacclair', 'oregon_yp', 'queens', 'torgnon']
# OOB n=204
# OOB multiclass accuracy=0.9559
# OOB binary accuracy 0 vs {1,2}=0.9706
# 10.99s
#
# === Bootstrap 34/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.21, data_quantity >= 16 | CV acc=0.9398, CV bin acc=0.9712, n_rows(dedup)=382
# OOB cameras: ['glees', 'old_jack_pine', 'oregon_yp', 'sodankyla_full', 'tammela', 'torgnon', 'underc', 'varrio']
# OOB n=574
# OOB multiclass accuracy=0.8937
# OOB binary accuracy 0 vs {1,2}=0.9948
# 9.16s
#
# === Bootstrap 35/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 32 | CV acc=0.9327, CV bin acc=0.9606, n_rows(dedup)=431
# OOB cameras: ['bartlett', 'glees', 'marcell_MN', 'oregon_yp', 'tammela', 'underc', 'wslcreek']
# OOB n=282
# OOB multiclass accuracy=0.9220
# OOB binary accuracy 0 vs {1,2}=0.9787
# 10.29s
#
# === Bootstrap 36/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 18 | CV acc=0.9238, CV bin acc=0.9736, n_rows(dedup)=643
# OOB cameras: ['marcell_MN', 'old_jack_pine', 'sodankyla_full', 'underhill', 'varrio']
# OOB n=344
# OOB multiclass accuracy=0.9680
# OOB binary accuracy 0 vs {1,2}=0.9942
# 10.25s
#
# === Bootstrap 37/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.26, data_quantity >= 30 | CV acc=0.9392, CV bin acc=0.9769, n_rows(dedup)=477
# OOB cameras: ['kenttarova', 'lacclair', 'oregon_yp', 'queens', 'tammela', 'wslcreek']
# OOB n=228
# OOB multiclass accuracy=0.9649
# OOB binary accuracy 0 vs {1,2}=0.9781
# 10.45s
#
# === Bootstrap 38/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.07, data_quantity >= 17 | CV acc=0.9102, CV bin acc=0.9661, n_rows(dedup)=501
# OOB cameras: ['bartlett', 'delta_junction', 'hyytiala', 'old_jack_pine', 'oregon_yp', 'varrio']
# OOB n=486
# OOB multiclass accuracy=0.9630
# OOB binary accuracy 0 vs {1,2}=0.9835
# 9.92s
#
# === Bootstrap 39/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 25 | CV acc=0.9531, CV bin acc=0.9749, n_rows(dedup)=597
# OOB cameras: ['bartlett', 'lacclair', 'marcell_MN', 'sodankyla_full', 'underc', 'varrio']
# OOB n=252
# OOB multiclass accuracy=0.8810
# OOB binary accuracy 0 vs {1,2}=0.9484
# 11.02s
#
# === Bootstrap 40/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.06, data_quantity >= 28 | CV acc=0.9511, CV bin acc=0.9860, n_rows(dedup)=573
# OOB cameras: ['marcell_MN', 'queens', 'tammela', 'underc', 'underhill', 'willowcreek', 'wslcreek']
# OOB n=218
# OOB multiclass accuracy=0.8945
# OOB binary accuracy 0 vs {1,2}=0.9541
# 11.15s
#
# === Bootstrap 41/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 35 | CV acc=0.9403, CV bin acc=0.9652, n_rows(dedup)=402
# OOB cameras: ['glees', 'marcell_MN', 'oregon_yp', 'queens', 'underc', 'varrio', 'wslcreek']
# OOB n=249
# OOB multiclass accuracy=0.9398
# OOB binary accuracy 0 vs {1,2}=0.9960
# 10.42s
#
# === Bootstrap 42/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 32 | CV acc=0.9257, CV bin acc=0.9894, n_rows(dedup)=377
# OOB cameras: ['marcell_MN', 'old_jack_pine', 'oregon_yp', 'varrio', 'willowcreek']
# OOB n=302
# OOB multiclass accuracy=0.9636
# OOB binary accuracy 0 vs {1,2}=0.9768
# 10.17s
#
# === Bootstrap 43/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.22, data_quantity >= 21 | CV acc=0.9324, CV bin acc=0.9809, n_rows(dedup)=680
# OOB cameras: ['hyytiala', 'marcell_MN', 'queens', 'varrio']
# OOB n=202
# OOB multiclass accuracy=0.9505
# OOB binary accuracy 0 vs {1,2}=0.9752
# 11.07s
#
# === Bootstrap 44/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 32 | CV acc=0.9501, CV bin acc=0.9889, n_rows(dedup)=541
# OOB cameras: ['lacclair', 'marcell_MN', 'queens', 'underhill', 'varrio', 'willowcreek', 'wslcreek']
# OOB n=172
# OOB multiclass accuracy=0.9070
# OOB binary accuracy 0 vs {1,2}=0.9419
# 11.44s
#
# === Bootstrap 45/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 14 | CV acc=0.9009, CV bin acc=0.9608, n_rows(dedup)=434
# OOB cameras: ['glees', 'hyytiala', 'kenttarova', 'oregon_yp', 'sodankyla_full', 'tammela', 'torgnon', 'varrio']
# OOB n=612
# OOB multiclass accuracy=0.9330
# OOB binary accuracy 0 vs {1,2}=0.9902
# 9.08s
#
# === Bootstrap 46/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 25 | CV acc=0.9624, CV bin acc=0.9839, n_rows(dedup)=372
# OOB cameras: ['oregon_yp', 'sodankyla_full', 'tammela', 'torgnon', 'underc', 'varrio', 'willowcreek', 'wslcreek']
# OOB n=438
# OOB multiclass accuracy=0.9269
# OOB binary accuracy 0 vs {1,2}=0.9863
# 9.51s
#
# === Bootstrap 47/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 32 | CV acc=0.9609, CV bin acc=0.9805, n_rows(dedup)=307
# OOB cameras: ['glees', 'marcell_MN', 'oregon_yp', 'sodankyla_full', 'underc', 'varrio', 'willowcreek', 'wslcreek']
# OOB n=372
# OOB multiclass accuracy=0.9086
# OOB binary accuracy 0 vs {1,2}=0.9785
# 9.54s
#
# === Bootstrap 48/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 35 | CV acc=0.9484, CV bin acc=0.9864, n_rows(dedup)=368
# OOB cameras: ['delta_junction', 'glees', 'marcell_MN', 'oregon_yp', 'varrio', 'willowcreek']
# OOB n=283
# OOB multiclass accuracy=0.9329
# OOB binary accuracy 0 vs {1,2}=0.9647
# 10.19s
#
# === Bootstrap 49/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.09, data_quantity >= 24 | CV acc=0.9573, CV bin acc=0.9764, n_rows(dedup)=679
# OOB cameras: ['delta_junction', 'glees', 'lacclair', 'marcell_MN', 'torgnon', 'underhill', 'wslcreek']
# OOB n=179
# OOB multiclass accuracy=0.8715
# OOB binary accuracy 0 vs {1,2}=0.9721
# 11.3s
#
# === Bootstrap 50/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.24, data_quantity >= 29 | CV acc=0.9531, CV bin acc=0.9913, n_rows(dedup)=576
# OOB cameras: ['tammela', 'torgnon', 'varrio', 'willowcreek']
# OOB n=159
# OOB multiclass accuracy=0.9245
# OOB binary accuracy 0 vs {1,2}=0.9497
# 11.45s
#
# === Bootstrap 51/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 27 | CV acc=0.9308, CV bin acc=0.9673, n_rows(dedup)=520
# OOB cameras: ['glees', 'hyytiala', 'kenttarova', 'queens', 'torgnon', 'underc', 'underhill', 'varrio']
# OOB n=290
# OOB multiclass accuracy=0.9241
# OOB binary accuracy 0 vs {1,2}=0.9862
# 10.74s
#
# === Bootstrap 52/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 18 | CV acc=0.9107, CV bin acc=0.9670, n_rows(dedup)=515
# OOB cameras: ['glees', 'kenttarova', 'marcell_MN', 'oregon_yp', 'queens', 'sodankyla_full', 'tammela']
# OOB n=472
# OOB multiclass accuracy=0.9555
# OOB binary accuracy 0 vs {1,2}=0.9958
# 9.65s
#
# === Bootstrap 53/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.28, data_quantity >= 25 | CV acc=0.9284, CV bin acc=0.9881, n_rows(dedup)=335
# OOB cameras: ['hyytiala', 'lacclair', 'oregon_yp', 'sodankyla_full', 'tammela', 'torgnon', 'varrio', 'willowcreek']
# OOB n=452
# OOB multiclass accuracy=0.9624
# OOB binary accuracy 0 vs {1,2}=0.9801
# 9.7s
#
# === Bootstrap 54/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.26, data_quantity >= 32 | CV acc=0.9477, CV bin acc=0.9935, n_rows(dedup)=459
# OOB cameras: ['lacclair', 'oregon_yp', 'tammela', 'torgnon', 'underhill', 'willowcreek']
# OOB n=207
# OOB multiclass accuracy=0.9372
# OOB binary accuracy 0 vs {1,2}=0.9517
# 11.18s
#
# === Bootstrap 55/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 27 | CV acc=0.9443, CV bin acc=0.9884, n_rows(dedup)=431
# OOB cameras: ['hyytiala', 'marcell_MN', 'old_jack_pine', 'torgnon', 'underc', 'varrio', 'willowcreek']
# OOB n=342
# OOB multiclass accuracy=0.9298
# OOB binary accuracy 0 vs {1,2}=0.9708
# 10.23s
#
# === Bootstrap 56/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.17, data_quantity >= 28 | CV acc=0.9436, CV bin acc=0.9745, n_rows(dedup)=550
# OOB cameras: ['bartlett', 'glees', 'kenttarova', 'lacclair', 'tammela', 'underhill', 'varrio']
# OOB n=216
# OOB multiclass accuracy=0.9028
# OOB binary accuracy 0 vs {1,2}=0.9352
# 11.33s
#
# === Bootstrap 57/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.09, data_quantity >= 27 | CV acc=0.9491, CV bin acc=0.9704, n_rows(dedup)=609
# OOB cameras: ['bartlett', 'glees', 'marcell_MN', 'torgnon', 'underc', 'underhill', 'varrio']
# OOB n=191
# OOB multiclass accuracy=0.8848
# OOB binary accuracy 0 vs {1,2}=0.9791
# 11.44s
#
# === Bootstrap 58/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 28 | CV acc=0.9314, CV bin acc=0.9709, n_rows(dedup)=481
# OOB cameras: ['kenttarova', 'lacclair', 'oregon_yp', 'tammela', 'underhill', 'varrio', 'wslcreek']
# OOB n=313
# OOB multiclass accuracy=0.9649
# OOB binary accuracy 0 vs {1,2}=0.9808
# 10.17s
#
# === Bootstrap 59/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 29 | CV acc=0.9414, CV bin acc=0.9716, n_rows(dedup)=529
# OOB cameras: ['lacclair', 'marcell_MN', 'queens', 'tammela', 'underc', 'varrio', 'wslcreek']
# OOB n=212
# OOB multiclass accuracy=0.9245
# OOB binary accuracy 0 vs {1,2}=0.9764
# 11.36s
#
# === Bootstrap 60/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.11, data_quantity >= 16 | CV acc=0.9348, CV bin acc=0.9793, n_rows(dedup)=629
# OOB cameras: ['hyytiala', 'oregon_yp', 'torgnon', 'underc', 'underhill', 'varrio']
# OOB n=363
# OOB multiclass accuracy=0.9421
# OOB binary accuracy 0 vs {1,2}=0.9862
# 10.5s
#
# === Bootstrap 61/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.27, data_quantity >= 14 | CV acc=0.9320, CV bin acc=0.9761, n_rows(dedup)=544
# OOB cameras: ['bartlett', 'delta_junction', 'glees', 'hyytiala', 'marcell_MN', 'sodankyla_full', 'underc']
# OOB n=426
# OOB multiclass accuracy=0.8850
# OOB binary accuracy 0 vs {1,2}=0.9695
# 10.15s
#
# === Bootstrap 62/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 25 | CV acc=0.9329, CV bin acc=0.9695, n_rows(dedup)=492
# OOB cameras: ['bartlett', 'delta_junction', 'hyytiala', 'kenttarova', 'lacclair', 'sodankyla_full', 'tammela', 'torgnon']
# OOB n=357
# OOB multiclass accuracy=0.9356
# OOB binary accuracy 0 vs {1,2}=0.9664
# 10.23s
#
# === Bootstrap 63/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 28 | CV acc=0.9473, CV bin acc=0.9840, n_rows(dedup)=626
# OOB cameras: ['lacclair', 'oregon_yp', 'queens']
# OOB n=131
# OOB multiclass accuracy=0.9771
# OOB binary accuracy 0 vs {1,2}=0.9771
# 11.45s
#
# === Bootstrap 64/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.06, data_quantity >= 28 | CV acc=0.9171, CV bin acc=0.9834, n_rows(dedup)=362
# OOB cameras: ['bartlett', 'hyytiala', 'kenttarova', 'lacclair', 'old_jack_pine', 'oregon_yp', 'sodankyla_full']
# OOB n=429
# OOB multiclass accuracy=0.9627
# OOB binary accuracy 0 vs {1,2}=0.9697
# 9.8s
#
# === Bootstrap 65/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.22, data_quantity >= 33 | CV acc=0.9294, CV bin acc=0.9741, n_rows(dedup)=425
# OOB cameras: ['delta_junction', 'lacclair', 'old_jack_pine', 'sodankyla_full', 'tammela']
# OOB n=236
# OOB multiclass accuracy=0.9703
# OOB binary accuracy 0 vs {1,2}=0.9915
# 10.48s
#
# === Bootstrap 66/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.28, data_quantity >= 28 | CV acc=0.9313, CV bin acc=0.9717, n_rows(dedup)=495
# OOB cameras: ['bartlett', 'glees', 'oregon_yp', 'underhill', 'varrio', 'wslcreek']
# OOB n=240
# OOB multiclass accuracy=0.9542
# OOB binary accuracy 0 vs {1,2}=0.9917
# 10.66s
#
# === Bootstrap 67/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.09, data_quantity >= 27 | CV acc=0.9155, CV bin acc=0.9601, n_rows(dedup)=426
# OOB cameras: ['bartlett', 'hyytiala', 'marcell_MN', 'old_jack_pine', 'tammela', 'torgnon', 'underc', 'varrio']
# OOB n=374
# OOB multiclass accuracy=0.9465
# OOB binary accuracy 0 vs {1,2}=0.9840
# 10.19s
#
# === Bootstrap 68/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 34 | CV acc=0.9409, CV bin acc=0.9858, n_rows(dedup)=423
# OOB cameras: ['bartlett', 'marcell_MN', 'old_jack_pine', 'varrio', 'willowcreek', 'wslcreek']
# OOB n=225
# OOB multiclass accuracy=0.9333
# OOB binary accuracy 0 vs {1,2}=0.9511
# 10.71s
#
# === Bootstrap 69/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 34 | CV acc=0.9446, CV bin acc=0.9798, n_rows(dedup)=397
# OOB cameras: ['bartlett', 'glees', 'hyytiala', 'marcell_MN', 'queens', 'tammela', 'underc', 'willowcreek']
# OOB n=251
# OOB multiclass accuracy=0.9004
# OOB binary accuracy 0 vs {1,2}=0.9442
# 10.67s
#
# === Bootstrap 70/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 28 | CV acc=0.9253, CV bin acc=0.9661, n_rows(dedup)=442
# OOB cameras: ['hyytiala', 'kenttarova', 'marcell_MN', 'queens', 'sodankyla_full', 'tammela', 'underc', 'underhill']
# OOB n=352
# OOB multiclass accuracy=0.9602
# OOB binary accuracy 0 vs {1,2}=0.9943
# 10.18s
#
# === Bootstrap 71/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.15, data_quantity >= 26 | CV acc=0.9072, CV bin acc=0.9788, n_rows(dedup)=377
# OOB cameras: ['bartlett', 'glees', 'old_jack_pine', 'oregon_yp', 'tammela', 'underhill', 'varrio', 'willowcreek']
# OOB n=427
# OOB multiclass accuracy=0.9555
# OOB binary accuracy 0 vs {1,2}=0.9719
# 10.08s
#
# === Bootstrap 72/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 17 | CV acc=0.9367, CV bin acc=0.9789, n_rows(dedup)=663
# OOB cameras: ['bartlett', 'hyytiala', 'kenttarova', 'sodankyla_full', 'underhill', 'wslcreek']
# OOB n=334
# OOB multiclass accuracy=0.8952
# OOB binary accuracy 0 vs {1,2}=0.9671
# 10.59s
#
# === Bootstrap 73/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.09, data_quantity >= 26 | CV acc=0.9176, CV bin acc=0.9808, n_rows(dedup)=364
# OOB cameras: ['delta_junction', 'lacclair', 'marcell_MN', 'old_jack_pine', 'oregon_yp', 'sodankyla_full', 'torgnon', 'varrio']
# OOB n=453
# OOB multiclass accuracy=0.9426
# OOB binary accuracy 0 vs {1,2}=0.9801
# 9.33s
#
# === Bootstrap 74/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 16 | CV acc=0.9274, CV bin acc=0.9740, n_rows(dedup)=730
# OOB cameras: ['kenttarova', 'old_jack_pine', 'queens', 'varrio', 'wslcreek']
# OOB n=283
# OOB multiclass accuracy=0.9753
# OOB binary accuracy 0 vs {1,2}=0.9929
# 11.17s
#
# === Bootstrap 75/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 23 | CV acc=0.9156, CV bin acc=0.9784, n_rows(dedup)=462
# OOB cameras: ['hyytiala', 'marcell_MN', 'old_jack_pine', 'oregon_yp', 'queens', 'torgnon', 'wslcreek']
# OOB n=386
# OOB multiclass accuracy=0.9767
# OOB binary accuracy 0 vs {1,2}=0.9922
# 10.17s
#
# === Bootstrap 76/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 34 | CV acc=0.9292, CV bin acc=0.9676, n_rows(dedup)=339
# OOB cameras: ['bartlett', 'delta_junction', 'hyytiala', 'kenttarova', 'lacclair', 'oregon_yp', 'queens', 'sodankyla_full', 'torgnon']
# OOB n=339
# OOB multiclass accuracy=0.9469
# OOB binary accuracy 0 vs {1,2}=0.9735
# 9.83s
#
# === Bootstrap 77/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.21, data_quantity >= 25 | CV acc=0.9409, CV bin acc=0.9789, n_rows(dedup)=711
# OOB cameras: ['bartlett', 'glees', 'kenttarova', 'queens']
# OOB n=95
# OOB multiclass accuracy=0.9158
# OOB binary accuracy 0 vs {1,2}=0.9684
# 11.72s
#
# === Bootstrap 78/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.30, data_quantity >= 25 | CV acc=0.9543, CV bin acc=0.9771, n_rows(dedup)=525
# OOB cameras: ['delta_junction', 'glees', 'hyytiala', 'kenttarova', 'marcell_MN', 'wslcreek']
# OOB n=252
# OOB multiclass accuracy=0.9048
# OOB binary accuracy 0 vs {1,2}=0.9881
# 10.66s
#
# === Bootstrap 79/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.30, data_quantity >= 22 | CV acc=0.9373, CV bin acc=0.9904, n_rows(dedup)=415
# OOB cameras: ['glees', 'hyytiala', 'kenttarova', 'queens', 'sodankyla_full', 'tammela', 'varrio', 'willowcreek']
# OOB n=417
# OOB multiclass accuracy=0.8897
# OOB binary accuracy 0 vs {1,2}=0.9760
# 9.78s
#
# === Bootstrap 80/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 22 | CV acc=0.9519, CV bin acc=0.9768, n_rows(dedup)=561
# OOB cameras: ['bartlett', 'delta_junction', 'hyytiala', 'kenttarova', 'torgnon', 'underc', 'varrio']
# OOB n=307
# OOB multiclass accuracy=0.9121
# OOB binary accuracy 0 vs {1,2}=0.9837
# 10.54s
#
# === Bootstrap 81/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.07, data_quantity >= 28 | CV acc=0.9462, CV bin acc=0.9870, n_rows(dedup)=539
# OOB cameras: ['bartlett', 'delta_junction', 'kenttarova', 'old_jack_pine', 'underhill', 'willowcreek']
# OOB n=249
# OOB multiclass accuracy=0.9116
# OOB binary accuracy 0 vs {1,2}=0.9558
# 10.92s
#
# === Bootstrap 82/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 16 | CV acc=0.9561, CV bin acc=0.9773, n_rows(dedup)=661
# OOB cameras: ['delta_junction', 'sodankyla_full', 'torgnon', 'underc', 'varrio']
# OOB n=301
# OOB multiclass accuracy=0.9169
# OOB binary accuracy 0 vs {1,2}=0.9967
# 10.88s
#
# === Bootstrap 83/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.21, data_quantity >= 17 | CV acc=0.9510, CV bin acc=0.9770, n_rows(dedup)=653
# OOB cameras: ['bartlett', 'kenttarova', 'sodankyla_full', 'underc', 'varrio']
# OOB n=289
# OOB multiclass accuracy=0.8166
# OOB binary accuracy 0 vs {1,2}=0.9862
# 10.9s
#
# === Bootstrap 84/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 28 | CV acc=0.9508, CV bin acc=0.9885, n_rows(dedup)=610
# OOB cameras: ['marcell_MN', 'sodankyla_full', 'willowcreek', 'wslcreek']
# OOB n=184
# OOB multiclass accuracy=0.9293
# OOB binary accuracy 0 vs {1,2}=0.9565
# 10.99s
#
# === Bootstrap 85/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 26 | CV acc=0.9382, CV bin acc=0.9691, n_rows(dedup)=550
# OOB cameras: ['oregon_yp', 'underc', 'varrio', 'wslcreek']
# OOB n=240
# OOB multiclass accuracy=0.9500
# OOB binary accuracy 0 vs {1,2}=1.0000
# 10.86s
#
# === Bootstrap 86/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 32 | CV acc=0.9678, CV bin acc=0.9931, n_rows(dedup)=435
# OOB cameras: ['delta_junction', 'glees', 'hyytiala', 'lacclair', 'marcell_MN', 'torgnon', 'willowcreek', 'wslcreek']
# OOB n=244
# OOB multiclass accuracy=0.9098
# OOB binary accuracy 0 vs {1,2}=0.9549
# 10.75s
#
# === Bootstrap 87/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 18 | CV acc=0.9188, CV bin acc=0.9762, n_rows(dedup)=505
# OOB cameras: ['hyytiala', 'marcell_MN', 'old_jack_pine', 'queens', 'sodankyla_full', 'torgnon', 'varrio']
# OOB n=432
# OOB multiclass accuracy=0.9653
# OOB binary accuracy 0 vs {1,2}=0.9907
# 10.03s
#
# === Bootstrap 88/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.09, data_quantity >= 16 | CV acc=0.9083, CV bin acc=0.9706, n_rows(dedup)=545
# OOB cameras: ['bartlett', 'glees', 'hyytiala', 'kenttarova', 'old_jack_pine', 'oregon_yp']
# OOB n=452
# OOB multiclass accuracy=0.9580
# OOB binary accuracy 0 vs {1,2}=0.9757
# 10.13s
#
# === Bootstrap 89/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 35 | CV acc=0.9121, CV bin acc=0.9544, n_rows(dedup)=307
# OOB cameras: ['glees', 'hyytiala', 'marcell_MN', 'oregon_yp', 'tammela', 'torgnon', 'underc', 'varrio']
# OOB n=344
# OOB multiclass accuracy=0.9535
# OOB binary accuracy 0 vs {1,2}=0.9942
# 9.74s
#
# === Bootstrap 90/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.11, data_quantity >= 22 | CV acc=0.9440, CV bin acc=0.9770, n_rows(dedup)=696
# OOB cameras: ['glees', 'marcell_MN', 'queens', 'sodankyla_full', 'torgnon', 'underhill']
# OOB n=199
# OOB multiclass accuracy=0.9296
# OOB binary accuracy 0 vs {1,2}=0.9899
# 11.15s
#
# === Bootstrap 91/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 28 | CV acc=0.9190, CV bin acc=0.9716, n_rows(dedup)=457
# OOB cameras: ['bartlett', 'glees', 'kenttarova', 'marcell_MN', 'old_jack_pine', 'queens', 'tammela', 'underhill', 'willowcreek']
# OOB n=337
# OOB multiclass accuracy=0.9347
# OOB binary accuracy 0 vs {1,2}=0.9555
# 10.59s
#
# === Bootstrap 92/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 17 | CV acc=0.9229, CV bin acc=0.9615, n_rows(dedup)=519
# OOB cameras: ['delta_junction', 'hyytiala', 'kenttarova', 'oregon_yp', 'queens', 'torgnon', 'varrio', 'wslcreek']
# OOB n=478
# OOB multiclass accuracy=0.9603
# OOB binary accuracy 0 vs {1,2}=0.9937
# 9.88s
#
# === Bootstrap 93/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.21, data_quantity >= 25 | CV acc=0.9516, CV bin acc=0.9917, n_rows(dedup)=599
# OOB cameras: ['bartlett', 'marcell_MN', 'sodankyla_full', 'torgnon', 'willowcreek', 'wslcreek']
# OOB n=207
# OOB multiclass accuracy=0.9227
# OOB binary accuracy 0 vs {1,2}=0.9614
# 11.15s
#
# === Bootstrap 94/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 33 | CV acc=0.9365, CV bin acc=0.9799, n_rows(dedup)=299
# OOB cameras: ['bartlett', 'delta_junction', 'glees', 'kenttarova', 'marcell_MN', 'old_jack_pine', 'oregon_yp', 'queens', 'willowcreek']
# OOB n=366
# OOB multiclass accuracy=0.9344
# OOB binary accuracy 0 vs {1,2}=0.9699
# 9.52s
#
# === Bootstrap 95/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 25 | CV acc=0.9350, CV bin acc=0.9783, n_rows(dedup)=600
# OOB cameras: ['bartlett', 'kenttarova', 'lacclair', 'oregon_yp', 'tammela']
# OOB n=249
# OOB multiclass accuracy=0.9518
# OOB binary accuracy 0 vs {1,2}=0.9679
# 11.02s
#
# === Bootstrap 96/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.09, data_quantity >= 28 | CV acc=0.9288, CV bin acc=0.9644, n_rows(dedup)=365
# OOB cameras: ['delta_junction', 'glees', 'kenttarova', 'lacclair', 'old_jack_pine', 'sodankyla_full', 'underc', 'varrio', 'wslcreek']
# OOB n=419
# OOB multiclass accuracy=0.8974
# OOB binary accuracy 0 vs {1,2}=0.9785
# 8.97s
#
# === Bootstrap 97/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 14 | CV acc=0.9559, CV bin acc=0.9717, n_rows(dedup)=635
# OOB cameras: ['delta_junction', 'glees', 'lacclair', 'sodankyla_full', 'tammela', 'torgnon', 'underc']
# OOB n=359
# OOB multiclass accuracy=0.8802
# OOB binary accuracy 0 vs {1,2}=0.9916
# 10.86s
#
# === Bootstrap 98/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 25 | CV acc=0.9341, CV bin acc=0.9802, n_rows(dedup)=607
# OOB cameras: ['hyytiala', 'lacclair', 'old_jack_pine', 'wslcreek']
# OOB n=203
# OOB multiclass accuracy=0.9655
# OOB binary accuracy 0 vs {1,2}=0.9704
# 11.06s
#
# === Bootstrap 99/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.12, data_quantity >= 25 | CV acc=0.9171, CV bin acc=0.9748, n_rows(dedup)=555
# OOB cameras: ['bartlett', 'kenttarova', 'old_jack_pine', 'tammela', 'underhill', 'varrio']
# OOB n=276
# OOB multiclass accuracy=0.9746
# OOB binary accuracy 0 vs {1,2}=0.9855
# 10.68s
#
# === Bootstrap 100/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.25, data_quantity >= 22 | CV acc=0.9560, CV bin acc=0.9739, n_rows(dedup)=614
# OOB cameras: ['queens', 'sodankyla_full', 'underc', 'underhill', 'varrio', 'wslcreek']
# OOB n=244
# OOB multiclass accuracy=0.8975
# OOB binary accuracy 0 vs {1,2}=1.0000
# 11.14s
#
# === Bootstrap 101/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.15, data_quantity >= 26 | CV acc=0.9337, CV bin acc=0.9566, n_rows(dedup)=392
# OOB cameras: ['bartlett', 'kenttarova', 'marcell_MN', 'oregon_yp', 'queens', 'sodankyla_full', 'torgnon', 'underc', 'underhill', 'varrio']
# OOB n=412
# OOB multiclass accuracy=0.9417
# OOB binary accuracy 0 vs {1,2}=0.9927
# 9.36s
#
# === Bootstrap 102/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 12 | CV acc=0.9199, CV bin acc=0.9719, n_rows(dedup)=462
# OOB cameras: ['bartlett', 'delta_junction', 'hyytiala', 'lacclair', 'marcell_MN', 'oregon_yp', 'sodankyla_full', 'underc', 'wslcreek']
# OOB n=618
# OOB multiclass accuracy=0.9078
# OOB binary accuracy 0 vs {1,2}=0.9628
# 9.47s
#
# === Bootstrap 103/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 22 | CV acc=0.9517, CV bin acc=0.9887, n_rows(dedup)=621
# OOB cameras: ['glees', 'kenttarova', 'queens', 'sodankyla_full', 'underhill', 'willowcreek']
# OOB n=247
# OOB multiclass accuracy=0.8623
# OOB binary accuracy 0 vs {1,2}=0.9636
# 10.86s
#
# === Bootstrap 104/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.25, data_quantity >= 16 | CV acc=0.9447, CV bin acc=0.9789, n_rows(dedup)=615
# OOB cameras: ['delta_junction', 'marcell_MN', 'old_jack_pine', 'torgnon', 'underc', 'varrio']
# OOB n=335
# OOB multiclass accuracy=0.8925
# OOB binary accuracy 0 vs {1,2}=0.9910
# 10.55s
#
# === Bootstrap 105/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.30, data_quantity >= 25 | CV acc=0.9217, CV bin acc=0.9922, n_rows(dedup)=383
# OOB cameras: ['bartlett', 'hyytiala', 'kenttarova', 'old_jack_pine', 'sodankyla_full', 'tammela', 'willowcreek']
# OOB n=394
# OOB multiclass accuracy=0.9695
# OOB binary accuracy 0 vs {1,2}=0.9721
# 9.79s
#
# === Bootstrap 106/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.27, data_quantity >= 25 | CV acc=0.9375, CV bin acc=0.9899, n_rows(dedup)=496
# OOB cameras: ['kenttarova', 'marcell_MN', 'sodankyla_full', 'tammela', 'underhill', 'willowcreek', 'wslcreek']
# OOB n=296
# OOB multiclass accuracy=0.9561
# OOB binary accuracy 0 vs {1,2}=0.9764
# 10.41s
#
# === Bootstrap 107/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 34 | CV acc=0.9332, CV bin acc=0.9793, n_rows(dedup)=434
# OOB cameras: ['bartlett', 'glees', 'marcell_MN', 'old_jack_pine', 'varrio', 'willowcreek']
# OOB n=244
# OOB multiclass accuracy=0.9221
# OOB binary accuracy 0 vs {1,2}=0.9426
# 10.82s
#
# === Bootstrap 108/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 26 | CV acc=0.9388, CV bin acc=0.9711, n_rows(dedup)=588
# OOB cameras: ['delta_junction', 'queens', 'sodankyla_full', 'tammela', 'torgnon', 'underhill', 'wslcreek']
# OOB n=240
# OOB multiclass accuracy=0.9583
# OOB binary accuracy 0 vs {1,2}=0.9958
# 10.71s
#
# === Bootstrap 109/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 27 | CV acc=0.9134, CV bin acc=0.9882, n_rows(dedup)=254
# OOB cameras: ['hyytiala', 'old_jack_pine', 'oregon_yp', 'sodankyla_full', 'tammela', 'varrio', 'willowcreek']
# OOB n=519
# OOB multiclass accuracy=0.9711
# OOB binary accuracy 0 vs {1,2}=0.9865
# 9.28s
#
# === Bootstrap 110/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 16 | CV acc=0.9437, CV bin acc=0.9792, n_rows(dedup)=817
# OOB cameras: ['bartlett', 'marcell_MN', 'tammela', 'underc', 'underhill']
# OOB n=196
# OOB multiclass accuracy=0.8878
# OOB binary accuracy 0 vs {1,2}=0.9643
# 11.47s
#
# === Bootstrap 111/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.09, data_quantity >= 27 | CV acc=0.9370, CV bin acc=0.9736, n_rows(dedup)=492
# OOB cameras: ['glees', 'hyytiala', 'kenttarova', 'lacclair', 'marcell_MN', 'tammela', 'underc', 'underhill']
# OOB n=308
# OOB multiclass accuracy=0.9188
# OOB binary accuracy 0 vs {1,2}=0.9578
# 10.82s
#
# === Bootstrap 112/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 33 | CV acc=0.9255, CV bin acc=0.9685, n_rows(dedup)=349
# OOB cameras: ['delta_junction', 'hyytiala', 'lacclair', 'marcell_MN', 'oregon_yp', 'queens', 'varrio', 'wslcreek']
# OOB n=316
# OOB multiclass accuracy=0.9620
# OOB binary accuracy 0 vs {1,2}=0.9873
# 10.01s
#
# === Bootstrap 113/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 25 | CV acc=0.9478, CV bin acc=0.9687, n_rows(dedup)=670
# OOB cameras: ['bartlett', 'glees', 'tammela', 'torgnon', 'underc', 'wslcreek']
# OOB n=179
# OOB multiclass accuracy=0.8715
# OOB binary accuracy 0 vs {1,2}=0.9665
# 11.47s
#
# === Bootstrap 114/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.17, data_quantity >= 28 | CV acc=0.9457, CV bin acc=0.9789, n_rows(dedup)=663
# OOB cameras: ['bartlett', 'kenttarova', 'lacclair', 'marcell_MN', 'underhill']
# OOB n=103
# OOB multiclass accuracy=0.8641
# OOB binary accuracy 0 vs {1,2}=0.9029
# 11.78s
#
# === Bootstrap 115/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 24 | CV acc=0.9360, CV bin acc=0.9720, n_rows(dedup)=500
# OOB cameras: ['bartlett', 'delta_junction', 'hyytiala', 'kenttarova', 'lacclair', 'sodankyla_full', 'torgnon', 'varrio']
# OOB n=369
# OOB multiclass accuracy=0.9133
# OOB binary accuracy 0 vs {1,2}=0.9702
# 10.35s
#
# === Bootstrap 116/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 32 | CV acc=0.9315, CV bin acc=0.9911, n_rows(dedup)=336
# OOB cameras: ['bartlett', 'glees', 'hyytiala', 'kenttarova', 'lacclair', 'oregon_yp', 'queens', 'varrio', 'willowcreek']
# OOB n=377
# OOB multiclass accuracy=0.9257
# OOB binary accuracy 0 vs {1,2}=0.9443
# 10.07s
#
# === Bootstrap 117/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.25, data_quantity >= 30 | CV acc=0.9629, CV bin acc=0.9920, n_rows(dedup)=377
# OOB cameras: ['delta_junction', 'hyytiala', 'lacclair', 'oregon_yp', 'torgnon', 'underc', 'willowcreek', 'wslcreek']
# OOB n=332
# OOB multiclass accuracy=0.9367
# OOB binary accuracy 0 vs {1,2}=0.9759
# 10.28s
#
# === Bootstrap 118/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.17, data_quantity >= 28 | CV acc=0.9511, CV bin acc=0.9793, n_rows(dedup)=675
# OOB cameras: ['bartlett', 'kenttarova', 'lacclair', 'underhill', 'wslcreek']
# OOB n=91
# OOB multiclass accuracy=0.8571
# OOB binary accuracy 0 vs {1,2}=0.9011
# 11.81s
#
# === Bootstrap 119/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.26, data_quantity >= 30 | CV acc=0.9386, CV bin acc=0.9831, n_rows(dedup)=472
# OOB cameras: ['bartlett', 'oregon_yp', 'tammela', 'torgnon', 'willowcreek', 'wslcreek']
# OOB n=233
# OOB multiclass accuracy=0.9442
# OOB binary accuracy 0 vs {1,2}=0.9657
# 11.05s
#
# === Bootstrap 120/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 19 | CV acc=0.9206, CV bin acc=0.9775, n_rows(dedup)=579
# OOB cameras: ['bartlett', 'old_jack_pine', 'oregon_yp', 'queens', 'sodankyla_full', 'underhill']
# OOB n=386
# OOB multiclass accuracy=0.9767
# OOB binary accuracy 0 vs {1,2}=0.9870
# 10.42s
#
# === Bootstrap 121/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.27, data_quantity >= 14 | CV acc=0.9431, CV bin acc=0.9703, n_rows(dedup)=404
# OOB cameras: ['delta_junction', 'glees', 'kenttarova', 'marcell_MN', 'old_jack_pine', 'oregon_yp', 'queens', 'tammela', 'underc']
# OOB n=566
# OOB multiclass accuracy=0.9028
# OOB binary accuracy 0 vs {1,2}=0.9912
# 9.47s
#
# === Bootstrap 122/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 19 | CV acc=0.9290, CV bin acc=0.9758, n_rows(dedup)=620
# OOB cameras: ['bartlett', 'delta_junction', 'hyytiala', 'old_jack_pine', 'tammela']
# OOB n=345
# OOB multiclass accuracy=0.9449
# OOB binary accuracy 0 vs {1,2}=0.9739
# 10.6s
#
# === Bootstrap 123/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 18 | CV acc=0.9005, CV bin acc=0.9645, n_rows(dedup)=422
# OOB cameras: ['delta_junction', 'old_jack_pine', 'oregon_yp', 'sodankyla_full', 'tammela', 'torgnon', 'underhill', 'varrio']
# OOB n=565
# OOB multiclass accuracy=0.9681
# OOB binary accuracy 0 vs {1,2}=0.9965
# 9.33s
#
# === Bootstrap 124/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 24 | CV acc=0.9397, CV bin acc=0.9896, n_rows(dedup)=481
# OOB cameras: ['bartlett', 'delta_junction', 'kenttarova', 'old_jack_pine', 'sodankyla_full', 'underhill', 'willowcreek', 'wslcreek']
# OOB n=388
# OOB multiclass accuracy=0.9330
# OOB binary accuracy 0 vs {1,2}=0.9716
# 10.05s
#
# === Bootstrap 125/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.27, data_quantity >= 14 | CV acc=0.9479, CV bin acc=0.9865, n_rows(dedup)=518
# OOB cameras: ['delta_junction', 'glees', 'kenttarova', 'old_jack_pine', 'oregon_yp', 'torgnon', 'willowcreek']
# OOB n=452
# OOB multiclass accuracy=0.9358
# OOB binary accuracy 0 vs {1,2}=0.9845
# 10.04s
#
# === Bootstrap 126/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 25 | CV acc=0.9556, CV bin acc=0.9778, n_rows(dedup)=630
# OOB cameras: ['lacclair', 'old_jack_pine', 'torgnon', 'underc', 'underhill', 'varrio']
# OOB n=219
# OOB multiclass accuracy=0.9041
# OOB binary accuracy 0 vs {1,2}=0.9817
# 11.27s
#
# === Bootstrap 127/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 18 | CV acc=0.9136, CV bin acc=0.9712, n_rows(dedup)=382
# OOB cameras: ['glees', 'hyytiala', 'old_jack_pine', 'oregon_yp', 'sodankyla_full', 'tammela', 'torgnon', 'underhill', 'wslcreek']
# OOB n=605
# OOB multiclass accuracy=0.9355
# OOB binary accuracy 0 vs {1,2}=0.9901
# 9.4s
#
# === Bootstrap 128/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 24 | CV acc=0.9391, CV bin acc=0.9779, n_rows(dedup)=542
# OOB cameras: ['bartlett', 'delta_junction', 'kenttarova', 'sodankyla_full', 'torgnon', 'varrio', 'wslcreek']
# OOB n=287
# OOB multiclass accuracy=0.9547
# OOB binary accuracy 0 vs {1,2}=0.9965
# 10.36s
#
# === Bootstrap 129/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.07, data_quantity >= 25 | CV acc=0.9643, CV bin acc=0.9881, n_rows(dedup)=673
# OOB cameras: ['torgnon', 'underc', 'underhill', 'varrio', 'willowcreek']
# OOB n=169
# OOB multiclass accuracy=0.8698
# OOB binary accuracy 0 vs {1,2}=0.9527
# 11.7s
#
# === Bootstrap 130/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.07, data_quantity >= 18 | CV acc=0.9499, CV bin acc=0.9900, n_rows(dedup)=699
# OOB cameras: ['bartlett', 'hyytiala', 'sodankyla_full', 'willowcreek']
# OOB n=278
# OOB multiclass accuracy=0.9245
# OOB binary accuracy 0 vs {1,2}=0.9424
# 11.16s
#
# === Bootstrap 131/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 33 | CV acc=0.9587, CV bin acc=0.9869, n_rows(dedup)=533
# OOB cameras: ['delta_junction', 'glees', 'marcell_MN', 'queens', 'torgnon', 'underhill', 'willowcreek']
# OOB n=163
# OOB multiclass accuracy=0.8773
# OOB binary accuracy 0 vs {1,2}=0.9325
# 11.48s
#
# === Bootstrap 132/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 27 | CV acc=0.9480, CV bin acc=0.9864, n_rows(dedup)=442
# OOB cameras: ['marcell_MN', 'old_jack_pine', 'queens', 'sodankyla_full', 'tammela', 'underc', 'underhill', 'willowcreek']
# OOB n=368
# OOB multiclass accuracy=0.9348
# OOB binary accuracy 0 vs {1,2}=0.9755
# 10.2s
#
# === Bootstrap 133/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.25, data_quantity >= 27 | CV acc=0.9531, CV bin acc=0.9930, n_rows(dedup)=426
# OOB cameras: ['hyytiala', 'kenttarova', 'lacclair', 'marcell_MN', 'old_jack_pine', 'queens', 'torgnon', 'underc', 'willowcreek']
# OOB n=337
# OOB multiclass accuracy=0.9169
# OOB binary accuracy 0 vs {1,2}=0.9614
# 10.42s
#
# === Bootstrap 134/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 25 | CV acc=0.9498, CV bin acc=0.9756, n_rows(dedup)=657
# OOB cameras: ['hyytiala', 'queens', 'torgnon', 'underc', 'wslcreek']
# OOB n=153
# OOB multiclass accuracy=0.8889
# OOB binary accuracy 0 vs {1,2}=0.9869
# 11.38s
#
# === Bootstrap 135/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.09, data_quantity >= 18 | CV acc=0.9330, CV bin acc=0.9735, n_rows(dedup)=642
# OOB cameras: ['bartlett', 'delta_junction', 'kenttarova', 'queens', 'sodankyla_full', 'varrio']
# OOB n=330
# OOB multiclass accuracy=0.9303
# OOB binary accuracy 0 vs {1,2}=0.9848
# 10.7s
#
# === Bootstrap 136/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 25 | CV acc=0.9221, CV bin acc=0.9697, n_rows(dedup)=462
# OOB cameras: ['kenttarova', 'marcell_MN', 'oregon_yp', 'sodankyla_full', 'tammela', 'torgnon', 'underhill', 'wslcreek']
# OOB n=387
# OOB multiclass accuracy=0.9767
# OOB binary accuracy 0 vs {1,2}=0.9974
# 9.72s
#
# === Bootstrap 137/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.20, data_quantity >= 28 | CV acc=0.9450, CV bin acc=0.9753, n_rows(dedup)=527
# OOB cameras: ['delta_junction', 'kenttarova', 'queens', 'tammela', 'varrio', 'wslcreek']
# OOB n=228
# OOB multiclass accuracy=0.9474
# OOB binary accuracy 0 vs {1,2}=1.0000
# 10.75s
#
# === Bootstrap 138/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 28 | CV acc=0.9538, CV bin acc=0.9790, n_rows(dedup)=715
# OOB cameras: ['bartlett', 'lacclair', 'marcell_MN', 'queens', 'torgnon', 'underhill']
# OOB n=79
# OOB multiclass accuracy=0.8101
# OOB binary accuracy 0 vs {1,2}=0.8608
# 12.02s
#
# === Bootstrap 139/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.18, data_quantity >= 23 | CV acc=0.9388, CV bin acc=0.9752, n_rows(dedup)=605
# OOB cameras: ['lacclair', 'marcell_MN', 'queens', 'sodankyla_full', 'varrio', 'wslcreek']
# OOB n=243
# OOB multiclass accuracy=0.9712
# OOB binary accuracy 0 vs {1,2}=1.0000
# 11.24s
#
# === Bootstrap 140/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.21, data_quantity >= 27 | CV acc=0.9705, CV bin acc=0.9895, n_rows(dedup)=475
# OOB cameras: ['kenttarova', 'queens', 'sodankyla_full', 'underc', 'varrio', 'willowcreek', 'wslcreek']
# OOB n=294
# OOB multiclass accuracy=0.8980
# OOB binary accuracy 0 vs {1,2}=0.9762
# 10.52s
#
# === Bootstrap 141/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 18 | CV acc=0.9183, CV bin acc=0.9699, n_rows(dedup)=465
# OOB cameras: ['delta_junction', 'hyytiala', 'kenttarova', 'marcell_MN', 'oregon_yp', 'sodankyla_full', 'underhill']
# OOB n=522
# OOB multiclass accuracy=0.9579
# OOB binary accuracy 0 vs {1,2}=0.9904
# 9.51s
#
# === Bootstrap 142/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.05, data_quantity >= 18 | CV acc=0.9334, CV bin acc=0.9750, n_rows(dedup)=601
# OOB cameras: ['delta_junction', 'glees', 'hyytiala', 'tammela', 'torgnon', 'underhill', 'varrio', 'wslcreek']
# OOB n=386
# OOB multiclass accuracy=0.9378
# OOB binary accuracy 0 vs {1,2}=0.9819
# 10.46s
#
# === Bootstrap 143/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.09, data_quantity >= 20 | CV acc=0.9545, CV bin acc=0.9860, n_rows(dedup)=572
# OOB cameras: ['delta_junction', 'glees', 'hyytiala', 'kenttarova', 'lacclair', 'queens', 'underhill', 'willowcreek', 'wslcreek']
# OOB n=365
# OOB multiclass accuracy=0.9041
# OOB binary accuracy 0 vs {1,2}=0.9562
# 10.62s
#
# === Bootstrap 144/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.09, data_quantity >= 28 | CV acc=0.9292, CV bin acc=0.9670, n_rows(dedup)=424
# OOB cameras: ['glees', 'lacclair', 'oregon_yp', 'queens', 'sodankyla_full', 'tammela', 'varrio']
# OOB n=360
# OOB multiclass accuracy=0.9444
# OOB binary accuracy 0 vs {1,2}=0.9806
# 9.97s
#
# === Bootstrap 145/1000 ===
# Chosen filter -> Eg_strong/Eg_weak >= 1.20, data_quantity >= 25 | CV acc=0.9417, CV bin acc=0.9777, n_rows(dedup)=583
# OOB cameras: ['glees', 'hyytiala', 'kenttarova', 'lacclair', 'varrio']
# OOB n=225
# OOB multiclass accuracy=0.9289
# ...
#        879   1.15  28            421                778         350              8 0.909739    0.966746 0.980000     0.988571
#        880   1.10  27            512               1023         286              8 0.931641    0.964844 0.905594     0.972028
#        881   1.17  28            575                777         191              4 0.949565    0.970435 0.916230     0.984293
#        882   1.05  32            349                816         364              9 0.931232    0.948424 0.950549     0.989011
#        883   1.28  12            478                844         513              8 0.916318    0.970711 0.883041     0.994152
#        884   1.05  16            528               1023         485              8 0.895833    0.967803 0.911340     0.975258
#        885   1.20  28            500                849         255              6 0.956000    0.972000 0.909804     0.992157
#        886   1.05  35            402                696         249              7 0.962687    0.980100 0.907631     0.963855
#        887   1.15  28            502                779         269              7 0.942231    0.968127 0.914498     0.981413
#        888   1.18  33            391                628         274              8 0.925831    0.966752 0.948905     0.985401
#        889   1.25  18            612                809         314              5 0.933007    0.982026 0.955414     0.984076
#        890   1.18  32            496                872         183              6 0.971774    0.991935 0.830601     0.918033
#        891   1.05  17            587                673         410              4 0.921635    0.972743 0.970732     0.995122
#        892   1.18  22            448                781         420              7 0.937500    0.988839 0.947619     0.980952
#        893   1.25  17            766               1035         170              5 0.959530    0.976501 0.829412     0.982353
#        894   1.05  33            471                746         225              6 0.940552    0.963907 0.906667     0.973333
#        895   1.05  28            600               1002         194              8 0.956667    0.976667 0.871134     0.953608
#        896   1.12  16            764               1194         225              6 0.931937    0.975131 0.920000     0.968889
#        897   1.18  18            604                864         333              6 0.950331    0.991722 0.882883     0.951952
#        898   1.26  34            456                711         179              6 0.956140    0.986842 0.888268     0.910615
#        899   1.07  18            707               1069         270              5 0.943423    0.975955 0.900000     0.977778
#        900   1.05  19            502                758         463              6 0.916335    0.988048 0.971922     0.971922
#        901   1.21  27            596                812         173              5 0.932886    0.976510 0.976879     0.988439
#        902   1.09  18            708               1110         264              7 0.950565    0.970339 0.905303     0.996212
#        903   1.21  18            701               1251         231              6 0.938659    0.975749 0.917749     1.000000
#        904   1.18  19            617                986         298              7 0.925446    0.980551 0.956376     0.976510
#        905   1.18  34            467                694         181              6 0.952891    0.985011 0.928177     0.955801
#        906   1.18  28            362                664         395              7 0.939227    0.988950 0.939241     0.974684
#        907   1.05  35            390                585         261              7 0.951282    0.987179 0.938697     0.965517
#        908   1.07  17            583               1063         404              6 0.929674    0.967410 0.952970     0.987624
#        909   1.18  22            724                954         144              4 0.937845    0.979282 0.951389     0.972222
#        910   1.18  12            593               1036         430              7 0.929174    0.973019 0.888372     0.967442
#        911   1.05  25            571                766         278              6 0.938704    0.978984 0.931655     0.946043
#        912   1.05  35            435                714         216              7 0.954023    0.986207 0.916667     0.958333
#        913   1.18  17            301                612         646              9 0.906977    0.983389 0.936533     0.984520
#        914   1.09  32            274                669         430             10 0.919708    0.985401 0.948837     0.974419
#        915   1.21  24            562                868         263              6 0.948399    0.985765 0.908745     0.969582
#        916   1.05  25            567                891         282              5 0.929453    0.977072 0.971631     0.989362
#        917   1.05  26            515                927         313              8 0.947573    0.990291 0.910543     0.939297
#        918   1.05  18            697                912         290              5 0.938307    0.972740 0.927586     0.982759
#        919   1.05  35            483                719         168              6 0.954451    0.971014 0.904762     0.982143
#        920   1.14  18            603                902         354              7 0.936982    0.975124 0.920904     0.977401
#        921   1.15  27            616                905         171              6 0.951299    0.974026 0.894737     0.982456
#        922   1.05  34            354                599         324              7 0.937853    0.988701 0.944444     0.966049
#        923   1.05  25            640               1098         209              7 0.959375    0.978125 0.818182     0.913876
#        924   1.25  27            432                715         331              7 0.942130    0.976852 0.933535     0.975831
#        925   1.05  26            596               1044         232              7 0.941275    0.974832 0.913793     0.943966
#        926   1.25  20            403                767         490              8 0.933002    0.975186 0.938776     0.981633
#        927   1.25  32            440                714         230              5 0.945455    0.990909 0.947826     0.952174
#        928   1.05  35            444                605         207              5 0.943694    0.988739 0.951691     0.966184
#        929   1.09  28            604                727         180              4 0.947020    0.980132 0.922222     0.950000
#        930   1.11  21            454                745         461              7 0.938326    0.973568 0.947939     0.991323
#        931   1.18  25            506                810         304              8 0.946640    0.990119 0.944079     0.973684
#        932   1.13  35            416                509         219              6 0.947115    0.966346 0.926941     0.995434
#        933   1.05  26            540                801         288              7 0.955556    0.987037 0.927083     0.965278
#        934   1.10  27            536                714         262              4 0.929104    0.972015 0.973282     0.996183
#        935   1.05  25            606                734         243              6 0.927393    0.970297 0.954733     0.995885
#        936   1.05  20            667               1132         285              7 0.958021    0.974513 0.905263     0.996491
#        937   1.05  28            401                827         393              8 0.915212    0.960100 0.974555     0.994911
#        938   1.07  32            562                635         145              4 0.960854    0.989324 0.875862     0.937931
#        939   1.14  23            618                985         248              6 0.946602    0.977346 0.923387     0.987903
#        940   1.18  19            494                862         421              8 0.955466    0.983806 0.931116     0.983373
#        941   1.28  35            331                503         272              7 0.918429    0.969789 0.974265     0.988971
#        942   1.05  25            695                769         154              4 0.936691    0.971223 0.974026     0.993506
#        943   1.18  25            437                800         373              7 0.922197    0.970252 0.949062     0.983914
#        944   1.21  18            563                913         369              7 0.944938    0.978686 0.924119     0.975610
#        945   1.05  28            411                623         383              8 0.922141    0.965937 0.968668     0.997389
#        946   1.09  27            540                798         260              6 0.959259    0.979630 0.884615     0.961538
#        947   1.18  26            524               1029         266              8 0.967557    0.988550 0.883459     0.966165
#        948   1.06  28            654               1011         137              6 0.955657    0.977064 0.832117     0.919708
#        949   1.05  35            410                468         241              5 0.951220    0.990244 0.941909     0.966805
#        950   1.18  25            570                732         240              5 0.924561    0.980702 0.975000     0.995833
#        951   1.05  28            657                798         137              4 0.937595    0.972603 0.934307     0.970803
#        952   1.09  28            432                759         352              9 0.937500    0.983796 0.937500     0.968750
#        953   1.18  28            375                960         382             10 0.949333    0.981333 0.905759     0.968586
#        954   1.25  26            358                819         422              8 0.935754    0.983240 0.943128     0.981043
#        955   1.11  17            539                953         438              7 0.946197    0.972171 0.904110     0.979452
#        956   1.05  35            348                466         303              6 0.942529    0.982759 0.947195     0.976898
#        957   1.07  28            433                575         355              7 0.921478    0.963048 0.974648     1.000000
#        958   1.25  32            435                726         235              7 0.954023    0.988506 0.931915     0.961702
#        959   1.21  18            646               1121         286              6 0.953560    0.979876 0.860140     0.975524
#        960   1.20  28            373                568         382              7 0.922252    0.989276 0.958115     0.979058
#        961   1.18  17            477                624         470              6 0.930818    0.972746 0.942553     0.995745
#        962   1.09  18            716               1173         256              6 0.930168    0.974860 0.949219     0.976562
#        963   1.05  25            491                871         358              8 0.934827    0.987780 0.949721     0.960894
#        964   1.11  14            677                956         348              5 0.954210    0.973412 0.876437     0.985632
#        965   1.05  12            675                934         405              6 0.946667    0.976296 0.861728     0.967901
#        966   1.05  24            419                914         450              9 0.923628    0.971360 0.917778     0.968889
#        967   1.15  18            570               1102         384              8 0.936842    0.973684 0.895833     0.955729
#        968   1.18  21            688               1005         199              6 0.943314    0.979651 0.914573     0.989950
#        969   1.15  27            651                949         136              5 0.952381    0.989247 0.911765     0.933824
#        970   1.21  28            623                695         130              4 0.956661    0.972713 0.853846     0.992308
#        971   1.18  25            404                652         406              7 0.938119    0.987624 0.967980     0.985222
#        972   1.05  23            644                904         245              5 0.942547    0.976708 0.918367     0.991837
#        973   1.18  34            372                593         276              7 0.932796    0.989247 0.949275     0.963768
#        974   1.13  17            607                839         364              7 0.942339    0.975288 0.903846     0.972527
#        975   1.09  34            315                498         354              8 0.920635    0.977778 0.954802     0.971751
#        976   1.07  18            641                861         336              5 0.943838    0.973479 0.925595     0.997024
#        977   1.18  32            583                701          96              4 0.957118    0.989708 0.875000     0.927083
#        978   1.18  25            589               1049         221              8 0.943973    0.977929 0.895928     0.927602
#        979   1.05  16            639                947         374              7 0.938967    0.981221 0.914439     0.967914
#        980   1.21  28            612                878         141              5 0.950980    0.988562 0.907801     0.936170
#        981   1.06  28            564                884         227              7 0.945035    0.975177 0.925110     0.942731
#        982   1.05  28            344                656         450              9 0.941860    0.991279 0.924444     0.955556
#        983   1.05  28            558               1098         236              9 0.951613    0.974910 0.881356     0.961864
#        984   1.05  28            636                829         158              4 0.948113    0.974843 0.930380     0.993671
#        985   1.05  27            519                855         291              7 0.936416    0.973025 0.951890     0.969072
#        986   1.15  27            592                858         195              5 0.940878    0.971284 0.892308     0.964103
#        987   1.05  19            568                961         397              6 0.931338    0.971831 0.952141     0.992443
#        988   1.06  35            387                465         261              5 0.930233    0.961240 0.969349     1.000000
#        989   1.05  25            593                960         256              6 0.934233    0.973019 0.976562     0.992188
#        990   1.05  18            728                948         259              6 0.947802    0.975275 0.911197     0.976834
#        991   1.05  17            640                968         357              6 0.940625    0.976562 0.921569     0.980392
#        992   1.09  27            558                770         242              6 0.946237    0.971326 0.896694     0.971074
#        993   1.05  34            263                501         415              9 0.935361    0.977186 0.949398     0.980723
#        994   1.10  25            454                833         382              7 0.929515    0.971366 0.918848     0.992147
#        995   1.18  17            333                511         614              8 0.888889    0.990991 0.967427     0.980456
#        996   1.25  32            342                591         328              7 0.964912    0.991228 0.914634     0.975610
#        997   1.15  25            377                711         447              9 0.928382    0.960212 0.908277     0.986577
#        998   1.18  28            422                563         335              5 0.917062    0.969194 0.985075     0.997015
#        999   1.09  28            515                818         269              7 0.922330    0.968932 0.944238     0.981413
#       1000   1.18  16            558                791         404              7 0.940860    0.992832 0.938119     0.967822
# ====================
# CUMULATIVE OOB CLASSIFICATION REPORT
# ====================
#                       precision    recall  f1-score   support
#
#              No Snow       0.97      0.99      0.98    180348
#          Ground Snow       0.86      0.82      0.84     68220
# Ground + Canopy Snow       0.87      0.86      0.86     53756
#
#             accuracy                           0.93    302324
#            macro avg       0.90      0.89      0.89    302324
#         weighted avg       0.93      0.93      0.93    302324

# %%
import numpy as np
import matplotlib.pyplot as plt

# Replace this with your existing confusion matrix variable if needed
cm = np.array([
    [178632, 1702,    14],
    [  5524, 55645, 7051],
    [    70,  7612, 46074]
])

classes = ["No Snow", "Ground Snow", "Ground + Canopy Snow"]

# Row-normalised percentages for colour and annotation
row_pct = cm / cm.sum(axis=1, keepdims=True) * 100

fig, ax = plt.subplots(figsize=(7.2, 5.8), constrained_layout=True)

im = ax.imshow(row_pct, cmap="Blues", vmin=0, vmax=100)

ax.set_title("Binary Bootstrap Confusion Matrix",
             fontsize=14, weight="bold", pad=12)

ax.set_xlabel("Predicted", fontsize=12)
ax.set_ylabel("Observed", fontsize=12)

ax.set_xticks(np.arange(len(classes)))
ax.set_yticks(np.arange(len(classes)))
ax.set_xticklabels(classes, rotation=25, ha="right", fontsize=10)
ax.set_yticklabels(classes, fontsize=10)

# Cell annotations
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        colour = "white" if row_pct[i, j] > 50 else "black"
        weight = "bold" if i == j else "normal"
        ax.text(
            j, i,
            f"{cm[i, j]}\n({row_pct[i, j]:.1f}%)",
            ha="center", va="center",
            color=colour,
            fontsize=11,
            weight=weight
        )

# Optional subtle grid between cells
ax.set_xticks(np.arange(-0.5, len(classes), 1), minor=True)
ax.set_yticks(np.arange(-0.5, len(classes), 1), minor=True)
ax.grid(which="minor", color="white", linewidth=1.5)
ax.tick_params(which="minor", bottom=False, left=False)

cbar = fig.colorbar(im, ax=ax)
cbar.set_label("% of Observed Class", fontsize=11)

plt.show()

# %%
from scripts.imports import *

import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)


# ===========================================================
# LOAD AND GROUP DATA
# ===========================================================

df = pd.read_pickle(
    'dataset_lcforest_noLOF_bin15_th3_80m_1kmsmallbox_noprior_ta_wc1_v7.pkl'
)

df['Eg_strong'] = np.where(
    (df['beam_str'] == 'strong') & (df['outlier'] == 1),
    df['Eg'],
    np.nan
)
df['Ev_strong'] = np.where(
    (df['beam_str'] == 'strong') & (df['outlier'] == 1),
    df['Ev'],
    np.nan
)
df['Eg_weak'] = np.where(
    (df['beam_str'] == 'weak') & (df['outlier'] == 1),
    df['Eg'],
    np.nan
)
df['Ev_weak'] = np.where(
    (df['beam_str'] == 'weak') & (df['outlier'] == 1),
    df['Ev'],
    np.nan
)

df['forest_type'] = np.where(df['segment_landcover'] < 119, 'closed', 'open')

df_grouped = df.groupby(['camera', 'date', 'lat', 'lon']).agg({
    'pvpg': 'mean',
    'pv': 'max',
    'pg': 'max',
    'Eg_strong': 'median',
    'Ev_strong': 'median',
    'Eg_weak': 'median',
    'Ev_weak': 'median',
    'data_quantity': 'max',
    'snr': 'mean',
    'FSC': 'mean',
    'TreeSnow': 'mean',
    'layer_flag': 'mean',
    'file_index': 'mean',
    'msw_flag': 'mean',
    'pv_ratio_mean': 'mean',
    'pv_ratio_max': 'mean',
    'forest_type': lambda x: pd.Series.mode(x).iloc[0],
}).reset_index()

df_grouped = df_grouped[df_grouped['Eg_strong'] >= 0].copy()
df_grouped['JointSnow'] = df_grouped['FSC'] + df_grouped['TreeSnow']

frac_data = df_grouped[((df_grouped['FSC'] >= 0.00)&(df_grouped['FSC'] <= 1.00))
    &(df_grouped['Eg_strong'] < 16)&(df_grouped['Ev_strong'] < 16)#&(df_grouped['pvpg'] <= 7.5)
# &
    # &(df_grouped['pv_ratio_mean'] >= 1.2)
    &(df_grouped['Eg_strong']/df_grouped['Eg_weak'] >= 1.05)
    # &((df_grouped['layer_flag'] <= 0.6)&(df_grouped['msw_flag'] <= 3.0))
    &(df_grouped['data_quantity'] >= 18)]
frac_data['JointSnowBinary'] = frac_data['JointSnow'].apply(lambda x: 1 if x >= 1 else x)
# Out:
# /tmp/ipykernel_233464/3331296749.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frac_data['JointSnowBinary'] = frac_data['JointSnow'].apply(lambda x: 1 if x >= 1 else x)

# %%
frac_data[(frac_data['camera']=='oregon_yp')&(frac_data['FSC']==0)&(frac_data['Eg_strong']>1.6)]#&(frac_data['Eg_strong']>1.8)].iloc[1]#&(frac_data['FSC']<1)]
# Out:
#          camera        date        lat         lon      pvpg        pv  \
# 957   oregon_yp  12/06/2023  44.319295 -121.594298  0.507002  1.380103
# 990   oregon_yp  16/06/2021  44.310286 -121.559958  0.748108  1.759550
# 1007  oregon_yp  17/06/2020  44.301277 -121.567964  0.620702  1.634961
# 1016  oregon_yp  17/06/2020  44.346323 -121.614157  0.625531  1.788897
# 1017  oregon_yp  17/06/2020  44.346323 -121.573850  0.541678  1.588807
# 1086  oregon_yp  24/10/2019  44.328305 -121.581679  0.647921  1.690573
#
#             pg  Eg_strong  Ev_strong   Eg_weak  ...  FSC  TreeSnow  \
# 957   2.722086   1.656863   0.500000  0.428571  ...  0.0       0.0
# 990   2.351999   1.611111   0.550000  0.654762  ...  0.0       0.0
# 1007  2.634053   1.673203   0.555454  0.892045  ...  0.0       0.0
# 1016  2.859805   1.647059   0.750000  0.550505  ...  0.0       0.0
# 1017  2.933123   1.609907   0.743034  0.773810  ...  0.0       0.0
# 1086  2.609225   1.717105   0.555556  0.857143  ...  0.0       0.0
#
#       layer_flag  file_index  msw_flag  pv_ratio_mean  pv_ratio_max  \
# 957          0.0        33.0  0.000000       1.384700      1.384700
# 990          0.0        18.0  0.000000       1.599909      1.599909
# 1007         0.0        11.0  0.000000       1.629056      1.629056
# 1016         0.0        11.0  0.000000       1.876818      1.876818
# 1017         0.0        11.0  0.000000       1.682381      1.682381
# 1086         0.0         7.0  1.096774       1.792500      1.792500
#
#       forest_type  JointSnow  JointSnowBinary
# 957          open        0.0              0.0
# 990          open        0.0              0.0
# 1007         open        0.0              0.0
# 1016       closed        0.0              0.0
# 1017       closed        0.0              0.0
# 1086         open        0.0              0.0
#
# [6 rows x 23 columns]

# %%
frac_data['camera'].unique()
# Out:
# array(['bartlett', 'delta_junction', 'glees', 'hyytiala', 'kenttarova',
#        'lacclair', 'marcell_MN', 'old_jack_pine', 'oregon_yp', 'queens',
#        'sodankyla_full', 'tammela', 'torgnon', 'underc', 'underhill',
#        'varrio', 'willowcreek', 'wslcreek'], dtype=object)

# %%
frac_data.columns
# Out:
# Index(['camera', 'date', 'lat', 'lon', 'pvpg', 'pv', 'pg', 'Eg_strong',
#        'Ev_strong', 'Eg_weak', 'Ev_weak', 'data_quantity', 'snr', 'FSC',
#        'TreeSnow', 'layer_flag', 'file_index', 'msw_flag', 'pv_ratio_mean',
#        'pv_ratio_max', 'forest_type', 'JointSnow', 'JointSnowBinary'],
#       dtype='object')

# %%
print(f"All filtered data: {len(frac_data)}")
from matplotlib.colors import LinearSegmentedColormap

# ------------------------------------------------------------
# Shared plotting settings
# ------------------------------------------------------------
# cmap = sns.color_palette("icefire", as_cmap=True)
cmap = LinearSegmentedColormap.from_list(
    "stronger_partial_icefire",
    [
        (0.00, "#b8eee6"),  # 0: pale cyan, snow-free
        (0.18, "#45b6d8"),  # stronger blue transition
        (0.34, "#2b55c7"),  # saturated blue
        (0.50, "#17151c"),  # 1: near black, full ground snow
        (0.66, "#7a1e3a"),  # red-purple
        (0.82, "#d24b2a"),  # orange-red
        (1.00, "#ffd2a1"),  # 2: pale orange, ground + canopy snow
    ]
)
norm = plt.Normalize(0, 2)

xlim = (
    frac_data['Eg_strong'].min(),
    frac_data['Eg_strong'].max()
)

ylim = (
    frac_data['Ev_strong'].min(),
    frac_data['Ev_strong'].max()
)

# Optional small padding so points are not tight against the edge
xpad = 0.05 * (xlim[1] - xlim[0])
ypad = 0.05 * (ylim[1] - ylim[0])

xlim = (xlim[0] - xpad, xlim[1] + xpad)
ylim = (ylim[0] - ypad, ylim[1] + ypad)

# ------------------------------------------------------------
# Plot 1: all filtered data
# ------------------------------------------------------------
plt.figure(figsize=(10, 6))
ax = plt.gca()

sns.scatterplot(
    data=frac_data.sort_values('JointSnow'),
    x='Eg_strong',
    y='Ev_strong',
    hue='JointSnow',
    palette=cmap,
    hue_norm=norm,
    edgecolor='black',
    s=60,
    ax=ax,
    legend=False
)

sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

cbar = plt.colorbar(sm, ax=ax)
cbar.set_ticks([0, 1, 2])
cbar.set_ticklabels([
    '0% Snow Cover',
    '100% Ground Snow Cover',
    '100% Ground and Canopy Snow Cover'
])

ax.set_xlim(xlim)
ax.set_ylim(ylim)

plt.xlabel('Median Ground Radiometry', fontsize=13)
plt.ylabel('Median Canopy Radiometry', fontsize=13)
plt.title('ICESat-2 Cell Median Radiometry - All Data', fontsize=14, weight='bold')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# ------------------------------------------------------------
# Plot 2: only partial JointSnow, 0 < JointSnow < 1
# ------------------------------------------------------------
partial_data = frac_data[
    (frac_data['JointSnow'] > 0) &
    (frac_data['JointSnow'] < 1)
].copy()

print(f"Partial JointSnow data, 0 < JointSnow < 1: {len(partial_data)}")

plt.figure(figsize=(10, 6))
ax = plt.gca()

sns.scatterplot(
    data=partial_data.sort_values('JointSnow'),
    x='Eg_strong',
    y='Ev_strong',
    hue='JointSnow',
    palette=cmap,
    hue_norm=norm,
    edgecolor='black',
    s=60,
    ax=ax,
    legend=False
)

sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

cbar = plt.colorbar(sm, ax=ax)
cbar.set_ticks([0, 1, 2])
cbar.set_ticklabels([
    '0% Snow Cover',
    '100% Ground Snow Cover',
    '100% Ground and Canopy Snow Cover'
])

ax.set_xlim(xlim)
ax.set_ylim(ylim)

plt.xlabel('Median Ground Radiometry', fontsize=13)
plt.ylabel('Median Canopy Radiometry', fontsize=13)
plt.title('ICESat-2 Cell Median Radiometry - Partial Snow Cover Data', fontsize=14, weight='bold')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# All filtered data: 1123
# Partial JointSnow data, 0 < JointSnow < 1: 109

# %%
print(f"All filtered data: {len(frac_data)}")

from matplotlib.colors import LinearSegmentedColormap
from matplotlib.lines import Line2D

# ------------------------------------------------------------
# Shared plotting settings
# ------------------------------------------------------------
cmap = LinearSegmentedColormap.from_list(
    "stronger_partial_icefire",
    [
        (0.00, "#b8eee6"),  # 0: pale cyan, snow-free
        (0.18, "#45b6d8"),  # stronger blue transition
        (0.34, "#2b55c7"),  # saturated blue
        (0.50, "#17151c"),  # 1: near black, full ground snow
        (0.66, "#7a1e3a"),  # red-purple
        (0.82, "#d24b2a"),  # orange-red
        (1.00, "#ffd2a1"),  # 2: pale orange, ground + canopy snow
    ]
)

norm = plt.Normalize(0, 2)

xlim = (
    frac_data['Eg_strong'].min(),
    frac_data['Eg_strong'].max()
)

ylim = (
    frac_data['Ev_strong'].min(),
    frac_data['Ev_strong'].max()
)

# Small padding
xpad = 0.05 * (xlim[1] - xlim[0])
ypad = 0.05 * (ylim[1] - ylim[0])

xlim = (xlim[0] - xpad, xlim[1] + xpad)
ylim = (ylim[0] - ypad, ylim[1] + ypad)


# ------------------------------------------------------------
# Selected sites and outline colours
# ------------------------------------------------------------
selected_sites = [
    'bartlett',
    'marcell_MN',
    'old_jack_pine',
    'underc',
    'sodankyla_full',
    'hyytiala',
    'kenttarova'
]

site_colours = {
    'bartlett': '#d62728',        # red
    'marcell_MN': '#2ca02c',      # green
    'old_jack_pine': '#e377c2',   # magenta/pink
    'underc': '#ffbf00',          # gold
    'sodankyla_full': '#1f77b4',  # blue
    'hyytiala': '#9467bd',        # purple
    'kenttarova': '#8c564b'       # brown
}

site_labels = {
    'bartlett': 'Bartlett',
    'marcell_MN': 'Marcell',
    'old_jack_pine': 'Old Jack Pine',
    'underc': 'UNDERC',
    'sodankyla_full': 'Sodankylä',
    'hyytiala': 'Hyytiala',
    'kenttarova': 'Kenttarova'
}


# ------------------------------------------------------------
# Isolate partial-snow points at selected sites
# ------------------------------------------------------------
partial_selected = frac_data[
    (frac_data['JointSnow'] > 0) &
    (frac_data['JointSnow'] < 1) &
    (frac_data['camera'].isin(selected_sites))
].copy()

print(
    f"Partial JointSnow data at selected sites, "
    f"0 < JointSnow < 1: {len(partial_selected)}"
)

print("\nNumber of partial-snow points per site:")
print(
    partial_selected['camera']
    .value_counts()
    .reindex(selected_sites, fill_value=0)
)


# ------------------------------------------------------------
# Plot all filtered data
# ------------------------------------------------------------
plt.figure(figsize=(10, 6))
ax = plt.gca()

sns.scatterplot(
    data=frac_data.sort_values('JointSnow'),
    x='Eg_strong',
    y='Ev_strong',
    hue='JointSnow',
    palette=cmap,
    hue_norm=norm,
    edgecolor='black',
    linewidth=0.4,
    s=40,
    alpha=0.75,
    ax=ax,
    legend=False
)


# ------------------------------------------------------------
# Redraw selected partial-snow points with coloured outlines
# ------------------------------------------------------------
for site in selected_sites:

    site_data = partial_selected[
        partial_selected['camera'] == site
    ].sort_values('JointSnow')

    ax.scatter(
        site_data['Eg_strong'],
        site_data['Ev_strong'],
        c=site_data['JointSnow'],
        cmap=cmap,
        norm=norm,
        s=40,
        edgecolors=site_colours[site],
        linewidths=1.8,
        alpha=1.0,
        zorder=10
    )


# ------------------------------------------------------------
# Snow-cover colourbar
# ------------------------------------------------------------
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

cbar = plt.colorbar(sm, ax=ax)

cbar.set_ticks([0, 1, 2])

cbar.set_ticklabels([
    '0% Snow Cover',
    '100% Ground Snow Cover',
    '100% Ground and Canopy Snow Cover'
])


# ------------------------------------------------------------
# Site legend
# ------------------------------------------------------------
site_legend_handles = [
    Line2D(
        [0],
        [0],
        marker='o',
        linestyle='None',
        markerfacecolor='white',
        markeredgecolor=site_colours[site],
        markeredgewidth=2,
        markersize=8,
        label=site_labels[site]
    )
    for site in selected_sites
]

ax.legend(
    handles=site_legend_handles,
    title='Partial-snow highlight',
    loc='upper right',
    frameon=True
)


# ------------------------------------------------------------
# Formatting
# ------------------------------------------------------------
ax.set_xlim(xlim)
ax.set_ylim(ylim)

plt.xlabel(
    'Median Ground Radiometry',
    fontsize=13
)

plt.ylabel(
    'Median Canopy Radiometry',
    fontsize=13
)

plt.title(
    'ICESat-2 Cell Median Radiometry',
    fontsize=14,
    weight='bold'
)

plt.grid(
    True,
    linestyle='--',
    alpha=0.5
)

plt.tight_layout()
plt.show()
# Out:
# All filtered data: 1123
# Partial JointSnow data at selected sites, 0 < JointSnow < 1: 57
#
# Number of partial-snow points per site:
# camera
# bartlett           6
# marcell_MN         3
# old_jack_pine     18
# underc            13
# sodankyla_full     1
# hyytiala           1
# kenttarova        15
# Name: count, dtype: int64

# %%
print(f"All filtered data: {len(frac_data)}")

from matplotlib.colors import LinearSegmentedColormap
from matplotlib.lines import Line2D
import numpy as np

# ------------------------------------------------------------
# Shared plotting settings
# ------------------------------------------------------------
cmap = LinearSegmentedColormap.from_list(
    "stronger_partial_icefire",
    [
        (0.00, "#b8eee6"),  # 0: pale cyan, snow-free
        (0.18, "#45b6d8"),  # stronger blue transition
        (0.34, "#2b55c7"),  # saturated blue
        (0.50, "#17151c"),  # 1: near black, full ground snow
        (0.66, "#7a1e3a"),  # red-purple
        (0.82, "#d24b2a"),  # orange-red
        (1.00, "#ffd2a1"),  # 2: pale orange, ground + canopy snow
    ]
)

norm = plt.Normalize(0, 2)

xlim = (
    frac_data['Eg_strong'].min(),
    frac_data['Eg_strong'].max()
)

ylim = (
    frac_data['Ev_strong'].min(),
    frac_data['Ev_strong'].max()
)

# Small padding
xpad = 0.05 * (xlim[1] - xlim[0])
ypad = 0.05 * (ylim[1] - ylim[0])

xlim = (xlim[0] - xpad, xlim[1] + xpad)
ylim = (ylim[0] - ypad, ylim[1] + ypad)


# ------------------------------------------------------------
# Selected sites and outline colours
# ------------------------------------------------------------
selected_sites = [
    'underhill',
    'willowcreek',
    'torgnon',
    'glees',
    'oregon_yp'
]

site_colours = {
    'underhill': '#d62728',      # red
    'willowcreek': '#006400',    # dark green
    'torgnon': '#e377c2',        # magenta/pink
    'glees': '#ffbf00',          # gold
    'oregon_yp': '#000080'       # navy
}

site_labels = {
    'underhill': 'Underhill',
    'willowcreek': 'Willow Creek',
    'torgnon': 'Torgnon',
    'glees': 'Glees',
    'oregon_yp': 'Oregon YP'
}


# ------------------------------------------------------------
# Plot order
#
# Willow Creek is behind Underhill, Glees, and Torgnon.
# Torgnon is drawn absolutely last so its single point is on top.
# ------------------------------------------------------------
highlight_order = [
    'oregon_yp',
    'willowcreek',
    'underhill',
    'glees',
    'torgnon'
]


# ------------------------------------------------------------
# Isolate 0% snow-cover points at selected sites
# ------------------------------------------------------------
zero_selected = frac_data[
    np.isclose(frac_data['JointSnow'], 0) &
    (frac_data['camera'].isin(selected_sites))
].copy()

print(
    f"0% snow-cover data at selected sites, "
    f"JointSnow == 0: {len(zero_selected)}"
)

print("\nNumber of 0%-snow points per site:")
print(
    zero_selected['camera']
    .value_counts()
    .reindex(selected_sites, fill_value=0)
)


# ------------------------------------------------------------
# Plot all filtered data
# ------------------------------------------------------------
plt.figure(figsize=(10, 6))
ax = plt.gca()

sns.scatterplot(
    data=frac_data.sort_values('JointSnow'),
    x='Eg_strong',
    y='Ev_strong',
    hue='JointSnow',
    palette=cmap,
    hue_norm=norm,
    edgecolor='black',
    linewidth=0.25,
    s=40,
    alpha=0.75,
    ax=ax,
    legend=False
)


# ------------------------------------------------------------
# Redraw selected 0%-snow points with coloured outlines
# ------------------------------------------------------------
for i, site in enumerate(highlight_order):

    site_data = zero_selected[
        zero_selected['camera'] == site
    ].sort_values('JointSnow')

    ax.scatter(
        site_data['Eg_strong'],
        site_data['Ev_strong'],
        c=site_data['JointSnow'],
        cmap=cmap,
        norm=norm,
        s=40,
        edgecolors=site_colours[site],
        linewidths=1.8,
        alpha=1.0,
        zorder=10 + i
    )


# ------------------------------------------------------------
# Snow-cover colourbar
# ------------------------------------------------------------
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

cbar = plt.colorbar(sm, ax=ax)
cbar.set_ticks([0, 1, 2])
cbar.set_ticklabels([
    '0% Snow Cover',
    '100% Ground Snow Cover',
    '100% Ground and Canopy Snow Cover'
])


# ------------------------------------------------------------
# Site legend
# ------------------------------------------------------------
site_legend_handles = [
    Line2D(
        [0],
        [0],
        marker='o',
        linestyle='None',
        markerfacecolor='white',
        markeredgecolor=site_colours[site],
        markeredgewidth=2,
        markersize=8,
        label=site_labels[site]
    )
    for site in selected_sites
]

ax.legend(
    handles=site_legend_handles,
    title='0%-snow highlight',
    loc='upper right',
    frameon=True
)


# ------------------------------------------------------------
# Formatting
# ------------------------------------------------------------
ax.set_xlim(xlim)
ax.set_ylim(ylim)

plt.xlabel('Median Ground Radiometry', fontsize=13)
plt.ylabel('Median Canopy Radiometry', fontsize=13)

plt.title(
    'ICESat-2 Cell Median Radiometry',
    fontsize=14,
    weight='bold'
)

plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# All filtered data: 1123
# 0% snow-cover data at selected sites, JointSnow == 0: 187
#
# Number of 0%-snow points per site:
# camera
# underhill        5
# willowcreek     33
# torgnon          1
# glees           14
# oregon_yp      134
# Name: count, dtype: int64

# %%
print(f"All filtered data: {len(frac_data)}")

from matplotlib.colors import LinearSegmentedColormap
from matplotlib.lines import Line2D
import numpy as np

# ------------------------------------------------------------
# Shared plotting settings
# ------------------------------------------------------------
cmap = LinearSegmentedColormap.from_list(
    "stronger_partial_icefire",
    [
        (0.00, "#b8eee6"),  # 0: pale cyan, snow-free
        (0.18, "#45b6d8"),  # stronger blue transition
        (0.34, "#2b55c7"),  # saturated blue
        (0.50, "#17151c"),  # 1: near black, full ground snow
        (0.66, "#7a1e3a"),  # red-purple
        (0.82, "#d24b2a"),  # orange-red
        (1.00, "#ffd2a1"),  # 2: pale orange, ground + canopy snow
    ]
)

norm = plt.Normalize(0, 2)

xlim = (
    frac_data['Eg_strong'].min(),
    frac_data['Eg_strong'].max()
)

ylim = (
    frac_data['Ev_strong'].min(),
    frac_data['Ev_strong'].max()
)

# Small padding
xpad = 0.05 * (xlim[1] - xlim[0])
ypad = 0.05 * (ylim[1] - ylim[0])

xlim = (xlim[0] - xpad, xlim[1] + xpad)
ylim = (ylim[0] - ypad, ylim[1] + ypad)


# ------------------------------------------------------------
# Selected sites and outline colours
# ------------------------------------------------------------
selected_sites = [
    'willowcreek',
    'hyytiala',
    'bartlett'
]

site_colours = {
    'willowcreek': '#2ca02c',  # green
    'hyytiala': '#d62728',     # red
    'bartlett': '#ffbf00'      # orange
}

site_labels = {
    'willowcreek': 'Willow Creek',
    'hyytiala': 'Hyytiala',
    'bartlett': 'Bartlett'
}


# ------------------------------------------------------------
# Plot order from back to front
#
# Bartlett is plotted last and therefore appears on top
# wherever points overlap.
# ------------------------------------------------------------
highlight_order = [
    'willowcreek',
    'hyytiala',
    'bartlett'
]


# ------------------------------------------------------------
# Isolate 100% ground snow-covered points at selected sites
# JointSnow == 1
# ------------------------------------------------------------
full_snow_selected = frac_data[
    np.isclose(frac_data['JointSnow'], 1) &
    (frac_data['camera'].isin(selected_sites))
].copy()

print(
    f"100% ground snow-covered data at selected sites, "
    f"JointSnow == 1: {len(full_snow_selected)}"
)

print("\nNumber of 100%-snow points per site:")
print(
    full_snow_selected['camera']
    .value_counts()
    .reindex(selected_sites, fill_value=0)
)


# ------------------------------------------------------------
# Plot all filtered data
# ------------------------------------------------------------
plt.figure(figsize=(10, 6))
ax = plt.gca()

sns.scatterplot(
    data=frac_data.sort_values('JointSnow'),
    x='Eg_strong',
    y='Ev_strong',
    hue='JointSnow',
    palette=cmap,
    hue_norm=norm,
    edgecolor='black',
    linewidth=0.25,
    s=40,
    alpha=0.75,
    ax=ax,
    legend=False
)


# ------------------------------------------------------------
# Redraw selected 100%-snow points with coloured outlines
# ------------------------------------------------------------
for i, site in enumerate(highlight_order):

    site_data = full_snow_selected[
        full_snow_selected['camera'] == site
    ]

    ax.scatter(
        site_data['Eg_strong'],
        site_data['Ev_strong'],
        c=site_data['JointSnow'],
        cmap=cmap,
        norm=norm,
        s=40,
        edgecolors=site_colours[site],
        linewidths=1.8,
        alpha=1.0,
        zorder=10 + i
    )


# ------------------------------------------------------------
# Snow-cover colourbar
# ------------------------------------------------------------
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

cbar = plt.colorbar(sm, ax=ax)

cbar.set_ticks([0, 1, 2])

cbar.set_ticklabels([
    '0% Snow Cover',
    '100% Ground Snow Cover',
    '100% Ground and Canopy Snow Cover'
])


# ------------------------------------------------------------
# Site legend
# ------------------------------------------------------------
site_legend_handles = [
    Line2D(
        [0],
        [0],
        marker='o',
        linestyle='None',
        markerfacecolor='white',
        markeredgecolor=site_colours[site],
        markeredgewidth=2,
        markersize=8,
        label=site_labels[site]
    )
    for site in selected_sites
]

ax.legend(
    handles=site_legend_handles,
    title='100%-snow highlight',
    loc='upper right',
    frameon=True
)


# ------------------------------------------------------------
# Formatting
# ------------------------------------------------------------
ax.set_xlim(xlim)
ax.set_ylim(ylim)

plt.xlabel(
    'Median Ground Radiometry',
    fontsize=13
)

plt.ylabel(
    'Median Canopy Radiometry',
    fontsize=13
)

plt.title(
    'ICESat-2 Cell Median Radiometry',
    fontsize=14,
    weight='bold'
)

plt.grid(
    True,
    linestyle='--',
    alpha=0.5
)

plt.tight_layout()
plt.show()
# Out:
# All filtered data: 1123
# 100% ground snow-covered data at selected sites, JointSnow == 1: 47
#
# Number of 100%-snow points per site:
# camera
# willowcreek    19
# hyytiala       14
# bartlett       14
# Name: count, dtype: int64
