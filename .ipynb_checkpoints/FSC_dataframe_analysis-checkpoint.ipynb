# %% [markdown]
# # Five Sites

# %%
from scripts.FSC_dataframe_phoreal import *

df=pd.read_pickle('five_sites_data.pkl')
loc_df = df[df['Confidence'] == 1].reset_index(drop=True)

# %%
# Correlation heatmap
sns.heatmap(loc_df.drop(['Location','Date','Joint Snow','Tree Snow'],axis=1).corr(), annot=True, cmap="coolwarm", fmt=".2f")
# plt.savefig('./images/five_sites/10kmrad.png')
# Out:
# <Axes: >

# %%
# Pairplot
hue = 'Joint Snow'

# setting the figure size
# width = 20
# height = 8
# sns.set(rc = {'figure.figsize':(width,height)})
sns.color_palette()
sns.pairplot(loc_df[loc_df['pvpg'] < 5], diag_kind='kde', hue=hue, palette='tab10')
# plt.savefig('./images/two_sites/30kmbox.png')

# %%
plt.figure()
plot = sns.histplot(loc_df[(loc_df['pvpg']<5)], x='pvpg', hue='Joint Snow', kde=True, palette='tab10', binwidth=.1)

hue_labels = {'0.0': 'No Snow', '1.0': 'Ground Snow', '2.0': 'Ground+Canopy Snow'}
legend = plot.legend_
# Set the new labels
new_labels = ['No Snow', 'Ground Snow', 'Ground+Canopy Snow']
for text, new_label in zip(legend.get_texts(), new_labels):
    text.set_text(new_label)

# plt.savefig('./images/five_sites/pvpg_10km.png')
plt.show()

# %%
plt.figure()

plot = sns.boxplot(loc_df[(loc_df['pvpg']<100)], x='pvpg', hue='Joint Snow', palette='tab10')

hue_labels = {'0.0': 'No Snow', '1.0': 'Ground Snow', '2.0': 'Ground+Canopy Snow'}
legend = plot.legend_
# Set the new labels
new_labels = ['No Snow', 'Ground Snow', 'Ground+Canopy Snow']
for text, new_label in zip(legend.get_texts(), new_labels):
    text.set_text(new_label)

# plt.savefig('./images/five_sites/pvpg_10km_boxplot100.png')
plt.show()

# %%
plt.figure()

hue_labels = {'0.0': 'No Snow', '1.0': 'Ground Snow', '2.0': 'Ground+Canopy Snow'}

plot = sns.histplot(loc_df, x='asr', hue='Joint Snow', kde=True, palette='tab10', stat='density')
legend = plot.legend_
# Set the new labels
new_labels = ['No Snow', 'Ground Snow', 'Ground+Canopy Snow']
for text, new_label in zip(legend.get_texts(), new_labels):
    text.set_text(new_label)
# handles, labels = scatter.get_legend_handles_labels()
# handles
# new_labels = [hue_labels[label] if label in hue_labels else label for label in labels]

plt.plot([.166,.166],[0,45], 'r--')
plt.plot([.462,.462],[0,45], 'r--')
plt.ylim(0,10)

# 166 for 5km, 186 for 10km
# 462 for upper threshold, both
# scatter.legend(handles=handles, labels=new_labels)

# plt.savefig('./images/five_sites/asr_5km_may31.png')
plt.show()

# %%
plt.figure()

hue_labels = {'0.0': 'No Snow', '1.0': 'Ground Snow', '2.0': 'Ground+Canopy Snow'}

plot = sns.histplot(loc_df, x='asr', hue='FSC', kde=True, palette='tab10')
legend = plot.legend_
# Set the new labels
new_labels = ['No Snow', 'Snow']
for text, new_label in zip(legend.get_texts(), new_labels):
    text.set_text(new_label)
# handles, labels = scatter.get_legend_handles_labels()
# handles
# new_labels = [hue_labels[label] if label in hue_labels else label for label in labels]

# scatter.legend(handles=handles, labels=new_labels)

# plt.savefig('./images/five_sites/asr_5km_binary.png')
plt.show()

# %%
sns.scatterplot(loc_df, x='mean_Eg_strong', y = 'asr' ,hue='Joint Snow', palette='tab10', style='Location')
plt.legend(loc='lower right')
# plt.savefig('./images/five_sites/10km_asr_Eg.png')
plt.show()

# %%
# %matplotlib ipympl

plt.figure()
sns.scatterplot(loc_df, x='mean_Eg_strong', y = 'mean_Ev_strong' ,hue='Joint Snow', palette='tab10', style='Location',
               legend='brief')
plt.plot([1.6,1.6],[0,5], 'r--')
plt.plot([4,4],[0,5], 'r--')
plt.legend(loc='upper right')
plt.xlim(0,9)
plt.ylim(0,5)
# plt.savefig('./images/five_sites/10km_scatter_Eg.png')
plt.show()

# %%
# %matplotlib ipympl

plt.figure()

hue_labels = {'0.0': 'No Snow', '1.0': 'Ground Snow', '2.0': 'Ground+Canopy Snow'}

scatter = sns.scatterplot(loc_df, x='asr', y = 'mean_Ev_strong' ,hue='Joint Snow', palette='tab10', style='Location',
               legend='brief')
handles, labels = scatter.get_legend_handles_labels()
new_labels = [hue_labels[label] if label in hue_labels else label for label in labels]

scatter.legend(handles=handles, labels=new_labels, loc='upper right')

plt.plot([.188,.188],[0,5], 'r--')
plt.plot([.462,.462],[0,5], 'r--')
# plt.legend(loc='upper right')
plt.xlim(0,1.1)
plt.ylim(0,5)
# plt.savefig('./images/five_sites/10km_scatter_asr.png')
plt.show()

# %%
# for a in ['sodankyla_full','delta_junction','marcell_MN','lacclair','torgnon']:

#     plt.figure()
#     sns.scatterplot(loc_df[loc_df['Location'] ==a], x='asr', y = 'mean_Ev_strong' ,
#                     hue='Joint Snow', palette='tab10', legend='brief')
#     plt.legend(loc='upper right')
#     plt.title(a)
#     plt.xlim(0,.75)
#     plt.ylim(0,4)
#     plt.show()
#     # plt.savefig(f'./images/five_sites/{a}_scatter_5km.png')

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

def plot_confusion_matrix(true_labels, predicted_labels, classes):
    # Compute confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)
    
    # Calculate evaluation metrics
    accuracy = accuracy_score(true_labels, predicted_labels)
    precision = precision_score(true_labels, predicted_labels, average='weighted')
    recall = recall_score(true_labels, predicted_labels, average='weighted')

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion Matrix\nAccuracy: {:.2f}, Precision: {:.2f}, Recall: {:.2f}'.format(accuracy, precision, recall))
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], fmt),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# Example usage:
# true_labels = [0, 1, 0, 1, 1, 0]
# predicted_labels = [0, 1, 1, 1, 1, 0]
# plt.savefig(

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd

truth = loc_df['Joint Snow'].values

# Assuming clean_df is your DataFrame

def assign_value(row):
    if row['asr'] < 0.175:
        return 0
    elif row['mean_Ev_strong'] < .88:
        return 1
    else:
        return 2

prediction = loc_df.apply(lambda row: assign_value(row), axis=1).values

classes = ['No Snow', 'Ground Snow', 'Ground and Canopy Snow']
plot_confusion_matrix(truth, prediction, classes)
# plt.savefig('./images/five_sites/confusion10km.png')

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd

truth = loc_df['Joint Snow'].values

# Assuming clean_df is your DataFrame

def assign_value(row):
    if row['asr'] < 0.166:
        return 0
    elif row['asr'] < .462:
        return 1
    else:
        return 2

prediction = loc_df.apply(lambda row: assign_value(row), axis=1).values

classes = ['No Snow', 'Ground Snow', 'Ground and Canopy Snow']
plot_confusion_matrix(truth, prediction, classes)
# plt.savefig('./images/five_sites/confusion5km.png')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd

truth = loc_df['Joint Snow'].values

# Assuming clean_df is your DataFrame

def assign_value(row):
    if row['mean_Eg_strong'] < 1.65:
        return 0
    elif row['mean_Ev_strong'] < .88:
        return 1
    else:
        return 2

prediction = loc_df.apply(lambda row: assign_value(row), axis=1).values

classes = ['No Snow', 'Ground Snow', 'Ground and Canopy Snow']
plot_confusion_matrix(truth, prediction, classes)
# plt.savefig('./images/five_sites/confusion10km.png')

# %% [markdown]
# # New scripts and functions

# %%
from scripts.hist_plot import *

# Load the dataframe
df = pd.read_pickle('five_sites_data_snow_cc.pkl')

for P in range(3):

    if P == 0:
        print('All')
        loc_df = df[(df['msw'] < 5.1) & (df['Confidence'] == 1)].reset_index(drop=True)
    # Filter the dataframe
    
    if P == 1:
        print('No Marcell')
        loc_df = df[(df['msw'] < 5.1) & (df['Confidence'] == 1)&(df['camera'] != 'marcell_MN')].reset_index(drop=True)

    elif P == 2:
        print('No Marcell msw < 2.1')
        loc_df = df[(df['msw'] < 2.1) & (df['Confidence'] == 1)&(df['camera'] != 'marcell_MN')].reset_index(drop=True)
        
    
    hue_labels = {'0.0': 'No Snow', '1.0': 'Ground Snow', '2.0': 'Ground+Canopy Snow'}
    
    titles = ['Cloud Gap-Filled MODIS FSC (MOD10A1F)', 'ICESat-2']
    x_axis = ['Fractional Snow Cover', 'Apparent Surface Reflectance']
    for i, ABC in enumerate(['MxD10A1F', 'asr']):

        # if ABC == 'MxD10A1F':
        
        Plot = sns.histplot(loc_df[loc_df[ABC] <= 100], x=ABC ,hue='JointSnow', palette='tab10', legend='brief', kde=True, bins=25)

        # else:
        #     Plot = sns.histplot(loc_df[loc_df[ABC] <= 100], x=ABC ,hue='JointSnow', palette='tab10', legend='brief', kde=True, bins=25)
        
        # Get the current legend and its handles
        legend = Plot.get_legend()
        handles = legend.legend_handles
        
        # print(labels)
        new_labels = [hue_labels[label] if label in hue_labels else label for label in hue_labels.keys()]
        
        Plot.legend(handles=handles, labels=new_labels, loc='upper right')
        plt.ylim(0,500)
        if ABC == 'MxD10A1F':
            plt.xlim(0,100)
        
        # Extracting the KDE lines from the seaborn plot
        lines = Plot.get_lines()
        
        # Getting the x and y data for each KDE line
        kde_data = {}
        for line in lines:
            label = line.get_label()
            x_data = line.get_xdata()
            y_data = line.get_ydata()
            kde_data[label] = (x_data, y_data)
    
        plt.title(titles[i])
        plt.xlabel(x_axis[i])
        
        plt.show()
    
    # FI = hist_plot(loc_df, hue_labels, X='MxD10A1F', Hue='JointSnow', save=None, plot=True, xlim=(0,100), ylim=None, preset=False)#, save='/500mres/meanEvstrong_hist_msw2')
    # FI = hist_plot(loc_df, hue_labels, X='asr', Hue='JointSnow', save=None, plot=True, ylim=None, preset=False)
    # print(FI)
# Out:
# All
# No Marcell
# No Marcell msw < 2.1

# %%
from scripts.FSC_dataframe_phoreal import *

df=pd.read_pickle('five_sites_data_snow_cc.pkl')

loc_df = df[(df['msw'] < 5.1)&(df['Confidence'] == 1)&(df['camera'] == 'marcell_MN')&(df['date']=='26/03/2019')].reset_index(drop=True)

plt.figure()

hue_labels = {'0.0': 'No Snow', '1.0': 'Ground Snow', '2.0': 'Ground+Canopy Snow'}

scatter = sns.scatterplot(loc_df, x='MxD10A1F', y = 'asr' ,hue='JointSnow', palette='tab10', style='camera',size='msw',
               legend='brief')
handles, labels = scatter.get_legend_handles_labels()
new_labels = [hue_labels[label] if label in hue_labels else label for label in labels]

scatter.legend(handles=handles, labels=new_labels, loc='upper right')

# plt.plot([.188,.188],[0,5], 'r--')
# plt.plot([.462,.462],[0,5], 'r--')
# plt.legend(loc='upper right')
# plt.xlim(0,10)
# plt.ylim(0,9)
# plt.savefig('./images/500mres/scatter_msw2_Eg')
plt.show()

# %%
from scripts.FSC_dataframe_phoreal import *

df=pd.read_pickle('five_sites_data_snow_cc.pkl')

locations = ['marcell_MN','sodankyla_full','delta_junction','lacclair','torgnon']

for l in locations:

    loc_df = df[(df['Confidence'] == 1)&(df['camera'] == l)].reset_index(drop=True)
    
    # Step 1: Convert the 'date' column from strings (dd/mm/yyyy) to datetime objects
    loc_df['date'] = pd.to_datetime(loc_df['date'], format='%d/%m/%Y', errors='coerce')
    
    # Step 2: Count occurrences of each unique date and assign the corresponding JointSnow value
    date_counts = loc_df.groupby('date').size()  # Count occurrences of each date
    joint_snow_values = loc_df.groupby('date')['JointSnow'].first()  # Get the first occurrence of JointSnow for each date
    
    # Step 3: Compute average 'asr' and 'msw' for each date
    average_asr = loc_df.groupby('date')['meanEgstrong'].mean()
    average_msw = loc_df.groupby('date')['msw'].mean()
    
    # Step 4: Sort the data chronologically by the date
    date_counts = date_counts.sort_index()
    joint_snow_values = joint_snow_values.loc[date_counts.index]  # Ensure JointSnow values are in the same order as dates
    average_asr = average_asr.loc[date_counts.index]
    average_msw = average_msw.loc[date_counts.index]
    
    # Step 5: Get the tab10 colormap and map JointSnow values to specific colors
    cmap = plt.get_cmap('tab10')
    colors = joint_snow_values.map({0: cmap(0), 1: cmap(1), 2: cmap(2)})  # Assign colors from tab10 based on JointSnow values
    
    # Step 6: Plot the counts with respective colors
    fig, ax1 = plt.subplots(figsize=(10,6))
    
    # Use 'bar' plot treating the date as a categorical variable (equidistant bars)
    bars = ax1.bar(date_counts.index.astype(str), date_counts, color=colors)
    
    # Step 7: Format the x-axis labels to display only the date (dd/mm/yyyy)
    ax1.set_xticklabels([d.strftime('%d/%m/%Y') for d in date_counts.index], rotation=45)
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Count of Dates')
    
    # Step 8: Create a secondary y-axis for the MSW averages
    ax2 = ax1.twinx()
    
    # Plot average 'msw' on the secondary y-axis
    ax2.plot(date_counts.index.astype(str), average_msw, color='orange', marker='x', linestyle='-', label='Average MSW', linewidth=2)
    ax2.set_ylabel('Average MSW')
    
    # Step 9: Add a third axis for the ASR values
    ax3 = ax1.twinx()
    
    # Adjust the position of the third axis to avoid overlap
    ax3.spines['right'].set_position(('outward', 60))  # Move it outward
    
    # Plot average 'asr' on the third y-axis
    ax3.plot(date_counts.index.astype(str), average_asr, color='blue', marker='o', linestyle='-', label='Average ASR', linewidth=2)
    ax3.set_ylabel('Average ASR')
    
    # Step 10: Add legends for the MSW and ASR axes
    ax2.legend(loc='upper left')
    ax3.legend(loc='upper right')
    
    plt.title(f'Number of Blocks Per Date with Average ASR and MSW - {l}')
    plt.tight_layout()
    # plt.savefig(f'./images/{l}_counts.png')
    plt.show()

# %% [markdown]
# # what if we don't cloud gap fill though

# %%
from scripts.hist_plot import *

# Load the dataframe
df = pd.read_pickle('five_sites_data_gapped.pkl')  #'five_sites_data_snow_cc.pkl')

loc_df = df[(df['MxD10A1']<=100)&(df['Confidence'] == 1)]

hue_labels = {'0.0': 'No Snow', '1.0': 'Ground Snow', '2.0': 'Ground+Canopy Snow'}

titles = ['MODIS', 'ICESat-2']
x_axis = ['Fractional Snow Cover', 'Apparent Surface Reflectance']
for i, ABC in enumerate(['MxD10A1', 'asr']):

    Plot = sns.histplot(loc_df, x=ABC ,hue='JointSnow', palette='tab10', legend='brief', kde=True, bins=25)
    
    # Get the current legend and its handles
    legend = Plot.get_legend()
    handles = legend.legend_handles
    
    # print(labels)
    new_labels = [hue_labels[label] if label in hue_labels else label for label in hue_labels.keys()]
    
    Plot.legend(handles=handles, labels=new_labels, loc='upper right')
    plt.ylim(0,300)
    
    # Extracting the KDE lines from the seaborn plot
    lines = Plot.get_lines()
    
    # Getting the x and y data for each KDE line
    kde_data = {}
    for line in lines:
        label = line.get_label()
        x_data = line.get_xdata()
        y_data = line.get_ydata()
        kde_data[label] = (x_data, y_data)

    plt.title(titles[i])
    plt.xlabel(x_axis[i])

    plt.savefig(f'./images/gapped_histplots_{ABC}')
    
    plt.show()

# # Filter the dataframe
# loc_df = df[(df['msw'] < 5.1) & (df['Confidence'] == 1)].reset_index(drop=True)

# hue_labels = {'0.0': 'No Snow', '1.0': 'Ground Snow', '2.0': 'Ground+Canopy Snow'}

# titles = ['MODIS', 'ICESat-2']
# x_axis = ['Fractional Snow Cover', 'Apparent Surface Reflectance']
# for i, ABC in enumerate(['MxD10A1F', 'asr']):

#     Plot = sns.histplot(loc_df, x=ABC ,hue='JointSnow', palette='tab10', legend='brief', kde=True, bins=25)
    
#     # Get the current legend and its handles
#     legend = Plot.get_legend()
#     handles = legend.legend_handles
    
#     # print(labels)
#     new_labels = [hue_labels[label] if label in hue_labels else label for label in hue_labels.keys()]
    
#     Plot.legend(handles=handles, labels=new_labels, loc='upper right')
#     plt.ylim(0,500)
    
#     # Extracting the KDE lines from the seaborn plot
#     lines = Plot.get_lines()
    
#     # Getting the x and y data for each KDE line
#     kde_data = {}
#     for line in lines:
#         label = line.get_label()
#         x_data = line.get_xdata()
#         y_data = line.get_ydata()
#         kde_data[label] = (x_data, y_data)

#     plt.title(titles[i])
#     plt.xlabel(x_axis[i])
    
#     plt.show()

# # FI = hist_plot(loc_df, hue_labels, X='MxD10A1F', Hue='JointSnow', save=None, plot=True, xlim=(0,100), ylim=None, preset=False)#, save='/500mres/meanEvstrong_hist_msw2')
# # FI = hist_plot(loc_df, hue_labels, X='asr', Hue='JointSnow', save=None, plot=True, ylim=None, preset=False)
# # print(FI)
