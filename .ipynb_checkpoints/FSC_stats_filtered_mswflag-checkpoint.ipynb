# %% [markdown]
# ## Sodankyla

# %% [markdown]
# ### Creation of Pandas Dataframe

# %%
from scripts.FSC_dataframe import *

# %matplotlib ipympl

# dirpaths = ['../data_store/data/sodankyla_full/','../data_store/data/nosnow_highref_amy/']
dirpaths = ['../data_store/data/sodankyla_full/']
csvpath = 'snow_cam_details.csv'

for i, dirpath in enumerate(dirpaths):
    if i == 0:
        df, df_pure = FSC_dataframe(dirpath, csvpath, width=.05, height=.05)
    else:
        df_, df_pure_ = FSC_dataframe(dirpath, csvpath, width=.05, height=.05)
        df = pd.concat([df, df_], axis=0)
        df_pure = pd.concat([df_pure, df_pure_], axis=0)
df
# Out:
# Beam 1 in file 4 has been skipped because of no data.
# Beam 2 in file 4 has been skipped because of no data.
# Beam 3 in file 4 has been skipped because of no data.
# Beam 4 in file 4 has been skipped because of no data.
# Beam 5 in file 4 has been skipped because of no data.
# Beam 6 in file 4 has been skipped because of no data.
# No beams have data in file 4, cannot regress.
# Beam 1 in file 5 has been skipped because of no data.
# Beam 2 in file 5 has been skipped because of no data.
# Beam 3 in file 5 has been skipped because of no data.
# Beam 4 in file 5 has been skipped because of no data.
# Beam 1 in file 7 has been skipped because of no data.
# Beam 2 in file 7 has been skipped because of no data.
# Beam 3 in file 7 has been skipped because of no data.
# Beam 4 in file 7 has been skipped because of no data.
# Beam 5 in file 7 has been skipped because of no data.
# Beam 6 in file 7 has been skipped because of no data.
# No beams have data in file 7, cannot regress.
# Beam 3 in file 8 has been skipped because of no data.
# Beam 4 in file 8 has been skipped because of no data.
# Beam 5 in file 8 has been skipped because of no data.
# Beam 6 in file 8 has been skipped because of no data.
# Beam 1 in file 9 has been skipped because of no data.
# Beam 2 in file 9 has been skipped because of no data.
# Beam 3 in file 9 has been skipped because of no data.
# Beam 4 in file 9 has been skipped because of no data.
# Beam 1 in file 10 has been skipped because of no data.
# Beam 2 in file 10 has been skipped because of no data.
# Beam 3 in file 10 has been skipped because of no data.
# Beam 4 in file 10 has been skipped because of no data.
# Beam 5 in file 10 has been skipped because of no data.
# Beam 6 in file 10 has been skipped because of no data.
# No beams have data in file 10, cannot regress.
# Beam 1 in file 16 has been skipped because of no data.
# Beam 2 in file 16 has been skipped because of no data.
# Beam 1 in file 19 has been skipped because of no data.
# Beam 2 in file 19 has been skipped because of no data.
# Beam 3 in file 19 has been skipped because of no data.
# Beam 4 in file 19 has been skipped because of no data.
# Beam 1 in file 21 has been skipped because of no data.
# Beam 2 in file 21 has been skipped because of no data.
# Beam 3 in file 21 has been skipped because of no data.
# Beam 4 in file 21 has been skipped because of no data.
# Beam 5 in file 21 has been skipped because of no data.
# Beam 6 in file 21 has been skipped because of no data.
# No beams have data in file 21, cannot regress.
# Beam 1 in file 25 has been skipped because of no data.
# Beam 2 in file 25 has been skipped because of no data.
# Beam 3 in file 25 has been skipped because of no data.
# Beam 4 in file 25 has been skipped because of no data.
# Beam 5 in file 25 has been skipped because of no data.
# Beam 6 in file 25 has been skipped because of no data.
# No beams have data in file 25, cannot regress.
# Beam 5 in file 33 has been skipped because of no data.
# Beam 6 in file 33 has been skipped because of no data.
# Beam 1 in file 34 has been skipped because of no data.
# Beam 2 in file 34 has been skipped because of no data.
# Beam 3 in file 34 has been skipped because of no data.
# Beam 4 in file 34 has been skipped because of no data.
# Beam 5 in file 34 has been skipped because of no data.
# Beam 6 in file 34 has been skipped because of no data.
# No beams have data in file 34, cannot regress.
# Beam 1 in file 35 has been skipped because of no data.
# Beam 2 in file 35 has been skipped because of no data.
# Beam 3 in file 35 has been skipped because of no data.
# Beam 4 in file 35 has been skipped because of no data.
# Beam 1 in file 37 has been skipped because of no data.
# Beam 2 in file 37 has been skipped because of no data.
# Beam 3 in file 37 has been skipped because of no data.
# Beam 4 in file 37 has been skipped because of no data.
# Beam 5 in file 37 has been skipped because of no data.
# Beam 6 in file 37 has been skipped because of no data.
# No beams have data in file 37, cannot regress.
# Beam 1 in file 38 has been skipped because of no data.
# Beam 2 in file 38 has been skipped because of no data.
# Beam 3 in file 38 has been skipped because of no data.
# Beam 4 in file 38 has been skipped because of no data.
# Beam 5 in file 40 has been skipped because of no data.
# Beam 6 in file 40 has been skipped because of no data.
# Beam 1 in file 42 has been skipped because of no data.
# Beam 2 in file 42 has been skipped because of no data.
# Beam 3 in file 42 has been skipped because of no data.
# Beam 4 in file 42 has been skipped because of no data.
# Beam 1 in file 45 has been skipped because of no data.
# Beam 2 in file 45 has been skipped because of no data.
# Beam 3 in file 45 has been skipped because of no data.
# Beam 4 in file 45 has been skipped because of no data.
# Beam 1 in file 46 has been skipped because of no data.
# Beam 2 in file 46 has been skipped because of no data.
# Beam 1 in file 56 has been skipped because of no data.
# Beam 2 in file 56 has been skipped because of no data.
# Beam 3 in file 56 has been skipped because of no data.
# Beam 4 in file 56 has been skipped because of no data.
# Beam 5 in file 56 has been skipped because of no data.
# Beam 6 in file 56 has been skipped because of no data.
# No beams have data in file 56, cannot regress.
# Beam 3 in file 57 has been skipped because of no data.
# Beam 4 in file 57 has been skipped because of no data.
# Beam 5 in file 57 has been skipped because of no data.
# Beam 6 in file 57 has been skipped because of no data.
# Beam 1 in file 58 has been skipped because of no data.
# Beam 2 in file 58 has been skipped because of no data.
# Beam 3 in file 58 has been skipped because of no data.
# Beam 4 in file 58 has been skipped because of no data.
# Beam 5 in file 58 has been skipped because of no data.
# Beam 6 in file 58 has been skipped because of no data.
# No beams have data in file 58, cannot regress.
# Beam 1 in file 63 has been skipped because of no data.
# Beam 2 in file 63 has been skipped because of no data.
# Beam 3 in file 63 has been skipped because of no data.
# Beam 4 in file 63 has been skipped because of no data.
# Beam 5 in file 63 has been skipped because of no data.
# Beam 6 in file 63 has been skipped because of no data.
# No beams have data in file 63, cannot regress.
#           Location        Date       pvpg  mean_Eg_strong  mean_Eg_weak  \
# 0   sodankyla_full  24/01/2019   0.513400        0.466374      0.465411
# 1   sodankyla_full  13/04/2019   1.029854        2.835211      0.695546
# 2   sodankyla_full  25/04/2019   0.098604        3.280370      1.024744
# 3   sodankyla_full  11/01/2020   0.257079        4.074753      1.332191
# 4   sodankyla_full  11/04/2020   0.825622        5.407659      1.402149
# 5   sodankyla_full  20/04/2021   0.513234        1.851182      0.649984
# 6   sodankyla_full  09/07/2021   1.335748        1.334322      0.286243
# 7   sodankyla_full  20/09/2021  31.484728        0.744211      0.117658
# 8   sodankyla_full  20/12/2021   0.815885        4.941353      1.177249
# 9   sodankyla_full  18/01/2022   0.350900        2.917018      0.996734
# 10  sodankyla_full  19/04/2022   0.208683        4.551893      1.202153
# 11  sodankyla_full  08/06/2022   0.983022        0.829028      0.090498
# 12  sodankyla_full  19/03/2023   0.868408        5.539092      1.536254
#
#     mean_Ev_strong  mean_Ev_weak  msw_flag  night_flag       asr FSC  \
# 0         0.451736      0.241441  3.000000         0.0  0.092632   1
# 1         0.460976      0.472513  1.000000         0.0  0.255333   1
# 2         0.296933      0.135098  0.000000         0.0  0.306398   1
# 3         0.460376      0.259779  1.000000         1.0  0.410676   1
# 4         0.519679      0.359485  0.000000         1.0  0.471228   1
# 5         0.508275      0.231766  1.000000         0.0  0.179531   1
# 6         0.415856      0.235057  0.000000         0.0  0.101107   0
# 7         0.563174      0.362492  2.000000         0.0  0.075918   0
# 8         1.182301      0.726271  0.000000         1.0  0.570042   1
# 9         0.343413      0.285466  1.000000         1.0  0.256975   1
# 10        0.374292      0.208149  0.000000         1.0  0.440470   1
# 11        0.587922      0.395785  1.963636         0.0  0.103912   0
# 12        1.445047      0.294675  0.000000         0.0  0.545382   1
#
#    Tree Snow Joint Snow
# 0          1          2
# 1          0          1
# 2          0          1
# 3          0          1
# 4          0          1
# 5          0          1
# 6          0          0
# 7          0          0
# 8          1          2
# 9          0          1
# 10         0          1
# 11         0          0
# 12         0          1

# %%
clean_df = df_pure[df_pure['msw_flag'] < 2]

# %% [markdown]
# ### Statistical Glance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 0 to 0
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pvpg            24 non-null     float64
#  1   mean_Eg_strong  24 non-null     float64
#  2   mean_Eg_weak    23 non-null     float64
#  3   mean_Ev_strong  24 non-null     float64
#  4   mean_Ev_weak    23 non-null     float64
#  5   msw_flag        24 non-null     float64
#  6   night_flag      24 non-null     float64
#  7   asr             24 non-null     float64
#  8   FSC             24 non-null     float64
#  9   Tree Snow       24 non-null     float64
#  10  Joint Snow      24 non-null     float64
# dtypes: float64(11)
# memory usage: 2.2 KB

# %%
df_pure.head()
# Out:
#        pvpg  mean_Eg_strong  mean_Eg_weak  mean_Ev_strong  mean_Ev_weak  \
# 0  0.038846        3.634023      1.198126        0.602533      0.346641
# 1  0.344606        1.035700      0.424717        0.910730      0.378241
# 2  1.032511        0.352601      0.124356        0.213841      0.160356
# 3  0.831393        2.580798      0.846353        0.431859      0.358542
# 4  0.054266        2.946372      0.736324        0.358108      0.264183
#
#    msw_flag  night_flag       asr  FSC  Tree Snow  Joint Snow
# 0  1.000000         1.0  0.366850  1.0        0.0         1.0
# 1  2.696701         0.0  0.186152  1.0        1.0         2.0
# 2  2.272537         0.0  0.039992  1.0        0.0         1.0
# 3  1.010336         0.0  0.257220  1.0        0.0         1.0
# 4  0.462264         0.0  0.249534  1.0        0.0         1.0

# %%
df.describe()
# Out:
#        File Number       pvpg  mean_Eg_strong  mean_Eg_weak  mean_Ev_strong  \
# count    23.000000  23.000000       23.000000     22.000000       23.000000
# mean     16.391304   0.785563        2.329018      0.715239        0.567271
# std      10.882593   0.347100        1.629436      0.459035        0.341207
# min       0.000000   0.218932        0.260734      0.090498        0.126290
# 25%       6.500000   0.526784        0.998561      0.251957        0.389122
# 50%      17.000000   0.770523        2.166465      0.640000        0.501309
# 75%      24.500000   1.037282        3.837193      1.133937        0.659664
# max      35.000000   1.312406        5.823964      1.506051        1.815182
#
#        mean_Ev_weak   msw_flag  night_flag        asr
# count     22.000000  23.000000   23.000000  23.000000
# mean       0.328744   0.916740    0.391304   0.231732
# std        0.122649   0.996288    0.499011   0.168069
# min        0.189513   0.000000    0.000000   0.017572
# 25%        0.252141   0.000000    0.000000   0.096824
# 50%        0.292569   1.000000    0.000000   0.194624
# 75%        0.365419   1.456522    1.000000   0.321076
# max        0.724196   3.000000    1.000000   0.563207

# %%
# Correlation heatmap
sns.heatmap(clean_df.drop(['Joint Snow','Tree Snow'],axis=1).corr(), annot=True, cmap="coolwarm", fmt=".2f")
# Out:
# <Axes: >
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Pairplot
hue = 'Joint Snow'

# setting the figure size
# width = 20
# height = 8
# sns.set(rc = {'figure.figsize':(width,height)})
sns.pairplot(clean_df, diag_kind='kde', hue=hue)
plt.savefig('./images/msw_flagged_stats/6kmbox.png')

# %%
# Distribution Plots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12, 8))

hue = 'Joint Snow'
stat = 'probability'
f = ['pvpg','asr','mean_Eg_strong','mean_Eg_weak','mean_Ev_strong','mean_Ev_weak']
i = 0
j = 0

for x in f:
    sns.histplot(df[df['msw_flag'] < 2], x=x, hue=hue, kde=True, stat=stat,ax=axes[i % 2, j % 3])
    j += 1
    if j == 3:
        i += 1

# Adjust layout
plt.tight_layout()

# Show plot
plt.show
plt.savefig('./images/msw_flagged_stats/6kmbox_hist.png')

# %%
# Violin plots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12, 8))

hue = 'Joint Snow'

# Distribution plots
sns.boxplot(df, x='pvpg', y=hue, ax=axes[0, 0])
sns.boxplot(df, x='asr', y=hue, ax=axes[0, 1])
sns.boxplot(df, x='mean_Eg_strong', y=hue, ax=axes[0, 2])
sns.boxplot(df, x='mean_Eg_weak', y=hue, ax=axes[1, 0])
sns.boxplot(df, x='mean_Ev_strong', y=hue, ax=axes[1, 1])
sns.boxplot(df, x='mean_Ev_weak', y=hue, ax=axes[1, 2])

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
# Out:
# C:\Users\s1803229\AppData\Local\miniforge-pypy3\envs\snow_env\lib\site-packages\pandas\io\formats\format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# C:\Users\s1803229\AppData\Local\miniforge-pypy3\envs\snow_env\lib\site-packages\pandas\io\formats\format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# C:\Users\s1803229\AppData\Local\miniforge-pypy3\envs\snow_env\lib\site-packages\pandas\io\formats\format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# C:\Users\s1803229\AppData\Local\miniforge-pypy3\envs\snow_env\lib\site-packages\pandas\io\formats\format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# C:\Users\s1803229\AppData\Local\miniforge-pypy3\envs\snow_env\lib\site-packages\pandas\io\formats\format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# C:\Users\s1803229\AppData\Local\miniforge-pypy3\envs\snow_env\lib\site-packages\pandas\io\formats\format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())

# %%
# Violin plots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12, 8))

hue = 'Joint Snow'

# Distribution plots
sns.violinplot(df, x='pvpg', y=hue, ax=axes[0, 0])
sns.violinplot(df, x='asr', y=hue, ax=axes[0, 1])
sns.violinplot(df, x='mean_Eg_strong', y=hue, ax=axes[0, 2])
sns.violinplot(df, x='mean_Eg_weak', y=hue, ax=axes[1, 0])
sns.violinplot(df, x='mean_Ev_strong', y=hue, ax=axes[1, 1])
sns.violinplot(df, x='mean_Ev_weak', y=hue, ax=axes[1, 2])

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
# Out:
# C:\Users\s1803229\AppData\Local\miniforge-pypy3\envs\snow_env\lib\site-packages\pandas\io\formats\format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# C:\Users\s1803229\AppData\Local\miniforge-pypy3\envs\snow_env\lib\site-packages\pandas\io\formats\format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# C:\Users\s1803229\AppData\Local\miniforge-pypy3\envs\snow_env\lib\site-packages\pandas\io\formats\format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# C:\Users\s1803229\AppData\Local\miniforge-pypy3\envs\snow_env\lib\site-packages\pandas\io\formats\format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# C:\Users\s1803229\AppData\Local\miniforge-pypy3\envs\snow_env\lib\site-packages\pandas\io\formats\format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# C:\Users\s1803229\AppData\Local\miniforge-pypy3\envs\snow_env\lib\site-packages\pandas\io\formats\format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())

# %% [markdown]
# ## Kenttarova

# %%
# from scripts.FSC_dataframe import *

# %matplotlib ipympl

# dirpath = '../data/kenttarova_cam/'
# csvpath = 'snow_cam_details.csv'

# df, df_pure = FSC_dataframe(dirpath, csvpath)
