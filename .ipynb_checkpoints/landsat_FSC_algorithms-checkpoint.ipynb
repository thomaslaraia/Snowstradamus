# %%
import matplotlib.pyplot as plt
from shapely.geometry import Polygon
import numpy as np

# Define approximate polygon (NDVI, NDSI) → flipped to (NDSI, NDVI)
region_coords = [
    (0.4, 1),
    (0.33, 0.91),
    (0.26, 0.75),
    (0.2, 0.6),
    (0.1, 0.25),  # bottom left
    (0.4, 0.1),  # top right
]

# Extract for plotting
polygon = Polygon(region_coords)
x_poly, y_poly = zip(*polygon.exterior.coords)

# Plot
fig, ax = plt.subplots(figsize=(8, 6))

# Shaded polygon
ax.fill(x_poly, y_poly, color='lightblue', alpha=0.5, label='Klein Snow Region')

# Axes and labels
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.set_xlabel('NDSI')
ax.set_ylabel('NDVI')
ax.set_title('Klein et al. (1998) Snow Classification Region\n(NDSI vs NDVI)')
ax.grid(True)

ax.legend()
plt.show()

# %%
from scripts.imports import *
from rasterio.enums import Resampling
from shapely.geometry import Polygon, Point

def find_masks(folder, cam):
    for filename in os.listdir(folder):
        if cam in filename and 'LandCover' in filename:
            corine_filepath = os.path.join(folder, filename)
        elif cam in filename and 'ALOS' in filename:
            elevation_filepath = os.path.join(folder, filename)
    return corine_filepath, elevation_filepath

def load_and_reproject_to_landsat(source_path, match_array, band_name, method=Resampling.nearest):
    src = rioxarray.open_rasterio(source_path, masked=True).squeeze()
    src.name = band_name
    return src.rio.reproject_match(match_array, resampling=method)

def combine_tifs(landsat_filepath, corine_filepath, elevation_filepath):
    landsat = rioxarray.open_rasterio(landsat_filepath, masked=True).squeeze()
    landsat.name = "landsat"
    corine = load_and_reproject_to_landsat(corine_filepath, landsat, "corine_landcover")
    elevation = load_and_reproject_to_landsat(elevation_filepath, landsat, "elevation")
    return xr.merge([landsat, corine, elevation])

def apply_valid_mask(ds, e=80):
    elevation = ds['elevation']
    corine = ds['corine_landcover']
    yc, xc = elevation.sizes['y'] // 2, elevation.sizes['x'] // 2
    centre_elev = elevation.isel(y=yc, x=xc).item()
    elev_mask = np.abs(elevation - centre_elev) <= e
    corine_mask = (corine >= 111) & (corine <= 126)
    valid_mask = elev_mask & corine_mask
    ds['valid_mask'] = valid_mask
    return ds

def compute_ndvi(red, nir):
    return (nir - red) / (nir + red)

def compute_ndsi(green, swir):
    return (green - swir) / (green + swir)

def compute_dozier(ds, ndsi, nir):
    corine = ds['corine_landcover']
    condition1 = (ndsi > 0.1) & (ndsi < 0.4) # & (corine >= 111) & (corine <= 126)
    condition2 = (ndsi >= 0.4) & (nir > 0.11) # ~((corine >= 111) & (corine <= 126))
    dozier = xr.where(condition1 | condition2, 1, 0)
    return dozier.where(~np.isnan(ndsi))

def compute_klein(ndsi, ndvi, green, nir):
    region_coords = [
        (0.4, 1), (0.33, 0.91), (0.26, 0.75),
        (0.2, 0.6), (0.1, 0.25), (0.4, 0.1),
    ]
    polygon = Polygon(region_coords)
    klein = xr.zeros_like(ndsi)
    klein = xr.where(ndsi >= 0.4, 1, klein)
    ndsi_vals, ndvi_vals = ndsi.values, ndvi.values
    mask = np.zeros(ndsi.shape, dtype=bool)
    for i in range(ndsi.shape[0]):
        for j in range(ndsi.shape[1]):
            if not np.isnan(ndsi_vals[i, j]) and not np.isnan(ndvi_vals[i, j]):
                if polygon.contains(Point(ndsi_vals[i, j], ndvi_vals[i, j])):
                    mask[i, j] = True
    klein = xr.where(xr.DataArray(mask, dims=ndsi.dims, coords=ndsi.coords), 1, klein)
    klein = xr.where((green <= 0.1) | (nir <= 0.11), 0, klein)
    return klein.where(~np.isnan(ndsi) & ~np.isnan(ndvi))

def compute_salomonson(ndsi):
    fsc = 0.06 + 1.21 * ndsi
    return fsc.clip(0, 1).where(~np.isnan(ndsi))

def normalize(img):
    img = img.transpose("y", "x", "band")
    p2 = img.quantile(0.02, dim=("x", "y"))
    p98 = img.quantile(0.98, dim=("x", "y"))
    return ((img - p2) / (p98 - p2)).clip(0, 1)

def plot_rgb(ds, landsat, cam, filtered=True):
    rgb_bands = [2, 1, 0] if landsat == 'Landsat7' else [3, 2, 1]
    rgb = ds['landsat'].isel(band=rgb_bands)

    if filtered and 'valid_mask' in ds:
        # Apply valid mask across all bands
        mask = ds['valid_mask']
        rgb = rgb.where(mask)

    rgb = normalize(rgb)

    plt.figure(figsize=(8, 8))
    title = f"RGB Composite for {cam}" + (" (Filtered)" if filtered else " (Raw)")
    plt.imshow(rgb)
    plt.title(title)
    plt.axis("off")
    plt.show()

import os
import re

def process_scene(i, apply_filter=True, plot_rgb_image=False, e=80):
    cams = ['bartlett', 'delta_junction', 'glees', 'hyytiala', 'kenttarova', 'lacclair', 'marcell', 'old_jack_pine',
            'oregon', 'queens', 'sodankyla', 'tammela', 'torgnon', 'underc', 'underhill', 'varrio', 'willowcreek', 'wslcreek']
    # cams = ['oregon']

    landsat_folder = '../scratch/data/landsat/'
    landsat_filepaths = sorted([
        os.path.join(landsat_folder, f) for f in os.listdir(landsat_folder)
        if os.path.isfile(os.path.join(landsat_folder, f))
    ])

    filepath = landsat_filepaths[i]
    print(filepath)
    cam = [c for c in cams if c in filepath][0]
    landsat = [l for l in ['Landsat7', 'Landsat8'] if l in filepath][0]

    # Extract FSC number from filename (e.g. 'bartlett80_')
    match = re.search(rf"{cam}(\d+)_", os.path.basename(filepath))
    fsc_value = int(match.group(1)) if match else None

    landsat_masking_folder = '../scratch/data/landsat_masking/'
    corine_fp, elev_fp = find_masks(landsat_masking_folder, cam)
    print(f"Processing i={i}: {filepath}")
    
    ds = combine_tifs(filepath, corine_fp, elev_fp)
    ds = apply_valid_mask(ds, e)

    bgrns = [1, 2, 3, 4, 5] if landsat == 'Landsat7' else [2, 3, 4, 5, 6]
    red, green, blue, nir, swir = [ds['landsat'].isel(band=b - 1) for b in bgrns]

    ndsi = compute_ndsi(green, swir)
    ndvi = compute_ndvi(red, nir)

    dozier = compute_dozier(ds, ndsi, nir)
    klein = compute_klein(ndsi, ndvi, green, nir)
    fsc = compute_salomonson(ndsi)
    if apply_filter:
        dozier = dozier.where(ds['valid_mask'])
        klein = klein.where(ds['valid_mask'])
        fsc = fsc.where(ds['valid_mask'])
    
    ds['Dozier'] = dozier.assign_attrs(name="Dozier")
    ds['Klein'] = klein.assign_attrs(name="Klein")
    ds['Salomonson'] = fsc.assign_attrs(name="Salomonson")

    if plot_rgb_image:
        plot_rgb(ds, landsat, cam, filtered=False)

    return ds, fsc_value, cam

def subcell_stats(ds, var='Salomonson', apply_filter=True, extent=4):
    """
    Compute mean value and valid_mask fraction in fixed 8x8 grid over dataset in meters.

    Args:
        ds (xr.Dataset): Dataset with 2D variable `var` and 'valid_mask'
        var (str): Variable to average (default: 'Salomonson')
        apply_filter (bool): If True, use 'valid_mask' to filter pixels before averaging

    Returns:
        pd.DataFrame with columns: ['cell_y', 'cell_x', 'mean', 'filtered_fraction']
    """
    data = ds[var]
    mask = ds['valid_mask']

    # Get coordinates
    y_vals = data['y'].values
    x_vals = data['x'].values
    yy, xx = np.meshgrid(y_vals, x_vals, indexing="ij")

    flat_y = yy.ravel()
    flat_x = xx.ravel()
    flat_data = data.values.ravel()
    flat_mask = mask.values.ravel()

    # Get bounding box and define 8 even bins in each direction
    y_min, y_max = y_vals.min(), y_vals.max()
    x_min, x_max = x_vals.min(), x_vals.max()

    y_edges = np.linspace(y_min, y_max, 9)  # 8 bins = 9 edges
    x_edges = np.linspace(x_min, x_max, 9)

    # Digitize assigns bin 1–8; subtract 1 → 0–7 for indexing
    cell_y = np.digitize(flat_y, y_edges) - 1
    cell_x = np.digitize(flat_x, x_edges) - 1

    # Keep only points within bin ranges
    valid = (cell_y >= 4 - extent) & (cell_y < 4 + extent) & (cell_x >= 4 - extent) & (cell_x < 4 + extent)

    df = pd.DataFrame({
        'cell_y': cell_y[valid],
        'cell_x': cell_x[valid],
        'data': flat_data[valid],
        'mask': flat_mask[valid]
    })

    # if apply_filter:
    #     df = df[df['mask'] == True]

    grouped = df.groupby(['cell_y', 'cell_x'], as_index=False).agg(
        mean=('data', 'mean'),
        filtered_fraction=('mask', lambda v: np.count_nonzero(v == True) / np.count_nonzero(~np.isnan(v)))
        if apply_filter else
        ('mask', lambda v: 1.0)  # If not filtering, assume full coverage
    )

    return grouped

N = len([f for f in os.listdir('../scratch/data/landsat/') if os.path.isfile(os.path.join('../scratch/data/landsat/', f))])
print(N)

merged_results = []

for i in range(N):  # or range(1) for testing
    # if (i >= 145 and i < 165) or (i >= 0 and i <= 5):
    if i < -1:
        ds, fsc, cam = process_scene(i=i, apply_filter=True, plot_rgb_image=True, e=100)
        
        fig, axes = plt.subplots(1, 1, figsize=(5, 5))  # 1 row, 3 columns
        
        ds.Dozier.plot(ax=axes)
        axes.set_title("Dozier")
        
        # ds.Klein.plot(ax=axes[1])
        # axes[1].set_title("Klein")
        
        # ds.Salomonson.plot(ax=axes[2])
        # axes[2].set_title("Salomonson")
        
        plt.tight_layout()
        plt.show()
    else:
        ds, fsc, cam = process_scene(i=i, apply_filter=True, plot_rgb_image=False, e=100)
    # if cam != 'oregon':
    #     continue
    
    print(fsc)
    fsc_norm = fsc / 100

    # Get results for all three metrics
    dozier = subcell_stats(ds, var='Dozier', apply_filter=True, extent=4)
    klein = subcell_stats(ds, var='Klein', apply_filter=True, extent=4)
    salo  = subcell_stats(ds, var='Salomonson', apply_filter=True, extent=4)

    # Filter by valid fraction
    dozier = dozier.where(dozier['filtered_fraction'] >= 0.2).dropna()
    klein  = klein.where(klein['filtered_fraction'] >= 0.2).dropna()
    salo   = salo.where(salo['filtered_fraction'] >= 0.2).dropna()

    # Merge on cell_x and cell_y
    merged = dozier[['cell_y', 'cell_x', 'filtered_fraction', 'mean']].rename(columns={'mean': 'Dozier'}) \
        .merge(klein[['cell_y', 'cell_x', 'mean']].rename(columns={'mean': 'Klein'}), on=['cell_y', 'cell_x']) \
        .merge(salo[['cell_y', 'cell_x', 'mean']].rename(columns={'mean': 'Salomonson'}), on=['cell_y', 'cell_x'])

    # Add fsc column
    merged['fsc'] = fsc_norm
    merged['cam'] = cam
    merged_results.append(merged)

# Final DataFrame
final_df = pd.concat(merged_results, ignore_index=True)

print(final_df)
# Out:
# 287
# ../scratch/data/landsat/Landsat7_bartlett80_clouds4_LE07_L2SP_013029_20220323_20220419_02_T1.tif
# Processing i=0: ../scratch/data/landsat/Landsat7_bartlett80_clouds4_LE07_L2SP_013029_20220323_20220419_02_T1.tif
# 80
# ../scratch/data/landsat/Landsat7_hyytiala95_clouds6_LE07_L2SP_189017_20190417_20200827_02_T1.tif
# Processing i=1: ../scratch/data/landsat/Landsat7_hyytiala95_clouds6_LE07_L2SP_189017_20190417_20200827_02_T1.tif
# 95
# ../scratch/data/landsat/Landsat7_kenttarova98_clouds0_LE07_L2SP_192012_20200526_20200820_02_T1.tif
# Processing i=2: ../scratch/data/landsat/Landsat7_kenttarova98_clouds0_LE07_L2SP_192012_20200526_20200820_02_T1.tif
# 98
# ../scratch/data/landsat/Landsat7_lacclair90_clouds0_LE07_L2SP_013027_20190502_20200825_02_T1.tif
# Processing i=3: ../scratch/data/landsat/Landsat7_lacclair90_clouds0_LE07_L2SP_013027_20190502_20200825_02_T1.tif
# 90
# ../scratch/data/landsat/Landsat7_marcell100_clouds12_LE07_L2SP_028027_20200326_20200822_02_T1.tif
# Processing i=4: ../scratch/data/landsat/Landsat7_marcell100_clouds12_LE07_L2SP_028027_20200326_20200822_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat7_marcell60_clouds0_LE07_L2SP_027027_20210306_20210401_02_T1.tif
# Processing i=5: ../scratch/data/landsat/Landsat7_marcell60_clouds0_LE07_L2SP_027027_20210306_20210401_02_T1.tif
# 60
# ../scratch/data/landsat/Landsat7_marcell70_clouds0_LE07_L2SP_027027_20200404_20200822_02_T1.tif
# Processing i=6: ../scratch/data/landsat/Landsat7_marcell70_clouds0_LE07_L2SP_027027_20200404_20200822_02_T1.tif
# 70
# ../scratch/data/landsat/Landsat7_marcell80_clouds0_LE07_L2SP_028027_20210313_20210410_02_T1.tif
# Processing i=7: ../scratch/data/landsat/Landsat7_marcell80_clouds0_LE07_L2SP_028027_20210313_20210410_02_T1.tif
# 80
# ../scratch/data/landsat/Landsat7_old_jack_pine44_clouds6_LE07_L2SP_037022_20210413_20210509_02_T1.tif
# Processing i=8: ../scratch/data/landsat/Landsat7_old_jack_pine44_clouds6_LE07_L2SP_037022_20210413_20210509_02_T1.tif
# 44
# ../scratch/data/landsat/Landsat7_oregon39_clouds23_LE07_L2SP_045029_20191228_20200823_02_T1.tif
# Processing i=9: ../scratch/data/landsat/Landsat7_oregon39_clouds23_LE07_L2SP_045029_20191228_20200823_02_T1.tif
# 39
# ../scratch/data/landsat/Landsat7_oregon42_clouds18_LE07_L2SP_045029_20190331_20200827_02_T1.tif
# Processing i=10: ../scratch/data/landsat/Landsat7_oregon42_clouds18_LE07_L2SP_045029_20190331_20200827_02_T1.tif
# 42
# ../scratch/data/landsat/Landsat7_oregon52_clouds17_LE07_L2SP_045029_20220203_20220301_02_T1.tif
# Processing i=11: ../scratch/data/landsat/Landsat7_oregon52_clouds17_LE07_L2SP_045029_20220203_20220301_02_T1.tif
# 52
# ../scratch/data/landsat/Landsat7_sodankyla35_clouds15_LE07_L2SP_192013_20200526_20200820_02_T1.tif
# Processing i=12: ../scratch/data/landsat/Landsat7_sodankyla35_clouds15_LE07_L2SP_192013_20200526_20200820_02_T1.tif
# 35
# ../scratch/data/landsat/Landsat7_sodankyla35_clouds21_LE07_L2SP_190013_20190510_20200825_02_T1.tif
# Processing i=13: ../scratch/data/landsat/Landsat7_sodankyla35_clouds21_LE07_L2SP_190013_20190510_20200825_02_T1.tif
# 35
# ../scratch/data/landsat/Landsat7_torgnon40_clouds24_LE07_L2SP_195028_20190513_20200825_02_T1.tif
# Processing i=14: ../scratch/data/landsat/Landsat7_torgnon40_clouds24_LE07_L2SP_195028_20190513_20200825_02_T1.tif
# 40
# ../scratch/data/landsat/Landsat7_torgnon70_clouds25_LE07_L2SP_194028_20190506_20200825_02_T1.tif
# Processing i=15: ../scratch/data/landsat/Landsat7_torgnon70_clouds25_LE07_L2SP_194028_20190506_20200825_02_T1.tif
# 70
# ../scratch/data/landsat/Landsat7_torgnon83_clouds4_LE07_L2SP_195028_20220302_20220328_02_T1.tif
# Processing i=16: ../scratch/data/landsat/Landsat7_torgnon83_clouds4_LE07_L2SP_195028_20220302_20220328_02_T1.tif
# 83
# ../scratch/data/landsat/Landsat7_torgnon84_clouds42_LE07_L2SP_195028_20200413_20200820_02_T1.tif
# Processing i=17: ../scratch/data/landsat/Landsat7_torgnon84_clouds42_LE07_L2SP_195028_20200413_20200820_02_T1.tif
# 84
# ../scratch/data/landsat/Landsat7_torgnon90_clouds17_LE07_L2SP_195028_20190326_20200827_02_T1.tif
# Processing i=18: ../scratch/data/landsat/Landsat7_torgnon90_clouds17_LE07_L2SP_195028_20190326_20200827_02_T1.tif
# 90
# ../scratch/data/landsat/Landsat7_torgnon96_clouds11_LE07_L2SP_194028_20220223_20220321_02_T1.tif
# Processing i=19: ../scratch/data/landsat/Landsat7_torgnon96_clouds11_LE07_L2SP_194028_20220223_20220321_02_T1.tif
# 96
# ../scratch/data/landsat/Landsat7_underc4_clouds2_LE07_L2SP_024028_20210402_20210428_02_T1.tif
# Processing i=20: ../scratch/data/landsat/Landsat7_underc4_clouds2_LE07_L2SP_024028_20210402_20210428_02_T1.tif
# 4
# ../scratch/data/landsat/Landsat7_underc60_clouds0_LE07_L2SP_025028_20190420_20200825_02_T1.tif
# Processing i=21: ../scratch/data/landsat/Landsat7_underc60_clouds0_LE07_L2SP_025028_20190420_20200825_02_T1.tif
# 60
# ../scratch/data/landsat/Landsat7_underhill75_clouds1_LE07_L2SP_013029_20210320_20210415_02_T1.tif
# Processing i=22: ../scratch/data/landsat/Landsat7_underhill75_clouds1_LE07_L2SP_013029_20210320_20210415_02_T1.tif
# 75
# ../scratch/data/landsat/Landsat7_underhill97_clouds26_LE07_L2SP_014029_20200308_20200822_02_T1.tif
# Processing i=23: ../scratch/data/landsat/Landsat7_underhill97_clouds26_LE07_L2SP_014029_20200308_20200822_02_T1.tif
# 97
# ../scratch/data/landsat/Landsat7_willowcreek85_clouds0_LE07_L2SP_025028_20190420_20200825_02_T1.tif
# Processing i=24: ../scratch/data/landsat/Landsat7_willowcreek85_clouds0_LE07_L2SP_025028_20190420_20200825_02_T1.tif
# 85
# ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_012029_20200130_20200823_02_T1.tif
# Processing i=25: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_012029_20200130_20200823_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_012029_20200926_20201006_02_T1.tif
# Processing i=26: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_012029_20200926_20201006_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_012029_20210524_20210529_02_T1.tif
# Processing i=27: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_012029_20210524_20210529_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_012030_20200521_20200820_02_T1.tif
# Processing i=28: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_012030_20200521_20200820_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_012030_20201129_20210316_02_T1.tif
# Processing i=29: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_012030_20201129_20210316_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_013029_20190713_20200827_02_T1.tif
# Processing i=30: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_013029_20190713_20200827_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_013029_20210920_20210925_02_T1.tif
# Processing i=31: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_013029_20210920_20210925_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_013029_20211107_20211117_02_T1.tif
# Processing i=32: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_013029_20211107_20211117_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_013029_20220518_20220525_02_T1.tif
# Processing i=33: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_013029_20220518_20220525_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_bartlett100_LC08_L2SP_012029_20190228_20200829_02_T1.tif
# Processing i=34: ../scratch/data/landsat/Landsat8_bartlett100_LC08_L2SP_012029_20190228_20200829_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_bartlett100_LC08_L2SP_012029_20200215_20200823_02_T1.tif
# Processing i=35: ../scratch/data/landsat/Landsat8_bartlett100_LC08_L2SP_012029_20200215_20200823_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_bartlett100_LC08_L2SP_012030_20210217_20210302_02_T1.tif
# Processing i=36: ../scratch/data/landsat/Landsat8_bartlett100_LC08_L2SP_012030_20210217_20210302_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_bartlett100_LC08_L2SP_013029_20190102_20200830_02_T1.tif
# Processing i=37: ../scratch/data/landsat/Landsat8_bartlett100_LC08_L2SP_013029_20190102_20200830_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_bartlett100_LC08_L2SP_013029_20220126_20220204_02_T1.tif
# Processing i=38: ../scratch/data/landsat/Landsat8_bartlett100_LC08_L2SP_013029_20220126_20220204_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_bartlett5_clouds1_LC08_L2SP_012030_20200419_20200822_02_T1.tif
# Processing i=39: ../scratch/data/landsat/Landsat8_bartlett5_clouds1_LC08_L2SP_012030_20200419_20200822_02_T1.tif
# 5
# ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_067015_20190723_20200827_02_T1.tif
# Processing i=40: ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_067015_20190723_20200827_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_067015_20210712_20210721_02_T1.tif
# Processing i=41: ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_067015_20210712_20210721_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_067015_20220528_20220603_02_T1.tif
# Processing i=42: ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_067015_20220528_20220603_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_067015_20220629_20220707_02_T1.tif
# Processing i=43: ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_067015_20220629_20220707_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_068015_20200817_20200920_02_T1.tif
# Processing i=44: ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_068015_20200817_20200920_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_068015_20210719_20210729_02_T1.tif
# Processing i=45: ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_068015_20210719_20210729_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_068015_20220706_20220722_02_T1.tif
# Processing i=46: ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_068015_20220706_20220722_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_delta_junction100_LC08_L2SP_067015_20210322_20210402_02_T1.tif
# Processing i=47: ../scratch/data/landsat/Landsat8_delta_junction100_LC08_L2SP_067015_20210322_20210402_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_delta_junction100_LC08_L2SP_068015_20210313_20210328_02_T1.tif
# Processing i=48: ../scratch/data/landsat/Landsat8_delta_junction100_LC08_L2SP_068015_20210313_20210328_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_delta_junction100_LC08_L2SP_068015_20220316_20220322_02_T1.tif
# Processing i=49: ../scratch/data/landsat/Landsat8_delta_junction100_LC08_L2SP_068015_20220316_20220322_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_delta_junction71_clouds16_LE07_L2SP_067015_20200428_20200820_02_T1.tif
# Processing i=50: ../scratch/data/landsat/Landsat8_delta_junction71_clouds16_LE07_L2SP_067015_20200428_20200820_02_T1.tif
# 71
# ../scratch/data/landsat/Landsat8_delta_junction79_clouds0_LC08_L2SP_068015_20200427_20200822_02_T1.tif
# Processing i=51: ../scratch/data/landsat/Landsat8_delta_junction79_clouds0_LC08_L2SP_068015_20200427_20200822_02_T1.tif
# 79
# ../scratch/data/landsat/Landsat8_delta_junction90_clouds15_LC08_L2SP_067015_20210423_20210501_02_T1.tif
# Processing i=52: ../scratch/data/landsat/Landsat8_delta_junction90_clouds15_LC08_L2SP_067015_20210423_20210501_02_T1.tif
# 90
# ../scratch/data/landsat/Landsat8_delta_junction90_clouds1_LE07_L2SP_066015_20210424_20210520_02_T1.tif
# Processing i=53: ../scratch/data/landsat/Landsat8_delta_junction90_clouds1_LE07_L2SP_066015_20210424_20210520_02_T1.tif
# 90
# ../scratch/data/landsat/Landsat8_delta_junction93_clouds57_LC08_L2SP_068015_20220503_20220511_02_T1.tif
# Processing i=54: ../scratch/data/landsat/Landsat8_delta_junction93_clouds57_LC08_L2SP_068015_20220503_20220511_02_T1.tif
# 93
# ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_034031_20190902_20200826_02_T1.tif
# Processing i=55: ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_034031_20190902_20200826_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_034031_20191004_20200825_02_T1.tif
# Processing i=56: ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_034031_20191004_20200825_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_034031_20200920_20201006_02_T1.tif
# Processing i=57: ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_034031_20200920_20201006_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_034031_20201006_20201016_02_T1.tif
# Processing i=58: ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_034031_20201006_20201016_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_034031_20210907_20210916_02_T1.tif
# Processing i=59: ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_034031_20210907_20210916_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_035031_20200810_20200918_02_T1.tif
# Processing i=60: ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_035031_20200810_20200918_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_035031_20210728_20210804_02_T1.tif
# Processing i=61: ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_035031_20210728_20210804_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20190105_20200830_02_T1.tif
# Processing i=62: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20190105_20200830_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20191105_20200825_02_T1.tif
# Processing i=63: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20191105_20200825_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20201209_20210313_02_T1.tif
# Processing i=64: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20201209_20210313_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20210110_20210307_02_T1.tif
# Processing i=65: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20210110_20210307_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20210331_20210409_02_T1.tif
# Processing i=66: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20210331_20210409_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20220129_20220204_02_T1.tif
# Processing i=67: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20220129_20220204_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20190112_20200830_02_T1.tif
# Processing i=68: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20190112_20200830_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20190317_20200829_02_T1.tif
# Processing i=69: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20190317_20200829_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20190504_20200829_02_T1.tif
# Processing i=70: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20190504_20200829_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20191230_20200824_02_T1.tif
# Processing i=71: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20191230_20200824_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20200115_20200823_02_T1.tif
# Processing i=72: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20200115_20200823_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20211203_20211209_02_T1.tif
# Processing i=73: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20211203_20211209_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20220120_20220127_02_T1.tif
# Processing i=74: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20220120_20220127_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_glees10_clouds2_LC08_L2SP_035031_20220613_20220617_02_T1.tif
# Processing i=75: ../scratch/data/landsat/Landsat8_glees10_clouds2_LC08_L2SP_035031_20220613_20220617_02_T1.tif
# 10
# ../scratch/data/landsat/Landsat8_glees83_clouds24_LC08_L2SP_034031_20220606_20220610_02_T1.tif
# Processing i=76: ../scratch/data/landsat/Landsat8_glees83_clouds24_LC08_L2SP_034031_20220606_20220610_02_T1.tif
# 83
# ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_189017_20190628_20200827_02_T1.tif
# Processing i=77: ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_189017_20190628_20200827_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_189017_20200614_20200823_02_T1.tif
# Processing i=78: ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_189017_20200614_20200823_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_190017_20190518_20200828_02_T1.tif
# Processing i=79: ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_190017_20190518_20200828_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_190017_20200808_20200917_02_T1.tif
# Processing i=80: ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_190017_20200808_20200917_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_190017_20220814_20220824_02_T1.tif
# Processing i=81: ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_190017_20220814_20220824_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_hyytiala100_LC08_L2SP_189017_20220228_20220309_02_T1.tif
# Processing i=82: ../scratch/data/landsat/Landsat8_hyytiala100_LC08_L2SP_189017_20220228_20220309_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_hyytiala100_LC08_L2SP_190017_20220323_20220330_02_T1.tif
# Processing i=83: ../scratch/data/landsat/Landsat8_hyytiala100_LC08_L2SP_190017_20220323_20220330_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_hyytiala55_clouds0_LE07_L2SP_188017_20210415_20210511_02_T1.tif
# Processing i=84: ../scratch/data/landsat/Landsat8_hyytiala55_clouds0_LE07_L2SP_188017_20210415_20210511_02_T1.tif
# 55
# ../scratch/data/landsat/Landsat8_hyytiala97_clouds1_LC08_L2SP_190017_20190416_20200828_02_T1.tif
# Processing i=85: ../scratch/data/landsat/Landsat8_hyytiala97_clouds1_LC08_L2SP_190017_20190416_20200828_02_T1.tif
# 97
# ../scratch/data/landsat/Landsat8_kenttarova0_LC08_L2SP_192012_20210606_20210615_02_T1.tif
# Processing i=86: ../scratch/data/landsat/Landsat8_kenttarova0_LC08_L2SP_192012_20210606_20210615_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_kenttarova0_LC08_L2SP_192012_20210910_20210916_02_T1.tif
# Processing i=87: ../scratch/data/landsat/Landsat8_kenttarova0_LC08_L2SP_192012_20210910_20210916_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_kenttarova0_LC08_L2SP_194012_20190615_20200828_02_T1.tif
# Processing i=88: ../scratch/data/landsat/Landsat8_kenttarova0_LC08_L2SP_194012_20190615_20200828_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_192012_20220321_20220329_02_T1.tif
# Processing i=89: ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_192012_20220321_20220329_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_193012_20190304_20200829_02_T1.tif
# Processing i=90: ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_193012_20190304_20200829_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_193012_20190405_20200829_02_T1.tif
# Processing i=91: ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_193012_20190405_20200829_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_193012_20210309_20210317_02_T1.tif
# Processing i=92: ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_193012_20210309_20210317_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_194012_20190311_20200829_02_T1.tif
# Processing i=93: ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_194012_20190311_20200829_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_194012_20210417_20210424_02_T1.tif
# Processing i=94: ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_194012_20210417_20210424_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_lacclair0_LC08_L2SP_013027_20200917_20201005_02_T1.tif
# Processing i=95: ../scratch/data/landsat/Landsat8_lacclair0_LC08_L2SP_013027_20200917_20201005_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_lacclair0_LC08_L2SP_013027_20210904_20210910_02_T1.tif
# Processing i=96: ../scratch/data/landsat/Landsat8_lacclair0_LC08_L2SP_013027_20210904_20210910_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_lacclair0_LC08_L2SP_014027_20190704_20200827_02_T1.tif
# Processing i=97: ../scratch/data/landsat/Landsat8_lacclair0_LC08_L2SP_014027_20190704_20200827_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_lacclair0_LC08_L2SP_014027_20200519_20200820_02_T1.tif
# Processing i=98: ../scratch/data/landsat/Landsat8_lacclair0_LC08_L2SP_014027_20200519_20200820_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_lacclair0_LC08_L2SP_014027_20200706_20200913_02_T1.tif
# Processing i=99: ../scratch/data/landsat/Landsat8_lacclair0_LC08_L2SP_014027_20200706_20200913_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_013027_20190102_20200830_02_T1.tif
# Processing i=100: ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_013027_20190102_20200830_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_013027_20190219_20200829_02_T1.tif
# Processing i=101: ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_013027_20190219_20200829_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_013027_20200121_20200823_02_T1.tif
# Processing i=102: ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_013027_20200121_20200823_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_013027_20210208_20210302_02_T1.tif
# Processing i=103: ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_013027_20210208_20210302_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_014027_20200316_20200822_02_T1.tif
# Processing i=104: ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_014027_20200316_20200822_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_014027_20210319_20210328_02_T1.tif
# Processing i=105: ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_014027_20210319_20210328_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_lacclair100_clouds7_LC08_L2SP_014027_20220423_20220428_02_T1.tif
# Processing i=106: ../scratch/data/landsat/Landsat8_lacclair100_clouds7_LC08_L2SP_014027_20220423_20220428_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_lacclair10_clouds0_LC08_L2SP_013027_20220502_20220511_02_T1.tif
# Processing i=107: ../scratch/data/landsat/Landsat8_lacclair10_clouds0_LC08_L2SP_013027_20220502_20220511_02_T1.tif
# 10
# ../scratch/data/landsat/Landsat8_lacclair97_clouds15_LC08_L2SP_014027_20210404_20210409_02_T1.tif
# Processing i=108: ../scratch/data/landsat/Landsat8_lacclair97_clouds15_LC08_L2SP_014027_20210404_20210409_02_T1.tif
# 97
# ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20190528_20200828_02_T1.tif
# Processing i=109: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20190528_20200828_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20190613_20200828_02_T1.tif
# Processing i=110: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20190613_20200828_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20190731_20200827_02_T1.tif
# Processing i=111: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20190731_20200827_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20200717_20200911_02_T1.tif
# Processing i=112: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20200717_20200911_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20210517_20210525_02_T1.tif
# Processing i=113: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20210517_20210525_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20210922_20210930_02_T1.tif
# Processing i=114: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20210922_20210930_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20211109_20211117_02_T1.tif
# Processing i=115: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20211109_20211117_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_028027_20190706_20200827_02_T1.tif
# Processing i=116: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_028027_20190706_20200827_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_028027_20200910_20200919_02_T1.tif
# Processing i=117: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_028027_20200910_20200919_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_028027_20201012_20201105_02_T1.tif
# Processing i=118: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_028027_20201012_20201105_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_028027_20210422_20210430_02_T1.tif
# Processing i=119: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_028027_20210422_20210430_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20190120_20200829_02_T1.tif
# Processing i=120: ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20190120_20200829_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20200107_20200823_02_T1.tif
# Processing i=121: ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20200107_20200823_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20201224_20210310_02_T1.tif
# Processing i=122: ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20201224_20210310_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20210210_20210302_02_T1.tif
# Processing i=123: ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20210210_20210302_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20211211_20211216_02_T1.tif
# Processing i=124: ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20211211_20211216_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_marcell50_clouds54_LC08_L2SP_027027_20210314_20210328_02_T1.tif
# Processing i=125: ../scratch/data/landsat/Landsat8_marcell50_clouds54_LC08_L2SP_027027_20210314_20210328_02_T1.tif
# 50
# ../scratch/data/landsat/Landsat8_marcell70_clouds1_LC08_L2SP_028027_20210305_20210312_02_T1.tif
# Processing i=126: ../scratch/data/landsat/Landsat8_marcell70_clouds1_LC08_L2SP_028027_20210305_20210312_02_T1.tif
# 70
# ../scratch/data/landsat/Landsat8_marcell90_clouds6_LC08_L2SP_028027_20220409_20220419_02_T1.tif
# Processing i=127: ../scratch/data/landsat/Landsat8_marcell90_clouds6_LC08_L2SP_028027_20220409_20220419_02_T1.tif
# 90
# ../scratch/data/landsat/Landsat8_marcell97_clouds0_LC08_L2SP_027027_20190325_20200829_02_T1.tif
# Processing i=128: ../scratch/data/landsat/Landsat8_marcell97_clouds0_LC08_L2SP_027027_20190325_20200829_02_T1.tif
# 97
# ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20200817_20200920_02_T1.tif
# Processing i=129: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20200817_20200920_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20200918_20201005_02_T1.tif
# Processing i=130: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20200918_20201005_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20211007_20211018_02_T1.tif
# Processing i=131: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20211007_20211018_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20220604_20220610_02_T1.tif
# Processing i=132: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20220604_20220610_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20221010_20221020_02_T1.tif
# Processing i=133: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20221010_20221020_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036023_20190527_20200828_02_T1.tif
# Processing i=134: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036023_20190527_20200828_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20190518_20200828_02_T1.tif
# Processing i=135: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20190518_20200828_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20190822_20200827_02_T1.tif
# Processing i=136: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20190822_20200827_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20210507_20210517_02_T1.tif
# Processing i=137: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20210507_20210517_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20210710_20210720_02_T1.tif
# Processing i=138: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20210710_20210720_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20210928_20211012_02_T1.tif
# Processing i=139: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20210928_20211012_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20220713_20220722_02_T1.tif
# Processing i=140: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20220713_20220722_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20220915_20220922_02_T1.tif
# Processing i=141: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20220915_20220922_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20190324_20200829_02_T1.tif
# Processing i=142: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20190324_20200829_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20200310_20200822_02_T1.tif
# Processing i=143: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20200310_20200822_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20210124_20210305_02_T1.tif
# Processing i=144: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20210124_20210305_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20210313_20210328_02_T1.tif
# Processing i=145: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20210313_20210328_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20220212_20220222_02_T1.tif
# Processing i=146: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20220212_20220222_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036023_20190308_20200829_02_T1.tif
# Processing i=147: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036023_20190308_20200829_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036023_20200223_20200822_02_T1.tif
# Processing i=148: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036023_20200223_20200822_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036023_20200326_20200822_02_T1.tif
# Processing i=149: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036023_20200326_20200822_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_037022_20210216_20210301_02_T1.tif
# Processing i=150: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_037022_20210216_20210301_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_037022_20220203_20220212_02_T1.tif
# Processing i=151: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_037022_20220203_20220212_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_037022_20220424_20220503_02_T1.tif
# Processing i=152: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_037022_20220424_20220503_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_old_jack_pine35_clouds14_LC08_L2SP_036022_20210414_20210423_02_T1.tif
# Processing i=153: ../scratch/data/landsat/Landsat8_old_jack_pine35_clouds14_LC08_L2SP_036022_20210414_20210423_02_T1.tif
# 35
# ../scratch/data/landsat/Landsat8_old_jack_pine98_clouds4_LC08_L2SP_037022_20220424_20220503_02_T1.tif
# Processing i=154: ../scratch/data/landsat/Landsat8_old_jack_pine98_clouds4_LC08_L2SP_037022_20220424_20220503_02_T1.tif
# 98
# ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20190424_20200828_02_T1.tif
# Processing i=155: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20190424_20200828_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20190510_20200829_02_T1.tif
# Processing i=156: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20190510_20200829_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20190611_20200828_02_T1.tif
# Processing i=157: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20190611_20200828_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20190729_20200827_02_T1.tif
# Processing i=158: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20190729_20200827_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20191102_20200825_02_T1.tif
# Processing i=159: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20191102_20200825_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20201120_20210315_02_T1.tif
# Processing i=160: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20201120_20210315_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20210616_20210622_02_T1.tif
# Processing i=161: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20210616_20210622_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20221110_20221121_02_T1.tif
# Processing i=162: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20221110_20221121_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_oregon100_LC08_L2SP_045029_20210123_20210305_02_T1.tif
# Processing i=163: ../scratch/data/landsat/Landsat8_oregon100_LC08_L2SP_045029_20210123_20210305_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_oregon100_clouds1_LC08_L2SP_045029_20210123_20210305_02_T1.tif
# Processing i=164: ../scratch/data/landsat/Landsat8_oregon100_clouds1_LC08_L2SP_045029_20210123_20210305_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_oregon30_clouds1_LC08_L2SP_045029_20220211_20220222_02_T1.tif
# Processing i=165: ../scratch/data/landsat/Landsat8_oregon30_clouds1_LC08_L2SP_045029_20220211_20220222_02_T1.tif
# 30
# ../scratch/data/landsat/Landsat8_oregon55_clouds30_LC08_L2SP_045029_20220126_20220204_02_T1.tif
# Processing i=166: ../scratch/data/landsat/Landsat8_oregon55_clouds30_LC08_L2SP_045029_20220126_20220204_02_T1.tif
# 55
# ../scratch/data/landsat/Landsat8_oregon81_clouds2_LC08_L2SP_045029_20210224_20210304_02_T1.tif
# Processing i=167: ../scratch/data/landsat/Landsat8_oregon81_clouds2_LC08_L2SP_045029_20210224_20210304_02_T1.tif
# 81
# ../scratch/data/landsat/Landsat8_queens0_LC08_L2SP_016029_20190413_20200829_02_T1.tif
# Processing i=168: ../scratch/data/landsat/Landsat8_queens0_LC08_L2SP_016029_20190413_20200829_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_queens0_LC08_L2SP_016029_20200618_20200823_02_T1.tif
# Processing i=169: ../scratch/data/landsat/Landsat8_queens0_LC08_L2SP_016029_20200618_20200823_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_queens0_LC08_L2SP_016029_20200704_20200913_02_T1.tif
# Processing i=170: ../scratch/data/landsat/Landsat8_queens0_LC08_L2SP_016029_20200704_20200913_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_queens0_LC08_L2SP_016029_20210402_20210409_02_T1.tif
# Processing i=171: ../scratch/data/landsat/Landsat8_queens0_LC08_L2SP_016029_20210402_20210409_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_queens0_LC08_L2SP_016029_20211214_20211223_02_T1.tif
# Processing i=172: ../scratch/data/landsat/Landsat8_queens0_LC08_L2SP_016029_20211214_20211223_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_queens100_LC08_L2SP_016029_20220115_20220123_02_T1.tif
# Processing i=173: ../scratch/data/landsat/Landsat8_queens100_LC08_L2SP_016029_20220115_20220123_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_sodankyla0_LC08_L2SP_190013_20200621_20200823_02_T1.tif
# Processing i=174: ../scratch/data/landsat/Landsat8_sodankyla0_LC08_L2SP_190013_20200621_20200823_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_sodankyla0_LC08_L2SP_191013_20190712_20200827_02_T1.tif
# Processing i=175: ../scratch/data/landsat/Landsat8_sodankyla0_LC08_L2SP_191013_20190712_20200827_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_sodankyla0_LC08_L2SP_191013_20200612_20200823_02_T1.tif
# Processing i=176: ../scratch/data/landsat/Landsat8_sodankyla0_LC08_L2SP_191013_20200612_20200823_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_sodankyla0_LC08_L2SP_191013_20200628_20200823_02_T1.tif
# Processing i=177: ../scratch/data/landsat/Landsat8_sodankyla0_LC08_L2SP_191013_20200628_20200823_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_sodankyla0_LC08_L2SP_191013_20210530_20210608_02_T1.tif
# Processing i=178: ../scratch/data/landsat/Landsat8_sodankyla0_LC08_L2SP_191013_20210530_20210608_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_sodankyla0_LC08_L2SP_192012_20190804_20200827_02_T1.tif
# Processing i=179: ../scratch/data/landsat/Landsat8_sodankyla0_LC08_L2SP_192012_20190804_20200827_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_sodankyla0_LC08_L2SP_192013_20190804_20200827_02_T1.tif
# Processing i=180: ../scratch/data/landsat/Landsat8_sodankyla0_LC08_L2SP_192013_20190804_20200827_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_sodankyla100_LC08_L2SP_191013_20210311_20210317_02_T1.tif
# Processing i=181: ../scratch/data/landsat/Landsat8_sodankyla100_LC08_L2SP_191013_20210311_20210317_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_sodankyla100_LC08_L2SP_192013_20210318_20210328_02_T1.tif
# Processing i=182: ../scratch/data/landsat/Landsat8_sodankyla100_LC08_L2SP_192013_20210318_20210328_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_sodankyla88_clouds56_LC08_L1TP_190013_20220424_20220428_02_T1.tif
# Processing i=183: ../scratch/data/landsat/Landsat8_sodankyla88_clouds56_LC08_L1TP_190013_20220424_20220428_02_T1.tif
# 88
# ../scratch/data/landsat/Landsat8_sodankyla88_clouds56_LC08_L2SP_190013_20220424_20220428_02_T1.tif
# Processing i=184: ../scratch/data/landsat/Landsat8_sodankyla88_clouds56_LC08_L2SP_190013_20220424_20220428_02_T1.tif
# 88
# ../scratch/data/landsat/Landsat8_sodankyla93_clouds0_LC08_L1TP_190013_20210421_20210430_02_T1.tif
# Processing i=185: ../scratch/data/landsat/Landsat8_sodankyla93_clouds0_LC08_L1TP_190013_20210421_20210430_02_T1.tif
# 93
# ../scratch/data/landsat/Landsat8_sodankyla93_clouds0_LC08_L2SP_190013_20210421_20210430_02_T1.tif
# Processing i=186: ../scratch/data/landsat/Landsat8_sodankyla93_clouds0_LC08_L2SP_190013_20210421_20210430_02_T1.tif
# 93
# ../scratch/data/landsat/Landsat8_sodankyla96_clouds0_LC08_L1TP_192012_20210419_20210424_02_T1.tif
# Processing i=187: ../scratch/data/landsat/Landsat8_sodankyla96_clouds0_LC08_L1TP_192012_20210419_20210424_02_T1.tif
# 96
# ../scratch/data/landsat/Landsat8_sodankyla96_clouds0_LC08_L2SP_192012_20210419_20210424_02_T1.tif
# Processing i=188: ../scratch/data/landsat/Landsat8_sodankyla96_clouds0_LC08_L2SP_192012_20210419_20210424_02_T1.tif
# 96
# ../scratch/data/landsat/Landsat8_tammela0_LC08_L2SP_188018_20190418_20200828_02_T1.tif
# Processing i=189: ../scratch/data/landsat/Landsat8_tammela0_LC08_L2SP_188018_20190418_20200828_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_tammela0_LC08_L2SP_188018_20200522_20200820_02_T1.tif
# Processing i=190: ../scratch/data/landsat/Landsat8_tammela0_LC08_L2SP_188018_20200522_20200820_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_tammela0_LC08_L2SP_189018_20190628_20200827_02_T1.tif
# Processing i=191: ../scratch/data/landsat/Landsat8_tammela0_LC08_L2SP_189018_20190628_20200827_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_tammela0_LC08_L2SP_189018_20200614_20200823_02_T1.tif
# Processing i=192: ../scratch/data/landsat/Landsat8_tammela0_LC08_L2SP_189018_20200614_20200823_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_tammela0_LC08_L2SP_189018_20210703_20210712_02_T1.tif
# Processing i=193: ../scratch/data/landsat/Landsat8_tammela0_LC08_L2SP_189018_20210703_20210712_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_tammela0_LC08_L2SP_190017_20190518_20200828_02_T1.tif
# Processing i=194: ../scratch/data/landsat/Landsat8_tammela0_LC08_L2SP_190017_20190518_20200828_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_tammela0_LC08_L2SP_190017_20200808_20200917_02_T1.tif
# Processing i=195: ../scratch/data/landsat/Landsat8_tammela0_LC08_L2SP_190017_20200808_20200917_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_tammela100_LC08_L2SP_188018_20190301_20200829_02_T1.tif
# Processing i=196: ../scratch/data/landsat/Landsat8_tammela100_LC08_L2SP_188018_20190301_20200829_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_tammela100_LC08_L2SP_188018_20210218_20210302_02_T1.tif
# Processing i=197: ../scratch/data/landsat/Landsat8_tammela100_LC08_L2SP_188018_20210218_20210302_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_tammela100_LC08_L2SP_188018_20210322_20210401_02_T1.tif
# Processing i=198: ../scratch/data/landsat/Landsat8_tammela100_LC08_L2SP_188018_20210322_20210401_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_tammela100_LC08_L2SP_189018_20220228_20220309_02_T1.tif
# Processing i=199: ../scratch/data/landsat/Landsat8_tammela100_LC08_L2SP_189018_20220228_20220309_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_torgnon0_LC08_L2SP_195028_20200507_20200820_02_T1.tif
# Processing i=200: ../scratch/data/landsat/Landsat8_torgnon0_LC08_L2SP_195028_20200507_20200820_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_torgnon0_LC08_L2SP_195028_20200827_20200906_02_T1.tif
# Processing i=201: ../scratch/data/landsat/Landsat8_torgnon0_LC08_L2SP_195028_20200827_20200906_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_torgnon0_LC08_L2SP_195028_20210814_20210819_02_T1.tif
# Processing i=202: ../scratch/data/landsat/Landsat8_torgnon0_LC08_L2SP_195028_20210814_20210819_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_torgnon0_LC08_L2SP_195028_20211017_20211026_02_T1.tif
# Processing i=203: ../scratch/data/landsat/Landsat8_torgnon0_LC08_L2SP_195028_20211017_20211026_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_torgnon0_LC08_L2SP_195028_20220801_20220806_02_T1.tif
# Processing i=204: ../scratch/data/landsat/Landsat8_torgnon0_LC08_L2SP_195028_20220801_20220806_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_torgnon100_LC08_L2SP_195028_20190129_20200830_02_T1.tif
# Processing i=205: ../scratch/data/landsat/Landsat8_torgnon100_LC08_L2SP_195028_20190129_20200830_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_torgnon100_LC08_L2SP_195028_20190214_20200829_02_T1.tif
# Processing i=206: ../scratch/data/landsat/Landsat8_torgnon100_LC08_L2SP_195028_20190214_20200829_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_torgnon100_LC08_L2SP_195028_20191231_20200824_02_T1.tif
# Processing i=207: ../scratch/data/landsat/Landsat8_torgnon100_LC08_L2SP_195028_20191231_20200824_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_torgnon100_LC08_L2SP_195028_20200116_20200823_02_T1.tif
# Processing i=208: ../scratch/data/landsat/Landsat8_torgnon100_LC08_L2SP_195028_20200116_20200823_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_torgnon100_LC08_L2SP_195028_20200304_20200822_02_T1.tif
# Processing i=209: ../scratch/data/landsat/Landsat8_torgnon100_LC08_L2SP_195028_20200304_20200822_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_torgnon100_LC08_L2SP_195028_20210118_20210306_02_T1.tif
# Processing i=210: ../scratch/data/landsat/Landsat8_torgnon100_LC08_L2SP_195028_20210118_20210306_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_torgnon100_LC08_L2SP_195028_20210323_20210402_02_T1.tif
# Processing i=211: ../scratch/data/landsat/Landsat8_torgnon100_LC08_L2SP_195028_20210323_20210402_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_torgnon100_LC08_L2SP_195028_20220222_20220301_02_T1.tif
# Processing i=212: ../scratch/data/landsat/Landsat8_torgnon100_LC08_L2SP_195028_20220222_20220301_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_torgnon100_clouds14_LC08_L2SP_195028_20220222_20220301_02_T1.tif
# Processing i=213: ../scratch/data/landsat/Landsat8_torgnon100_clouds14_LC08_L2SP_195028_20220222_20220301_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_torgnon40_clouds5_LC08_L2SP_195028_20220326_20220330_02_T1.tif
# Processing i=214: ../scratch/data/landsat/Landsat8_torgnon40_clouds5_LC08_L2SP_195028_20220326_20220330_02_T1.tif
# 40
# ../scratch/data/landsat/Landsat8_torgnon65_clouds3_LC08_L2SP_195028_20220310_20220315_02_T1.tif
# Processing i=215: ../scratch/data/landsat/Landsat8_torgnon65_clouds3_LC08_L2SP_195028_20220310_20220315_02_T1.tif
# 65
# ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_024028_20190507_20200828_02_T1.tif
# Processing i=216: ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_024028_20190507_20200828_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_024028_20190608_20200828_02_T1.tif
# Processing i=217: ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_024028_20190608_20200828_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_024028_20210512_20210524_02_T1.tif
# Processing i=218: ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_024028_20210512_20210524_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_024028_20210901_20210909_02_T1.tif
# Processing i=219: ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_024028_20210901_20210909_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_024028_20221123_20221205_02_T1.tif
# Processing i=220: ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_024028_20221123_20221205_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_025028_20200430_20200820_02_T1.tif
# Processing i=221: ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_025028_20200430_20200820_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_025028_20200617_20200824_02_T1.tif
# Processing i=222: ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_025028_20200617_20200824_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_025028_20200905_20200918_02_T1.tif
# Processing i=223: ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_025028_20200905_20200918_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_025028_20220506_20220512_02_T1.tif
# Processing i=224: ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_025028_20220506_20220512_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_025028_20220623_20220705_02_T1.tif
# Processing i=225: ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_025028_20220623_20220705_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_025028_20221029_20221108_02_T1.tif
# Processing i=226: ../scratch/data/landsat/Landsat8_underc0_LC08_L2SP_025028_20221029_20221108_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_underc100_LC08_L2SP_024028_20190304_20200829_02_T1.tif
# Processing i=227: ../scratch/data/landsat/Landsat8_underc100_LC08_L2SP_024028_20190304_20200829_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_underc100_LC08_L2SP_025028_20200210_20200823_02_T1.tif
# Processing i=228: ../scratch/data/landsat/Landsat8_underc100_LC08_L2SP_025028_20200210_20200823_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_underc100_LC08_L2SP_025028_20211213_20211222_02_T1.tif
# Processing i=229: ../scratch/data/landsat/Landsat8_underc100_LC08_L2SP_025028_20211213_20211222_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_underc100_LC08_L2SP_025028_20211229_20220105_02_T1.tif
# Processing i=230: ../scratch/data/landsat/Landsat8_underc100_LC08_L2SP_025028_20211229_20220105_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_underc100_LC08_L2SP_025028_20220303_20220314_02_T1.tif
# Processing i=231: ../scratch/data/landsat/Landsat8_underc100_LC08_L2SP_025028_20220303_20220314_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_underc5_clouds2_LC08_L2SP_025028_20210401_20210409_02_T1.tif
# Processing i=232: ../scratch/data/landsat/Landsat8_underc5_clouds2_LC08_L2SP_025028_20210401_20210409_02_T1.tif
# 5
# ../scratch/data/landsat/Landsat8_underhill0_LC08_L2SP_013029_20210920_20210925_02_T1.tif
# Processing i=233: ../scratch/data/landsat/Landsat8_underhill0_LC08_L2SP_013029_20210920_20210925_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_underhill0_LC08_L2SP_013029_20211107_20211117_02_T1.tif
# Processing i=234: ../scratch/data/landsat/Landsat8_underhill0_LC08_L2SP_013029_20211107_20211117_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_underhill0_LC08_L2SP_014029_20190805_20200827_02_T1.tif
# Processing i=235: ../scratch/data/landsat/Landsat8_underhill0_LC08_L2SP_014029_20190805_20200827_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_underhill0_LC08_L2SP_014029_20200519_20200820_02_T1.tif
# Processing i=236: ../scratch/data/landsat/Landsat8_underhill0_LC08_L2SP_014029_20200519_20200820_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_underhill0_LC08_L2SP_014029_20220509_20220518_02_T1.tif
# Processing i=237: ../scratch/data/landsat/Landsat8_underhill0_LC08_L2SP_014029_20220509_20220518_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_underhill0_LC08_L2SP_014029_20220930_20221005_02_T1.tif
# Processing i=238: ../scratch/data/landsat/Landsat8_underhill0_LC08_L2SP_014029_20220930_20221005_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_underhill100_LC08_L2SP_013029_20210208_20210302_02_T1.tif
# Processing i=239: ../scratch/data/landsat/Landsat8_underhill100_LC08_L2SP_013029_20210208_20210302_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_underhill100_LC08_L2SP_013029_20220126_20220204_02_T1.tif
# Processing i=240: ../scratch/data/landsat/Landsat8_underhill100_LC08_L2SP_013029_20220126_20220204_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_underhill10_LC08_L2SP_014029_20201010_20201016_02_T1.tif
# Processing i=241: ../scratch/data/landsat/Landsat8_underhill10_LC08_L2SP_014029_20201010_20201016_02_T1.tif
# 10
# ../scratch/data/landsat/Landsat8_underhill80_clouds3_LC08_L2SP_014029_20210319_20210328_02_T1.tif
# Processing i=242: ../scratch/data/landsat/Landsat8_underhill80_clouds3_LC08_L2SP_014029_20210319_20210328_02_T1.tif
# 80
# ../scratch/data/landsat/Landsat8_underhill90_clouds29_LC08_L2SP_013029_20200309_20200822_02_T1.tif
# Processing i=243: ../scratch/data/landsat/Landsat8_underhill90_clouds29_LC08_L2SP_013029_20200309_20200822_02_T1.tif
# 90
# ../scratch/data/landsat/Landsat8_varrio0_LC08_L2SP_025028_20220506_20220512_02_T1.tif
# Processing i=244: ../scratch/data/landsat/Landsat8_varrio0_LC08_L2SP_025028_20220506_20220512_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_varrio0_LC08_L2SP_025028_20220810_20220817_02_T1.tif
# Processing i=245: ../scratch/data/landsat/Landsat8_varrio0_LC08_L2SP_025028_20220810_20220817_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_varrio0_LC08_L2SP_025028_20221029_20221108_02_T1.tif
# Processing i=246: ../scratch/data/landsat/Landsat8_varrio0_LC08_L2SP_025028_20221029_20221108_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_varrio0_LC08_L2SP_188013_20200623_20200823_02_T1.tif
# Processing i=247: ../scratch/data/landsat/Landsat8_varrio0_LC08_L2SP_188013_20200623_20200823_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_varrio0_LC08_L2SP_189012_20220823_20220923_02_T1.tif
# Processing i=248: ../scratch/data/landsat/Landsat8_varrio0_LC08_L2SP_189012_20220823_20220923_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_varrio0_LC08_L2SP_189013_20200902_20200906_02_T1.tif
# Processing i=249: ../scratch/data/landsat/Landsat8_varrio0_LC08_L2SP_189013_20200902_20200906_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_varrio0_LC08_L2SP_190012_20210827_20210901_02_T1.tif
# Processing i=250: ../scratch/data/landsat/Landsat8_varrio0_LC08_L2SP_190012_20210827_20210901_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_varrio0_LC08_L2SP_191012_20190712_20200827_02_T1.tif
# Processing i=251: ../scratch/data/landsat/Landsat8_varrio0_LC08_L2SP_191012_20190712_20200827_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_025028_20220303_20220314_02_T1.tif
# Processing i=252: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_025028_20220303_20220314_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_188013_20190418_20200829_02_T1.tif
# Processing i=253: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_188013_20190418_20200829_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_188013_20200404_20200822_02_T1.tif
# Processing i=254: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_188013_20200404_20200822_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_188013_20200522_20200820_02_T1.tif
# Processing i=255: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_188013_20200522_20200820_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_188013_20210322_20210401_02_T1.tif
# Processing i=256: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_188013_20210322_20210401_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_189012_20200326_20200822_02_T1.tif
# Processing i=257: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_189012_20200326_20200822_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_189012_20220316_20220322_02_T1.tif
# Processing i=258: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_189012_20220316_20220322_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_189013_20190425_20200828_02_T1.tif
# Processing i=259: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_189013_20190425_20200828_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_189013_20200411_20200822_02_T1.tif
# Processing i=260: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_189013_20200411_20200822_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_190012_20210421_20210430_02_T1.tif
# Processing i=261: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_190012_20210421_20210430_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_varrio10_clouds5_LC08_L2SP_190012_20220526_20220603_02_T1.tif
# Processing i=262: ../scratch/data/landsat/Landsat8_varrio10_clouds5_LC08_L2SP_190012_20220526_20220603_02_T1.tif
# 10
# ../scratch/data/landsat/Landsat8_willowcreek0_LC08_L2SP_025028_20200430_20200820_02_T1.tif
# Processing i=263: ../scratch/data/landsat/Landsat8_willowcreek0_LC08_L2SP_025028_20200430_20200820_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_willowcreek0_LC08_L2SP_025028_20200617_20200824_02_T1.tif
# Processing i=264: ../scratch/data/landsat/Landsat8_willowcreek0_LC08_L2SP_025028_20200617_20200824_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_willowcreek0_LC08_L2SP_025028_20200905_20200918_02_T1.tif
# Processing i=265: ../scratch/data/landsat/Landsat8_willowcreek0_LC08_L2SP_025028_20200905_20200918_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_willowcreek0_LC08_L2SP_025028_20210401_20210409_02_T1.tif
# Processing i=266: ../scratch/data/landsat/Landsat8_willowcreek0_LC08_L2SP_025028_20210401_20210409_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_willowcreek0_LC08_L2SP_025028_20210604_20210614_02_T1.tif
# Processing i=267: ../scratch/data/landsat/Landsat8_willowcreek0_LC08_L2SP_025028_20210604_20210614_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_willowcreek100_LC08_L2SP_025028_20190311_20200829_02_T1.tif
# Processing i=268: ../scratch/data/landsat/Landsat8_willowcreek100_LC08_L2SP_025028_20190311_20200829_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_willowcreek100_LC08_L2SP_025028_20190530_20200828_02_T1.tif
# Processing i=269: ../scratch/data/landsat/Landsat8_willowcreek100_LC08_L2SP_025028_20190530_20200828_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_willowcreek100_LC08_L2SP_025028_20200210_20200823_02_T1.tif
# Processing i=270: ../scratch/data/landsat/Landsat8_willowcreek100_LC08_L2SP_025028_20200210_20200823_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_willowcreek100_LC08_L2SP_025028_20211229_20220105_02_T1.tif
# Processing i=271: ../scratch/data/landsat/Landsat8_willowcreek100_LC08_L2SP_025028_20211229_20220105_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20190716_20200827_02_T1.tif
# Processing i=272: ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20190716_20200827_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20200904_20200918_02_T1.tif
# Processing i=273: ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20200904_20200918_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20201006_20201016_02_T1.tif
# Processing i=274: ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20201006_20201016_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20210907_20210916_02_T1.tif
# Processing i=275: ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20210907_20210916_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20220809_20220818_02_T1.tif
# Processing i=276: ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20220809_20220818_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20220926_20221004_02_T1.tif
# Processing i=277: ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20220926_20221004_02_T1.tif
# 0
# ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20191105_20200825_02_T1.tif
# Processing i=278: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20191105_20200825_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20200108_20200823_02_T1.tif
# Processing i=279: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20200108_20200823_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20201225_20210310_02_T1.tif
# Processing i=280: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20201225_20210310_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20210331_20210409_02_T1.tif
# Processing i=281: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20210331_20210409_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20220113_20220123_02_T1.tif
# Processing i=282: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20220113_20220123_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20220214_20220222_02_T1.tif
# Processing i=283: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20220214_20220222_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20220318_20220322_02_T1.tif
# Processing i=284: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20220318_20220322_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20221028_20221108_02_T1.tif
# Processing i=285: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20221028_20221108_02_T1.tif
# 100
# ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20221215_20221227_02_T1.tif
# Processing i=286: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20221215_20221227_02_T1.tif
# 100
#        cell_y  cell_x  filtered_fraction    Dozier     Klein  Salomonson  fsc  \
# 0         2.0     3.0           0.550173  0.123791  0.108317    0.051361  0.8
# 1         2.0     4.0           0.862457  0.162903  0.146774    0.060665  0.8
# 2         2.0     5.0           0.235294  0.077670  0.058252    0.039601  0.8
# 3         3.0     2.0           0.460208  0.077922  0.067532    0.036694  0.8
# 4         3.0     3.0           1.000000  0.183473  0.159664    0.074839  0.8
# ...       ...     ...                ...       ...       ...         ...  ...
# 14150     7.0     2.0           0.233512  1.000000  0.000000    0.406624  1.0
# 14151     7.0     3.0           0.295684  1.000000  0.000000    0.473742  1.0
# 14152     7.0     4.0           0.902852  1.000000  0.000000    0.478127  1.0
# 14153     7.0     5.0           0.539027  1.000000  0.000000    0.441284  1.0
# 14154     7.0     6.0           0.744207  1.000000  0.000000    0.450377  1.0
#
#             cam
# 0      bartlett
# 1      bartlett
# 2      bartlett
# 3      bartlett
# 4      bartlett
# ...         ...
# 14150  wslcreek
# 14151  wslcreek
# 14152  wslcreek
# 14153  wslcreek
# 14154  wslcreek
#
# [14155 rows x 8 columns]

# %%
import pandas as pd
final_df = pd.to_pickle('./landsat_df_80m_0.2ff.pkl')
# len(final_df[(final_df['fsc']<1)&(final_df['fsc']>0)])
# final_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 import pandas as pd
# ----> 2 final_df = pd.to_pickle('./landsat_df_80m_0.2ff.pkl')
#       3 # len(final_df[(final_df['fsc']<1)&(final_df['fsc']>0)])
#       4 # final_df
#
# TypeError: to_pickle() missing 1 required positional argument: 'filepath_or_buffer'

# %% [markdown]
# # 4km extent results

# %%
#60m

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Melt the dataframe to long format for individual method plots
melted = final_df.melt(
    id_vars=["fsc", "filtered_fraction", "cam"],
    value_vars=["Dozier", "Klein"],  # , "Salomonson"
    var_name="method",
    value_name="predicted"
)

# Convert to percentages for plotting (0–100)
melted["fsc"] = melted["fsc"] * 100.0
melted["predicted"] = melted["predicted"] * 100.0

# Define color map (blue for Dozier, green for Klein)
method_colors = {
    "Dozier": "#1f77b4",
    "Klein": "#2ca02c",
    # "Salomonson": "#d62728"
}

# ---------- Scatter: Observed vs Predicted, one figure per method ----------
for method in ["Dozier", "Klein"]:  # , "Salomonson"
    subset = melted[melted["method"] == method]

    plt.figure(figsize=(6, 6))
    plt.scatter(
        subset["fsc"],
        subset["predicted"],
        alpha=0.6,
        edgecolor='k',
        c=method_colors[method],
        label=method
    )
    plt.plot([0, 100], [0, 100], 'r--', lw=1)
    plt.xlabel("Observed FSC (%)")
    plt.ylabel("Predicted FSC (%)")
    plt.title(f"Observed vs Predicted FSC: {method}")
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    # plt.savefig(f'poster_landsat_{method}_actual_predicted.svg')
    plt.show()

# ---------- Metric helpers ----------
def rmse(y_true, y_pred):
    diff = y_pred - y_true
    return np.sqrt(np.nanmean(diff**2)) if np.isfinite(diff).any() else np.nan

def bias(y_true, y_pred):
    diff = y_pred - y_true
    return np.nanmean(diff) if np.isfinite(diff).any() else np.nan

def compute_all_metrics(df_method):
    """df_method: melted subset for a single method, with fsc/predicted in 0–100 units."""
    y = df_method["fsc"].to_numpy()
    yhat = df_method["predicted"].to_numpy()

    # Overall
    overall_rmse  = rmse(y, yhat)
    overall_bias  = bias(y, yhat)

    # Fractional (strictly between 0 and 100)
    frac_mask = (y > 0) & (y < 100)
    frac_rmse  = rmse(y[frac_mask], yhat[frac_mask])
    frac_bias  = bias(y[frac_mask], yhat[frac_mask])

    # Errors at the extremes
    zero_mask = (y == 0)
    full_mask = (y == 100)

    zero_bias = bias(y[zero_mask], yhat[zero_mask])   # "0%SC Error"
    full_bias = bias(y[full_mask], yhat[full_mask])   # "100%SC Error"

    metrics_order = ["RMSE", "Bias", "Fractional RMSE", "Fractional Bias", "0%SC Error", "100%SC Error"]
    values = np.array([
        overall_rmse,
        overall_bias,
        frac_rmse,
        frac_bias,
        zero_bias,
        full_bias
    ], dtype=float)

    return metrics_order, values

# ---------- Bar chart per method with six metrics ----------
for method in ["Dozier", "Klein"]:
    subset = melted[melted["method"] == method]
    metrics_labels, values = compute_all_metrics(subset)

    plt.figure(figsize=(8, 5))
    x = np.arange(len(metrics_labels))
    bars = plt.bar(x, values, edgecolor='black', color=method_colors[method])

    # Labels on bars (handle NaNs gracefully)
    for bar, val in zip(bars, values):
        height = 0 if np.isnan(val) else float(val)
        txt = "NaN" if np.isnan(val) else f"{height:.1f}%"
        x_offset = bar.get_x() + bar.get_width() * 0.6
        y_offset = 1 * np.sign(height if height != 0 else 1)
        plt.text(
            x_offset,
            height + y_offset,
            txt,
            ha='left',
            va='bottom' if height >= 0 else 'top',
            fontsize=13
        )

    plt.xticks(x, metrics_labels, rotation=0)
    plt.ylabel("Value (%)")
    plt.title(f"{method} – FSC Estimation Metrics")
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Y-lims with padding, robust to NaNs
    finite_vals = values[np.isfinite(values)]
    if finite_vals.size == 0:
        ymin, ymax = -1, 1
    else:
        ymin = min(0.0, float(finite_vals.min())) - 4
        ymax = (float(finite_vals.max()) + 4) if float(finite_vals.max()) > 0 else 1
    plt.ylim(ymin, ymax)

    plt.tight_layout()
    # plt.savefig(f'poster_landsat_{method}_metrics.svg')
    plt.show()

# %%
#80m

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Melt the dataframe to long format for individual method plots
melted = final_df.melt(
    id_vars=["fsc", "filtered_fraction", "cam"],
    value_vars=["Dozier", "Klein"],  # , "Salomonson"
    var_name="method",
    value_name="predicted"
)

# Convert to percentages for plotting (0–100)
melted["fsc"] = melted["fsc"] * 100.0
melted["predicted"] = melted["predicted"] * 100.0

# Define color map (blue for Dozier, green for Klein)
method_colors = {
    "Dozier": "#1f77b4",
    "Klein": "#2ca02c",
    # "Salomonson": "#d62728"
}

# ---------- Scatter: Observed vs Predicted, one figure per method ----------
for method in ["Dozier", "Klein"]:  # , "Salomonson"
    subset = melted[melted["method"] == method]

    plt.figure(figsize=(6, 6))
    plt.scatter(
        subset["fsc"],
        subset["predicted"],
        alpha=0.6,
        edgecolor='k',
        c=method_colors[method],
        label=method
    )
    plt.plot([0, 100], [0, 100], 'r--', lw=1)
    plt.xlabel("Observed FSC (%)")
    plt.ylabel("Predicted FSC (%)")
    plt.title(f"Observed vs Predicted FSC: {method}")
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    # plt.savefig(f'poster_landsat_{method}_actual_predicted.svg')
    plt.show()

# ---------- Metric helpers ----------
def rmse(y_true, y_pred):
    diff = y_pred - y_true
    return np.sqrt(np.nanmean(diff**2)) if np.isfinite(diff).any() else np.nan

def bias(y_true, y_pred):
    diff = y_pred - y_true
    return np.nanmean(diff) if np.isfinite(diff).any() else np.nan

def compute_all_metrics(df_method):
    """df_method: melted subset for a single method, with fsc/predicted in 0–100 units."""
    y = df_method["fsc"].to_numpy()
    yhat = df_method["predicted"].to_numpy()

    # Overall
    overall_rmse  = rmse(y, yhat)
    overall_bias  = bias(y, yhat)

    # Fractional (strictly between 0 and 100)
    frac_mask = (y > 0) & (y < 100)
    frac_rmse  = rmse(y[frac_mask], yhat[frac_mask])
    frac_bias  = bias(y[frac_mask], yhat[frac_mask])

    # Errors at the extremes
    zero_mask = (y == 0)
    full_mask = (y == 100)

    zero_bias = bias(y[zero_mask], yhat[zero_mask])   # "0%SC Error"
    full_bias = bias(y[full_mask], yhat[full_mask])   # "100%SC Error"

    metrics_order = ["RMSE", "Bias", "Fractional RMSE", "Fractional Bias", "0%SC Error", "100%SC Error"]
    values = np.array([
        overall_rmse,
        overall_bias,
        frac_rmse,
        frac_bias,
        zero_bias,
        full_bias
    ], dtype=float)

    return metrics_order, values

# ---------- Bar chart per method with six metrics ----------
for method in ["Dozier", "Klein"]:
    subset = melted[melted["method"] == method]
    metrics_labels, values = compute_all_metrics(subset)

    plt.figure(figsize=(8, 5))
    x = np.arange(len(metrics_labels))
    bars = plt.bar(x, values, edgecolor='black', color=method_colors[method])

    # Labels on bars (handle NaNs gracefully)
    for bar, val in zip(bars, values):
        height = 0 if np.isnan(val) else float(val)
        txt = "NaN" if np.isnan(val) else f"{height:.1f}%"
        x_offset = bar.get_x() + bar.get_width() * 0.6
        y_offset = 1 * np.sign(height if height != 0 else 1)
        plt.text(
            x_offset,
            height + y_offset,
            txt,
            ha='left',
            va='bottom' if height >= 0 else 'top',
            fontsize=13
        )

    plt.xticks(x, metrics_labels, rotation=0)
    plt.ylabel("Value (%)")
    plt.title(f"{method} – FSC Estimation Metrics")
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Y-lims with padding, robust to NaNs
    finite_vals = values[np.isfinite(values)]
    if finite_vals.size == 0:
        ymin, ymax = -1, 1
    else:
        ymin = min(0.0, float(finite_vals.min())) - 4
        ymax = (float(finite_vals.max()) + 4) if float(finite_vals.max()) > 0 else 1
    plt.ylim(ymin, ymax)

    plt.tight_layout()
    # plt.savefig(f'poster_landsat_{method}_metrics.svg')
    plt.show()

# %%
#100m

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Melt the dataframe to long format for individual method plots
melted = final_df.melt(
    id_vars=["fsc", "filtered_fraction", "cam"],
    value_vars=["Dozier", "Klein"],  # , "Salomonson"
    var_name="method",
    value_name="predicted"
)

# Convert to percentages for plotting (0–100)
melted["fsc"] = melted["fsc"] * 100.0
melted["predicted"] = melted["predicted"] * 100.0

# Define color map (blue for Dozier, green for Klein)
method_colors = {
    "Dozier": "#1f77b4",
    "Klein": "#2ca02c",
    # "Salomonson": "#d62728"
}

# ---------- Scatter: Observed vs Predicted, one figure per method ----------
for method in ["Dozier", "Klein"]:  # , "Salomonson"
    subset = melted[melted["method"] == method]

    plt.figure(figsize=(6, 6))
    plt.scatter(
        subset["fsc"],
        subset["predicted"],
        alpha=0.6,
        edgecolor='k',
        c=method_colors[method],
        label=method
    )
    plt.plot([0, 100], [0, 100], 'r--', lw=1)
    plt.xlabel("Observed FSC (%)")
    plt.ylabel("Predicted FSC (%)")
    plt.title(f"Observed vs Predicted FSC: {method}")
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    # plt.savefig(f'poster_landsat_{method}_actual_predicted.svg')
    plt.show()

# ---------- Metric helpers ----------
def rmse(y_true, y_pred):
    diff = y_pred - y_true
    return np.sqrt(np.nanmean(diff**2)) if np.isfinite(diff).any() else np.nan

def bias(y_true, y_pred):
    diff = y_pred - y_true
    return np.nanmean(diff) if np.isfinite(diff).any() else np.nan

def compute_all_metrics(df_method):
    """df_method: melted subset for a single method, with fsc/predicted in 0–100 units."""
    y = df_method["fsc"].to_numpy()
    yhat = df_method["predicted"].to_numpy()

    # Overall
    overall_rmse  = rmse(y, yhat)
    overall_bias  = bias(y, yhat)

    # Fractional (strictly between 0 and 100)
    frac_mask = (y > 0) & (y < 100)
    frac_rmse  = rmse(y[frac_mask], yhat[frac_mask])
    frac_bias  = bias(y[frac_mask], yhat[frac_mask])

    # Errors at the extremes
    zero_mask = (y == 0)
    full_mask = (y == 100)

    zero_bias = bias(y[zero_mask], yhat[zero_mask])   # "0%SC Error"
    full_bias = bias(y[full_mask], yhat[full_mask])   # "100%SC Error"

    metrics_order = ["RMSE", "Bias", "Fractional RMSE", "Fractional Bias", "0%SC Error", "100%SC Error"]
    values = np.array([
        overall_rmse,
        overall_bias,
        frac_rmse,
        frac_bias,
        zero_bias,
        full_bias
    ], dtype=float)

    return metrics_order, values

# ---------- Bar chart per method with six metrics ----------
for method in ["Dozier", "Klein"]:
    subset = melted[melted["method"] == method]
    metrics_labels, values = compute_all_metrics(subset)

    plt.figure(figsize=(8, 5))
    x = np.arange(len(metrics_labels))
    bars = plt.bar(x, values, edgecolor='black', color=method_colors[method])

    # Labels on bars (handle NaNs gracefully)
    for bar, val in zip(bars, values):
        height = 0 if np.isnan(val) else float(val)
        txt = "NaN" if np.isnan(val) else f"{height:.1f}%"
        x_offset = bar.get_x() + bar.get_width() * 0.6
        y_offset = 1 * np.sign(height if height != 0 else 1)
        plt.text(
            x_offset,
            height + y_offset,
            txt,
            ha='left',
            va='bottom' if height >= 0 else 'top',
            fontsize=13
        )

    plt.xticks(x, metrics_labels, rotation=0)
    plt.ylabel("Value (%)")
    plt.title(f"{method} – FSC Estimation Metrics")
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Y-lims with padding, robust to NaNs
    finite_vals = values[np.isfinite(values)]
    if finite_vals.size == 0:
        ymin, ymax = -1, 1
    else:
        ymin = min(0.0, float(finite_vals.min())) - 4
        ymax = (float(finite_vals.max()) + 4) if float(finite_vals.max()) > 0 else 1
    plt.ylim(ymin, ymax)

    plt.tight_layout()
    # plt.savefig(f'poster_landsat_{method}_metrics.svg')
    plt.show()

# %% [markdown]
# # 1km extent results

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Melt the dataframe to long format for individual method plots
melted = final_df.melt(
    id_vars=["fsc", "filtered_fraction", "cam"],
    value_vars=["Dozier", "Klein", "Salomonson"],
    var_name="method",
    value_name="predicted"
)

# Define color map for consistency
method_colors = {
    "Dozier": "#1f77b4",
    "Klein": "#2ca02c",
    "Salomonson": "#d62728"
}

# Loop through methods and plot
for method in ["Dozier", "Klein", "Salomonson"]:
    subset = melted[melted["method"] == method]

    plt.figure(figsize=(6, 6))
    plt.scatter(
        subset["fsc"],
        subset["predicted"],
        alpha=0.6,
        edgecolor='k',
        c=method_colors[method],
        # s=subset["filtered_fraction"] * 200 + 20,
        label=method
    )
    plt.plot([0, 1], [0, 1], 'r--', lw=1)
    plt.xlabel("Observed FSC")
    plt.ylabel("Predicted FSC")
    plt.title(f"Observed vs Predicted FSC: {method}")
    plt.grid(True)
    plt.tight_layout()
    # plt.savefig(f'poster_landsat_{method}_actual_predicted.svg')
    plt.show()

# Compute RMSE and Bias
def compute_rmse_bias(group):
    rmse = np.sqrt(np.mean((group["predicted"] - group["fsc"])**2))
    bias = np.mean(group["predicted"] - group["fsc"])
    return pd.Series({"RMSE": rmse, "Bias": bias})

metrics = melted.groupby("method").apply(compute_rmse_bias).reset_index()

# Barplot of RMSE and Bias
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.barplot(data=metrics, x="method", y="RMSE", ax=axes[0], palette=method_colors)
axes[0].set_title("RMSE by Method")
axes[0].set_ylim(0, metrics["RMSE"].max() * 1.2)
for container in axes[0].containers:
    axes[0].bar_label(container, labels=[f"{v.get_height():.3f}" for v in container], padding=3)

sns.barplot(data=metrics, x="method", y="Bias", ax=axes[1], palette=method_colors)
axes[1].set_title("Bias by Method")
axes[1].axhline(0, color='black', lw=0.8)
axes[1].set_ylim(
    min(0, metrics["Bias"].min()) * 1.2,
    max(0, metrics["Bias"].max()) * 1.2
)
for container in axes[1].containers:
    axes[1].bar_label(container, labels=[f"{v.get_height():.3f}" for v in container], padding=3)

plt.suptitle("Model Performance Metrics", fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95])
# plt.savefig('poster_landsat_rmse.svg')
plt.show()
# Out:
# /tmp/ipykernel_3512661/2148821787.py:50: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   metrics = melted.groupby("method").apply(compute_rmse_bias).reset_index()
# /tmp/ipykernel_3512661/2148821787.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=metrics, x="method", y="RMSE", ax=axes[0], palette=method_colors)
# /tmp/ipykernel_3512661/2148821787.py:61: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=metrics, x="method", y="Bias", ax=axes[1], palette=method_colors)
