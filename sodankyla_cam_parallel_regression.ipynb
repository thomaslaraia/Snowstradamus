# %%
from scripts.imports import os, glob, pdb, np, h5py, pd, xr, gpd, Proj, Transformer, CRS, \
                        plt, cmap, cmap2, Model, Data, ODR, datetime, rasterio, show, \
                        ccrs, cfeature
from scripts.classes_fixed import *
from scripts.pvpg_concise import *
from scripts.track_pairs import *
from scripts.show_tracks import *

# %matplotlib ipympl

dirpath = '../data/FMI_cam_sodankyla/'
all_ATL03, all_ATL08 = track_pairs(dirpath)
N = len(all_ATL03)

for j in range(0,4):
    pvpg_concise(all_ATL03[j],all_ATL08[j],
                 f_scale = .1, # Default is .1
                 loss = 'arctan', # Default is 'arctan'
                 bounds = ([-100, 0], [-1/100, 16]), # Default is ([-100, 0], [-1/100, 16])
                 file_index = j, # Default is None, this puts the index of the file within all_ATL03 into the plot title
                 #res = residuals, # If so desired, you can change the residual function
                 #model = model, # If so desired, you can change the model function
                 zeros=None, # This is default, change to anything if you want to keep the outliers that have been thrown out.
                 beam = None, # This is default, change to an array of beam numbers to restrict info to those beams, i.e. [3,4]
                 detail = 2, # Default is 0, change to 1 to see pv/pg plot, change to 2 to also see all the groundtracks
                 canopy_frac=True) # Default is None, activate to show fraction of segments that have canopy photons for each groundtrack
# Out:
# /home/s1803229/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# Beam 6 in file 0 has been skipped because of no data.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Beam 1 in file 1 has been skipped because of no data.
# File 1 has been skipped because none of the beams that successfully read had any data.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from scripts.imports import os, glob, pdb, np, h5py, pd, xr, gpd, Proj, Transformer, CRS, \
                        plt, cmap, cmap2, Model, Data, ODR, datetime, rasterio, show, \
                        ccrs, cfeature
from scripts.classes_fixed import *
from scripts.pvpg_concise import *
from scripts.track_pairs import *
from scripts.show_tracks import *
from scripts.parallel import pvpg_parallel

# %matplotlib ipympl

dirpath = '../data/rovaniemi_w/'
all_ATL03, all_ATL08 = track_pairs(dirpath)
N = len(all_ATL03)

for j in range(0,5):
    pvpg_parallel(all_ATL03[j],all_ATL08[j],
                  f_scale = 0.1, # Default is 0.1
                  loss = 'arctan', # Default is 'arctan'
                  init = -1, # Default is 1
                  lb = -100, # Default is -100
                  ub = -1/100, # Default is -1/100
                  file_index = j, # Default is None
                  # model = model, # see script
                  # res = res, # see script
                  # odr = odr, # see script
                  zeros = None, # Default is None, activate to include outliers
                  beam = None, #Default is None, activate a la e.g. [3,4] to show info for only beams 3 and 4
                  y_init = np.max, # Default is np.max, used to choose initial guess for y_intercept
                  graph_detail = 2, # Default is 0, change to 1 to see pv/pg plot, change to 2 to also see all the groundtracks
                  canopy_frac=True) # Default is None, activate to show fraction of segments that have canopy photons for each groundtrack
# Out:
# /home/s1803229/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# File 1 has been skipped.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
