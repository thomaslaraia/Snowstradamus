# %% [markdown]
# # Parallel regression

# %% [markdown]
# #### Arctan loss, f_scale = .1

# %%
from scripts.parallel import *

dirpath = '../data/nosnow_highref_amy/'

# data = []

all_ATL03, all_ATL08 = track_pairs(dirpath)
N = len(all_ATL03)

sodankyla_coords = (22.5, 61.5)

# for i in range(N):
for i in [0]:
    data = pvpg_parallel(all_ATL03[i], all_ATL08[i], coords=sodankyla_coords, width=.5,height=.5,\
                         graph_detail=2, loss='arctan',file_index=i, keep_flagged=1, opsys='bad',f_scale=.1)
    print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15200\3098361359.py in <module>
#       5 # data = []
#       6
# ----> 7 all_ATL03, all_ATL08 = track_pairs(dirpath)
#       8 N = len(all_ATL03)
#       9
#
# ~\Documents\Snowstradamus\Snowstradamus\scripts\track_pairs.py in track_pairs(dirpath, failed)
#      16
#      17     # Extract characters after 'ATL03' and check for corresponding 'ATL08' file
# ---> 18     for file in os.listdir(dirpath):
#      19         if 'processed_ATL03' in file:
#      20             # Extract string of characters after 'ATL03'
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../data/nosnow_highref_amy/'

# %% [markdown]
# #### Arctan loss, f_scale = 1

# %%
from scripts.parallel import *

dirpath = '../data/sodankyla_full/'

# data = []

all_ATL03, all_ATL08 = track_pairs(dirpath)
N = len(all_ATL03)

sodankyla_coords = (26.634154, 67.361833)

for i in range(N):
    data = pvpg_parallel(all_ATL03[i], all_ATL08[i], coords=sodankyla_coords, width=.1,height=.1,\
                         graph_detail=2, loss='arctan',file_index=i, keep_flagged=1, opsys='bad',f_scale=1)
# Out:
# Beam 1 in file 0 has been skipped because of no data.
# Beam 2 in file 0 has been skipped because of no data.
# Beam 3 in file 0 has been skipped because of no data.
# Beam 4 in file 0 has been skipped because of no data.
# Beam 1 in file 1 has been skipped because of no data.
# Beam 2 in file 1 has been skipped because of no data.
# Beam 3 in file 1 has been skipped because of no data.
# Beam 4 in file 1 has been skipped because of no data.
# Beam 3 in file 2 has been skipped because of no data.
# Beam 4 in file 2 has been skipped because of no data.
# Beam 5 in file 2 has been skipped because of no data.
# Beam 6 in file 2 has been skipped because of no data.
# Beam 2 in file 3 has been skipped because of no data.
# Beam 4 in file 3 has been skipped because of no data.
# Beam 5 in file 3 has been skipped because of no data.
# Beam 6 in file 3 has been skipped because of no data.
# Beam 1 in file 4 has been skipped because of no data.
# Beam 2 in file 4 has been skipped because of no data.
# Beam 3 in file 4 has been skipped because of no data.
# Beam 4 in file 4 has been skipped because of no data.
# Beam 5 in file 4 has been skipped because of no data.
# Beam 6 in file 4 has been skipped because of no data.
# No beams have data in file 4, cannot regress.

# %% [markdown]
# #### Linear loss

# %%
from scripts.parallel import *

dirpath = '../data/sodankyla_full/'

# data = []

all_ATL03, all_ATL08 = track_pairs(dirpath)
N = len(all_ATL03)

sodankyla_coords = (26.634154, 67.361833)

for i in range(N):
    data = pvpg_parallel(all_ATL03[i], all_ATL08[i], coords=sodankyla_coords, width=.1,height=.1,\
                         graph_detail=2, loss='linear',file_index=i, keep_flagged=1, opsys='bad',f_scale=1)
    print(data)
# Out:
# Beam 1 in file 0 has been skipped because of no data.
# Beam 2 in file 0 has been skipped because of no data.
# Beam 3 in file 0 has been skipped because of no data.
# Beam 4 in file 0 has been skipped because of no data.
# (array([-0.01      ,  0.50711467,  0.26910397]), [[nan, nan, 0.58060545], [nan, nan, 0.109433815], [nan, nan, 0.5013086], [nan, nan, 0.26800963]], 2.25, 0.0, 0.08363905530422926)
# Beam 1 in file 1 has been skipped because of no data.
# Beam 2 in file 1 has been skipped because of no data.
# Beam 3 in file 1 has been skipped because of no data.
# Beam 4 in file 1 has been skipped because of no data.
# (array([-17.71228351,  16.        ,   2.4285415 ]), [[nan, nan, 0.8776861], [nan, nan, 0.12113095], [nan, nan, 0.45834288], [nan, nan, 0.28303573]], 2.0, 0.0, 0.0706413638065843)
# Beam 3 in file 2 has been skipped because of no data.
# Beam 4 in file 2 has been skipped because of no data.
# Beam 5 in file 2 has been skipped because of no data.
# Beam 6 in file 2 has been skipped because of no data.
# (array([-1.12571447,  1.3072229 ,  1.22988448]), [[0.6887015, nan, nan], [0.57069767, nan, nan], [0.5319416, nan, nan], [0.58744186, nan, nan]], 2.0, 1.0, 0.01696028932929039)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16068\201414985.py in <module>
#      12 for i in range(10):
#      13     data = pvpg_parallel(all_ATL03[i], all_ATL08[i], coords=sodankyla_coords, width=.1,height=.1,\
# ---> 14                          graph_detail=2, loss='linear',file_index=i, keep_flagged=1, opsys='bad',f_scale=1)
#      15     print(data)
#
# ~\Documents\Snowstradamus\Snowstradamus\scripts\parallel.py in pvpg_parallel(atl03path, atl08path, coords, width, height, f_scale, loss, init, lb, ub, file_index, model, res, odr, zeros, beam, y_init, graph_detail, canopy_frac, terrain_frac, keep_flagged, opsys)
#     405             # Filter the dataframe within the ranges of latitudes and longitudes
#     406             atl03.df = atl03.df[(atl03.df['lon'] >= min_lon) & (atl03.df['lon'] <= max_lon) &\
# --> 407                                 (atl03.df['lat'] >= min_lat) & (atl03.df['lat'] <= max_lat)]
#     408
#     409
#
# ~\AppData\Local\miniforge-pypy3\envs\snow_env\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\AppData\Local\miniforge-pypy3\envs\snow_env\lib\site-packages\pandas\core\arraylike.py in __and__(self, other)
#      60     @unpack_zerodim_and_defer("__and__")
#      61     def __and__(self, other):
# ---> 62         return self._logical_method(other, operator.and_)
#      63
#      64     @unpack_zerodim_and_defer("__rand__")
#
# ~\AppData\Local\miniforge-pypy3\envs\snow_env\lib\site-packages\pandas\core\series.py in _logical_method(self, other, op)
#    5511         rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5512
# -> 5513         res_values = ops.logical_op(lvalues, rvalues, op)
#    5514         return self._construct_result(res_values, name=res_name)
#    5515
#
# ~\AppData\Local\miniforge-pypy3\envs\snow_env\lib\site-packages\pandas\core\ops\array_ops.py in logical_op(left, right, op)
#     392         res_values = na_logical_op(lvalues, rvalues, op)
#     393         # error: Cannot call function of unknown type
# --> 394         res_values = filler(res_values)  # type: ignore[operator]
#     395
#     396     return res_values
#
# ~\AppData\Local\miniforge-pypy3\envs\snow_env\lib\site-packages\pandas\core\ops\array_ops.py in fill_bool(x, left)
#     359
#     360         if left is None or is_bool_dtype(left.dtype):
# --> 361             x = x.astype(bool)
#     362         return x
#     363
#
# KeyboardInterrupt:
