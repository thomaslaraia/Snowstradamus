# %%
    df_grouped = data.groupby(['camera','date','lat','lon']).agg({
        'pvpg': 'mean',
        'pv': 'max',
        'pg': 'max',
        'data_quantity': 'max',
        'pv_ratio': 'mean',
        'snr': 'mean',
        'msw_flag': 'mean',
        'segment_landcover': pd.Series.mode,
        'cloud_flag_atm': 'mean',
        'layer_flag': 'mean'
    }).reset_index()
    
    print(df_grouped)

# %% [markdown]
# # Torgnon

# %%
from scripts.parallel_blocks import *
# from scripts.parallel_phoreal import *
# pd.set_option('display.max_rows', None)  # Show all rows
# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.width', None)  # Adjust the display width to show all columns
# pd.set_option('display.max_colwidth', None)  # Show full content of each column

dirpath = '../data_store/data/torgnon/'

all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
N = len(all_ATL03)

coords = (7.5609, 45.8238)

# for i in range(N):
# for i in [18,23,27]:
for i in [18]:
    # print(all_ATL03[i], all_ATL08[i])

    # BASE
    # data = pvpg_parallel(all_ATL03[i], all_ATL08[i], coords=coords, width=5,height=5,file_index=i, alt_thresh=80,\
    #                      altitude=2091, threshold=1, graph_detail=1)

    # BLOCKS
    data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=coords, width=4,height=4,file_index=i, alt_thresh=80,\
                         altitude=2091, threshold=4, small_box=1, graph_detail=1, loss='linear', rebinned=30, f_scale=.05,\
                         outlier_removal=.1,method='bimodal', landcover='forest')
    # data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=coords, width=5,height=5,file_index=i, alt_thresh=80,\
    #                      altitude=2091, threshold=1, small_box=10, graph_detail=1, loss='arctan', rebinned=30, f_scale=.05,
    #                      outlier_removal=3)

    df_grouped = data.groupby(['camera','date','lat','lon']).agg({
        'pvpg': 'mean',
        'pv': 'max',
        'pg': 'max',
        'data_quantity': 'max',
        'pv_ratio_max': 'mean',
        'pv_ratio_mean': 'mean',
        'snr': 'mean',
        'msw_flag': 'mean',
        'segment_landcover': pd.Series.mode,
        'cloud_flag_atm': 'mean',
        'layer_flag': 'mean'
    }).reset_index()
    
    print(df_grouped)
# Out:
# Nothing in rebinned section for torgnon file 18's beam 1.
# Nothing in rebinned section for torgnon file 18's beam 2.
# Beam 6, box 0 in torgnon file 18 has insufficient data.
#     camera        date        lat       lon      pvpg        pv        pg  \
# 0  torgnon  22/02/2022  45.824025  7.561223  3.321809  4.421147  1.330946
#
#    data_quantity  pv_ratio_max  pv_ratio_mean      snr  msw_flag  \
# 0             45      2.258465       2.258465  0.50701       0.0
#
#    segment_landcover  cloud_flag_atm  layer_flag
# 0              111.0             0.0        0.15

# %% [markdown]
# # Lac Clair

# %%
from scripts.parallel_blocks import *
# from scripts.parallel_phoreal import *
# pd.set_option('display.max_rows', None)  # Show all rows
# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.width', None)  # Adjust the display width to show all columns
# pd.set_option('display.max_colwidth', None)  # Show full content of each column

dirpath = '../data_store/data/lacclair/'

all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
N = len(all_ATL03)

coords = (-71.6696, 46.9521)

# for i in range(N):
for i in [9,23,16]:
    # print(all_ATL03[i], all_ATL08[i])

    # BASE
    # data = pvpg_parallel(all_ATL03[i], all_ATL08[i], coords=coords, width=5,height=5,file_index=i, alt_thresh=80,\
    #                      altitude=313, threshold=1, graph_detail=1)

    # BLOCKS
    data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=coords, width=4,height=4,file_index=i, alt_thresh=80,\
                         altitude=313, threshold=1, small_box=8.05, graph_detail=1, loss='linear', rebinned=30, f_scale=.05,\
                         outlier_removal=.1,method='bimodal', landcover='all')
    # data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=coords, width=5,height=5,file_index=i, alt_thresh=80,\
    #                      altitude=313, threshold=1, small_box=10, graph_detail=1, loss='arctan', rebinned=30, f_scale=.05,
    #                      outlier_removal=3)

    df_grouped = data.groupby(['camera','date','lat','lon']).agg({
        'pvpg': 'mean',
        'pv': 'max',
        'pg': 'max',
        'data_quantity': 'max',
        'pv_ratio_mean': 'mean',
        'snr': 'mean',
        'msw_flag': 'mean',
        'segment_landcover': pd.Series.mode,
        'cloud_flag_atm': 'mean',
        'layer_flag': 'mean'
    }).reset_index()
    
    print(df_grouped)
# Out:
# Nothing in rebinned section for lacclair file 9's beam 3.
# Nothing in rebinned section for lacclair file 9's beam 4.
# Nothing in rebinned section for lacclair file 9's beam 5.
# Nothing in rebinned section for lacclair file 9's beam 6.
#      camera        date        lat       lon       pvpg        pv        pg  \
# 0  lacclair  02/08/2020  46.952325 -71.66927  33.981963  7.269448  0.213921
#
#    data_quantity  pv_ratio_mean       snr  msw_flag  segment_landcover  \
# 0             57       0.495551  0.352358       1.0              114.0
#
#    cloud_flag_atm  layer_flag
# 0        1.051724    0.362069
# Nothing in rebinned section for lacclair file 23's beam 1.
# Nothing in rebinned section for lacclair file 23's beam 2.
#      camera        date        lat       lon    pvpg        pv        pg  \
# 0  lacclair  03/07/2024  46.952325 -71.66927  9.6868  2.431318  0.250993
#
#    data_quantity  pv_ratio_mean        snr  msw_flag  segment_landcover  \
# 0            121       0.906863  62.974683  0.042705              114.0
#
#    cloud_flag_atm  layer_flag
# 0        0.042705         1.0
# Nothing in rebinned section for lacclair file 16's beam 3.
# Nothing in rebinned section for lacclair file 16's beam 4.
# Nothing in rebinned section for lacclair file 16's beam 5.
# Nothing in rebinned section for lacclair file 16's beam 6.
#      camera        date        lat       lon       pvpg        pv        pg  \
# 0  lacclair  28/08/2022  46.952325 -71.66927  10.931703  2.227296  0.203746
#
#    data_quantity  pv_ratio_mean        snr  msw_flag  segment_landcover  \
# 0             45       0.960401  63.821087       0.0              114.0
#
#    cloud_flag_atm  layer_flag
# 0             0.0         1.0

# %% [markdown]
# # Marcell

# %%
from scripts.parallel_blocks import *
# from scripts.parallel_phoreal import *
# pd.set_option('display.max_rows', None)  # Show all rows
# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.width', None)  # Adjust the display width to show all columns
# pd.set_option('display.max_colwidth', None)  # Show full content of each column

dirpath = '../data_store/data/marcell_MN/'

all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
N = len(all_ATL03)

coords = (-93.4541, 47.5049)

# for i in range(N):
for i in [1,3,6,14,13,22]:
    # print(all_ATL03[i], all_ATL08[i])

    # BASE
    # data = pvpg_parallel(all_ATL03[i], all_ATL08[i], coords=coords, width=5,height=5,file_index=i, alt_thresh=80,\
    #                      altitude=413, threshold=1, graph_detail=1)

    # BLOCKS
    # data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=coords, width=5,height=5,file_index=i, alt_thresh=80,\
    #                      altitude=413, threshold=1, small_box=10, graph_detail=2, loss='linear', rebinned=0, f_scale=.05,\
    #                      outlier_removal=2,method='bimodal')
    data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=coords, width=4,height=4,file_index=i, alt_thresh=80,\
                         altitude=413, threshold=1, small_box=8.05, graph_detail=1, loss='linear', rebinned=30, f_scale=.05,\
                         outlier_removal=.1,method='bimodal', landcover='all')
    # data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=coords, width=5,height=5,file_index=i, alt_thresh=80,\
    #                      altitude=413, threshold=1, small_box=10, graph_detail=1, loss='arctan', rebinned=30, f_scale=.05,
    #                      outlier_removal=3)
# Out:
# Nothing in rebinned section for marcell_MN file 1's beam 1.
# Nothing in rebinned section for marcell_MN file 1's beam 2.
# Nothing in rebinned section for marcell_MN file 1's beam 3.
# Nothing in rebinned section for marcell_MN file 1's beam 4.
# Nothing in rebinned section for marcell_MN file 3's beam 1.
# Nothing in rebinned section for marcell_MN file 3's beam 2.
# Nothing in rebinned section for marcell_MN file 3's beam 3.
# Nothing in rebinned section for marcell_MN file 3's beam 4.
# Nothing in rebinned section for marcell_MN file 14's beam 3.
# Nothing in rebinned section for marcell_MN file 14's beam 4.
# Nothing in rebinned section for marcell_MN file 14's beam 5.
# Nothing in rebinned section for marcell_MN file 14's beam 6.
# Nothing in rebinned section for marcell_MN file 22's beam 1.
# Nothing in rebinned section for marcell_MN file 22's beam 2.
# Nothing in rebinned section for marcell_MN file 22's beam 3.
# Nothing in rebinned section for marcell_MN file 22's beam 4.

# %% [markdown]
# # Delta Junction

# %%
from scripts.parallel_blocks import *
# from scripts.parallel_phoreal import *
# pd.set_option('display.max_rows', None)  # Show all rows
# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.width', None)  # Adjust the display width to show all columns
# pd.set_option('display.max_colwidth', None)  # Show full content of each column

dirpath = '../data_store/data/delta_junction/'

all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
N = len(all_ATL03)

coords = (-145.7514, 63.8811)

# for i in range(N):
for i in [3]:
    # print(all_ATL03[i], all_ATL08[i])

    # BASE
    # data = pvpg_parallel(all_ATL03[i], all_ATL08[i], coords=coords, width=5,height=5,file_index=i, alt_thresh=80,\
    #                      altitude=504, threshold=1, graph_detail=1)

    # BLOCKS
    # data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=coords, width=4,height=4,file_index=i, alt_thresh=80,\
    #                      altitude=504, threshold=1, small_box=8, graph_detail=1, loss='linear', rebinned=0, f_scale=.05,\
    #                      outlier_removal=2,method='bimodal')
    # data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=coords, width=4,height=4,file_index=i, alt_thresh=80,\
    #                      altitude=504, threshold=1, small_box=8.05, graph_detail=2, loss='linear', rebinned=0, f_scale=.05,\
    #                      outlier_removal=2,method='bimodal')
    for p in [True, False]:
        data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=coords, width=4,height=4,file_index=i, alt_thresh=80,\
                             altitude=504, threshold=1, small_box=8.05, graph_detail=1, loss='linear', rebinned=30, f_scale=.05,
                             outlier_removal=.3, method='normal', landcover='forest', trim_atmospheric=p)
    
        df_grouped = data.groupby(['camera','date','lat','lon']).agg({
            'pvpg': 'mean',
            'pv': 'max',
            'pg': 'max',
            'data_quantity': 'max',
            'pv_ratio_mean': 'mean',
            'pv_ratio_max': 'mean',
            'snr': 'mean',
            'msw_flag': 'mean',
            'segment_landcover': pd.Series.mode,
            'cloud_flag_atm': 'mean',
            'layer_flag': 'mean'
        }).reset_index()
        
        print(df_grouped)
# Out:
# Nothing in rebinned section for delta_junction file 3's beam 1.
# Nothing in rebinned section for delta_junction file 3's beam 2.
#            camera        date        lat         lon      pvpg        pv  \
# 0  delta_junction  16/05/2019  63.881325 -145.750888  0.423552  0.991544
#
#          pg  data_quantity  pv_ratio_mean  pv_ratio_max       snr  msw_flag  \
# 0  2.341018            106       1.178063      1.178798  0.156588  0.017143
#
#    segment_landcover  cloud_flag_atm  layer_flag
# 0              111.0        0.017143    0.062857
# Nothing in rebinned section for delta_junction file 3's beam 1.
# Nothing in rebinned section for delta_junction file 3's beam 2.
#            camera        date        lat         lon      pvpg        pv  \
# 0  delta_junction  16/05/2019  63.881325 -145.750888  0.426369  0.990266
#
#          pg  data_quantity  pv_ratio_mean  pv_ratio_max       snr  msw_flag  \
# 0  2.322556            111       1.177971      1.174909  0.156597  0.060109
#
#    segment_landcover  cloud_flag_atm  layer_flag
# 0              111.0        0.060109    0.103825

# %% [markdown]
# # Sodankyla

# %%
from scripts.parallel_blocks import *
# pd.set_option('display.max_rows', None)  # Show all rows
# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.width', None)  # Adjust the display width to show all columns
# pd.set_option('display.max_colwidth', None)  # Show full content of each column

dirpath = '../data_store/data/sodankyla_full/'

all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
N = len(all_ATL03)

coords = (26.634154, 67.361833)

# for i in range(N):
for i in [13]:
    data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=coords, width=4,height=4,file_index=i, alt_thresh=80,\
                         altitude=185, threshold=1, small_box=1, graph_detail=1, loss='linear', rebinned=30, f_scale=.05,\
                         outlier_removal=0.22,method='bimodal', landcover='forest')

    df_grouped = data.groupby(['camera','date','lat','lon']).agg({
        'pvpg': 'mean',
        'pv': 'max',
        'pg': 'max',
        'data_quantity': 'max',
        'pv_ratio_max': 'mean',
        'pv_ratio_mean': 'mean',
        'snr': 'mean',
        'msw_flag': 'mean',
        'segment_landcover': pd.Series.mode,
        'cloud_flag_atm': 'mean',
        'layer_flag': 'mean'
    }).reset_index()
    
    print(df_grouped)
# Out:
# Nothing in rebinned section for sodankyla_full file 13's beam 1.
# Nothing in rebinned section for sodankyla_full file 13's beam 2.
# Nothing in rebinned section for sodankyla_full file 13's beam 3.
# Nothing in rebinned section for sodankyla_full file 13's beam 4.
#            camera        date        lat        lon       pvpg         pv  \
# 0  sodankyla_full  10/09/2020  67.330301  26.552235   0.977790   1.760182
# 1  sodankyla_full  10/09/2020  67.339310  26.552235   1.009822   1.607915
# 2  sodankyla_full  10/09/2020  67.348319  26.552235   0.994220   1.664342
# 3  sodankyla_full  10/09/2020  67.357328  26.552235   0.817525   1.515169
# 4  sodankyla_full  10/09/2020  67.366338  26.552235   1.007985   1.608754
# 5  sodankyla_full  10/09/2020  67.375347  26.552235   1.010643   1.887995
# 6  sodankyla_full  10/09/2020  67.384356  26.552235   0.794107   1.561868
# 7  sodankyla_full  10/09/2020  67.393365  26.552235   0.965703   1.733695
# 8  sodankyla_full  10/09/2020  67.393365  26.575640  16.616938  16.000000
#
#          pg  data_quantity  pv_ratio_max  pv_ratio_mean        snr  msw_flag  \
# 0  1.800164             34      1.516536       1.516536   9.310324       0.0
# 1  1.592276             28      1.379281       1.379281   9.824427       0.0
# 2  1.674018             11      1.378488       1.378488   7.700329       0.0
# 3  1.853361             24      1.466839       1.466839   8.764168       0.0
# 4  1.596009             20      1.450550       1.450550   8.162292       0.0
# 5  1.868112             34      1.613539       1.613539   8.097563       0.0
# 6  1.966822             34      1.553619       1.553619   8.825797       0.0
# 7  1.795266             24      1.556508       1.556508   8.449843       0.0
# 8  0.962873              8           NaN            NaN  11.310361       0.0
#
#    segment_landcover  cloud_flag_atm  layer_flag
# 0              111.0             0.0         0.0
# 1              111.0             0.0         0.0
# 2              111.0             0.0         0.0
# 3              111.0             0.0         0.0
# 4              111.0             0.0         0.0
# 5              111.0             0.0         0.0
# 6              111.0             0.0         0.0
# 7              111.0             0.0         0.0
# 8              111.0             0.0         0.0

# %%
from scripts.parallel_blocks import *
# pd.set_option('display.max_rows', None)  # Show all rows
# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.width', None)  # Adjust the display width to show all columns
# pd.set_option('display.max_colwidth', None)  # Show full content of each column

dirpath = '../data_store/data/sodankyla_full/'

all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
N = len(all_ATL03)

coords = (26.634154, 67.361833)
# print(len(all_ATL03))
# for i in range(N):
for i in [36]:
    data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=coords, width=4,height=4,file_index=i, alt_thresh=80,\
                         altitude=185, threshold=3, small_box=8.05, graph_detail=1, loss='linear', rebinned=30, f_scale=.05,\
                         outlier_removal=False,method='normal', landcover='forest', w=[1,0.25])

    df_grouped = data.groupby(['camera','date','lat','lon']).agg({
        'pvpg': 'mean',
        'pv': 'max',
        'pg': 'max',
        'data_quantity': 'max',
        'pv_ratio_max': 'mean',
        'pv_ratio_mean': 'mean',
        'snr': 'mean',
        'msw_flag': 'mean',
        'segment_landcover': pd.Series.mode,
        'cloud_flag_atm': 'mean',
        'layer_flag': 'mean'
    }).reset_index()
    
    print(df_grouped)
# Out:
#            camera        date        lat        lon      pvpg        pv  \
# 0  sodankyla_full  03/04/2024  67.362058  26.634739  0.257336  1.896506
#
#          pg  data_quantity  pv_ratio_max  pv_ratio_mean         snr  msw_flag  \
# 0  7.369757             96      2.244897       2.257087  135.199363       0.0
#
#    segment_landcover  cloud_flag_atm  layer_flag
# 0              111.0             0.0         0.0

# %%
from scripts.parallel_blocks import *
# pd.set_option('display.max_rows', None)  # Show all rows
# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.width', None)  # Adjust the display width to show all columns
# pd.set_option('display.max_colwidth', None)  # Show full content of each column

dirpath = '../data_store/data/sodankyla_full/'

all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
N = len(all_ATL03)

coords = (26.634154, 67.361833)

# for i in range(N):
for i in [36]:
    data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=coords, width=4,height=4,file_index=i, alt_thresh=80,\
                         altitude=185, threshold=3, small_box=8.05, graph_detail=1, loss='linear', rebinned=30, f_scale=.05,\
                         outlier_removal=False,method='bimodal', landcover='forest', w=[1,1])

    df_grouped = data.groupby(['camera','date','lat','lon']).agg({
        'pvpg': 'mean',
        'pv': 'max',
        'pg': 'max',
        'data_quantity': 'max',
        'pv_ratio_max': 'mean',
        'pv_ratio_mean': 'mean',
        'snr': 'mean',
        'msw_flag': 'mean',
        'segment_landcover': pd.Series.mode,
        'cloud_flag_atm': 'mean',
        'layer_flag': 'mean'
    }).reset_index()
    
    print(df_grouped)
# Out:
#            camera        date        lat        lon      pvpg        pv  \
# 0  sodankyla_full  03/04/2024  67.362058  26.634739  0.693189  3.962769
#
#          pg  data_quantity  pv_ratio_max  pv_ratio_mean         snr  msw_flag  \
# 0  5.716722             96      2.892737       2.717977  135.199363       0.0
#
#    segment_landcover  cloud_flag_atm  layer_flag
# 0              111.0             0.0         0.0

# %% [markdown]
# # Old Jack Pine

# %%
from scripts.parallel_blocks import *

dirpath = '../scratch/data/old_jack_pine/'

all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
N = len(all_ATL03)
print(N-1)

coords = (-104.6920, 53.9163)

for i in [23]:#range(N):
    data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=coords, width=4,height=4,file_index=i, alt_thresh=80,\
                         altitude=451, threshold=3, small_box=1, graph_detail=1, loss='linear', rebinned=30, f_scale=.05,\
                         outlier_removal=0.22,method='normal', landcover='forest', trim_atmospheric=False)
    # print(data)
# Out:
# 28
# Beam 1, box 0 in old_jack_pine file 23 has no data.
# Beam 1, box 1 in old_jack_pine file 23 has no data.
# Beam 1, box 2 in old_jack_pine file 23 has no data.
# Beam 1, box 3 in old_jack_pine file 23 has no data.
# Beam 1, box 5 in old_jack_pine file 23 has no data.
# Beam 1, box 6 in old_jack_pine file 23 has no data.
# Beam 1, box 7 in old_jack_pine file 23 has no data.
# Beam 1, box 8 in old_jack_pine file 23 has no data.
# Beam 1, box 9 in old_jack_pine file 23 has no data.
# Beam 1, box 10 in old_jack_pine file 23 has no data.
# Beam 1, box 11 in old_jack_pine file 23 has no data.
# Beam 1, box 13 in old_jack_pine file 23 has no data.
# Beam 1, box 14 in old_jack_pine file 23 has no data.
# Beam 1, box 15 in old_jack_pine file 23 has no data.
# Beam 1, box 16 in old_jack_pine file 23 has no data.
# Beam 1, box 17 in old_jack_pine file 23 has no data.
# Beam 1, box 18 in old_jack_pine file 23 has no data.
# Beam 1, box 19 in old_jack_pine file 23 has no data.
# Beam 1, box 21 in old_jack_pine file 23 has no data.
# Beam 1, box 22 in old_jack_pine file 23 has no data.
# Beam 1, box 23 in old_jack_pine file 23 has no data.
# Beam 1, box 24 in old_jack_pine file 23 has no data.
# Beam 1, box 25 in old_jack_pine file 23 has no data.
# Beam 1, box 26 in old_jack_pine file 23 has no data.
# Beam 1, box 27 in old_jack_pine file 23 has no data.
# Beam 1, box 29 in old_jack_pine file 23 has no data.
# Beam 1, box 30 in old_jack_pine file 23 has no data.
# Beam 1, box 31 in old_jack_pine file 23 has no data.
# Beam 1, box 32 in old_jack_pine file 23 has no data.
# Beam 1, box 33 in old_jack_pine file 23 has no data.
# Beam 1, box 34 in old_jack_pine file 23 has no data.
# Beam 1, box 35 in old_jack_pine file 23 has no data.
# Beam 1, box 37 in old_jack_pine file 23 has no data.
# Beam 1, box 38 in old_jack_pine file 23 has no data.
# Beam 1, box 39 in old_jack_pine file 23 has no data.
# Beam 1, box 40 in old_jack_pine file 23 has no data.
# Beam 1, box 41 in old_jack_pine file 23 has no data.
# Beam 1, box 42 in old_jack_pine file 23 has no data.
# Beam 1, box 43 in old_jack_pine file 23 has no data.
# Beam 1, box 45 in old_jack_pine file 23 has no data.
# Beam 1, box 46 in old_jack_pine file 23 has no data.
# Beam 1, box 47 in old_jack_pine file 23 has no data.
# Beam 1, box 48 in old_jack_pine file 23 has no data.
# Beam 1, box 49 in old_jack_pine file 23 has no data.
# Beam 1, box 50 in old_jack_pine file 23 has no data.
# Beam 1, box 53 in old_jack_pine file 23 has no data.
# Beam 1, box 54 in old_jack_pine file 23 has no data.
# Beam 1, box 55 in old_jack_pine file 23 has no data.
# Beam 1, box 56 in old_jack_pine file 23 has no data.
# Beam 1, box 57 in old_jack_pine file 23 has no data.
# Beam 1, box 58 in old_jack_pine file 23 has no data.
# Beam 1, box 60 in old_jack_pine file 23 has no data.
# Beam 1, box 61 in old_jack_pine file 23 has no data.
# Beam 1, box 62 in old_jack_pine file 23 has no data.
# Beam 1, box 63 in old_jack_pine file 23 has no data.
# Beam 1, box 64 in old_jack_pine file 23 has no data.
# Beam 1, box 65 in old_jack_pine file 23 has no data.
# Beam 1, box 66 in old_jack_pine file 23 has no data.
# Beam 1, box 67 in old_jack_pine file 23 has no data.
# Beam 1, box 68 in old_jack_pine file 23 has no data.
# Beam 1, box 69 in old_jack_pine file 23 has no data.
# Beam 1, box 70 in old_jack_pine file 23 has no data.
# Beam 1, box 71 in old_jack_pine file 23 has no data.
# Beam 2, box 0 in old_jack_pine file 23 has no data.
# Beam 2, box 1 in old_jack_pine file 23 has no data.
# Beam 2, box 2 in old_jack_pine file 23 has no data.
# Beam 2, box 3 in old_jack_pine file 23 has no data.
# Beam 2, box 5 in old_jack_pine file 23 has no data.
# Beam 2, box 6 in old_jack_pine file 23 has no data.
# Beam 2, box 7 in old_jack_pine file 23 has no data.
# Beam 2, box 8 in old_jack_pine file 23 has no data.
# Beam 2, box 9 in old_jack_pine file 23 has no data.
# Beam 2, box 10 in old_jack_pine file 23 has no data.
# Beam 2, box 11 in old_jack_pine file 23 has no data.
# Beam 2, box 13 in old_jack_pine file 23 has no data.
# Beam 2, box 14 in old_jack_pine file 23 has no data.
# Beam 2, box 15 in old_jack_pine file 23 has no data.
# Beam 2, box 16 in old_jack_pine file 23 has no data.
# Beam 2, box 17 in old_jack_pine file 23 has no data.
# Beam 2, box 18 in old_jack_pine file 23 has no data.
# Beam 2, box 19 in old_jack_pine file 23 has no data.
# Beam 2, box 21 in old_jack_pine file 23 has no data.
# Beam 2, box 22 in old_jack_pine file 23 has no data.
# Beam 2, box 23 in old_jack_pine file 23 has no data.
# Beam 2, box 24 in old_jack_pine file 23 has no data.
# Beam 2, box 25 in old_jack_pine file 23 has no data.
# Beam 2, box 26 in old_jack_pine file 23 has no data.
# Beam 2, box 27 in old_jack_pine file 23 has no data.
# Beam 2, box 29 in old_jack_pine file 23 has no data.
# Beam 2, box 30 in old_jack_pine file 23 has no data.
# Beam 2, box 31 in old_jack_pine file 23 has no data.
# Beam 2, box 32 in old_jack_pine file 23 has no data.
# Beam 2, box 33 in old_jack_pine file 23 has no data.
# Beam 2, box 34 in old_jack_pine file 23 has no data.
# Beam 2, box 35 in old_jack_pine file 23 has no data.
# Beam 2, box 37 in old_jack_pine file 23 has no data.
# Beam 2, box 38 in old_jack_pine file 23 has no data.
# Beam 2, box 39 in old_jack_pine file 23 has no data.
# Beam 2, box 40 in old_jack_pine file 23 has no data.
# Beam 2, box 41 in old_jack_pine file 23 has no data.
# Beam 2, box 42 in old_jack_pine file 23 has no data.
# Beam 2, box 43 in old_jack_pine file 23 has no data.
# Beam 2, box 45 in old_jack_pine file 23 has no data.
# Beam 2, box 46 in old_jack_pine file 23 has no data.
# Beam 2, box 47 in old_jack_pine file 23 has no data.
# Beam 2, box 48 in old_jack_pine file 23 has no data.
# Beam 2, box 49 in old_jack_pine file 23 has no data.
# Beam 2, box 50 in old_jack_pine file 23 has no data.
# Beam 2, box 51 in old_jack_pine file 23 has no data.
# Beam 2, box 53 in old_jack_pine file 23 has no data.
# Beam 2, box 54 in old_jack_pine file 23 has no data.
# Beam 2, box 55 in old_jack_pine file 23 has no data.
# Beam 2, box 56 in old_jack_pine file 23 has no data.
# Beam 2, box 57 in old_jack_pine file 23 has no data.
# Beam 2, box 58 in old_jack_pine file 23 has no data.
# Beam 2, box 61 in old_jack_pine file 23 has no data.
# Beam 2, box 62 in old_jack_pine file 23 has no data.
# Beam 2, box 63 in old_jack_pine file 23 has no data.
# Beam 2, box 64 in old_jack_pine file 23 has no data.
# Beam 2, box 65 in old_jack_pine file 23 has no data.
# Beam 2, box 66 in old_jack_pine file 23 has no data.
# Beam 2, box 67 in old_jack_pine file 23 has no data.
# Beam 2, box 68 in old_jack_pine file 23 has no data.
# Beam 2, box 69 in old_jack_pine file 23 has no data.
# Beam 2, box 70 in old_jack_pine file 23 has no data.
# Beam 2, box 71 in old_jack_pine file 23 has no data.
# Beam 3, box 0 in old_jack_pine file 23 has no data.
# Beam 3, box 2 in old_jack_pine file 23 has no data.
# Beam 3, box 3 in old_jack_pine file 23 has no data.
# Beam 3, box 4 in old_jack_pine file 23 has no data.
# Beam 3, box 5 in old_jack_pine file 23 has no data.
# Beam 3, box 6 in old_jack_pine file 23 has no data.
# Beam 3, box 7 in old_jack_pine file 23 has no data.
# Beam 3, box 8 in old_jack_pine file 23 has no data.
# Beam 3, box 10 in old_jack_pine file 23 has no data.
# Beam 3, box 11 in old_jack_pine file 23 has no data.
# Beam 3, box 12 in old_jack_pine file 23 has no data.
# Beam 3, box 13 in old_jack_pine file 23 has no data.
# Beam 3, box 14 in old_jack_pine file 23 has no data.
# Beam 3, box 15 in old_jack_pine file 23 has no data.
# Beam 3, box 16 in old_jack_pine file 23 has no data.
# Beam 3, box 18 in old_jack_pine file 23 has no data.
# Beam 3, box 19 in old_jack_pine file 23 has no data.
# Beam 3, box 20 in old_jack_pine file 23 has no data.
# Beam 3, box 21 in old_jack_pine file 23 has no data.
# Beam 3, box 22 in old_jack_pine file 23 has no data.
# Beam 3, box 23 in old_jack_pine file 23 has no data.
# Beam 3, box 24 in old_jack_pine file 23 has no data.
# Beam 3, box 26 in old_jack_pine file 23 has no data.
# Beam 3, box 27 in old_jack_pine file 23 has no data.
# Beam 3, box 28 in old_jack_pine file 23 has no data.
# Beam 3, box 29 in old_jack_pine file 23 has no data.
# Beam 3, box 30 in old_jack_pine file 23 has no data.
# Beam 3, box 31 in old_jack_pine file 23 has no data.
# Beam 3, box 34 in old_jack_pine file 23 has no data.
# Beam 3, box 35 in old_jack_pine file 23 has no data.
# Beam 3, box 36 in old_jack_pine file 23 has no data.
# Beam 3, box 37 in old_jack_pine file 23 has no data.
# Beam 3, box 38 in old_jack_pine file 23 has no data.
# Beam 3, box 39 in old_jack_pine file 23 has no data.
# Beam 3, box 41 in old_jack_pine file 23 has no data.
# Beam 3, box 42 in old_jack_pine file 23 has no data.
# Beam 3, box 43 in old_jack_pine file 23 has no data.
# Beam 3, box 44 in old_jack_pine file 23 has no data.
# Beam 3, box 45 in old_jack_pine file 23 has no data.
# Beam 3, box 46 in old_jack_pine file 23 has no data.
# Beam 3, box 47 in old_jack_pine file 23 has no data.
# Beam 3, box 49 in old_jack_pine file 23 has no data.
# Beam 3, box 50 in old_jack_pine file 23 has no data.
# Beam 3, box 51 in old_jack_pine file 23 has no data.
# Beam 3, box 52 in old_jack_pine file 23 has no data.
# Beam 3, box 53 in old_jack_pine file 23 has no data.
# Beam 3, box 54 in old_jack_pine file 23 has no data.
# Beam 3, box 55 in old_jack_pine file 23 has no data.
# Beam 3, box 57 in old_jack_pine file 23 has no data.
# Beam 3, box 58 in old_jack_pine file 23 has no data.
# Beam 3, box 59 in old_jack_pine file 23 has no data.
# Beam 3, box 60 in old_jack_pine file 23 has no data.
# Beam 3, box 61 in old_jack_pine file 23 has no data.
# Beam 3, box 62 in old_jack_pine file 23 has no data.
# Beam 3, box 63 in old_jack_pine file 23 has no data.
# Beam 3, box 64 in old_jack_pine file 23 has no data.
# Beam 3, box 65 in old_jack_pine file 23 has no data.
# Beam 3, box 66 in old_jack_pine file 23 has no data.
# Beam 3, box 67 in old_jack_pine file 23 has no data.
# Beam 3, box 68 in old_jack_pine file 23 has no data.
# Beam 3, box 69 in old_jack_pine file 23 has no data.
# Beam 3, box 70 in old_jack_pine file 23 has no data.
# Beam 3, box 71 in old_jack_pine file 23 has no data.
# Beam 4, box 0 in old_jack_pine file 23 has no data.
# Beam 4, box 2 in old_jack_pine file 23 has no data.
# Beam 4, box 3 in old_jack_pine file 23 has no data.
# Beam 4, box 4 in old_jack_pine file 23 has no data.
# Beam 4, box 5 in old_jack_pine file 23 has no data.
# Beam 4, box 6 in old_jack_pine file 23 has no data.
# Beam 4, box 7 in old_jack_pine file 23 has no data.
# Beam 4, box 8 in old_jack_pine file 23 has no data.
# Beam 4, box 9 in old_jack_pine file 23 has no data.
# Beam 4, box 10 in old_jack_pine file 23 has no data.
# Beam 4, box 11 in old_jack_pine file 23 has no data.
# Beam 4, box 12 in old_jack_pine file 23 has no data.
# Beam 4, box 13 in old_jack_pine file 23 has no data.
# Beam 4, box 14 in old_jack_pine file 23 has no data.
# Beam 4, box 15 in old_jack_pine file 23 has no data.
# Beam 4, box 16 in old_jack_pine file 23 has no data.
# Beam 4, box 18 in old_jack_pine file 23 has no data.
# Beam 4, box 19 in old_jack_pine file 23 has no data.
# Beam 4, box 20 in old_jack_pine file 23 has no data.
# Beam 4, box 21 in old_jack_pine file 23 has no data.
# Beam 4, box 22 in old_jack_pine file 23 has no data.
# Beam 4, box 23 in old_jack_pine file 23 has no data.
# Beam 4, box 24 in old_jack_pine file 23 has no data.
# Beam 4, box 26 in old_jack_pine file 23 has no data.
# Beam 4, box 27 in old_jack_pine file 23 has no data.
# Beam 4, box 28 in old_jack_pine file 23 has no data.
# Beam 4, box 29 in old_jack_pine file 23 has no data.
# Beam 4, box 30 in old_jack_pine file 23 has no data.
# Beam 4, box 31 in old_jack_pine file 23 has no data.
# Beam 4, box 32 in old_jack_pine file 23 has no data.
# Beam 4, box 34 in old_jack_pine file 23 has no data.
# Beam 4, box 35 in old_jack_pine file 23 has no data.
# Beam 4, box 36 in old_jack_pine file 23 has no data.
# Beam 4, box 37 in old_jack_pine file 23 has no data.
# Beam 4, box 38 in old_jack_pine file 23 has no data.
# Beam 4, box 39 in old_jack_pine file 23 has no data.
# Beam 4, box 42 in old_jack_pine file 23 has no data.
# Beam 4, box 43 in old_jack_pine file 23 has no data.
# Beam 4, box 44 in old_jack_pine file 23 has no data.
# Beam 4, box 45 in old_jack_pine file 23 has no data.
# Beam 4, box 46 in old_jack_pine file 23 has no data.
# Beam 4, box 47 in old_jack_pine file 23 has no data.
# Beam 4, box 49 in old_jack_pine file 23 has no data.
# Beam 4, box 50 in old_jack_pine file 23 has no data.
# Beam 4, box 51 in old_jack_pine file 23 has no data.
# Beam 4, box 52 in old_jack_pine file 23 has no data.
# Beam 4, box 53 in old_jack_pine file 23 has no data.
# Beam 4, box 54 in old_jack_pine file 23 has no data.
# Beam 4, box 55 in old_jack_pine file 23 has no data.
# Beam 4, box 57 in old_jack_pine file 23 has no data.
# Beam 4, box 58 in old_jack_pine file 23 has no data.
# Beam 4, box 59 in old_jack_pine file 23 has no data.
# Beam 4, box 60 in old_jack_pine file 23 has no data.
# Beam 4, box 61 in old_jack_pine file 23 has no data.
# Beam 4, box 62 in old_jack_pine file 23 has no data.
# Beam 4, box 63 in old_jack_pine file 23 has no data.
# Beam 4, box 64 in old_jack_pine file 23 has no data.
# Beam 4, box 65 in old_jack_pine file 23 has no data.
# Beam 4, box 66 in old_jack_pine file 23 has no data.
# Beam 4, box 67 in old_jack_pine file 23 has no data.
# Beam 4, box 68 in old_jack_pine file 23 has no data.
# Beam 4, box 69 in old_jack_pine file 23 has no data.
# Beam 4, box 70 in old_jack_pine file 23 has no data.
# Beam 4, box 71 in old_jack_pine file 23 has no data.
# Nothing in rebinned section for old_jack_pine file 23's beam 5.
# Nothing in rebinned section for old_jack_pine file 23's beam 6.
