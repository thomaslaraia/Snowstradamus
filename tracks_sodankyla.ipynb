# %%
from scripts.track_pairs import *
from scripts.show_tracks import *

dirpath = '../data/sodankyla_full/'
impath = '../data/sodankyla_cam/'
# all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed = True)
all_ATL03, all_ATL08 = track_pairs(dirpath)

# extent = None
extent = (24,30,62,72)
fig, ax = map_setup(map_path = impath + '/sodankyla_cam_image.tiff', extent = extent)

# ax = show_tracks_only_atl03(failed_ATL03, ax)
ax = show_tracks([all_ATL03[0]], [all_ATL08[0]], ax, c='Ev', CBAR = 1)

# i = 5
# ax = show_tracks([all_ATL03[i]], [all_ATL08[i]], ax, c='Eg', CBAR = 1)

# Show the plot
plt.show()

# for f in failed_ATL03:
#     print(f)

# %%
from scripts.track_pairs import *
from scripts.show_tracks import *

dirpath = '../data/FMI_cam_sodankyla_failed/'
all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed = True)

extent = None
# extent = (26.53,26.735,67.32,67.405)
extent = (24,30,60,75)
fig, ax = map_setup(map_path = dirpath + '/sodankyla_cam_image.tiff', extent = extent)

ax = show_tracks_only_atl03(failed_ATL03, ax)
ax = show_tracks(all_ATL03, all_ATL08, ax, c='Ev', CBAR = 1)

# i = 5
# ax = show_tracks([all_ATL03[i]], [all_ATL08[i]], ax, c='Eg', CBAR = 1)

# Show the plot
plt.show()

for f in all_ATL03:
    print(f)
# Out:
# ../data/FMI_cam_sodankyla_failed/ATL03_20181014020411_02360105_006_02.h5
# ../data/FMI_cam_sodankyla_failed/ATL03_20181025125420_04110103_006_02.h5
# ../data/FMI_cam_sodankyla_failed/ATL03_20181214230756_11810105_006_02.h5
# ../data/FMI_cam_sodankyla_failed/ATL03_20181226095805_13560103_006_02.h5
# ../data/FMI_cam_sodankyla_failed/ATL03_20190315184755_11810205_006_02.h5
# ../data/FMI_cam_sodankyla_failed/ATL03_20190713130322_02360405_006_02.h5
# ../data/FMI_cam_sodankyla_failed/ATL03_20190724235335_04110403_006_02.h5
