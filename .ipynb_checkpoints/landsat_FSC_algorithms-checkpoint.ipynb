# %%
import matplotlib.pyplot as plt
from shapely.geometry import Polygon
import numpy as np
import matplotlib.image as mpimg

# Define approximate polygon (NDSI, NDVI)
region_coords = [
    (0.4, 1),
    (0.33, 0.9),
    (0.26, 0.75),
    (0.2, 0.59),
    (0.1, 0.24),  # bottom left
    (0.2,0.2),
    (0.4, 0.1),   # top right
]

# Extract polygon coordinates
polygon = Polygon(region_coords)
x_poly, y_poly = zip(*polygon.exterior.coords)

# Load the background image
img = mpimg.imread('./images/klein.png')

# Plot
fig, ax = plt.subplots(figsize=(12, 8))

# Show background image to fill the entire axes
ax.imshow(
    img,
    extent=(-1, 1, -1, 1),   # match your axis limits
    aspect='auto',
    zorder=0
)

# Shaded polygon on top
ax.fill(x_poly, y_poly, color='blue', alpha=0.5, label='Klein Snow Region', zorder=1)

# Axes and labels
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.set_xlabel('NDSI')
ax.set_ylabel('NDVI')
ax.set_title('Klein et al. (1998) Snow Classification Region\n(NDSI vs NDVI)')
ax.grid(True, zorder=2)

ax.legend()
plt.show()

# %%
from scripts.imports import *
from rasterio.enums import Resampling
from shapely.geometry import Polygon, Point

SR_SCALE = 0.0000275
SR_OFFSET = -0.2

# positions for SR bands in your stacks
L7_SR_IDX = slice(0, 6)   # SR_B1..SR_B5, SR_B7
L8_SR_IDX = slice(0, 7)   # SR_B1..SR_B7

def _sr_slice(landsat_type):
    return L7_SR_IDX if landsat_type == 'Landsat7' else L8_SR_IDX

def _is_dn_encoded(sr_subset, high_thresh=10.0, frac_thresh=1e-3):
    """
    Heuristic: SR reflectance should live in ~[0,1] with rare outliers.
    If a *nontrivial* fraction (> frac_thresh) of pixels exceed `high_thresh`,
    call it DN-encoded (needs scaling). Robust to a few 1.6 spikes.
    """
    a = sr_subset.values
    a = a[np.isfinite(a)]
    if a.size == 0:
        return False
    frac_high = (a > high_thresh).mean()
    return frac_high > frac_thresh

def _mask_l7_spikes_inplace(sr, spike=1.5):
    """
    L7 quirk: ~1.6 in B1/B2/B3 over water. Mask across all SR bands.
    Operates in place on a (band,y,x) DataArray assumed reflectance-ish.
    """
    b1 = sr.isel(band=0)
    b2 = sr.isel(band=1)
    b3 = sr.isel(band=2)
    bad = (b1 > spike) | (b2 > spike) | (b3 > spike)
    sr[:] = sr.where(~bad).clip(0, 1)

def ensure_reflectance(landsat_da, landsat_type, log_prefix=""):
    """
    Returns a DataArray where SR bands are guaranteed reflectance in [0,1].
    - Detect DN per scene; if DN-like → apply SR_SCALE/OFFSET.
    - Always mask L7 ~1.6 spikes across SR bands.
    - Clip SR to [0,1]. QA/thermal untouched.
    Also returns a tiny dict of what happened for debugging.
    """
    da = landsat_da.copy()
    s = _sr_slice(landsat_type)
    sr_sub = da.isel(band=s)  # positional slice

    actions = {"dn_scaled": False, "l7_spikes_masked": False}

    # 1) DN detection (both L7 & L8)
    if _is_dn_encoded(sr_sub):
        scaled = sr_sub * SR_SCALE + SR_OFFSET
        scaled = scaled.clip(0, 1)
        # assign back by position
        da.values[s, :, :] = scaled.values
        actions["dn_scaled"] = True
        sr_sub = da.isel(band=s)  # refresh view

    # 2) L7 spike masking (after we are in reflectance space)
    if landsat_type == 'Landsat7':
        _mask_l7_spikes_inplace(sr_sub, spike=1.5)
        da.values[s, :, :] = sr_sub.values
        actions["l7_spikes_masked"] = True

    # 3) Final clip to be safe
    da.values[s, :, :] = np.clip(da.values[s, :, :], 0, 1)

    # Optional: quick log
    try:
        m = float(np.nanmean(da.isel(band=s).values))
        mn = float(np.nanmin(da.isel(band=s).values))
        mx = float(np.nanmax(da.isel(band=s).values))
        print(f"{log_prefix}{landsat_type} reflectance ready | scaled={actions['dn_scaled']} "
              f"| l7_masked={actions['l7_spikes_masked']} | mean/min/max: {m:.4f}/{mn:.4f}/{mx:.4f}")
    except Exception:
        pass

    return da, actions

def scale_l8_sr_to_reflectance(landsat_da):
    """Apply L2 SR scale/offset to SR_B1..SR_B7 for Landsat 8."""
    sr = landsat_da.copy()
    sr_vals = sr.isel(band=L8_SR_IDX) * SR_SCALE + SR_OFFSET
    sr_vals = sr_vals.clip(0, 1)
    sr.loc[dict(band=landsat_da.band.values[L8_SR_IDX])] = sr_vals
    return sr

def mask_l7_spikes(landsat_da, spike_thresh=1.5):
    """Mask pixels where any of B1/B2/B3 exceed ~1.6 across SR bands 1–6."""
    sr = landsat_da.copy()
    b1 = sr.isel(band=0)
    b2 = sr.isel(band=1)
    b3 = sr.isel(band=2)
    bad = (b1 > spike_thresh) | (b2 > spike_thresh) | (b3 > spike_thresh)

    sr_vals = sr.isel(band=L7_SR_IDX).where(~bad)
    sr_vals = sr_vals.clip(0, 1)
    sr.loc[dict(band=landsat_da.band.values[L7_SR_IDX])] = sr_vals
    return sr

def prepare_landsat_sr(landsat_da, landsat_type):
    """Apply proper correction depending on sensor."""
    if landsat_type == 'Landsat8':
        return scale_l8_sr_to_reflectance(landsat_da)
    elif landsat_type == 'Landsat7':
        return mask_l7_spikes(landsat_da, spike_thresh=1.5)
    else:
        return landsat_da

def extract_core_sr(landsat_da, landsat_type):
    """
    Return (blue, green, red, nir, swir1) as reflectance in [0,1],
    with consistent meaning across sensors.
    """
    if landsat_type == 'Landsat7':
        # ('SR_B1','SR_B2','SR_B3','SR_B4','SR_B5','SR_B7', ...)
        blue  = landsat_da.isel(band=0)  # SR_B1
        green = landsat_da.isel(band=1)  # SR_B2
        red   = landsat_da.isel(band=2)  # SR_B3
        nir   = landsat_da.isel(band=3)  # SR_B4
        swir1 = landsat_da.isel(band=4)  # SR_B5 (1.6 µm)
    else:
        # ('SR_B1','SR_B2','SR_B3','SR_B4','SR_B5','SR_B6','SR_B7', ...)
        blue  = landsat_da.isel(band=1)  # SR_B2
        green = landsat_da.isel(band=2)  # SR_B3
        red   = landsat_da.isel(band=3)  # SR_B4
        nir   = landsat_da.isel(band=4)  # SR_B5
        swir1 = landsat_da.isel(band=5)  # SR_B6 (1.6 µm)
    return blue, green, red, nir, swir1

def find_masks(folder, cam):
    for filename in os.listdir(folder):
        if cam in filename and 'LandCover' in filename:
            corine_filepath = os.path.join(folder, filename)
        elif cam in filename and 'ALOS' in filename:
            elevation_filepath = os.path.join(folder, filename)
    return corine_filepath, elevation_filepath

def load_and_reproject_to_landsat(source_path, match_array, band_name, method=Resampling.nearest):
    src = rioxarray.open_rasterio(source_path, masked=True).squeeze()
    src.name = band_name
    return src.rio.reproject_match(match_array, resampling=method)

def combine_tifs(landsat_filepath, corine_filepath, elevation_filepath, landsat_type):
    landsat = rioxarray.open_rasterio(landsat_filepath, masked=True).squeeze()
    landsat.name = "landsat"

    # NEW: per-scene DN detection + fix, plus L7 spike mask
    landsat, _ = ensure_reflectance(landsat, landsat_type, log_prefix="prep: ")

    corine = load_and_reproject_to_landsat(corine_filepath, landsat, "corine_landcover")
    elevation = load_and_reproject_to_landsat(elevation_filepath, landsat, "elevation")
    return xr.merge([landsat, corine, elevation])

def apply_valid_mask(ds, e=80):
    elevation = ds['elevation']
    corine = ds['corine_landcover']
    yc, xc = elevation.sizes['y'] // 2, elevation.sizes['x'] // 2
    centre_elev = elevation.isel(y=yc, x=xc).item()
    elev_mask = np.abs(elevation - centre_elev) <= e
    corine_mask = (corine >= 111) & (corine <= 126)
    valid_mask = elev_mask & corine_mask
    ds['valid_mask'] = valid_mask
    return ds

def compute_index(b1, b2):
    denom = b1 + b2
    return xr.where(denom != 0, (b1 - b2) / denom, np.nan)

def compute_dozier(ds, ndsi, nir):
    corine = ds['corine_landcover']
    condition1 = (ndsi > 0.1) & (ndsi < 0.4) # & (corine >= 111) & (corine <= 126)
    condition2 = (ndsi >= 0.4) & (nir > 0.11) # ~((corine >= 111) & (corine <= 126))
    dozier = xr.where(condition1 | condition2, 1, 0)
    return dozier.where(~np.isnan(ndsi))

def compute_klein(ndsi, ndvi, green, nir):
    region_coords = [
        (0.4, 1),
        (0.33, 0.9),
        (0.26, 0.75),
        (0.2, 0.59),
        (0.1, 0.24),  # bottom left
        (0.2,0.2),
        (0.4, 0.1),   # top right
    ]
    polygon = Polygon(region_coords)
    klein = xr.zeros_like(ndsi)
    klein = xr.where((ndsi >= 0.4)&(nir > 0.11), 1, klein)
    ndsi_vals, ndvi_vals = ndsi.values, ndvi.values
    mask = np.zeros(ndsi.shape, dtype=bool)
    for i in range(ndsi.shape[0]):
        for j in range(ndsi.shape[1]):
            if not np.isnan(ndsi_vals[i, j]) and not np.isnan(ndvi_vals[i, j]):
                if polygon.contains(Point(ndsi_vals[i, j], ndvi_vals[i, j])):
                    mask[i, j] = True
    klein = xr.where(xr.DataArray(mask, dims=ndsi.dims, coords=ndsi.coords), 1, klein)
    klein = xr.where((green <= 0.1), 0, klein)
    return klein.where(~np.isnan(ndsi) & ~np.isnan(ndvi))

def compute_salomonson(ndsi):
    fsc = 0.06 + 1.21 * ndsi
    return fsc.clip(0, 1).where(~np.isnan(ndsi))

def normalize(img):
    img = img.transpose("y", "x", "band")
    p2 = img.quantile(0.02, dim=("x", "y"))
    p98 = img.quantile(0.98, dim=("x", "y"))
    return ((img - p2) / (p98 - p2)).clip(0, 1)

def plot_rgb(ds, landsat, cam, filtered=True):
    # red, green, blue from the unified extractor
    blue, green, red, _, _ = extract_core_sr(ds['landsat'], landsat)
    rgb = xr.concat([red, green, blue], dim='band')

    if filtered and 'valid_mask' in ds:
        rgb = rgb.where(ds['valid_mask'])

    rgb = normalize(rgb)
    plt.figure(figsize=(8, 8))
    plt.imshow(rgb.transpose("y","x","band"))
    plt.title(f"RGB Composite for {cam}")
    plt.axis("off")
    plt.show()

import os
import re

def process_scene(i, apply_filter=True, plot_rgb_image=False, e=80):
    cams = ['bartlett', 'delta_junction', 'glees', 'hyytiala', 'kenttarova', 'lacclair', 'marcell', 'old_jack_pine',
            'oregon', 'queens', 'sodankyla', 'tammela', 'torgnon', 'underc', 'underhill', 'varrio', 'willowcreek', 'wslcreek']
    # cams = ['old_jack_pine']

    landsat_folder = '../scratch/data/landsat/'
    landsat_filepaths = sorted([
        os.path.join(landsat_folder, f) for f in os.listdir(landsat_folder)
        if os.path.isfile(os.path.join(landsat_folder, f))
        and f.endswith('.tif') ])

    filepath = landsat_filepaths[i]
    # print(filepath)
    cam = [c for c in cams if c in filepath][0]
    landsat = [l for l in ['Landsat7', 'Landsat8'] if l in filepath][0]

    # if cam != 'old_jack_pine':
    #     return 0, 0, cam

    # Extract FSC number from filename (e.g. 'bartlett80_')
    match = re.search(rf"{cam}(\d+)_", os.path.basename(filepath))
    fsc_value = int(match.group(1)) if match else None

    # if fsc_value != 100:
    #     return 0, fsc_value, cam

    landsat_masking_folder = '../scratch/data/landsat_masking/'
    corine_fp, elev_fp = find_masks(landsat_masking_folder, cam)
    print(f"Processing i={i}: {filepath}")
    
    ds = combine_tifs(filepath, corine_fp, elev_fp, landsat)
    ds = apply_valid_mask(ds, e)

    if landsat == 'Landsat7':
        src = 'L7'
        band_slice = slice(0, 6)   # first 6 SR bands
    else:
        src = 'L8'
        band_slice = slice(0, 7)   # first 7 SR bands
    
    sr_subset = ds['landsat'].isel(band=_sr_slice(landsat))
    print(f"{landsat} SR (post-prep) mean/min/max:",
          float(np.nanmean(sr_subset.values)),
          float(np.nanmin(sr_subset.values)),
          float(np.nanmax(sr_subset.values)))

    # print(ds.long_name)

    blue, green, red, nir, swir = extract_core_sr(ds['landsat'], landsat)
    # print(np.nanmean(red.values))
    ndsi = compute_index(green, swir)   # classic: green vs SWIR1 (~1.6 µm)
    ndvi = compute_index(nir, red)

    dozier = compute_dozier(ds, ndsi, nir)
    klein = compute_klein(ndsi, ndvi, green, nir)
    fsc = compute_salomonson(ndsi)
    if apply_filter:
        dozier = dozier.where(ds['valid_mask'])
        klein = klein.where(ds['valid_mask'])
        fsc = fsc.where(ds['valid_mask'])
    
    ds['Dozier'] = dozier.assign_attrs(name="Dozier")
    ds['Klein'] = klein.assign_attrs(name="Klein")
    ds['Salomonson'] = fsc.assign_attrs(name="Salomonson")

    if plot_rgb_image:
        plot_rgb(ds, landsat, cam, filtered=False)

    return ds, fsc_value, cam, filepath

def subcell_stats(ds, var='Salomonson', apply_filter=True, extent=4, bins=8, only_dominant=False):
    data = ds[var]
    mask = ds['valid_mask']

    ny, nx = data.shape
    # use integer indices
    yy, xx = np.meshgrid(np.arange(ny), np.arange(nx), indexing="ij")

    flat_y = yy.ravel()
    flat_x = xx.ravel()
    flat_data = data.values.ravel()
    flat_mask = mask.values.ravel()

    # integer-range edges; last edge nudged to be inclusive
    y_edges = np.linspace(0, ny, bins + 1)
    x_edges = np.linspace(0, nx, bins + 1)
    y_edges[-1] = np.nextafter(y_edges[-1], np.inf)
    x_edges[-1] = np.nextafter(x_edges[-1], np.inf)

    cell_y = np.digitize(flat_y, y_edges, right=False) - 1
    cell_x = np.digitize(flat_x, x_edges, right=False) - 1
    cell_y = np.clip(cell_y, 0, bins - 1)
    cell_x = np.clip(cell_x, 0, bins - 1)

    # central window logic (safe when bins=1)
    center = bins // 2
    eff_extent = min(extent, bins)
    valid_sel = (
        (cell_y >= center - eff_extent) & (cell_y <= center + eff_extent) &
        (cell_x >= center - eff_extent) & (cell_x <= center + eff_extent)
    )

    df = pd.DataFrame({
        'cell_y': cell_y[valid_sel],
        'cell_x': cell_x[valid_sel],
        'data':   flat_data[valid_sel],
        'mask':   flat_mask[valid_sel]
    })

    grouped = df.groupby(['cell_y','cell_x'], as_index=False).agg(
        mean=('data','mean'),
        filtered_fraction=('mask', lambda v: np.count_nonzero(v == True) /
                                     max(1, np.count_nonzero(~np.isnan(v)))),
        pixel_count=('data', 'size')  # <-- count per bin
    )

    if only_dominant:
        # keep the largest bin by pixel count (break ties by higher filtered_fraction)
        grouped = grouped.sort_values(['pixel_count','filtered_fraction'], ascending=False).head(1)

    grouped['cell_y'] = grouped['cell_y'].astype(int)
    grouped['cell_x'] = grouped['cell_x'].astype(int)
    return grouped

N = len([
    f for f in os.listdir('../scratch/data/landsat/')
    if os.path.isfile(os.path.join('../scratch/data/landsat/', f)) and f.endswith('.tif')
])
print(N)

merged_results = []
e = 80

for i in range(N):  # or range(1) for testing
    # if (i >= 145 and i < 165) or (i >= 0 and i <= 5):
    if i < -1:
        ds, fsc, cam, filepath = process_scene(i=i, apply_filter=True, plot_rgb_image=True, e=e)

        # if cam != 'old_jack_pine':
        #     continue

        # if fsc != 100:
        #     continue
        
        fig, axes = plt.subplots(1, 1, figsize=(5, 5))  # 1 row, 3 columns
        
        # ds.Dozier.plot(ax=axes)
        # axes.set_title("Dozier")
        
        ds.Klein.plot(ax=axes)
        axes.set_title("Klein")
        
        # ds.Salomonson.plot(ax=axes[2])
        # axes[2].set_title("Salomonson")
        
        plt.tight_layout()
        plt.show()
    else:
        ds, fsc, cam, filepath = process_scene(i=i, apply_filter=True, plot_rgb_image=False, e=e)



    
    # if cam != 'old_jack_pine':
    #     continue



    
    print(fsc)
    fsc_norm = fsc / 100

    # Get results for all three metrics
    dozier = subcell_stats(ds, var='Dozier', apply_filter=True, extent=4, bins=8, only_dominant=False)
    klein = subcell_stats(ds, var='Klein', apply_filter=True, extent=4, bins=8, only_dominant=False)
    salo  = subcell_stats(ds, var='Salomonson', apply_filter=True, extent=4, bins=8, only_dominant=False)

    # Filter by valid fraction
    dozier = dozier.where(dozier['filtered_fraction'] >= 0.2).dropna()
    klein  = klein.where(klein['filtered_fraction'] >= 0.2).dropna()
    salo   = salo.where(salo['filtered_fraction'] >= 0.2).dropna()

    # Merge on cell_x and cell_y
    merged = dozier[['cell_y', 'cell_x', 'filtered_fraction', 'mean']].rename(columns={'mean': 'Dozier'}) \
        .merge(klein[['cell_y', 'cell_x', 'mean']].rename(columns={'mean': 'Klein'}), on=['cell_y', 'cell_x']) \
        .merge(salo[['cell_y', 'cell_x', 'mean']].rename(columns={'mean': 'Salomonson'}), on=['cell_y', 'cell_x'])

    # Add fsc column
    merged['fsc'] = fsc_norm
    merged['cam'] = cam
    merged['filepath'] = filepath
    merged_results.append(merged)

# Final DataFrame
final_df = pd.concat(merged_results, ignore_index=True)

print(final_df)
# Out:
# 287
# Processing i=0: ../scratch/data/landsat/Landsat7_bartlett80_clouds4_LE07_L2SP_013029_20220323_20220419_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.0887/0.0000/0.5689
# Landsat7 SR (post-prep) mean/min/max: 0.08865556865930557 0.0 0.5688725113868713
# 80
# Processing i=1: ../scratch/data/landsat/Landsat7_hyytiala95_clouds6_LE07_L2SP_189017_20190417_20200827_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.1166/0.0000/0.7317
# Landsat7 SR (post-prep) mean/min/max: 0.11664024740457535 0.0 0.7317000031471252
# 95
# Processing i=2: ../scratch/data/landsat/Landsat7_kenttarova98_clouds0_LE07_L2SP_192012_20200526_20200820_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.2638/0.0000/0.7866
# Landsat7 SR (post-prep) mean/min/max: 0.26378515362739563 0.0 0.7865899801254272
# 98
# Processing i=3: ../scratch/data/landsat/Landsat7_lacclair90_clouds0_LE07_L2SP_013027_20190502_20200825_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.1506/0.0000/0.5037
# Landsat7 SR (post-prep) mean/min/max: 0.15055915713310242 0.0 0.503724992275238
# 90
# Processing i=4: ../scratch/data/landsat/Landsat7_marcell100_clouds12_LE07_L2SP_028027_20200326_20200822_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.2098/0.0000/0.5795
# Landsat7 SR (post-prep) mean/min/max: 0.2097749412059784 0.0 0.5795149803161621
# 100
# Processing i=5: ../scratch/data/landsat/Landsat7_marcell60_clouds0_LE07_L2SP_027027_20210306_20210401_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.1984/0.0000/0.6888
# Landsat7 SR (post-prep) mean/min/max: 0.19844205677509308 0.0 0.6888275146484375
# 60
# Processing i=6: ../scratch/data/landsat/Landsat7_marcell70_clouds0_LE07_L2SP_027027_20200404_20200822_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.1853/0.0024/0.5259
# Landsat7 SR (post-prep) mean/min/max: 0.18525248765945435 0.0023725000210106373 0.5259450078010559
# 70
# Processing i=7: ../scratch/data/landsat/Landsat7_marcell80_clouds0_LE07_L2SP_028027_20210313_20210410_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.1909/0.0031/0.7036
# Landsat7 SR (post-prep) mean/min/max: 0.1909487396478653 0.003114999970421195 0.703594982624054
# 80
# Processing i=8: ../scratch/data/landsat/Landsat7_old_jack_pine44_clouds6_LE07_L2SP_037022_20210413_20210509_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.1039/0.0087/0.6787
# Landsat7 SR (post-prep) mean/min/max: 0.10386376827955246 0.008697500452399254 0.6786800026893616
# 44
# Processing i=9: ../scratch/data/landsat/Landsat7_oregon39_clouds23_LE07_L2SP_045029_20191228_20200823_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.0733/0.0000/0.7987
# Landsat7 SR (post-prep) mean/min/max: 0.07328715920448303 0.0 0.7987449765205383
# 39
# Processing i=10: ../scratch/data/landsat/Landsat7_oregon42_clouds18_LE07_L2SP_045029_20190331_20200827_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.
0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.32302168011665344 0.0 1.0
# 100
# Processing i=64: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20201209_20210313_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2972/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.29717162251472473 0.0 1.0
# 100
# Processing i=65: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20210110_20210307_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3699/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.36987972259521484 0.0 1.0
# 100
# Processing i=66: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20210331_20210409_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.4172/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.4171977639198303 0.0 1.0
# 100
# Processing i=67: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20220129_20220204_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3512/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.3511992394924164 0.0 1.0
# 100
# Processing i=68: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20190112_20200830_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3531/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.3530772924423218 0.0 1.0
# 100
# Processing i=69: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20190317_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.4101/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.4101148247718811 0.0 1.0
# 100
# Processing i=70: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20190504_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.4157/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.41567033529281616 0.0 1.0
# 100
# Processing i=71: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20191230_20200824_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3494/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.3494315445423126 0.0 1.0
# 100
# Processing i=72: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20200115_20200823_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3919/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.391899436712265 0.0 1.0
# 100
# Processing i=73: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20211203_20211209_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2387/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.23866359889507294 0.0 1.0
# 100
# Processing i=74: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20220120_20220127_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3519/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.3518733084201813 0.0 1.0
# 100
# Processing i=75: ../scratch/data/landsat/Landsat8_glees10_clouds2_LC08_L2SP_035031_20220613_20220617_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.1315/0.0000/0.8199
# Landsat8 SR (post-prep) mean/min/max: 0.13150456547737122 0.0 0.819920003414154
# 10
# Processing i=76: ../scratch/data/landsat/Landsat8_glees83_clouds24_LC08_L2SP_034031_20220606_20220610_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.1927/0.0000/0.9119
# Landsat8 SR (post-prep) mean/min/max: 0.19267049431800842 0.0 0.9119349718093872
# 83
# Processing i=77: ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_189017_20190628_20200827_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0740/0.0000/0.5802
# Landsat8 SR (post-prep) mean/min/max: 0.07398919761180878 0.0 0.5801750421524048
# 0
# Processing i=78: ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_189017_20200614_20200823_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0771/0.0000/0.6069
# Landsat8 SR (post-prep) mean/min/max: 0.07705795764923096 0.0 0.6069050431251526
# 0
# Processing i=79: ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_190017_20190518_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0722/0.0000/0.4279
# Landsat8 SR (post-prep) mean/min/max: 0.07218221575021744 0.0 0.4278799891471863
# 0
# Processing i=80: ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_190017_20200808_20200917_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0639/0.0000/0.6256
# Landsat8 SR (post-prep) mean/min/max: 0.06386128067970276 0.0 0.6256325244903564
# 0
# Processing i=81: ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_190017_20220814_20220824_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0654/0.0000/0.5684
# Landsat8 SR (post-prep) mean/min/max: 0.06540750712156296 0.0 0.568405032157898
# 0
# Processing i=82: ../scratch/data/landsat/Landsat8_hyytiala100_LC08_L2SP_189017_20220228_20220309_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1528/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.15284420549869537 0.0 1.0
# 100
# Processing i=83: ../scratch/data/landsat/Landsat8_hyytiala100_LC08_L2SP_190017_20220323_20220330_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1450/0.0000/0.9485
# Landsat8 SR (post-prep) mean/min/max: 0.1450018584728241 0.0 0.9485099911689758
# 100
# Processing i=84: ../scratch/data/landsat/Landsat8_hyytiala55_clouds0_LE07_L2SP_188017_20210415_20210511_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0000/0.0000/0.0000
# Landsat8 SR (post-prep) mean/min/max: 0.0 0.0 0.0
# 55
# Processing i=85: ../scratch/data/landsat/Landsat8_hyytiala97_clouds1_LC08_L2SP_190017_20190416_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.1197/0.0000/0.8218
# Landsat8 SR (post-prep) mean/min/max: 0.11971991509199142 0.0 0.8218175172805786
# 97
# Processing i=86: ../scratch/data/landsat/Landsat8_kenttarova0_LC08_L2SP_192012_20210606_20210615_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.
20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0881/0.0000/0.4776
# Landsat8 SR (post-prep) mean/min/max: 0.08806425333023071 0.0 0.4776000380516052
# 0
# Processing i=110: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20190613_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0902/0.0000/0.5942
# Landsat8 SR (post-prep) mean/min/max: 0.09018458425998688 0.0 0.5942000150680542
# 0
# Processing i=111: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20190731_20200827_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0894/0.0000/0.5833
# Landsat8 SR (post-prep) mean/min/max: 0.08935900032520294 0.0 0.5832549929618835
# 0
# Processing i=112: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20200717_20200911_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0901/0.0000/0.6188
# Landsat8 SR (post-prep) mean/min/max: 0.09012602269649506 0.0 0.61878502368927
# 0
# Processing i=113: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20210517_20210525_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0901/0.0000/0.4394
# Landsat8 SR (post-prep) mean/min/max: 0.09011583030223846 0.0 0.43937504291534424
# 0
# Processing i=114: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20210922_20210930_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0708/0.0000/0.4478
# Landsat8 SR (post-prep) mean/min/max: 0.07076133042573929 0.0 0.44781750440597534
# 0
# Processing i=115: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20211109_20211117_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0641/0.0000/0.4316
# Landsat8 SR (post-prep) mean/min/max: 0.06410606950521469 0.0 0.4315650463104248
# 0
# Processing i=116: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_028027_20190706_20200827_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0881/0.0000/0.5687
# Landsat8 SR (post-prep) mean/min/max: 0.08810847997665405 0.0 0.5687350034713745
# 0
# Processing i=117: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_028027_20200910_20200919_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0685/0.0000/0.4485
# Landsat8 SR (post-prep) mean/min/max: 0.06849677115678787 0.0 0.4485325217247009
# 0
# Processing i=118: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_028027_20201012_20201105_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0632/0.0000/0.4189
# Landsat8 SR (post-prep) mean/min/max: 0.0631788894534111 0.0 0.4188600182533264
# 0
# Processing i=119: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_028027_20210422_20210430_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0867/0.0000/0.4007
# Landsat8 SR (post-prep) mean/min/max: 0.08674247562885284 0.0 0.4006825089454651
# 0
# Processing i=120: ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20190120_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2599/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2599155604839325 0.0 1.0
# 100
# Processing i=121: ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20200107_20200823_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2618/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2618368864059448 0.0 1.0
# 100
# Processing i=122: ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20201224_20210310_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2472/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.24717989563941956 0.0 1.0
# 100
# Processing i=123: ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20210210_20210302_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2801/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.28014934062957764 0.0 1.0
# 100
# Processing i=124: ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20211211_20211216_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2405/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2404921054840088 0.0 1.0
# 100
# Processing i=125: ../scratch/data/landsat/Landsat8_marcell50_clouds54_LC08_L2SP_027027_20210314_20210328_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.1350/0.0000/0.5897
# Landsat8 SR (post-prep) mean/min/max: 0.13496437668800354 0.0 0.589662492275238
# 50
# Processing i=126: ../scratch/data/landsat/Landsat8_marcell70_clouds1_LC08_L2SP_028027_20210305_20210312_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.2164/0.0000/0.8763
# Landsat8 SR (post-prep) mean/min/max: 0.21639542281627655 0.0 0.8763499855995178
# 70
# Processing i=127: ../scratch/data/landsat/Landsat8_marcell90_clouds6_LC08_L2SP_028027_20220409_20220419_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.2818/0.0000/0.9504
# Landsat8 SR (post-prep) mean/min/max: 0.2818165123462677 0.0 0.9504075050354004
# 90
# Processing i=128: ../scratch/data/landsat/Landsat8_marcell97_clouds0_LC08_L2SP_027027_20190325_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.2545/0.0000/0.9375
# Landsat8 SR (post-prep) mean/min/max: 0.2544865608215332 0.0 0.9374549984931946
# 97
# Processing i=129: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20200817_20200920_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0835/0.0029/0.4290
# Landsat8 SR (post-prep) mean/min/max: 0.08345363289117813 0.0029225051403045654 0.42895251512527466
# 0
# Processing i=130: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20200918_20201005_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0755/0.0012/0.3772
# Landsat8 SR (post-prep) mean/min/max: 0.07551749795675278 0.0012449920177459717 0.3771975040435791
# 0
# Processing i=131: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20211007_20211018_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0683/0.0023/0.3600
# Landsat8 SR (post-prep) mean/min/max: 0.06832122057676315 0.0023449957370758057 0.3599550127983093
# 0
# Processing i=132: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20220604_20220610_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0945/0.0000/0.4031
# Landsat8 SR (post-prep) mean/min/max: 0.09450098127126694 0.0 0.4031299948692322
# 0
# Processing i=133: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20221010_20221020_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0694/0.0008/0.3456
# Landsat8 SR (post-prep) mean/min/max: 0.06943760067224503 0.0007774978876113892 0.3456000089645386
# 0
# Processing i=134: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036023_20190527_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0958/0.0048/0.4011
# Landsat8 SR (post-prep) mean/min/max: 0.09577050060033798 0.004820004105567932 0.40109503269195557
# 0
# Processing i=135: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20190518_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0844/0.0000/0.3908
# Landsat8 SR (post-prep) mean/min/max: 0.08439455181360245 0.0 0.39078253507614136
# 0
# Processing i=136: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20190822_20200827_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0751/0.0001/0.3927
# Landsat8 SR (post-prep) mean/min/max: 0.07511506229639053 9.000301361083984e-05 0.3926525115966797
# 0
# Processing i=137: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20210507_20210517_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0860/0.0000/0.3849
# Landsat8 SR (post-prep) mean/min/max: 0.08595054596662521 0.0 0.3848699927330017
# 0
# Processing i=138: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20210710_20210720_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0850/0.0037/0.4186
# Landsat8 SR (post-prep) mean/min/max: 0.08497162163257599 0.0036650002002716064 0.41858500242233276
# 0
# Processing i=139: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20210928_20211012_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0683/0.0000/0.3541
# Landsat8 SR (post-prep) mean/min/max: 0.06827739626169205 0.0 0.35409754514694214
# 0
# Processing i=140: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20220713_20220722_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0827/0.0005/0.4758
# Landsat8 SR (post-prep) mean/min/max: 0.08265481144189835 0.00047500431537628174 0.47575753927230835
# 0
# Processing i=141: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20220915_20220922_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0689/0.0000/0.3719
# Landsat8 SR (post-prep) mean/min/max: 0.06886234879493713 0.0 0.37189000844955444
# 0
# Processing i=142: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20190324_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1543/0.0000/0.9176
# Landsat8 SR (post-prep) mean/min/max: 0.15432299673557281 0.0 0.9176275134086609
# 100
# Processing i=143: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20200310_20200822_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2513/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.25133952498435974 0.0 1.0
# 100
# Processing i=144: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20210124_20210305_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1935/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.19354985654354095 0.0 1.0
# 100
# Processing i=145: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20210313_20210328_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1984/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.19836929440498352 0.0 1.0
# 100
# Processing i=146: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20220212_20220222_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2048/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2048157900571823 0.0 1.0
# 100
# Processing i=147: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036023_20190308_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2270/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.22700239717960358 0.0 1.0
# 100
# Processing i=148: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036023_20200223_20200822_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2110/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.21098627150058746 0.0 1.0
# 100
# Processing i=149: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036023_20200326_20200822_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2581/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2581394612789154 0.0 1.0
# 100
# Processing i=150: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_037022_20210216_20210301_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2005/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2004884034395218 0.0 1.0
# 100
# Processing i=151: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_037022_20220203_20220212_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2178/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2177731841802597 0.0 1.0
# 100
# Processing i=152: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_037022_20220424_20220503_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1645/0.0000/0.8893
# Landsat8 SR (post-prep) mean/min/max: 0.1645333468914032 0.0 0.8893025517463684
# 100
# Processing i=153: ../scratch/data/landsat/Landsat8_old_jack_pine35_clouds14_LC08_L2SP_036022_20210414_20210423_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.0919/0.0000/0.7361
# Landsat8 SR (post-prep) mean/min/max: 0.09187354147434235 0.0 0.7360724806785583
# 35
# Processing i=154: ../scratch/data/landsat/Landsat8_old_jack_pine98_clouds4_LC08_L2SP_037022_20220424_20220503_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.1645/0.0000/0.8893
# Landsat8 SR (post-prep) mean/min/max: 0.1645376831293106 0.0 0.8893024921417236
# 98
# Processing i=155: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20190424_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0899/0.0000/0.6599
# Landsat8 SR (post-prep) mean/min/max: 0.08992810547351837 0.0 0.6598700284957886
# 0
# Processing i=156: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20190510_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0956/0.0009/0.6515
# Landsat8 SR (post-prep) mean/min/max: 0.09555120766162872 0.0009150058031082153 0.6514825224876404
# 0
# Processing i=157: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20190611_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0969/0.0000/0.6761
# Landsat8 SR (post-prep) mean/min/max: 0.09692633897066116 0.0 0.6761225461959839
# 0
# Processing i=158: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20190729_20200827_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0933/0.0000/0.6947
# Landsat8 SR (post-prep) mean/min/max: 0.09328503906726837 0.0 0.6947399973869324
# 0
# Processing i=159: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20191102_20200825_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0674/0.0000/0.7086
# Landsat8 SR (post-prep) mean/min/max: 0.06740985065698624 0.0 0.7086000442504883
# 0
# Processing i=160: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20201120_20210315_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0560/0.0000/0.6687
# Landsat8 SR (post-prep) mean/min/max: 0.05602278932929039 0.0 0.6686975359916687
# 0
# Processing i=161: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20210616_20210622_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0980/0.0000/0.6817
# Landsat8 SR (post-prep) mean/min/max: 0.0979544073343277 0.0 0.681677520275116
# 0
# Processing i=162: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20221110_20221121_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0587/0.0000/0.6879
# Landsat8 SR (post-prep) mean/min/max: 0.05869719013571739 0.0 0.6879200339317322
# 0
# Processing i=163: ../scratch/data/landsat/Landsat8_oregon100_LC08_L2SP_045029_20210123_20210305_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1850/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.18500302731990814 0.0 1.0
# 100
# Processing i=164: ../scratch/data/landsat/Landsat8_oregon100_clouds1_LC08_L2SP_045029_20210123_20210305_02_T1.tif
# ...
# Landsat8 SR (post-prep) mean/min/max: 0.09475540369749069 0.0 0.5965099930763245
# 0
# Processing i=236: ../scratch/data/landsat/Landsat8_underhill0_LC08_L2SP_014029_20200519_20200820_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1025/0.0000/0.5083
# Landsat8 SR (post-prep) mean/min/max: 0.10248062759637833 0.0 0.5083450078964233
# 0
# Processing i=237: ../scratch/data/landsat/Landsat8_underhill0_LC08_L2SP_014029_20220509_20220518_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1017/0.0000/0.6296
# Landsat8 SR (post-prep) mean/min/max: 0.1017327830195427 0.0 0.6295650005340576
# 0
# Processing i=238: ../scratch/data/landsat/Landsat8_underhill0_LC08_L2SP_014029_20220930_20221005_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0661/0.0000/0.4842
# Landsat8 SR (post-prep) mean/min/max: 0.06613536924123764 0.0 0.4842275381088257
# 0
# Processing i=239: ../scratch/data/landsat/Landsat8_underhill100_LC08_L2SP_013029_20210208_20210302_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1765/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.1765299290418625 0.0 1.0
# 100
# Processing i=240: ../scratch/data/landsat/Landsat8_underhill100_LC08_L2SP_013029_20220126_20220204_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1449/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.14488372206687927 0.0 1.0
# 100
# Processing i=241: ../scratch/data/landsat/Landsat8_underhill10_LC08_L2SP_014029_20201010_20201016_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0883/0.0000/0.4488
# Landsat8 SR (post-prep) mean/min/max: 0.08833873271942139 0.0 0.44878000020980835
# 10
# Processing i=242: ../scratch/data/landsat/Landsat8_underhill80_clouds3_LC08_L2SP_014029_20210319_20210328_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.
# 270     0.0     4.0           0.780277  0.240909  0.152273    0.158488  1.00
# 271     0.0     4.0           0.780277  0.286364  0.192045    0.189476  1.00
# 272     0.0     4.0           0.780277  0.956818  0.314773    0.758444  1.00
# 273     0.0     4.0           0.780277  0.807955  0.247727    0.655092  1.00
# 274     0.0     4.0           0.780277  1.000000  1.000000    0.715769  1.00
#
#             cam
# 0      bartlett
# 1      hyytiala
# 2    kenttarova
# 3      lacclair
# 4       marcell
# ..          ...
# 270    wslcreek
# 271    wslcreek
# 272    wslcreek
# 273    wslcreek
# 274    wslcreek
#
# [275 rows x 8 columns]

# %%
import pandas as pd
pd.to_pickle(final_df,'landsat_df_80m_0.2ff.pkl')
# final_df = pd.read_pickle('landsat_df_80m_0.2ff.pkl')
# len(final_df[(final_df['fsc']<1)&(final_df['fsc']>0)])
# final_df

# %% [markdown]
# # 4km extent results

# %%
#60m

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# final_df = pd.read_pickle('landsat_df_80m_0.2ff.pkl')
# final_df = final_df[final_df['cam']=='old_jack_pine']

# Melt the dataframe to long format for individual method plots
melted = final_df.melt(
    id_vars=["fsc", "filtered_fraction", "cam"],
    value_vars=["Dozier", "Klein"],  # , "Salomonson"
    var_name="method",
    value_name="predicted"
)

# Convert to percentages for plotting (0–100)
melted["fsc"] = melted["fsc"] * 100.0
melted["predicted"] = melted["predicted"] * 100.0

# Define color map (blue for Dozier, green for Klein)
method_colors = {
    "Dozier": "#1f77b4",
    "Klein": "#2ca02c",
    # "Salomonson": "#d62728"
}

# ---------- Scatter: Observed vs Predicted, one figure per method ----------
for method in ["Dozier", "Klein"]:  # , "Salomonson"
    subset = melted[melted["method"] == method]

    plt.figure(figsize=(6, 6))
    plt.scatter(
        subset["fsc"],
        subset["predicted"],
        alpha=0.6,
        edgecolor='k',
        c=method_colors[method],
        label=method
    )
    plt.plot([0, 100], [0, 100], 'r--', lw=1)
    plt.xlabel("Observed FSC (%)")
    plt.ylabel("Predicted FSC (%)")
    plt.title(f"Observed vs Predicted FSC: {method}")
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    # plt.savefig(f'poster_landsat_{method}_actual_predicted.svg')
    plt.show()

# ---------- Metric helpers ----------
def rmse(y_true, y_pred):
    diff = y_pred - y_true
    return np.sqrt(np.nanmean(diff**2)) if np.isfinite(diff).any() else np.nan

def bias(y_true, y_pred):
    diff = y_pred - y_true
    return np.nanmean(diff) if np.isfinite(diff).any() else np.nan

def compute_all_metrics(df_method):
    """df_method: melted subset for a single method, with fsc/predicted in 0–100 units."""
    y = df_method["fsc"].to_numpy()
    yhat = df_method["predicted"].to_numpy()

    # Overall
    overall_rmse  = rmse(y, yhat)
    overall_bias  = bias(y, yhat)

    # Fractional (strictly between 0 and 100)
    frac_mask = (y > 0) & (y < 100)
    frac_rmse  = rmse(y[frac_mask], yhat[frac_mask])
    frac_bias  = bias(y[frac_mask], yhat[frac_mask])

    # Errors at the extremes
    zero_mask = (y == 0)
    full_mask = (y == 100)

    zero_bias = bias(y[zero_mask], yhat[zero_mask])   # "0%SC Error"
    full_bias = bias(y[full_mask], yhat[full_mask])   # "100%SC Error"

    metrics_order = ["RMSE", "Bias", "Fractional RMSE", "Fractional Bias", "0%SC Error", "100%SC Error"]
    values = np.array([
        overall_rmse,
        overall_bias,
        frac_rmse,
        frac_bias,
        zero_bias,
        full_bias
    ], dtype=float)

    return metrics_order, values

# ---------- Bar chart per method with six metrics ----------
for method in ["Dozier", "Klein"]:
    subset = melted[melted["method"] == method]
    metrics_labels, values = compute_all_metrics(subset)

    plt.figure(figsize=(8, 5))
    x = np.arange(len(metrics_labels))
    bars = plt.bar(x, values, edgecolor='black', color=method_colors[method])

    # Labels on bars (handle NaNs gracefully)
    for bar, val in zip(bars, values):
        height = 0 if np.isnan(val) else float(val)
        txt = "NaN" if np.isnan(val) else f"{height:.1f}%"
        x_offset = bar.get_x() + bar.get_width() * 0.6
        y_offset = 1 * np.sign(height if height != 0 else 1)
        plt.text(
            x_offset,
            height + y_offset,
            txt,
            ha='left',
            va='bottom' if height >= 0 else 'top',
            fontsize=13
        )

    plt.xticks(x, metrics_labels, rotation=0)
    plt.ylabel("Value (%)")
    plt.title(f"{method} – FSC Estimation Metrics")
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Y-lims with padding, robust to NaNs
    finite_vals = values[np.isfinite(values)]
    if finite_vals.size == 0:
        ymin, ymax = -1, 1
    else:
        ymin = min(0.0, float(finite_vals.min())) - 4
        ymax = (float(finite_vals.max()) + 4) if float(finite_vals.max()) > 0 else 1
    plt.ylim(ymin, ymax)

    plt.tight_layout()
    # plt.savefig(f'poster_landsat_{method}_metrics.svg')
    plt.show()

# ---------- Histogram: Predicted FSC where observed FSC = 100% ----------

# Filter scenes where observed FSC is 100%
full_snow = melted[melted["fsc"] == 100].copy()

# Set up plot
plt.figure(figsize=(7, 5))
bins = np.linspace(0, 100, 21)  # 0–100 in 5% increments

for method in ["Dozier", "Klein"]:
# for method in ["Klein"]:
    subset = full_snow[full_snow["method"] == method]
    sns.histplot(
        subset["predicted"],
        bins=bins,
        kde=False,
        color=method_colors[method],
        label=f"{method} (n={len(subset)})",
        alpha=0.6,
        edgecolor="black"
    )

# Reference line at 100% (perfect prediction)
# plt.axvline(100, color="red", linestyle="--", linewidth=1, label="Observed = 100%")

plt.xlabel("Predicted FSC (%)")
plt.ylabel("Count")
plt.title("Distribution of Predicted FSC for Scenes with Observed Full Snow Cover (Old Jack Pine)")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
# plt.savefig("poster_landsat_full_snow_hist.svg")
plt.show()

# %%
#80m

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# final_df = pd.read_pickle('landsat_df_80m_0.2ff.pkl')
# final_df = final_df[final_df['cam']=='old_jack_pine']

# Melt the dataframe to long format for individual method plots
melted = final_df.melt(
    id_vars=["fsc", "filtered_fraction", "cam"],
    value_vars=["Dozier", "Klein"],  # , "Salomonson"
    var_name="method",
    value_name="predicted"
)

# Convert to percentages for plotting (0–100)
melted["fsc"] = melted["fsc"] * 100.0
melted["predicted"] = melted["predicted"] * 100.0

# Define color map (blue for Dozier, green for Klein)
method_colors = {
    "Dozier": "#1f77b4",
    "Klein": "#2ca02c",
    # "Salomonson": "#d62728"
}

# ---------- Scatter: Observed vs Predicted, one figure per method ----------
for method in ["Dozier", "Klein"]:  # , "Salomonson"
    subset = melted[melted["method"] == method]

    plt.figure(figsize=(6, 6))
    plt.scatter(
        subset["fsc"],
        subset["predicted"],
        alpha=0.6,
        edgecolor='k',
        c=method_colors[method],
        label=method
    )
    plt.plot([0, 100], [0, 100], 'r--', lw=1)
    plt.xlabel("Observed FSC (%)")
    plt.ylabel("Predicted FSC (%)")
    plt.title(f"Observed vs Predicted FSC: {method}")
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    # plt.savefig(f'poster_landsat_{method}_actual_predicted.svg')
    plt.show()

# ---------- Metric helpers ----------
def rmse(y_true, y_pred):
    diff = y_pred - y_true
    return np.sqrt(np.nanmean(diff**2)) if np.isfinite(diff).any() else np.nan

def bias(y_true, y_pred):
    diff = y_pred - y_true
    return np.nanmean(diff) if np.isfinite(diff).any() else np.nan

def compute_all_metrics(df_method):
    """df_method: melted subset for a single method, with fsc/predicted in 0–100 units."""
    y = df_method["fsc"].to_numpy()
    yhat = df_method["predicted"].to_numpy()

    # Overall
    overall_rmse  = rmse(y, yhat)
    overall_bias  = bias(y, yhat)

    # Fractional (strictly between 0 and 100)
    frac_mask = (y > 0) & (y < 100)
    frac_rmse  = rmse(y[frac_mask], yhat[frac_mask])
    frac_bias  = bias(y[frac_mask], yhat[frac_mask])

    # Errors at the extremes
    zero_mask = (y == 0)
    full_mask = (y == 100)

    zero_bias = bias(y[zero_mask], yhat[zero_mask])   # "0%SC Error"
    full_bias = bias(y[full_mask], yhat[full_mask])   # "100%SC Error"

    metrics_order = ["RMSE", "Bias", "Fractional RMSE", "Fractional Bias", "0%SC Error", "100%SC Error"]
    values = np.array([
        overall_rmse,
        overall_bias,
        frac_rmse,
        frac_bias,
        zero_bias,
        full_bias
    ], dtype=float)

    return metrics_order, values

# ---------- Bar chart per method with six metrics ----------
for method in ["Dozier", "Klein"]:
    subset = melted[melted["method"] == method]
    metrics_labels, values = compute_all_metrics(subset)

    plt.figure(figsize=(8, 5))
    x = np.arange(len(metrics_labels))
    bars = plt.bar(x, values, edgecolor='black', color=method_colors[method])

    # Labels on bars (handle NaNs gracefully)
    for bar, val in zip(bars, values):
        height = 0 if np.isnan(val) else float(val)
        txt = "NaN" if np.isnan(val) else f"{height:.1f}%"
        x_offset = bar.get_x() + bar.get_width() * 0.6
        y_offset = 1 * np.sign(height if height != 0 else 1)
        plt.text(
            x_offset,
            height + y_offset,
            txt,
            ha='left',
            va='bottom' if height >= 0 else 'top',
            fontsize=13
        )

    plt.xticks(x, metrics_labels, rotation=0)
    plt.ylabel("Value (%)")
    plt.title(f"{method} – FSC Estimation Metrics")
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Y-lims with padding, robust to NaNs
    finite_vals = values[np.isfinite(values)]
    if finite_vals.size == 0:
        ymin, ymax = -1, 1
    else:
        ymin = min(0.0, float(finite_vals.min())) - 4
        ymax = (float(finite_vals.max()) + 4) if float(finite_vals.max()) > 0 else 1
    plt.ylim(ymin, ymax)

    plt.tight_layout()
    # plt.savefig(f'poster_landsat_{method}_metrics.svg')
    plt.show()

# ---------- Histogram: Predicted FSC where observed FSC = 100% ----------

# Filter scenes where observed FSC is 100%
full_snow = melted[melted["fsc"] == 100].copy()

# Set up plot
plt.figure(figsize=(7, 5))
bins = np.linspace(0, 100, 21)  # 0–100 in 5% increments

for method in ["Dozier", "Klein"]:
# for method in ["Klein"]:
    subset = full_snow[full_snow["method"] == method]
    sns.histplot(
        subset["predicted"],
        bins=bins,
        kde=False,
        color=method_colors[method],
        label=f"{method} (n={len(subset)})",
        alpha=0.6,
        edgecolor="black"
    )

# Reference line at 100% (perfect prediction)
# plt.axvline(100, color="red", linestyle="--", linewidth=1, label="Observed = 100%")

plt.xlabel("Predicted FSC (%)")
plt.ylabel("Count")
plt.title("Distribution of Predicted FSC for Scenes with Observed Full Snow Cover")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
# plt.savefig("poster_landsat_full_snow_hist.svg")
plt.show()

# %%
#100m

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# final_df = pd.read_pickle('landsat_df_80m_0.2ff.pkl')
# final_df = final_df[final_df['cam']=='old_jack_pine']

# Melt the dataframe to long format for individual method plots
melted = final_df.melt(
    id_vars=["fsc", "filtered_fraction", "cam"],
    value_vars=["Dozier", "Klein"],  # , "Salomonson"
    var_name="method",
    value_name="predicted"
)

# Convert to percentages for plotting (0–100)
melted["fsc"] = melted["fsc"] * 100.0
melted["predicted"] = melted["predicted"] * 100.0

# Define color map (blue for Dozier, green for Klein)
method_colors = {
    "Dozier": "#1f77b4",
    "Klein": "#2ca02c",
    # "Salomonson": "#d62728"
}

# ---------- Scatter: Observed vs Predicted, one figure per method ----------
for method in ["Dozier", "Klein"]:  # , "Salomonson"
    subset = melted[melted["method"] == method]

    plt.figure(figsize=(6, 6))
    plt.scatter(
        subset["fsc"],
        subset["predicted"],
        alpha=0.6,
        edgecolor='k',
        c=method_colors[method],
        label=method
    )
    plt.plot([0, 100], [0, 100], 'r--', lw=1)
    plt.xlabel("Observed FSC (%)")
    plt.ylabel("Predicted FSC (%)")
    plt.title(f"Observed vs Predicted FSC: {method}")
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    # plt.savefig(f'poster_landsat_{method}_actual_predicted.svg')
    plt.show()

# ---------- Metric helpers ----------
def rmse(y_true, y_pred):
    diff = y_pred - y_true
    return np.sqrt(np.nanmean(diff**2)) if np.isfinite(diff).any() else np.nan

def bias(y_true, y_pred):
    diff = y_pred - y_true
    return np.nanmean(diff) if np.isfinite(diff).any() else np.nan

def compute_all_metrics(df_method):
    """df_method: melted subset for a single method, with fsc/predicted in 0–100 units."""
    y = df_method["fsc"].to_numpy()
    yhat = df_method["predicted"].to_numpy()

    # Overall
    overall_rmse  = rmse(y, yhat)
    overall_bias  = bias(y, yhat)

    # Fractional (strictly between 0 and 100)
    frac_mask = (y > 0) & (y < 100)
    frac_rmse  = rmse(y[frac_mask], yhat[frac_mask])
    frac_bias  = bias(y[frac_mask], yhat[frac_mask])

    # Errors at the extremes
    zero_mask = (y == 0)
    full_mask = (y == 100)

    zero_bias = bias(y[zero_mask], yhat[zero_mask])   # "0%SC Error"
    full_bias = bias(y[full_mask], yhat[full_mask])   # "100%SC Error"

    metrics_order = ["RMSE", "Bias", "Fractional RMSE", "Fractional Bias", "0%SC Error", "100%SC Error"]
    values = np.array([
        overall_rmse,
        overall_bias,
        frac_rmse,
        frac_bias,
        zero_bias,
        full_bias
    ], dtype=float)

    return metrics_order, values

# ---------- Bar chart per method with six metrics ----------
for method in ["Dozier", "Klein"]:
    subset = melted[melted["method"] == method]
    metrics_labels, values = compute_all_metrics(subset)

    plt.figure(figsize=(8, 5))
    x = np.arange(len(metrics_labels))
    bars = plt.bar(x, values, edgecolor='black', color=method_colors[method])

    # Labels on bars (handle NaNs gracefully)
    for bar, val in zip(bars, values):
        height = 0 if np.isnan(val) else float(val)
        txt = "NaN" if np.isnan(val) else f"{height:.1f}%"
        x_offset = bar.get_x() + bar.get_width() * 0.6
        y_offset = 1 * np.sign(height if height != 0 else 1)
        plt.text(
            x_offset,
            height + y_offset,
            txt,
            ha='left',
            va='bottom' if height >= 0 else 'top',
            fontsize=13
        )

    plt.xticks(x, metrics_labels, rotation=0)
    plt.ylabel("Value (%)")
    plt.title(f"{method} – FSC Estimation Metrics")
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Y-lims with padding, robust to NaNs
    finite_vals = values[np.isfinite(values)]
    if finite_vals.size == 0:
        ymin, ymax = -1, 1
    else:
        ymin = min(0.0, float(finite_vals.min())) - 4
        ymax = (float(finite_vals.max()) + 4) if float(finite_vals.max()) > 0 else 1
    plt.ylim(ymin, ymax)

    plt.tight_layout()
    # plt.savefig(f'poster_landsat_{method}_metrics.svg')
    plt.show()

# ---------- Histogram: Predicted FSC where observed FSC = 100% ----------

# Filter scenes where observed FSC is 100%
full_snow = melted[melted["fsc"] == 100].copy()

# Set up plot
plt.figure(figsize=(7, 5))
bins = np.linspace(0, 100, 21)  # 0–100 in 5% increments

for method in ["Dozier", "Klein"]:
# for method in ["Klein"]:
    subset = full_snow[full_snow["method"] == method]
    sns.histplot(
        subset["predicted"],
        bins=bins,
        kde=False,
        color=method_colors[method],
        label=f"{method} (n={len(subset)})",
        alpha=0.6,
        edgecolor="black"
    )

# Reference line at 100% (perfect prediction)
# plt.axvline(100, color="red", linestyle="--", linewidth=1, label="Observed = 100%")

plt.xlabel("Predicted FSC (%)")
plt.ylabel("Count")
plt.title("Distribution of Predicted FSC for Scenes with Observed Full Snow Cover (Old Jack Pine)")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
# plt.savefig("poster_landsat_full_snow_hist.svg")
plt.show()

# %% [markdown]
# # old jack pine results

# %%
from scripts.imports import *
from rasterio.enums import Resampling
from shapely.geometry import Polygon, Point

SR_SCALE = 0.0000275
SR_OFFSET = -0.2

# positions for SR bands in your stacks
L7_SR_IDX = slice(0, 6)   # SR_B1..SR_B5, SR_B7
L8_SR_IDX = slice(0, 7)   # SR_B1..SR_B7

def _sr_slice(landsat_type):
    return L7_SR_IDX if landsat_type == 'Landsat7' else L8_SR_IDX

def _is_dn_encoded(sr_subset, high_thresh=10.0, frac_thresh=1e-3):
    """
    Heuristic: SR reflectance should live in ~[0,1] with rare outliers.
    If a *nontrivial* fraction (> frac_thresh) of pixels exceed `high_thresh`,
    call it DN-encoded (needs scaling). Robust to a few 1.6 spikes.
    """
    a = sr_subset.values
    a = a[np.isfinite(a)]
    if a.size == 0:
        return False
    frac_high = (a > high_thresh).mean()
    return frac_high > frac_thresh

def _mask_l7_spikes_inplace(sr, spike=1.5):
    """
    L7 quirk: ~1.6 in B1/B2/B3 over water. Mask across all SR bands.
    Operates in place on a (band,y,x) DataArray assumed reflectance-ish.
    """
    b1 = sr.isel(band=0)
    b2 = sr.isel(band=1)
    b3 = sr.isel(band=2)
    bad = (b1 > spike) | (b2 > spike) | (b3 > spike)
    sr[:] = sr.where(~bad).clip(0, 1)

def ensure_reflectance(landsat_da, landsat_type, log_prefix=""):
    """
    Returns a DataArray where SR bands are guaranteed reflectance in [0,1].
    - Detect DN per scene; if DN-like → apply SR_SCALE/OFFSET.
    - Always mask L7 ~1.6 spikes across SR bands.
    - Clip SR to [0,1]. QA/thermal untouched.
    Also returns a tiny dict of what happened for debugging.
    """
    da = landsat_da.copy()
    s = _sr_slice(landsat_type)
    sr_sub = da.isel(band=s)  # positional slice

    actions = {"dn_scaled": False, "l7_spikes_masked": False}

    # 1) DN detection (both L7 & L8)
    if _is_dn_encoded(sr_sub):
        scaled = sr_sub * SR_SCALE + SR_OFFSET
        scaled = scaled.clip(0, 1)
        # assign back by position
        da.values[s, :, :] = scaled.values
        actions["dn_scaled"] = True
        sr_sub = da.isel(band=s)  # refresh view

    # 2) L7 spike masking (after we are in reflectance space)
    if landsat_type == 'Landsat7':
        _mask_l7_spikes_inplace(sr_sub, spike=1.5)
        da.values[s, :, :] = sr_sub.values
        actions["l7_spikes_masked"] = True

    # 3) Final clip to be safe
    da.values[s, :, :] = np.clip(da.values[s, :, :], 0, 1)

    # Optional: quick log
    try:
        m = float(np.nanmean(da.isel(band=s).values))
        mn = float(np.nanmin(da.isel(band=s).values))
        mx = float(np.nanmax(da.isel(band=s).values))
        print(f"{log_prefix}{landsat_type} reflectance ready | scaled={actions['dn_scaled']} "
              f"| l7_masked={actions['l7_spikes_masked']} | mean/min/max: {m:.4f}/{mn:.4f}/{mx:.4f}")
    except Exception:
        pass

    return da, actions

def scale_l8_sr_to_reflectance(landsat_da):
    """Apply L2 SR scale/offset to SR_B1..SR_B7 for Landsat 8."""
    sr = landsat_da.copy()
    sr_vals = sr.isel(band=L8_SR_IDX) * SR_SCALE + SR_OFFSET
    sr_vals = sr_vals.clip(0, 1)
    sr.loc[dict(band=landsat_da.band.values[L8_SR_IDX])] = sr_vals
    return sr

def mask_l7_spikes(landsat_da, spike_thresh=1.5):
    """Mask pixels where any of B1/B2/B3 exceed ~1.6 across SR bands 1–6."""
    sr = landsat_da.copy()
    b1 = sr.isel(band=0)
    b2 = sr.isel(band=1)
    b3 = sr.isel(band=2)
    bad = (b1 > spike_thresh) | (b2 > spike_thresh) | (b3 > spike_thresh)

    sr_vals = sr.isel(band=L7_SR_IDX).where(~bad)
    sr_vals = sr_vals.clip(0, 1)
    sr.loc[dict(band=landsat_da.band.values[L7_SR_IDX])] = sr_vals
    return sr

def prepare_landsat_sr(landsat_da, landsat_type):
    """Apply proper correction depending on sensor."""
    if landsat_type == 'Landsat8':
        return scale_l8_sr_to_reflectance(landsat_da)
    elif landsat_type == 'Landsat7':
        return mask_l7_spikes(landsat_da, spike_thresh=1.5)
    else:
        return landsat_da

def extract_core_sr(landsat_da, landsat_type):
    """
    Return (blue, green, red, nir, swir1) as reflectance in [0,1],
    with consistent meaning across sensors.
    """
    if landsat_type == 'Landsat7':
        # ('SR_B1','SR_B2','SR_B3','SR_B4','SR_B5','SR_B7', ...)
        blue  = landsat_da.isel(band=0)  # SR_B1
        green = landsat_da.isel(band=1)  # SR_B2
        red   = landsat_da.isel(band=2)  # SR_B3
        nir   = landsat_da.isel(band=3)  # SR_B4
        swir1 = landsat_da.isel(band=4)  # SR_B5 (1.6 µm)
    else:
        # ('SR_B1','SR_B2','SR_B3','SR_B4','SR_B5','SR_B6','SR_B7', ...)
        blue  = landsat_da.isel(band=1)  # SR_B2
        green = landsat_da.isel(band=2)  # SR_B3
        red   = landsat_da.isel(band=3)  # SR_B4
        nir   = landsat_da.isel(band=4)  # SR_B5
        swir1 = landsat_da.isel(band=5)  # SR_B6 (1.6 µm)
    return blue, green, red, nir, swir1

def find_masks(folder, cam):
    for filename in os.listdir(folder):
        if cam in filename and 'LandCover' in filename:
            corine_filepath = os.path.join(folder, filename)
        elif cam in filename and 'ALOS' in filename:
            elevation_filepath = os.path.join(folder, filename)
    return corine_filepath, elevation_filepath

def load_and_reproject_to_landsat(source_path, match_array, band_name, method=Resampling.nearest):
    src = rioxarray.open_rasterio(source_path, masked=True).squeeze()
    src.name = band_name
    return src.rio.reproject_match(match_array, resampling=method)

def combine_tifs(landsat_filepath, corine_filepath, elevation_filepath, landsat_type):
    landsat = rioxarray.open_rasterio(landsat_filepath, masked=True).squeeze()
    landsat.name = "landsat"

    # NEW: per-scene DN detection + fix, plus L7 spike mask
    landsat, _ = ensure_reflectance(landsat, landsat_type, log_prefix="prep: ")

    corine = load_and_reproject_to_landsat(corine_filepath, landsat, "corine_landcover")
    elevation = load_and_reproject_to_landsat(elevation_filepath, landsat, "elevation")
    return xr.merge([landsat, corine, elevation])

def apply_valid_mask(ds, e=80):
    elevation = ds['elevation']
    corine = ds['corine_landcover']
    yc, xc = elevation.sizes['y'] // 2, elevation.sizes['x'] // 2
    centre_elev = elevation.isel(y=yc, x=xc).item()
    elev_mask = np.abs(elevation - centre_elev) <= e
    corine_mask = (corine >= 111) & (corine <= 126)
    valid_mask = elev_mask & corine_mask
    ds['valid_mask'] = valid_mask
    return ds

def compute_index(b1, b2):
    denom = b1 + b2
    return xr.where(denom != 0, (b1 - b2) / denom, np.nan)

def compute_dozier(ds, ndsi, nir):
    corine = ds['corine_landcover']
    condition1 = (ndsi > 0.1) & (ndsi < 0.4) # & (corine >= 111) & (corine <= 126)
    condition2 = (ndsi >= 0.4) & (nir > 0.11) # ~((corine >= 111) & (corine <= 126))
    dozier = xr.where(condition1 | condition2, 1, 0)
    return dozier.where(~np.isnan(ndsi))

def compute_klein(ndsi, ndvi, green, nir):
    region_coords = [
        (0.4, 1),
        (0.33, 0.9),
        (0.26, 0.75),
        (0.2, 0.59),
        (0.1, 0.24),  # bottom left
        (0.2,0.2),
        (0.4, 0.1),   # top right
    ]
    polygon = Polygon(region_coords)
    klein = xr.zeros_like(ndsi)
    klein = xr.where((ndsi >= 0.4)&(nir > 0.11), 1, klein)
    ndsi_vals, ndvi_vals = ndsi.values, ndvi.values
    mask = np.zeros(ndsi.shape, dtype=bool)
    for i in range(ndsi.shape[0]):
        for j in range(ndsi.shape[1]):
            if not np.isnan(ndsi_vals[i, j]) and not np.isnan(ndvi_vals[i, j]):
                if polygon.contains(Point(ndsi_vals[i, j], ndvi_vals[i, j])):
                    mask[i, j] = True
    klein = xr.where(xr.DataArray(mask, dims=ndsi.dims, coords=ndsi.coords), 1, klein)
    klein = xr.where((green <= 0.1), 0, klein)
    return klein.where(~np.isnan(ndsi) & ~np.isnan(ndvi))

def compute_salomonson(ndsi):
    fsc = 0.06 + 1.21 * ndsi
    return fsc.clip(0, 1).where(~np.isnan(ndsi))

def normalize(img):
    img = img.transpose("y", "x", "band")
    p2 = img.quantile(0.02, dim=("x", "y"))
    p98 = img.quantile(0.98, dim=("x", "y"))
    return ((img - p2) / (p98 - p2)).clip(0, 1)

def plot_rgb(ds, landsat, cam, filtered=True):
    # red, green, blue from the unified extractor
    blue, green, red, _, _ = extract_core_sr(ds['landsat'], landsat)
    rgb = xr.concat([red, green, blue], dim='band')

    if filtered and 'valid_mask' in ds:
        rgb = rgb.where(ds['valid_mask'])

    rgb = normalize(rgb)
    plt.figure(figsize=(8, 8))
    plt.imshow(rgb.transpose("y","x","band"))
    plt.title(f"RGB Composite for {cam}")
    plt.axis("off")
    plt.show()

import os
import re

def process_scene(i, apply_filter=True, plot_rgb_image=False, e=80):
    cams = ['bartlett', 'delta_junction', 'glees', 'hyytiala', 'kenttarova', 'lacclair', 'marcell', 'old_jack_pine',
            'oregon', 'queens', 'sodankyla', 'tammela', 'torgnon', 'underc', 'underhill', 'varrio', 'willowcreek', 'wslcreek']
    # cams = ['old_jack_pine']

    landsat_folder = '../scratch/data/landsat/'
    landsat_filepaths = sorted([
        os.path.join(landsat_folder, f) for f in os.listdir(landsat_folder)
        if os.path.isfile(os.path.join(landsat_folder, f))
        and f.endswith('.tif') ])

    filepath = landsat_filepaths[i]
    # print(filepath)
    cam = [c for c in cams if c in filepath][0]
    landsat = [l for l in ['Landsat7', 'Landsat8'] if l in filepath][0]

    # if cam != 'old_jack_pine':
    #     return 0, 0, cam

    # Extract FSC number from filename (e.g. 'bartlett80_')
    match = re.search(rf"{cam}(\d+)_", os.path.basename(filepath))
    fsc_value = int(match.group(1)) if match else None

    # if fsc_value != 100:
    #     return 0, fsc_value, cam

    landsat_masking_folder = '../scratch/data/landsat_masking/'
    corine_fp, elev_fp = find_masks(landsat_masking_folder, cam)
    print(f"Processing i={i}: {filepath}")
    
    ds = combine_tifs(filepath, corine_fp, elev_fp, landsat)
    ds = apply_valid_mask(ds, e)

    if landsat == 'Landsat7':
        src = 'L7'
        band_slice = slice(0, 6)   # first 6 SR bands
    else:
        src = 'L8'
        band_slice = slice(0, 7)   # first 7 SR bands
    
    sr_subset = ds['landsat'].isel(band=_sr_slice(landsat))
    print(f"{landsat} SR (post-prep) mean/min/max:",
          float(np.nanmean(sr_subset.values)),
          float(np.nanmin(sr_subset.values)),
          float(np.nanmax(sr_subset.values)))

    # print(ds.long_name)

    blue, green, red, nir, swir = extract_core_sr(ds['landsat'], landsat)
    # print(np.nanmean(red.values))
    ndsi = compute_index(green, swir)   # classic: green vs SWIR1 (~1.6 µm)
    ndvi = compute_index(nir, red)

    dozier = compute_dozier(ds, ndsi, nir)
    klein = compute_klein(ndsi, ndvi, green, nir)
    fsc = compute_salomonson(ndsi)
    if apply_filter:
        dozier = dozier.where(ds['valid_mask'])
        klein = klein.where(ds['valid_mask'])
        fsc = fsc.where(ds['valid_mask'])
    
    ds['Dozier'] = dozier.assign_attrs(name="Dozier")
    ds['Klein'] = klein.assign_attrs(name="Klein")
    ds['Salomonson'] = fsc.assign_attrs(name="Salomonson")

    if plot_rgb_image:
        plot_rgb(ds, landsat, cam, filtered=False)

    return ds, fsc_value, cam, filepath

def subcell_stats(ds, var='Salomonson', apply_filter=True, extent=4, bins=8, only_dominant=False):
    data = ds[var]
    mask = ds['valid_mask']

    ny, nx = data.shape
    # use integer indices
    yy, xx = np.meshgrid(np.arange(ny), np.arange(nx), indexing="ij")

    flat_y = yy.ravel()
    flat_x = xx.ravel()
    flat_data = data.values.ravel()
    flat_mask = mask.values.ravel()

    # integer-range edges; last edge nudged to be inclusive
    y_edges = np.linspace(0, ny, bins + 1)
    x_edges = np.linspace(0, nx, bins + 1)
    y_edges[-1] = np.nextafter(y_edges[-1], np.inf)
    x_edges[-1] = np.nextafter(x_edges[-1], np.inf)

    cell_y = np.digitize(flat_y, y_edges, right=False) - 1
    cell_x = np.digitize(flat_x, x_edges, right=False) - 1
    cell_y = np.clip(cell_y, 0, bins - 1)
    cell_x = np.clip(cell_x, 0, bins - 1)

    # central window logic (safe when bins=1)
    center = bins // 2
    eff_extent = min(extent, bins)
    valid_sel = (
        (cell_y >= center - eff_extent) & (cell_y <= center + eff_extent) &
        (cell_x >= center - eff_extent) & (cell_x <= center + eff_extent)
    )

    df = pd.DataFrame({
        'cell_y': cell_y[valid_sel],
        'cell_x': cell_x[valid_sel],
        'data':   flat_data[valid_sel],
        'mask':   flat_mask[valid_sel]
    })

    grouped = df.groupby(['cell_y','cell_x'], as_index=False).agg(
        mean=('data','mean'),
        filtered_fraction=('mask', lambda v: np.count_nonzero(v == True) /
                                     max(1, np.count_nonzero(~np.isnan(v)))),
        pixel_count=('data', 'size')  # <-- count per bin
    )

    if only_dominant:
        # keep the largest bin by pixel count (break ties by higher filtered_fraction)
        grouped = grouped.sort_values(['pixel_count','filtered_fraction'], ascending=False).head(1)

    grouped['cell_y'] = grouped['cell_y'].astype(int)
    grouped['cell_x'] = grouped['cell_x'].astype(int)
    return grouped


N = len([
    f for f in os.listdir('../scratch/data/landsat/')
    if os.path.isfile(os.path.join('../scratch/data/landsat/', f)) and f.endswith('.tif')
])
print(N)

merged_results = []
e = 80

for i in range(N):  # or range(1) for testing
    # if (i >= 145 and i < 165) or (i >= 0 and i <= 5):
    if i < -1:
        ds, fsc, cam, filepath = process_scene(i=i, apply_filter=False, plot_rgb_image=True, e=e)

        # if cam != 'old_jack_pine':
        #     continue

        # if fsc != 100:
        #     continue
        
        fig, axes = plt.subplots(1, 1, figsize=(5, 5))  # 1 row, 3 columns
        
        # ds.Dozier.plot(ax=axes)
        # axes.set_title("Dozier")
        
        ds.Klein.plot(ax=axes)
        axes.set_title("Klein")
        
        # ds.Salomonson.plot(ax=axes[2])
        # axes[2].set_title("Salomonson")
        
        plt.tight_layout()
        plt.show()
    else:
        ds, fsc, cam, filepath = process_scene(i=i, apply_filter=False, plot_rgb_image=False, e=e)



    
    # if cam != 'old_jack_pine':
    #     continue



    
    print(fsc)
    fsc_norm = fsc / 100

    # Get results for all three metrics
    dozier = subcell_stats(ds, var='Dozier', apply_filter=True, extent=4, bins=1, only_dominant=True)
    klein = subcell_stats(ds, var='Klein', apply_filter=True, extent=4, bins=1, only_dominant=True)
    salo  = subcell_stats(ds, var='Salomonson', apply_filter=True, extent=4, bins=1, only_dominant=True)

    # Filter by valid fraction
    dozier = dozier.where(dozier['filtered_fraction'] >= 0.2).dropna()
    klein  = klein.where(klein['filtered_fraction'] >= 0.2).dropna()
    salo   = salo.where(salo['filtered_fraction'] >= 0.2).dropna()

    # Merge on cell_x and cell_y
    merged = dozier[['cell_y', 'cell_x', 'filtered_fraction', 'mean']].rename(columns={'mean': 'Dozier'}) \
        .merge(klein[['cell_y', 'cell_x', 'mean']].rename(columns={'mean': 'Klein'}), on=['cell_y', 'cell_x']) \
        .merge(salo[['cell_y', 'cell_x', 'mean']].rename(columns={'mean': 'Salomonson'}), on=['cell_y', 'cell_x'])

    # Add fsc column
    merged['fsc'] = fsc_norm
    merged['cam'] = cam
    merged['filepath'] = filepath
    merged_results.append(merged)

# Final DataFrame
final_df = pd.concat(merged_results, ignore_index=True)

print(final_df)
# Out:
# 287
# Processing i=0: ../scratch/data/landsat/Landsat7_bartlett80_clouds4_LE07_L2SP_013029_20220323_20220419_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.0887/0.0000/0.5689
# Landsat7 SR (post-prep) mean/min/max: 0.08865556865930557 0.0 0.5688725113868713
# 80
# Processing i=1: ../scratch/data/landsat/Landsat7_hyytiala95_clouds6_LE07_L2SP_189017_20190417_20200827_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.1166/0.0000/0.7317
# Landsat7 SR (post-prep) mean/min/max: 0.11664024740457535 0.0 0.7317000031471252
# 95
# Processing i=2: ../scratch/data/landsat/Landsat7_kenttarova98_clouds0_LE07_L2SP_192012_20200526_20200820_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.2638/0.0000/0.7866
# Landsat7 SR (post-prep) mean/min/max: 0.26378515362739563 0.0 0.7865899801254272
# 98
# Processing i=3: ../scratch/data/landsat/Landsat7_lacclair90_clouds0_LE07_L2SP_013027_20190502_20200825_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.1506/0.0000/0.5037
# Landsat7 SR (post-prep) mean/min/max: 0.15055915713310242 0.0 0.503724992275238
# 90
# Processing i=4: ../scratch/data/landsat/Landsat7_marcell100_clouds12_LE07_L2SP_028027_20200326_20200822_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.2098/0.0000/0.5795
# Landsat7 SR (post-prep) mean/min/max: 0.2097749412059784 0.0 0.5795149803161621
# 100
# Processing i=5: ../scratch/data/landsat/Landsat7_marcell60_clouds0_LE07_L2SP_027027_20210306_20210401_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.1984/0.0000/0.6888
# Landsat7 SR (post-prep) mean/min/max: 0.19844205677509308 0.0 0.6888275146484375
# 60
# Processing i=6: ../scratch/data/landsat/Landsat7_marcell70_clouds0_LE07_L2SP_027027_20200404_20200822_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.
02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.2473/0.0000/1.0000
# Landsat7 SR (post-prep) mean/min/max: 0.24732087552547455 0.0 1.0
# 96
# Processing i=20: ../scratch/data/landsat/Landsat7_underc4_clouds2_LE07_L2SP_024028_20210402_20210428_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.1133/0.0000/0.4785
# Landsat7 SR (post-prep) mean/min/max: 0.11333547532558441 0.0 0.478534996509552
# 4
# Processing i=21: ../scratch/data/landsat/Landsat7_underc60_clouds0_LE07_L2SP_025028_20190420_20200825_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.1204/0.0000/0.5079
# Landsat7 SR (post-prep) mean/min/max: 0.120374396443367 0.0 0.50787752866745
# 60
# Processing i=22: ../scratch/data/landsat/Landsat7_underhill75_clouds1_LE07_L2SP_013029_20210320_20210415_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.1484/0.0000/0.7021
# Landsat7 SR (post-prep) mean/min/max: 0.14840885996818542 0.0 0.7021099925041199
# 75
# Processing i=23: ../scratch/data/landsat/Landsat7_underhill97_clouds26_LE07_L2SP_014029_20200308_20200822_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.1634/0.0000/0.7493
# Landsat7 SR (post-prep) mean/min/max: 0.16337664425373077 0.0 0.7493274807929993
# 97
# Processing i=24: ../scratch/data/landsat/Landsat7_willowcreek85_clouds0_LE07_L2SP_025028_20190420_20200825_02_T1.tif
# prep: Landsat7 reflectance ready | scaled=False | l7_masked=True | mean/min/max: 0.1352/0.0049/0.3943
# Landsat7 SR (post-prep) mean/min/max: 0.13524505496025085 0.004875000100582838 0.3943299949169159
# 85
# Processing i=25: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_012029_20200130_20200823_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1026/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.1025860533118248 0.0 1.0
# 0
# Processing i=26: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_012029_20200926_20201006_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0940/0.0000/0.5984
# Landsat8 SR (post-prep) mean/min/max: 0.09395801275968552 0.0 0.598407506942749
# 0
# Processing i=27: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_012029_20210524_20210529_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1082/0.0000/0.6177
# Landsat8 SR (post-prep) mean/min/max: 0.1081591546535492 0.0 0.6176575422286987
# 0
# Processing i=28: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_012030_20200521_20200820_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1035/0.0000/0.5496
# Landsat8 SR (post-prep) mean/min/max: 0.10351458191871643 0.0 0.5496225357055664
# 0
# Processing i=29: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_012030_20201129_20210316_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0584/0.0000/0.5727
# Landsat8 SR (post-prep) mean/min/max: 0.058382097631692886 0.0 0.5726950168609619
# 0
# Processing i=30: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_013029_20190713_20200827_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0993/0.0000/0.6577
# Landsat8 SR (post-prep) mean/min/max: 0.09931124746799469 0.0 0.6577250361442566
# 0
# Processing i=31: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_013029_20210920_20210925_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0808/0.0000/0.5805
# Landsat8 SR (post-prep) mean/min/max: 0.08075867593288422 0.0 0.5805324912071228
# 0
# Processing i=32: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_013029_20211107_20211117_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0657/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.06569311022758484 0.0 1.0
# 0
# Processing i=33: ../scratch/data/landsat/Landsat8_bartlett0_LC08_L2SP_013029_20220518_20220525_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0880/0.0000/0.5517
# Landsat8 SR (post-prep) mean/min/max: 0.08797728270292282 0.0 0.5517399907112122
# 0
# Processing i=34: ../scratch/data/landsat/Landsat8_bartlett100_LC08_L2SP_012029_20190228_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1539/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.15391594171524048 0.0 1.0
# 100
# Processing i=35: ../scratch/data/landsat/Landsat8_bartlett100_LC08_L2SP_012029_20200215_20200823_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1297/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.12972253561019897 0.0 1.0
# 100
# Processing i=36: ../scratch/data/landsat/Landsat8_bartlett100_LC08_L2SP_012030_20210217_20210302_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1282/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.12820833921432495 0.0 1.0
# 100
# Processing i=37: ../scratch/data/landsat/Landsat8_bartlett100_LC08_L2SP_013029_20190102_20200830_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0860/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.08599488437175751 0.0 1.0
# 100
# Processing i=38: ../scratch/data/landsat/Landsat8_bartlett100_LC08_L2SP_013029_20220126_20220204_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1061/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.10613127797842026 0.0 1.0
# 100
# Processing i=39: ../scratch/data/landsat/Landsat8_bartlett5_clouds1_LC08_L2SP_012030_20200419_20200822_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.1053/0.0000/0.6353
# Landsat8 SR (post-prep) mean/min/max: 0.10532142966985703 0.0 0.6353124976158142
# 5
# Processing i=40: ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_067015_20190723_20200827_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0933/0.0079/0.3587
# Landsat8 SR (post-prep) mean/min/max: 0.09325353801250458 0.007927492260932922 0.35866254568099976
# 0
# Processing i=41: ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_067015_20210712_20210721_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0907/0.0000/0.4565
# Landsat8 SR (post-prep) mean/min/max: 0.09067597985267639 0.0 0.4565350413322449
# 0
# Processing i=42: ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_067015_20220528_20220603_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0872/0.0000/0.4151
# Landsat8 SR (post-prep) mean/min/max: 0.08719554543495178 0.0 0.4150649905204773
# 0
# Processing i=43: ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_067015_20220629_20220707_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0988/0.0000/0.4099
# Landsat8 SR (post-prep) mean/min/max: 0.09882814437150955 0.0 0.40989500284194946
# 0
# Processing i=44: ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_068015_20200817_20200920_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0757/0.0000/0.3859
# Landsat8 SR (post-prep) mean/min/max: 0.07570795714855194 0.0 0.38586002588272095
# 0
# Processing i=45: ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_068015_20210719_20210729_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0866/0.0000/0.4467
# Landsat8 SR (post-prep) mean/min/max: 0.08656477928161621 0.0 0.44674503803253174
# 0
# Processing i=46: ../scratch/data/landsat/Landsat8_delta_junction0_LC08_L2SP_068015_20220706_20220722_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0911/0.0003/0.4395
# Landsat8 SR (post-prep) mean/min/max: 0.09113337844610214 0.00031000375747680664 0.43948501348495483
# 0
# Processing i=47: ../scratch/data/landsat/Landsat8_delta_junction100_LC08_L2SP_067015_20210322_20210402_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.4285/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.4285079836845398 0.0 1.0
# 100
# Processing i=48: ../scratch/data/landsat/Landsat8_delta_junction100_LC08_L2SP_068015_20210313_20210328_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.4258/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.4257887601852417 0.0 1.0
# 100
# Processing i=49: ../scratch/data/landsat/Landsat8_delta_junction100_LC08_L2SP_068015_20220316_20220322_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3032/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.3032344579696655 0.0 1.0
# 100
# Processing i=50: ../scratch/data/landsat/Landsat8_delta_junction71_clouds16_LE07_L2SP_067015_20200428_20200820_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0000/0.0000/0.0000
# Landsat8 SR (post-prep) mean/min/max: 0.0 0.0 0.0
# 71
# Processing i=51: ../scratch/data/landsat/Landsat8_delta_junction79_clouds0_LC08_L2SP_068015_20200427_20200822_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.1018/0.0000/0.6952
# Landsat8 SR (post-prep) mean/min/max: 0.10179877281188965 0.0 0.6951799988746643
# 79
# Processing i=52: ../scratch/data/landsat/Landsat8_delta_junction90_clouds15_LC08_L2SP_067015_20210423_20210501_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.1257/0.0000/0.6920
# Landsat8 SR (post-prep) mean/min/max: 0.1257498562335968 0.0 0.6920174956321716
# 90
# Processing i=53: ../scratch/data/landsat/Landsat8_delta_junction90_clouds1_LE07_L2SP_066015_20210424_20210520_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0000/0.0000/0.0000
# Landsat8 SR (post-prep) mean/min/max: 0.0 0.0 0.0
# 90
# Processing i=54: ../scratch/data/landsat/Landsat8_delta_junction93_clouds57_LC08_L2SP_068015_20220503_20220511_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.1745/0.0000/0.8355
# Landsat8 SR (post-prep) mean/min/max: 0.17449650168418884 0.0 0.8354849815368652
# 93
# Processing i=55: ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_034031_20190902_20200826_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0973/0.0000/0.8138
# Landsat8 SR (post-prep) mean/min/max: 0.09727729856967926 0.0 0.813759982585907
# 0
# Processing i=56: ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_034031_20191004_20200825_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0921/0.0000/0.8275
# Landsat8 SR (post-prep) mean/min/max: 0.09212464839220047 0.0 0.8274825215339661
# 0
# Processing i=57: ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_034031_20200920_20201006_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0966/0.0000/0.7149
# Landsat8 SR (post-prep) mean/min/max: 0.09656058996915817 0.0 0.714870035648346
# 0
# Processing i=58: ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_034031_20201006_20201016_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0948/0.0000/0.7968
# Landsat8 SR (post-prep) mean/min/max: 0.09480822086334229 0.0 0.7968475222587585
# 0
# Processing i=59: ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_034031_20210907_20210916_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1012/0.0004/0.7297
# Landsat8 SR (post-prep) mean/min/max: 0.10115749388933182 0.00036500394344329834 0.7297475337982178
# 0
# Processing i=60: ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_035031_20200810_20200918_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0921/0.0000/0.7338
# Landsat8 SR (post-prep) mean/min/max: 0.09208805859088898 0.0 0.7337625026702881
# 0
# Processing i=61: ../scratch/data/landsat/Landsat8_glees0_LC08_L2SP_035031_20210728_20210804_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0956/0.0000/0.6975
# Landsat8 SR (post-prep) mean/min/max: 0.0956360325217247 0.0 0.6974624991416931
# 0
# Processing i=62: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20190105_20200830_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3324/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.3323511481285095 0.0 1.0
# 100
# Processing i=63: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20191105_20200825_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3230/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.32302168011665344 0.0 1.0
# 100
# Processing i=64: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20201209_20210313_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2972/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.29717162251472473 0.0 1.0
# 100
# Processing i=65: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20210110_20210307_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3699/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.36987972259521484 0.0 1.0
# 100
# Processing i=66: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20210331_20210409_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.4172/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.4171977639198303 0.0 1.0
# 100
# Processing i=67: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_034031_20220129_20220204_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3512/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.3511992394924164 0.0 1.0
# 100
# Processing i=68: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20190112_20200830_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3531/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.3530772924423218 0.0 1.0
# 100
# Processing i=69: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20190317_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.4101/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.4101148247718811 0.0 1.0
# 100
# Processing i=70: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20190504_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.4157/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.41567033529281616 0.0 1.0
# 100
# Processing i=71: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20191230_20200824_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3494/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.3494315445423126 0.0 1.0
# 100
# Processing i=72: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20200115_20200823_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3919/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.391899436712265 0.0 1.0
# 100
# Processing i=73: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20211203_20211209_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2387/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.23866359889507294 0.0 1.0
# 100
# Processing i=74: ../scratch/data/landsat/Landsat8_glees100_LC08_L2SP_035031_20220120_20220127_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3519/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.3518733084201813 0.0 1.0
# 100
# Processing i=75: ../scratch/data/landsat/Landsat8_glees10_clouds2_LC08_L2SP_035031_20220613_20220617_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.1315/0.0000/0.8199
# Landsat8 SR (post-prep) mean/min/max: 0.13150456547737122 0.0 0.819920003414154
# 10
# Processing i=76: ../scratch/data/landsat/Landsat8_glees83_clouds24_LC08_L2SP_034031_20220606_20220610_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.1927/0.0000/0.9119
# Landsat8 SR (post-prep) mean/min/max: 0.19267049431800842 0.0 0.9119349718093872
# 83
# Processing i=77: ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_189017_20190628_20200827_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0740/0.0000/0.5802
# Landsat8 SR (post-prep) mean/min/max: 0.07398919761180878 0.0 0.5801750421524048
# 0
# Processing i=78: ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_189017_20200614_20200823_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0771/0.0000/0.6069
# Landsat8 SR (post-prep) mean/min/max: 0.07705795764923096 0.0 0.6069050431251526
# 0
# Processing i=79: ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_190017_20190518_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0722/0.0000/0.4279
# Landsat8 SR (post-prep) mean/min/max: 0.07218221575021744 0.0 0.4278799891471863
# 0
# Processing i=80: ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_190017_20200808_20200917_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0639/0.0000/0.6256
# Landsat8 SR (post-prep) mean/min/max: 0.06386128067970276 0.0 0.6256325244903564
# 0
# Processing i=81: ../scratch/data/landsat/Landsat8_hyytiala0_LC08_L2SP_190017_20220814_20220824_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0654/0.0000/0.5684
# Landsat8 SR (post-prep) mean/min/max: 0.06540750712156296 0.0 0.568405032157898
# 0
# Processing i=82: ../scratch/data/landsat/Landsat8_hyytiala100_LC08_L2SP_189017_20220228_20220309_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1528/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.15284420549869537 0.0 1.0
# 100
# Processing i=83: ../scratch/data/landsat/Landsat8_hyytiala100_LC08_L2SP_190017_20220323_20220330_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1450/0.0000/0.9485
# Landsat8 SR (post-prep) mean/min/max: 0.1450018584728241 0.0 0.9485099911689758
# 100
# Processing i=84: ../scratch/data/landsat/Landsat8_hyytiala55_clouds0_LE07_L2SP_188017_20210415_20210511_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0000/0.0000/0.0000
# Landsat8 SR (post-prep) mean/min/max: 0.0 0.0 0.0
# 55
# Processing i=85: ../scratch/data/landsat/Landsat8_hyytiala97_clouds1_LC08_L2SP_190017_20190416_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.1197/0.0000/0.8218
# Landsat8 SR (post-prep) mean/min/max: 0.11971991509199142 0.0 0.8218175172805786
# 97
# Processing i=86: ../scratch/data/landsat/Landsat8_kenttarova0_LC08_L2SP_192012_20210606_20210615_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0716/0.0000/0.4622
# Landsat8 SR (post-prep) mean/min/max: 0.0715666115283966 0.0 0.4622275233268738
# 0
# Processing i=87: ../scratch/data/landsat/Landsat8_kenttarova0_LC08_L2SP_192012_20210910_20210916_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0554/0.0000/0.4139
# Landsat8 SR (post-prep) mean/min/max: 0.05538421869277954 0.0 0.4138824939727783
# 0
# Processing i=88: ../scratch/data/landsat/Landsat8_kenttarova0_LC08_L2SP_194012_20190615_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0640/0.0000/0.4012
# Landsat8 SR (post-prep) mean/min/max: 0.06399950385093689 0.0 0.4011775255203247
# 0
# Processing i=89: ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_192012_20220321_20220329_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3045/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.3044859766960144 0.0 1.0
# 100
# Processing i=90: ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_193012_20190304_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3065/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.30646902322769165 0.0 1.0
# 100
# Processing i=91: ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_193012_20190405_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3719/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.3719496726989746 0.0 1.0
# 100
# Processing i=92: ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_193012_20210309_20210317_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3553/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.3552995026111603 0.0 1.0
# 100
# Processing i=93: ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_194012_20190311_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3263/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.32634252309799194 0.0 1.0
# 100
# Processing i=94: ../scratch/data/landsat/Landsat8_kenttarova100_LC08_L2SP_194012_20210417_20210424_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3472/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.3472428023815155 0.0 1.0
# 100
# Processing i=95: ../scratch/data/landsat/Landsat8_lacclair0_LC08_L2SP_013027_20200917_20201005_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0805/0.0000/0.5523
# Landsat8 SR (post-prep) mean/min/max: 0.08048522472381592 0.0 0.5523450374603271
# 0
# Processing i=96: ../scratch/data/landsat/Landsat8_lacclair0_LC08_L2SP_013027_20210904_20210910_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0867/0.0000/0.5354
# Landsat8 SR (post-prep) mean/min/max: 0.08665603399276733 0.0 0.5354050397872925
# 0
# Processing i=97: ../scratch/data/landsat/Landsat8_lacclair0_LC08_L2SP_014027_20190704_20200827_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0960/0.0000/0.6039
# Landsat8 SR (post-prep) mean/min/max: 0.09600473940372467 0.0 0.6038800477981567
# 0
# Processing i=98: ../scratch/data/landsat/Landsat8_lacclair0_LC08_L2SP_014027_20200519_20200820_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0973/0.0000/0.3703
# Landsat8 SR (post-prep) mean/min/max: 0.09733529388904572 0.0 0.3703225255012512
# 0
# Processing i=99: ../scratch/data/landsat/Landsat8_lacclair0_LC08_L2SP_014027_20200706_20200913_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0925/0.0000/0.6003
# Landsat8 SR (post-prep) mean/min/max: 0.09252236783504486 0.0 0.6002775430679321
# 0
# Processing i=100: ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_013027_20190102_20200830_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1825/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.18253424763679504 0.0 1.0
# 100
# Processing i=101: ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_013027_20190219_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2410/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.24100202322006226 0.0 1.0
# 100
# Processing i=102: ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_013027_20200121_20200823_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1967/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.19669415056705475 0.0 1.0
# 100
# Processing i=103: ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_013027_20210208_20210302_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2101/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2100909948348999 0.0 1.0
# 100
# Processing i=104: ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_014027_20200316_20200822_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2432/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.24321377277374268 0.0 1.0
# 100
# Processing i=105: ../scratch/data/landsat/Landsat8_lacclair100_LC08_L2SP_014027_20210319_20210328_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2135/0.0000/0.9746
# Landsat8 SR (post-prep) mean/min/max: 0.2134949266910553 0.0 0.974552571773529
# 100
# Processing i=106: ../scratch/data/landsat/Landsat8_lacclair100_clouds7_LC08_L2SP_014027_20220423_20220428_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.1518/0.0000/0.7441
# Landsat8 SR (post-prep) mean/min/max: 0.15182746946811676 0.0 0.7440750002861023
# 100
# Processing i=107: ../scratch/data/landsat/Landsat8_lacclair10_clouds0_LC08_L2SP_013027_20220502_20220511_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.1017/0.0000/0.6235
# Landsat8 SR (post-prep) mean/min/max: 0.10170799493789673 0.0 0.6235424876213074
# 10
# Processing i=108: ../scratch/data/landsat/Landsat8_lacclair97_clouds15_LC08_L2SP_014027_20210404_20210409_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.1677/0.0000/0.8176
# Landsat8 SR (post-prep) mean/min/max: 0.167696014046669 0.0 0.8175550103187561
# 97
# Processing i=109: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20190528_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0881/0.0000/0.4776
# Landsat8 SR (post-prep) mean/min/max: 0.08806425333023071 0.0 0.4776000380516052
# 0
# Processing i=110: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20190613_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0902/0.0000/0.5942
# Landsat8 SR (post-prep) mean/min/max: 0.09018458425998688 0.0 0.5942000150680542
# 0
# Processing i=111: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20190731_20200827_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0894/0.0000/0.5833
# Landsat8 SR (post-prep) mean/min/max: 0.08935900032520294 0.0 0.5832549929618835
# 0
# Processing i=112: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20200717_20200911_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0901/0.0000/0.6188
# Landsat8 SR (post-prep) mean/min/max: 0.09012602269649506 0.0 0.61878502368927
# 0
# Processing i=113: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20210517_20210525_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0901/0.0000/0.4394
# Landsat8 SR (post-prep) mean/min/max: 0.09011583030223846 0.0 0.43937504291534424
# 0
# Processing i=114: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20210922_20210930_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0708/0.0000/0.4478
# Landsat8 SR (post-prep) mean/min/max: 0.07076133042573929 0.0 0.44781750440597534
# 0
# Processing i=115: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_027027_20211109_20211117_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0641/0.0000/0.4316
# Landsat8 SR (post-prep) mean/min/max: 0.06410606950521469 0.0 0.4315650463104248
# 0
# Processing i=116: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_028027_20190706_20200827_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0881/0.0000/0.5687
# Landsat8 SR (post-prep) mean/min/max: 0.08810847997665405 0.0 0.5687350034713745
# 0
# Processing i=117: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_028027_20200910_20200919_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0685/0.0000/0.4485
# Landsat8 SR (post-prep) mean/min/max: 0.06849677115678787 0.0 0.4485325217247009
# 0
# Processing i=118: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_028027_20201012_20201105_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0632/0.0000/0.4189
# Landsat8 SR (post-prep) mean/min/max: 0.0631788894534111 0.0 0.4188600182533264
# 0
# Processing i=119: ../scratch/data/landsat/Landsat8_marcell0_LC08_L2SP_028027_20210422_20210430_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0867/0.0000/0.4007
# Landsat8 SR (post-prep) mean/min/max: 0.08674247562885284 0.0 0.4006825089454651
# 0
# Processing i=120: ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20190120_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2599/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2599155604839325 0.0 1.0
# 100
# Processing i=121: ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20200107_20200823_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2618/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2618368864059448 0.0 1.0
# 100
# Processing i=122: ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20201224_20210310_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2472/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.24717989563941956 0.0 1.0
# 100
# Processing i=123: ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20210210_20210302_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2801/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.28014934062957764 0.0 1.0
# 100
# Processing i=124: ../scratch/data/landsat/Landsat8_marcell100_LC08_L2SP_027027_20211211_20211216_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2405/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2404921054840088 0.0 1.0
# 100
# Processing i=125: ../scratch/data/landsat/Landsat8_marcell50_clouds54_LC08_L2SP_027027_20210314_20210328_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.1350/0.0000/0.5897
# Landsat8 SR (post-prep) mean/min/max: 0.13496437668800354 0.0 0.589662492275238
# 50
# Processing i=126: ../scratch/data/landsat/Landsat8_marcell70_clouds1_LC08_L2SP_028027_20210305_20210312_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.2164/0.0000/0.8763
# Landsat8 SR (post-prep) mean/min/max: 0.21639542281627655 0.0 0.8763499855995178
# 70
# Processing i=127: ../scratch/data/landsat/Landsat8_marcell90_clouds6_LC08_L2SP_028027_20220409_20220419_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.2818/0.0000/0.9504
# Landsat8 SR (post-prep) mean/min/max: 0.2818165123462677 0.0 0.9504075050354004
# 90
# Processing i=128: ../scratch/data/landsat/Landsat8_marcell97_clouds0_LC08_L2SP_027027_20190325_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.2545/0.0000/0.9375
# Landsat8 SR (post-prep) mean/min/max: 0.2544865608215332 0.0 0.9374549984931946
# 97
# Processing i=129: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20200817_20200920_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0835/0.0029/0.4290
# Landsat8 SR (post-prep) mean/min/max: 0.08345363289117813 0.0029225051403045654 0.42895251512527466
# 0
# Processing i=130: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20200918_20201005_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0755/0.0012/0.3772
# Landsat8 SR (post-prep) mean/min/max: 0.07551749795675278 0.0012449920177459717 0.3771975040435791
# 0
# Processing i=131: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20211007_20211018_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0683/0.0023/0.3600
# Landsat8 SR (post-prep) mean/min/max: 0.06832122057676315 0.0023449957370758057 0.3599550127983093
# 0
# Processing i=132: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20220604_20220610_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0945/0.0000/0.4031
# Landsat8 SR (post-prep) mean/min/max: 0.09450098127126694 0.0 0.4031299948692322
# 0
# Processing i=133: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036022_20221010_20221020_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0694/0.0008/0.3456
# Landsat8 SR (post-prep) mean/min/max: 0.06943760067224503 0.0007774978876113892 0.3456000089645386
# 0
# Processing i=134: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_036023_20190527_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0958/0.0048/0.4011
# Landsat8 SR (post-prep) mean/min/max: 0.09577050060033798 0.004820004105567932 0.40109503269195557
# 0
# Processing i=135: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20190518_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0844/0.0000/0.3908
# Landsat8 SR (post-prep) mean/min/max: 0.08439455181360245 0.0 0.39078253507614136
# 0
# Processing i=136: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20190822_20200827_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0751/0.0001/0.3927
# Landsat8 SR (post-prep) mean/min/max: 0.07511506229639053 9.000301361083984e-05 0.3926525115966797
# 0
# Processing i=137: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20210507_20210517_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0860/0.0000/0.3849
# Landsat8 SR (post-prep) mean/min/max: 0.08595054596662521 0.0 0.3848699927330017
# 0
# Processing i=138: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20210710_20210720_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0850/0.0037/0.4186
# Landsat8 SR (post-prep) mean/min/max: 0.08497162163257599 0.0036650002002716064 0.41858500242233276
# 0
# Processing i=139: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20210928_20211012_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0683/0.0000/0.3541
# Landsat8 SR (post-prep) mean/min/max: 0.06827739626169205 0.0 0.35409754514694214
# 0
# Processing i=140: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20220713_20220722_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0827/0.0005/0.4758
# Landsat8 SR (post-prep) mean/min/max: 0.08265481144189835 0.00047500431537628174 0.47575753927230835
# 0
# Processing i=141: ../scratch/data/landsat/Landsat8_old_jack_pine0_LC08_L2SP_037022_20220915_20220922_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0689/0.0000/0.3719
# Landsat8 SR (post-prep) mean/min/max: 0.06886234879493713 0.0 0.37189000844955444
# 0
# Processing i=142: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20190324_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1543/0.0000/0.9176
# Landsat8 SR (post-prep) mean/min/max: 0.15432299673557281 0.0 0.9176275134086609
# 100
# Processing i=143: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20200310_20200822_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2513/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.25133952498435974 0.0 1.0
# 100
# Processing i=144: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20210124_20210305_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1935/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.19354985654354095 0.0 1.0
# 100
# Processing i=145: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20210313_20210328_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1984/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.19836929440498352 0.0 1.0
# 100
# Processing i=146: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036022_20220212_20220222_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2048/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2048157900571823 0.0 1.0
# 100
# Processing i=147: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036023_20190308_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2270/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.22700239717960358 0.0 1.0
# 100
# Processing i=148: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036023_20200223_20200822_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2110/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.21098627150058746 0.0 1.0
# 100
# Processing i=149: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_036023_20200326_20200822_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2581/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2581394612789154 0.0 1.0
# 100
# Processing i=150: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_037022_20210216_20210301_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2005/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2004884034395218 0.0 1.0
# 100
# Processing i=151: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_037022_20220203_20220212_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2178/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2177731841802597 0.0 1.0
# 100
# Processing i=152: ../scratch/data/landsat/Landsat8_old_jack_pine100_LC08_L2SP_037022_20220424_20220503_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1645/0.0000/0.8893
# Landsat8 SR (post-prep) mean/min/max: 0.1645333468914032 0.0 0.8893025517463684
# 100
# Processing i=153: ../scratch/data/landsat/Landsat8_old_jack_pine35_clouds14_LC08_L2SP_036022_20210414_20210423_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.0919/0.0000/0.7361
# Landsat8 SR (post-prep) mean/min/max: 0.09187354147434235 0.0 0.7360724806785583
# 35
# Processing i=154: ../scratch/data/landsat/Landsat8_old_jack_pine98_clouds4_LC08_L2SP_037022_20220424_20220503_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.1645/0.0000/0.8893
# Landsat8 SR (post-prep) mean/min/max: 0.1645376831293106 0.0 0.8893024921417236
# 98
# Processing i=155: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20190424_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0899/0.0000/0.6599
# Landsat8 SR (post-prep) mean/min/max: 0.08992810547351837 0.0 0.6598700284957886
# 0
# Processing i=156: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20190510_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0956/0.0009/0.6515
# Landsat8 SR (post-prep) mean/min/max: 0.09555120766162872 0.0009150058031082153 0.6514825224876404
# 0
# Processing i=157: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20190611_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0969/0.0000/0.6761
# Landsat8 SR (post-prep) mean/min/max: 0.09692633897066116 0.0 0.6761225461959839
# 0
# Processing i=158: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20190729_20200827_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0933/0.0000/0.6947
# Landsat8 SR (post-prep) mean/min/max: 0.09328503906726837 0.0 0.6947399973869324
# 0
# Processing i=159: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_20191102_20200825_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0674/0.0000/0.7086
# Landsat8 SR (post-prep) mean/min/max: 0.06740985065698624 0.0 0.7086000442504883
# 0
# Processing i=160: ../scratch/data/landsat/Landsat8_oregon0_LC08_L2SP_045029_
02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0741/0.0000/0.4076
# Landsat8 SR (post-prep) mean/min/max: 0.07414618879556656 0.0 0.40761250257492065
# 0
# Processing i=251: ../scratch/data/landsat/Landsat8_varrio0_LC08_L2SP_191012_20190712_20200827_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0753/0.0000/0.4214
# Landsat8 SR (post-prep) mean/min/max: 0.07528720796108246 0.0 0.42144501209259033
# 0
# Processing i=252: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_025028_20220303_20220314_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2179/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.21792101860046387 0.0 1.0
# 100
# Processing i=253: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_188013_20190418_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2772/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2772422730922699 0.0 1.0
# 100
# Processing i=254: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_188013_20200404_20200822_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3042/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.30417394638061523 0.0 1.0
# 100
# Processing i=255: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_188013_20200522_20200820_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2696/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2696478068828583 0.0 1.0
# 100
# Processing i=256: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_188013_20210322_20210401_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2561/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2561061382293701 0.0 1.0
# 100
# Processing i=257: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_189012_20200326_20200822_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2448/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.24482259154319763 0.0 1.0
# 100
# Processing i=258: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_189012_20220316_20220322_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2219/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.22193492949008942 0.0 1.0
# 100
# Processing i=259: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_189013_20190425_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2349/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.234903484582901 0.0 1.0
# 100
# Processing i=260: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_189013_20200411_20200822_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.3067/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.30671706795692444 0.0 1.0
# 100
# Processing i=261: ../scratch/data/landsat/Landsat8_varrio100_LC08_L2SP_190012_20210421_20210430_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2300/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.22995804250240326 0.0 1.0
# 100
# Processing i=262: ../scratch/data/landsat/Landsat8_varrio10_clouds5_LC08_L2SP_190012_20220526_20220603_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=False | l7_masked=False | mean/min/max: 0.0854/0.0000/0.5783
# Landsat8 SR (post-prep) mean/min/max: 0.08541693538427353 0.0 0.5783324837684631
# 10
# Processing i=263: ../scratch/data/landsat/Landsat8_willowcreek0_LC08_L2SP_025028_20200430_20200820_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1019/0.0000/0.4290
# Landsat8 SR (post-prep) mean/min/max: 0.10189453512430191 0.0 0.4289799928665161
# 0
# Processing i=264: ../scratch/data/landsat/Landsat8_willowcreek0_LC08_L2SP_025028_20200617_20200824_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1038/0.0000/0.5905
# Landsat8 SR (post-prep) mean/min/max: 0.10377759486436844 0.0 0.5905424952507019
# 0
# Processing i=265: ../scratch/data/landsat/Landsat8_willowcreek0_LC08_L2SP_025028_20200905_20200918_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0865/0.0000/0.5000
# Landsat8 SR (post-prep) mean/min/max: 0.08652056008577347 0.0 0.49995750188827515
# 0
# Processing i=266: ../scratch/data/landsat/Landsat8_willowcreek0_LC08_L2SP_025028_20210401_20210409_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0998/0.0000/0.3883
# Landsat8 SR (post-prep) mean/min/max: 0.09978929907083511 0.0 0.38830751180648804
# 0
# Processing i=267: ../scratch/data/landsat/Landsat8_willowcreek0_LC08_L2SP_025028_20210604_20210614_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1021/0.0000/0.5885
# Landsat8 SR (post-prep) mean/min/max: 0.10209621489048004 0.0 0.5884525179862976
# 0
# Processing i=268: ../scratch/data/landsat/Landsat8_willowcreek100_LC08_L2SP_025028_20190311_20200829_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2571/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.25711172819137573 0.0 1.0
# 100
# Processing i=269: ../scratch/data/landsat/Landsat8_willowcreek100_LC08_L2SP_025028_20190530_20200828_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1014/0.0000/0.4076
# Landsat8 SR (post-prep) mean/min/max: 0.10142111778259277 0.0 0.4076400399208069
# 100
# Processing i=270: ../scratch/data/landsat/Landsat8_willowcreek100_LC08_L2SP_025028_20200210_20200823_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1833/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.18334464728832245 0.0 1.0
# 100
# Processing i=271: ../scratch/data/landsat/Landsat8_willowcreek100_LC08_L2SP_025028_20211229_20220105_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0895/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.08951746672391891 0.0 1.0
# 100
# Processing i=272: ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20190716_20200827_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0747/0.0000/0.7932
# Landsat8 SR (post-prep) mean/min/max: 0.07465629279613495 0.0 0.7932450175285339
# 0
# Processing i=273: ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20200904_20200918_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0643/0.0027/0.4325
# Landsat8 SR (post-prep) mean/min/max: 0.06431813538074493 0.002674996852874756 0.4324725270271301
# 0
# Processing i=274: ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20201006_20201016_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0608/0.0000/0.4891
# Landsat8 SR (post-prep) mean/min/max: 0.06078910082578659 0.0 0.4890950322151184
# 0
# Processing i=275: ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20210907_20210916_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0664/0.0021/0.4238
# Landsat8 SR (post-prep) mean/min/max: 0.06642254441976547 0.00209750235080719 0.4238375425338745
# 0
# Processing i=276: ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20220809_20220818_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0713/0.0042/0.4372
# Landsat8 SR (post-prep) mean/min/max: 0.07131458818912506 0.004160001873970032 0.43717503547668457
# 0
# Processing i=277: ../scratch/data/landsat/Landsat8_wslcreek0_LC08_L2SP_034032_20220926_20221004_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.0574/0.0000/0.4457
# Landsat8 SR (post-prep) mean/min/max: 0.05735491216182709 0.0 0.44572752714157104
# 0
# Processing i=278: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20191105_20200825_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1298/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.12975673377513885 0.0 1.0
# 100
# Processing i=279: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20200108_20200823_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1387/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.13874778151512146 0.0 1.0
# 100
# Processing i=280: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20201225_20210310_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1466/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.14659282565116882 0.0 1.0
# 100
# Processing i=281: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20210331_20210409_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2300/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2300439476966858 0.0 1.0
# 100
# Processing i=282: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20220113_20220123_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1475/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.14747460186481476 0.0 1.0
# 100
# Processing i=283: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20220214_20220222_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1664/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.16635486483573914 0.0 1.0
# 100
# Processing i=284: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20220318_20220322_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.2402/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.2401624172925949 0.0 1.0
# 100
# Processing i=285: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20221028_20221108_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.1473/0.0000/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.1473039835691452 0.0 1.0
# 100
# Processing i=286: ../scratch/data/landsat/Landsat8_wslcreek100_LC08_L2SP_034032_20221215_20221227_02_T1.tif
# prep: Landsat8 reflectance ready | scaled=True | l7_masked=False | mean/min/max: 0.5148/0.0569/1.0000
# Landsat8 SR (post-prep) mean/min/max: 0.5148318409919739 0.056877508759498596 1.0
# 100
#      cell_y  cell_x  filtered_fraction    Dozier     Klein  Salomonson   fsc  \
# 0       0.0     0.0           0.375740  0.066931  0.018718    0.030451  0.80
# 1       0.0     0.0           0.966182  0.563215  0.393189    0.301180  0.95
# 2       0.0     0.0           0.723425  0.998501  0.994614    0.900840  0.98
# 3       0.0     0.0           0.656808  0.632566  0.408044    0.371270  0.90
# 4       0.0     0.0           0.887426  0.994184  0.948303    0.742114  1.00
# ..      ...     ...                ...       ...       ...         ...   ...
# 253     0.0     0.0           0.216371  0.523991  0.394008    0.453023  1.00
# 254     0.0     0.0           0.216371  0.623225  0.469198    0.519310  1.00
# 255     0.0     0.0           0.216371  0.973856  0.762054    0.834754  1.00
# 256     0.0     0.0           0.216371  0.848820  0.529450    0.730643  1.00
# 257     0.0     0.0           0.216371  1.000000  0.916695    0.675985  1.00
#
#             cam                                           filepath
# 0      bartlett  ../scratch/data/landsat/Landsat7_bartlett80_cl...
# 1      hyytiala  ../scratch/data/landsat/Landsat7_hyytiala95_cl...
# 2    kenttarova  ../scratch/data/landsat/Landsat7_kenttarova98_...
# 3      lacclair  ../scratch/data/landsat/Landsat7_lacclair90_cl...
# 4       marcell  ../scratch/data/landsat/Landsat7_marcell100_cl...
# ..          ...                                                ...
# 253    wslcreek  ../scratch/data/landsat/Landsat8_wslcreek100_L...
# 254    wslcreek  ../scratch/data/landsat/Landsat8_wslcreek100_L...
# 255    wslcreek  ../scratch/data/landsat/Landsat8_wslcreek100_L...
# 256    wslcreek  ../scratch/data/landsat/Landsat8_wslcreek100_L...
# 257    wslcreek  ../scratch/data/landsat/Landsat8_wslcreek100_L...
#
# [258 rows x 9 columns]

# %%
#80m

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# final_df = pd.read_pickle('landsat_df_80m_0.2ff.pkl')
final_df_ = final_df[final_df['cam']=='old_jack_pine'].copy()

# Melt the dataframe to long format for individual method plots
melted = final_df_.melt(
    id_vars=["fsc", "filtered_fraction", "cam", "filepath"],
    value_vars=["Dozier", "Klein"],  # , "Salomonson"
    var_name="method",
    value_name="predicted"
)

# Convert to percentages for plotting (0–100)
melted["fsc"] = melted["fsc"] * 100.0
melted["predicted"] = melted["predicted"] * 100.0

# Define color map (blue for Dozier, green for Klein)
method_colors = {
    "Dozier": "#1f77b4",
    "Klein": "#2ca02c",
    # "Salomonson": "#d62728"
}

# ---------- Scatter: Observed vs Predicted, one figure per method ----------
for method in ["Dozier", "Klein"]:  # , "Salomonson"
    subset = melted[melted["method"] == method]

    plt.figure(figsize=(6, 6))
    plt.scatter(
        subset["fsc"],
        subset["predicted"],
        alpha=0.6,
        edgecolor='k',
        c=method_colors[method],
        label=method
    )
    plt.plot([0, 100], [0, 100], 'r--', lw=1)
    plt.xlabel("Observed FSC (%)")
    plt.ylabel("Predicted FSC (%)")
    plt.title(f"Observed vs Predicted FSC: {method}")
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    # plt.savefig(f'poster_landsat_{method}_actual_predicted.svg')
    plt.show()

# ---------- Metric helpers ----------
def rmse(y_true, y_pred):
    diff = y_pred - y_true
    return np.sqrt(np.nanmean(diff**2)) if np.isfinite(diff).any() else np.nan

def bias(y_true, y_pred):
    diff = y_pred - y_true
    return np.nanmean(diff) if np.isfinite(diff).any() else np.nan

def compute_all_metrics(df_method):
    """df_method: melted subset for a single method, with fsc/predicted in 0–100 units."""
    y = df_method["fsc"].to_numpy()
    yhat = df_method["predicted"].to_numpy()

    # Overall
    overall_rmse  = rmse(y, yhat)
    overall_bias  = bias(y, yhat)

    # Fractional (strictly between 0 and 100)
    frac_mask = (y > 0) & (y < 100)
    frac_rmse  = rmse(y[frac_mask], yhat[frac_mask])
    frac_bias  = bias(y[frac_mask], yhat[frac_mask])

    # Errors at the extremes
    zero_mask = (y == 0)
    full_mask = (y == 100)

    zero_bias = bias(y[zero_mask], yhat[zero_mask])   # "0%SC Error"
    full_bias = bias(y[full_mask], yhat[full_mask])   # "100%SC Error"

    metrics_order = ["RMSE", "Bias", "Fractional RMSE", "Fractional Bias", "0%SC Error", "100%SC Error"]
    values = np.array([
        overall_rmse,
        overall_bias,
        frac_rmse,
        frac_bias,
        zero_bias,
        full_bias
    ], dtype=float)

    return metrics_order, values

# ---------- Bar chart per method with six metrics ----------
for method in ["Dozier", "Klein"]:
    subset = melted[melted["method"] == method]
    metrics_labels, values = compute_all_metrics(subset)

    plt.figure(figsize=(8, 5))
    x = np.arange(len(metrics_labels))
    bars = plt.bar(x, values, edgecolor='black', color=method_colors[method])

    # Labels on bars (handle NaNs gracefully)
    for bar, val in zip(bars, values):
        height = 0 if np.isnan(val) else float(val)
        txt = "NaN" if np.isnan(val) else f"{height:.1f}%"
        x_offset = bar.get_x() + bar.get_width() * 0.6
        y_offset = 1 * np.sign(height if height != 0 else 1)
        plt.text(
            x_offset,
            height + y_offset,
            txt,
            ha='left',
            va='bottom' if height >= 0 else 'top',
            fontsize=13
        )

    plt.xticks(x, metrics_labels, rotation=0)
    plt.ylabel("Value (%)")
    plt.title(f"{method} – FSC Estimation Metrics")
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Y-lims with padding, robust to NaNs
    finite_vals = values[np.isfinite(values)]
    if finite_vals.size == 0:
        ymin, ymax = -1, 1
    else:
        ymin = min(0.0, float(finite_vals.min())) - 4
        ymax = (float(finite_vals.max()) + 4) if float(finite_vals.max()) > 0 else 1
    plt.ylim(ymin, ymax)

    plt.tight_layout()
    # plt.savefig(f'poster_landsat_{method}_metrics.svg')
    plt.show()

# ---------- Histogram: Predicted FSC where observed FSC = 100% ----------

# Filter scenes where observed FSC is 100%
full_snow = melted[melted["fsc"] == 100].copy()

# Set up plot
plt.figure(figsize=(7, 5))
bins = np.linspace(0, 100, 21)  # 0–100 in 5% increments

for method in ["Dozier", "Klein"]:
# for method in ["Klein"]:
    subset = full_snow[full_snow["method"] == method]
    sns.histplot(
        subset["predicted"],
        bins=bins,
        kde=False,
        color=method_colors[method],
        label=f"{method} (n={len(subset)})",
        alpha=0.6,
        edgecolor="black"
    )

# Reference line at 100% (perfect prediction)
# plt.axvline(100, color="red", linestyle="--", linewidth=1, label="Observed = 100%")

plt.xlabel("Predicted FSC (%)")
plt.ylabel("Count")
plt.title("Distribution of Predicted FSC for Scenes with Observed Full Snow Cover (Old Jack Pine)")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
# plt.savefig("poster_landsat_full_snow_hist.svg")
plt.show()

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)  # show full strings in cells

final_df_
# Out:
#      cell_y  cell_x  filtered_fraction    Dozier     Klein  Salomonson   fsc  \
# 8       0.0     0.0           0.910434  0.287658  0.101513    0.115113  0.44
# 120     0.0     0.0           0.910434  0.000336  0.000000    0.000159  0.00
# 121     0.0     0.0           0.910434  0.000028  0.000000    0.000016  0.00
# 122     0.0     0.0           0.910434  0.000336  0.000000    0.000168  0.00
# 123     0.0     0.0           0.910434  0.000336  0.000000    0.000136  0.00
# 124     0.0     0.0           0.910434  0.000294  0.000000    0.000144  0.00
# 125     0.0     0.0           0.910434  0.000504  0.000000    0.000206  0.00
# 126     0.0     0.0           0.910434  0.000350  0.000000    0.000175  0.00
# 127     0.0     0.0           0.910434  0.000336  0.000000    0.000111  0.00
# 128     0.0     0.0           0.910434  0.000350  0.000000    0.000151  0.00
# 129     0.0     0.0           0.910434  0.000252  0.000000    0.000317  0.00
# 130     0.0     0.0           0.910434  0.000546  0.000000    0.000219  0.00
# 131     0.0     0.0           0.910434  0.000028  0.000000    0.000042  0.00
# 132     0.0     0.0           0.910434  0.000406  0.000000    0.000139  0.00
# 133     0.0     0.0           0.910434  0.817574  0.652269    0.596519  1.00
# 134     0.0     0.0           0.910434  0.832133  0.673171    0.634128  1.00
