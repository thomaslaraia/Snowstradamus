# %% [markdown]
# # Drafting

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt
from rasterio.warp import reproject, Resampling
from pyproj import Transformer
from matplotlib.colors import ListedColormap

# Define paths for Sentinel-2 and DEM files
sentinel_path = "../data_store/data/S2B_MSIL2A_20230515T095559_N0509_R122_T35WMQ_20230515T113307.SAFE/GRANULE/L2A_T35WMQ_A032323_20230515T095746/IMG_DATA/R20m/"
dem_base_path = "../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/"

# Define Sentinel-2 Band files
band12_file = sentinel_path + "T35WMQ_20230515T095559_B12_20m.jp2"  # SWIR
band11_file = sentinel_path + "T35WMQ_20230515T095559_B11_20m.jp2"  # SWIR
band5_file = sentinel_path + "T35WMQ_20230515T095559_B05_20m.jp2"  # NIR
band6_file = sentinel_path + "T35WMQ_20230515T095559_B06_20m.jp2"  # NIR
band7_file = sentinel_path + "T35WMQ_20230515T095559_B07_20m.jp2"  # NIR
band8a_file = sentinel_path + "T35WMQ_20230515T095559_B8A_20m.jp2"  # NIR
band4_file = sentinel_path + "T35WMQ_20230515T095559_B04_20m.jp2"   # Red
band3_file = sentinel_path + "T35WMQ_20230515T095559_B03_20m.jp2"   # Green
band2_file = sentinel_path + "T35WMQ_20230515T095559_B02_20m.jp2"   # Blue

# Load Sentinel-2 bands and DEM data
def load_raster(file_path):
    with rasterio.open(file_path) as src:
        return src.read(1), src.transform, src.crs, src


# Load the Sentinel-2 bands
band12, transform_band12, crs_band12, src_band12 = load_raster(band12_file)
band11, transform_band11, crs_band11, src_band11 = load_raster(band11_file)
band8a, transform_band8a, crs_band8a, src_band8a = load_raster(band8a_file)
band7, transform_band7, crs_band7, src_band8a = load_raster(band7_file)
band6, transform_band6, crs_band6, src_band8a = load_raster(band6_file)
band5, transform_band5, crs_band5, src_band8a = load_raster(band5_file)
band4, transform_band4, crs_band4, src_band4 = load_raster(band4_file)
band3, transform_band3, crs_band3, src_band3 = load_raster(band3_file)
band2, transform_band2, crs_band2, src_band2 = load_raster(band2_file)

# List all DEM files and dynamically assign the correct folder (U43 or U44)
dem_file_names = [
    "U4341G.tif", "U4341H.tif", "U4342G.tif", "U4342H.tif",
    "U4343A.tif", "U4343B.tif", "U4343C.tif", "U4343D.tif", "U4343E.tif", "U4343F.tif", "U4343G.tif", "U4343H.tif",
    "U4344A.tif", "U4344B.tif", "U4344C.tif", "U4344D.tif", "U4344E.tif", "U4344F.tif", "U4344G.tif", "U4344H.tif",
    "U4431G.tif", "U4433A.tif", "U4433C.tif", "U4433E.tif", "U4433G.tif"
]

# Function to assign correct folder based on file name prefix
def get_dem_path(filename):
    if filename.startswith("U43"):
        return dem_base_path + "U43/" + filename
    elif filename.startswith("U44"):
        return dem_base_path + "U44/" + filename
    else:
        raise ValueError(f"Unexpected DEM file name: {filename}")

# Generate full paths for each DEM file
dem_files = [get_dem_path(fname) for fname in dem_file_names]

# Load and merge DEM files
def merge_dems(dem_files):
    dem_list = []
    for file in dem_files:
        dem, transform_dem, crs_dem, src_dem = load_raster(file)
        dem_list.append(dem)
    merged_dem = np.maximum.reduce(dem_list)  # Simple maximum operation to merge DEMs
    return merged_dem, transform_dem, crs_dem

# Merge all DEMs
dem_combined, transform_dem_combined, crs_dem_combined = merge_dems(dem_files)

# Reproject DEM to match Sentinel-2 CRS and resolution (Band 12 for reference)
def reproject_raster(src_array, src_transform, src_crs, dst_transform, dst_crs, dst_shape, resampling=Resampling.nearest):
    dst_array = np.empty(dst_shape, dtype=src_array.dtype)
    reproject(
        source=src_array,
        destination=dst_array,
        src_transform=src_transform,
        src_crs=src_crs,
        dst_transform=dst_transform,
        dst_crs=dst_crs,
        resampling=resampling
    )
    return dst_array

# Reproject the DEM to match the Sentinel-2 data (SWIR band reference)
dem_reprojected = reproject_raster(
    dem_combined,
    transform_dem_combined,
    crs_dem_combined,
    transform_band12,
    crs_band12,
    band12.shape
)

# Function to apply contrast stretching
def contrast_stretch(band, low_perc=2, high_perc=98):
    """
    Stretch the image contrast by clipping pixel values based on percentiles.
    """
    low = np.percentile(band, low_perc)
    high = np.percentile(band, high_perc)
    stretched_band = np.clip(band, low, high)
    stretched_band = (stretched_band - low) / (high - low) * 255  # Rescale to 0-255
    return stretched_band

# Create true color composite using bands 4, 3, and 2 with contrast adjustment
def create_true_color_composite(band4, band3, band2, apply_stretch=True):
    if apply_stretch:
        band4 = contrast_stretch(band4)
        band3 = contrast_stretch(band3)
        band2 = contrast_stretch(band2)

    # Stack the bands into a single composite image
    composite = np.dstack((band4, band3, band2))
    return composite.astype(np.uint8)  # Convert to 8-bit format

# Create SWIR composite using bands 12, 8A, and 4 (for visualization)
def create_swir_composite(band12, band8a, band4):
    composite = np.dstack((band12, band8a, band4))
    return composite

def create_mask(swir_composite):
    """
    Generates a mask where active areas are marked and inactive areas are set to NaN.
    """
    # Thresholds based on the description of the features
    water_marsh_mask = ((swir_composite[:, :, 0] < 1200))  # Dark in SWIR (water/marsh)
    cloud_mask = (swir_composite[:, :, 0] > 5000) & (swir_composite[:, :, 1] > 5000) & (swir_composite[:, :, 2] > 5000)  # White clouds
    
    # Combine all masks
    combined_mask = np.logical_or.reduce([water_marsh_mask, cloud_mask])
    #print(combined_mask)
    
    # Set mask to NaN where it's not active, and 1 where it is active
    combined_mask = np.where(combined_mask, 1, np.nan)
    
    return combined_mask

# Convert pixel coordinates to lat/lon (EPSG:4326)
def pixel_to_latlon(transform, crs, width, height):
    transformer = Transformer.from_crs(crs, "EPSG:4326", always_xy=True)
    xs, ys = np.meshgrid(np.arange(width), np.arange(height))
    lon, lat = rasterio.transform.xy(transform, ys, xs, offset='center')
    lon = np.array(lon)
    lat = np.array(lat)
    lon_lat_transformed = np.vectorize(lambda x, y: transformer.transform(x, y))(lon, lat)
    return lon_lat_transformed[0], lon_lat_transformed[1]

# Visualize the SWIR composite and the mask
def plot_image(image, title, cmap='gray'):
    plt.figure(figsize=(10, 10))
    plt.imshow(image, cmap=cmap, interpolation='none')
    plt.colorbar()
    plt.title(title)
    plt.show()

# Plot true color image with bright yellow mask overlay
def plot_true_color_with_mask(true_color_composite, mask=None, transform=None, crs=None, title="True Color Image"):
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.imshow(true_color_composite)

    # Define a hard yellow colormap (banana yellow)
    banana_yellow = ListedColormap(['yellow'])

    # Overlay the mask in bright yellow, where the mask is active (mask != NaN)
    if mask is not None:
        ax.imshow(mask, cmap=banana_yellow, alpha=1, interpolation='none')  # Apply hard banana yellow with full alpha
    
    if transform is not None and crs is not None:
        lon, lat = pixel_to_latlon(transform, crs, true_color_composite.shape[1], true_color_composite.shape[0])
        ax.set_xticks(np.linspace(0, true_color_composite.shape[1], 5))
        ax.set_yticks(np.linspace(0, true_color_composite.shape[0], 5))
        ax.set_xticklabels(np.round(np.linspace(np.min(lon), np.max(lon), 5), 4))
        ax.set_yticklabels(np.round(np.linspace(np.min(lat), np.max(lat), 5), 4))
        ax.set_xlabel("Longitude")
        ax.set_ylabel("Latitude")
    
    ax.set_title(title)
    plt.show()

# Create SWIR composite and mask (if needed)
swir_composite = create_swir_composite(band12, band8a, band4)
mask = create_mask(swir_composite)  # Mask generation (can be omitted if not needed)

# # Show the mask
# plot_image(mask, 'Mask for Lakes, Marshes, Icy Lakes, and Clouds', cmap='gray')

# Create the true color composite with contrast adjustment
true_color_composite = create_true_color_composite(band4, band3, band2, apply_stretch=True)

# Plot true color scene with optional mask overlay
plot_true_color_with_mask(true_color_composite, mask=mask, transform=transform_band4, crs=crs_band4, title="True Color Scene with Lat/Lon Axes")

# %%
import numpy as np
import matplotlib.pyplot as plt
import rasterio
from pyproj import Transformer

def calculate_ndfsi(green_band, swir_band):
    """
    Calculate the NDFSI using Green (Band 3) and SWIR (Band 12).
    """
    ndfsi = (green_band - swir_band) / (green_band + swir_band)
    return ndfsi

def apply_mask(ndfsi, mask):
    """
    Apply the mask to the NDFSI array. Masked areas will be set to NaN.
    """
    # Set NDFSI values where the mask is NaN to the NDFSI value, and everything else to NaN
    masked_ndfsi = np.where(np.isnan(mask), ndfsi, np.nan)
    return masked_ndfsi

def pixel_to_latlon(transform, crs, width, height):
    """
    Convert pixel coordinates to latitude/longitude coordinates (EPSG:4326).
    """
    transformer = Transformer.from_crs(crs, "EPSG:4326", always_xy=True)
    xs, ys = np.meshgrid(np.arange(width), np.arange(height))
    lon, lat = rasterio.transform.xy(transform, ys, xs, offset='center')
    lon = np.array(lon)
    lat = np.array(lat)
    lon_lat_transformed = np.vectorize(lambda x, y: transformer.transform(x, y))(lon, lat)
    return lon_lat_transformed[0], lon_lat_transformed[1]

def plot_ndfsi_latlon(ndfsi, transform, crs, title="Sentinel-2 NDFSI in Lat/Lon"):
    """
    Plot the NDFSI with latitude/longitude coordinates.
    """
    # Convert pixel coordinates to latitude and longitude
    lon, lat = pixel_to_latlon(transform, crs, ndfsi.shape[1], ndfsi.shape[0])
    
    # Calculate the aspect ratio based on the dimensions of the NDFSI array
    aspect_ratio = ndfsi.shape[0] / ndfsi.shape[1]
    
    # Plotting the NDFSI with lat/lon coordinates
    plt.figure(figsize=(12, 12 * aspect_ratio))
    plt.imshow(ndfsi, extent=(lon.min(), lon.max(), lat.min(), lat.max()), cmap='coolwarm', interpolation='none', aspect='auto')
    plt.colorbar()
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title(title)
    plt.show()

def apply_snow_threshold(ndfsi, threshold):
    """
    Apply a snow threshold to the NDFSI. 
    Below the threshold, set values to 1 (snow), and above it, set to 0 (no snow).
    """
    snow_mask = np.where(ndfsi <= threshold, 1, 0)
    return snow_mask

def plot_single_snow_mask_latlon(ndfsi, threshold, transform, crs):
    """
    Plot a single snow mask for a given threshold in latitude/longitude, preserving aspect ratio.
    """
    snow_mask = apply_snow_threshold(ndfsi, threshold)
    
    # Convert pixel coordinates to latitude and longitude
    lon, lat = pixel_to_latlon(transform, crs, snow_mask.shape[1], snow_mask.shape[0])
    
    # Calculate the aspect ratio based on the dimensions of the NDFSI array
    aspect_ratio = snow_mask.shape[0] / snow_mask.shape[1]
    
    # Plotting the snow mask with lat/lon coordinates
    plt.figure(figsize=(12, 12 * aspect_ratio))
    plt.imshow(snow_mask, extent=(lon.min(), lon.max(), lat.min(), lat.max()), cmap='gray', interpolation='none', aspect='auto')
    plt.colorbar()
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title(f'Snow Mask (Threshold = {threshold}) in Lat/Lon')
    plt.show()

# Load Sentinel-2 bands (Band 3 - Green, Band 12 - SWIR)
# green_band, transform_band3, crs_band3, _ = load_raster(band3_file)
for i, other in enumerate([band11_file]): #band11_file, band12_file
    for file in [band3_file]: #band3_file, band5_file
        nir_band, transform_band5, crs_band5, _ = load_raster(file)
        swir_band, transform_band11, crs_band11, _ = load_raster(other)
        # swir_band2, transform_band12, crs_band12, _ = load_raster(band12_file)
        
        # Calculate the NDFSI using Bands 3 and 12
        ndfsi = calculate_ndfsi(nir_band, swir_band)
        # ndfsi = calculate_ndfsi(green_band, swir_band)
        # ndfsi2 = calculate_ndfsi(green_band, swir_band2)
        
        # Create the mask using SWIR composite (assumed to be defined earlier)
        mask = create_mask(swir_composite)
        
        # Apply the mask to the NDFSI to ignore masked areas
        masked_ndfsi = apply_mask(ndfsi, mask)
        # masked_ndfsi = apply_mask(ndfsi2 - ndfsi, mask)
        
        # Plot the NDFSI with latitude/longitude coordinates
        # plot_ndfsi_latlon(masked_ndfsi, transform_band3, crs_band3, title="Sentinel-2 NDFSI in Lat/Lon")

        # Plot the snow mask based on the chosen threshold with latitude/longitude coordinates and proper scaling
        plot_single_snow_mask_latlon(masked_ndfsi, 0.40, transform_band4, crs_band4)

# %%
import numpy as np
import matplotlib.pyplot as plt
from pyproj import Transformer

def apply_snow_threshold(ndfsi, threshold):
    """
    Apply a snow threshold to the NDFSI. 
    Below the threshold, set values to 1 (snow), and above it, set to 0 (no snow).
    """
    snow_mask = np.where(ndfsi <= threshold, 1, 0)
    return snow_mask

def pixel_to_latlon(transform, crs, width, height):
    """
    Convert pixel coordinates to latitude/longitude coordinates (EPSG:4326).
    """
    transformer = Transformer.from_crs(crs, "EPSG:4326", always_xy=True)
    xs, ys = np.meshgrid(np.arange(width), np.arange(height))
    lon, lat = rasterio.transform.xy(transform, ys, xs, offset='center')
    lon = np.array(lon)
    lat = np.array(lat)
    lon_lat_transformed = np.vectorize(lambda x, y: transformer.transform(x, y))(lon, lat)
    return lon_lat_transformed[0], lon_lat_transformed[1]

def average_snow_cover_in_blocks(snow_mask, transform, block_size_meters=1000):
    """
    Calculate the fractional snow cover in 1 km x 1 km blocks.
    """
    pixel_size_x = abs(transform[0])
    pixel_size_y = abs(transform[4])

    # Calculate the number of pixels that correspond to the block size (1 km x 1 km)
    block_size_x = int(block_size_meters / pixel_size_x)
    block_size_y = int(block_size_meters / pixel_size_y)
    
    # Get the dimensions of the snow mask
    rows, cols = snow_mask.shape
    
    # Initialize an array for the averaged snow cover
    averaged_snow_cover = np.full_like(snow_mask, np.nan, dtype=float)
    
    # Iterate over the blocks
    for i in range(0, rows, block_size_y):
        for j in range(0, cols, block_size_x):
            # Extract the block
            block = snow_mask[i:i+block_size_y, j:j+block_size_x]
            
            # Calculate the mean of the block, ignoring NaNs
            if np.isnan(block).all():
                block_mean = np.nan
            else:
                block_mean = np.nanmean(block)
            
            # Assign the mean value to the entire block
            averaged_snow_cover[i:i+block_size_y, j:j+block_size_x] = block_mean
    
    return averaged_snow_cover

def plot_averaged_snow_cover_latlon(averaged_snow_cover, transform, crs, title="Averaged Snow Cover (1 km x 1 km)"):
    """
    Plot the averaged snow cover with latitude/longitude coordinates.
    """
    # Convert pixel coordinates to latitude and longitude
    lon, lat = pixel_to_latlon(transform, crs, averaged_snow_cover.shape[1], averaged_snow_cover.shape[0])
    
    # Calculate the aspect ratio based on the dimensions of the averaged snow cover array
    aspect_ratio = averaged_snow_cover.shape[0] / averaged_snow_cover.shape[1]
    
    # Plotting the averaged snow cover with lat/lon coordinates
    plt.figure(figsize=(12, 12 * aspect_ratio))
    plt.imshow(averaged_snow_cover, extent=(lon.min(), lon.max(), lat.min(), lat.max()), cmap='gray', interpolation='none', aspect='auto')
    plt.colorbar()
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title(title)
    plt.show()

# Set the threshold to 1
threshold = 0.4

# Apply the threshold to create a binary snow mask
snow_mask = apply_snow_threshold(masked_ndfsi, threshold)

# Calculate the averaged snow cover in 1 km x 1 km blocks
averaged_snow_cover = average_snow_cover_in_blocks(snow_mask, transform_band4)

# Plot the averaged snow cover with latitude/longitude coordinates
plot_averaged_snow_cover_latlon(averaged_snow_cover, transform_band4, crs_band4, title="Averaged Snow Cover (1 km x 1 km) in Lat/Lon")

# %% [markdown]
# # FSC

# %%
import os
import numpy as np
import rasterio
from rasterio.enums import Resampling
from rasterio.merge import merge
from rasterio.warp import calculate_default_transform, reproject
import matplotlib.pyplot as plt
from pyproj import Transformer

# Load Sentinel-2 bands and DEM data
def load_raster(file_path):
    with rasterio.open(file_path) as src:
        return src.read(1), src.transform, src.crs, src

# Define paths for Sentinel-2 and DEM files
sentinel_path = "../data_store/data/S2B_MSIL2A_20230515T095559_N0509_R122_T35WMQ_20230515T113307.SAFE/GRANULE/L2A_T35WMQ_A032323_20230515T095746/IMG_DATA/R20m/"
base_directory = '../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/'

# Define Sentinel-2 Band files
band12_file = sentinel_path + "T35WMQ_20230515T095559_B12_20m.jp2"  # SWIR
band11_file = sentinel_path + "T35WMQ_20230515T095559_B11_20m.jp2"  # SWIR
band5_file = sentinel_path + "T35WMQ_20230515T095559_B05_20m.jp2"  # NIR
band6_file = sentinel_path + "T35WMQ_20230515T095559_B06_20m.jp2"  # NIR
band7_file = sentinel_path + "T35WMQ_20230515T095559_B07_20m.jp2"  # NIR
band8a_file = sentinel_path + "T35WMQ_20230515T095559_B8A_20m.jp2"  # NIR
band4_file = sentinel_path + "T35WMQ_20230515T095559_B04_20m.jp2"   # Red
band3_file = sentinel_path + "T35WMQ_20230515T095559_B03_20m.jp2"   # Green
band2_file = sentinel_path + "T35WMQ_20230515T095559_B02_20m.jp2"   # Blue
# Load the Sentinel-2 bands
band12, transform_band12, crs_band12, src_band12 = load_raster(band12_file)
band11, transform_band11, crs_band11, src_band11 = load_raster(band11_file)
band8a, transform_band8a, crs_band8a, src_band8a = load_raster(band8a_file)
band7, transform_band7, crs_band7, src_band8a = load_raster(band7_file)
band6, transform_band6, crs_band6, src_band8a = load_raster(band6_file)
band5, transform_band5, crs_band5, src_band8a = load_raster(band5_file)
band4, transform_band4, crs_band4, src_band4 = load_raster(band4_file)
band3, transform_band3, crs_band3, src_band3 = load_raster(band3_file)
band2, transform_band2, crs_band2, src_band2 = load_raster(band2_file)

# Resample DEM files to 10m resolution and merge
def find_and_merge_dems(base_dir):
    dem_files = [os.path.join(root, file)
                 for root, _, files in os.walk(base_dir)
                 for file in files if file.endswith('.tif')]
    resampled_datasets = []

    for dem_file in dem_files:
        with rasterio.open(dem_file) as src:
            resampled_data = src.read(
                1,
                out_shape=(src.height // 5, src.width // 5),
                resampling=Resampling.average
            )
            new_transform = src.transform * src.transform.scale(5, 5)
            memfile = rasterio.io.MemoryFile()
            dataset = memfile.open(
                driver='GTiff',
                height=resampled_data.shape[0],
                width=resampled_data.shape[1],
                count=1,
                dtype=resampled_data.dtype,
                crs=src.crs,
                transform=new_transform
            )
            dataset.write(resampled_data, 1)
            resampled_datasets.append(dataset)

    merged_dem, merged_transform = merge(resampled_datasets)
    for dataset in resampled_datasets:
        dataset.close()
    return merged_dem, merged_transform, src.crs

# Calculate bounds from transform
def calculate_bounds(transform, width, height):
    left = transform.c
    top = transform.f
    right = left + transform.a * width
    bottom = top + transform.e * height
    return (left, bottom, right, top)

def create_mask(swir_composite):
    """
    Generates a mask where active areas are marked and inactive areas are set to NaN.
    """
    # Thresholds based on the description of the features
    water_marsh_mask = (swir_composite[:, :, 0] < 1200)  # Dark in SWIR (water/marsh)
    cloud_mask = (swir_composite[:, :, 0] > 5000) & (swir_composite[:, :, 1] > 5000) & (swir_composite[:, :, 2] > 5000)  # White clouds
    
    # Combine all masks
    combined_mask = np.logical_or.reduce([water_marsh_mask, cloud_mask])
    
    # Set mask to NaN where it's not active, and 1 where it is active
    combined_mask = np.where(combined_mask, np.nan, 1)
    
    return combined_mask

# Create SWIR composite using bands 12, 8A, and 4 (for visualization)
def create_swir_composite(band12, band8a, band4):
    composite = np.dstack((band12, band8a, band4))
    return composite

def apply_mask(ndfsi, mask):
    """
    Apply the mask to the NDFSI array. Masked areas will be set to NaN.
    """
    masked_ndfsi = np.where(mask == 1, ndfsi, np.nan)
    return masked_ndfsi

# Reproject DEM to latitude/longitude (EPSG:4326)
def reproject_to_latlon(src_array, src_transform, src_crs):
    dst_crs = 'EPSG:4326'
    bounds = calculate_bounds(src_transform, src_array.shape[1], src_array.shape[0])
    dst_transform, width, height = calculate_default_transform(
        src_crs, dst_crs, src_array.shape[1], src_array.shape[0], *bounds)

    dst_array = np.empty((height, width), dtype=np.float32)
    reproject(
        source=src_array,
        destination=dst_array,
        src_transform=src_transform,
        src_crs=src_crs,
        dst_transform=dst_transform,
        dst_crs=dst_crs,
        resampling=Resampling.nearest
    )
    return dst_array, dst_transform

# Calculate NDFSI using Green and SWIR bands
def calculate_ndfsi(green_band, swir_band):
    return (green_band - swir_band) / (green_band + swir_band)

# Apply a snow threshold
def apply_snow_threshold(ndfsi, threshold):
    return np.where(ndfsi <= threshold, 1, 0)

def average_snow_cover_in_blocks(snow_mask, transform, block_size_meters=1000):
    """
    Calculate the fractional snow cover in 1 km x 1 km blocks.
    """
    pixel_size_x = abs(transform[0])
    pixel_size_y = abs(transform[4])

    # Calculate the number of pixels that correspond to the block size (1 km x 1 km)
    block_size_x = int(block_size_meters / pixel_size_x)
    block_size_y = int(block_size_meters / pixel_size_y)
    
    # Get the dimensions of the snow mask
    rows, cols = snow_mask.shape
    
    # Initialize an array for the averaged snow cover
    averaged_snow_cover = np.full_like(snow_mask, np.nan, dtype=float)
    
    # Iterate over the blocks
    for i in range(0, rows, block_size_y):
        for j in range(0, cols, block_size_x):
            # Extract the block
            block = snow_mask[i:i+block_size_y, j:j+block_size_x]
            
            # Calculate the mean of the block, ignoring NaNs
            if np.isnan(block).all():
                block_mean = np.nan
            else:
                block_mean = np.nanmean(block)
            
            # Assign the mean value to the entire block
            averaged_snow_cover[i:i+block_size_y, j:j+block_size_x] = block_mean
    
    return averaged_snow_cover

# Convert pixel coordinates to lat/lon (EPSG:4326)
def pixel_to_latlon(transform, crs, width, height):
    transformer = Transformer.from_crs(crs, "EPSG:4326", always_xy=True)
    xs, ys = np.meshgrid(np.arange(width), np.arange(height))
    lon, lat = rasterio.transform.xy(transform, ys, xs, offset='center')
    lon = np.array(lon)
    lat = np.array(lat)
    lon_lat_transformed = np.vectorize(lambda x, y: transformer.transform(x, y))(lon, lat)
    return lon_lat_transformed[0], lon_lat_transformed[1]

def plot_averaged_snow_cover_latlon(averaged_snow_cover, transform, crs, title="Averaged Snow Cover (1 km x 1 km)"):
    """
    Plot the averaged snow cover with latitude/longitude coordinates.
    """
    # Convert pixel coordinates to latitude and longitude
    lon, lat = pixel_to_latlon(transform, crs, averaged_snow_cover.shape[1], averaged_snow_cover.shape[0])
    
    # Calculate the aspect ratio based on the dimensions of the averaged snow cover array
    aspect_ratio = averaged_snow_cover.shape[0] / averaged_snow_cover.shape[1]
    
    # Plotting the averaged snow cover with lat/lon coordinates
    plt.figure(figsize=(12, 12 * aspect_ratio))
    plt.imshow(averaged_snow_cover, extent=(lon.min(), lon.max(), lat.min(), lat.max()), cmap='gray', interpolation='none', aspect='auto')
    plt.colorbar()
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title(title)
    plt.show()

# Assuming swir_composite is already created using SWIR and other bands
swir_composite = create_swir_composite(band12, band8a, band4)

# Create the mask for water and clouds
mask = create_mask(swir_composite)

# Calculate the NDFSI
ndfsi = calculate_ndfsi(band3, band11)

# Assuming ndfsi is already calculated using Bands 3 (Green) and 12 (SWIR)
masked_ndfsi = apply_mask(ndfsi, mask)

# Apply the snow threshold to create a binary snow mask
threshold = 0.4
snow_mask = apply_snow_threshold(masked_ndfsi, threshold)

# Calculate the averaged snow cover in 1 km x 1 km blocks
averaged_snow_cover = average_snow_cover_in_blocks(snow_mask, transform_band3)

# Plot the averaged snow cover with latitude/longitude coordinates
plot_averaged_snow_cover_latlon(averaged_snow_cover, transform_band3, crs_band3, title="Averaged Snow Cover (1 km x 1 km) in Lat/Lon")

# %% [markdown]
# # DEM

# %%
import os
import numpy as np
import rasterio
from rasterio.enums import Resampling
from rasterio.merge import merge
from rasterio.io import MemoryFile
from rasterio.warp import calculate_default_transform, reproject
import matplotlib.pyplot as plt

# Define the base directory containing DEM files
base_directory = '../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/'

def find_all_tif_files(base_dir):
    """
    Find all .tif files recursively in the given directory.
    """
    print("Searching for .tif files in the directory...")
    tif_files = []
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.endswith('.tif'):
                full_path = os.path.join(root, file)
                tif_files.append(full_path)
                # print(f"Found: {full_path}")
    print(f"Total .tif files found: {len(tif_files)}")
    return tif_files

def resample_dem_to_10m(src):
    """
    Resample the DEM from 2m to 10m resolution using mean aggregation, in-memory.
    """
    transform = src.transform
    # Calculate new dimensions and transform for the 10m resolution
    new_width = src.width // 5
    new_height = src.height // 5
    new_transform = transform * transform.scale(5, 5)

    # Resample in memory
    resampled_data = src.read(
        1,
        out_shape=(new_height, new_width),
        resampling=Resampling.average
    )

    return resampled_data, new_transform, src.crs

def create_memory_dataset(data, transform, crs):
    """
    Create an in-memory rasterio dataset from the resampled data.
    """
    memfile = MemoryFile()
    dataset = memfile.open(
        driver='GTiff',
        height=data.shape[0],
        width=data.shape[1],
        count=1,
        dtype=data.dtype,
        crs=crs,
        transform=transform
    )
    dataset.write(data, 1)
    return dataset

def resample_and_merge_dems(dem_files):
    """
    Resample all DEM files to 10m resolution and merge them using rasterio's merge function.
    """
    print("Resampling and merging DEM files...")
    datasets = []

    for i, dem_file in enumerate(dem_files):
        # print(f"Processing file {i+1}/{len(dem_files)}: {dem_file}")
        with rasterio.open(dem_file) as src:
            try:
                resampled_data, resampled_transform, resampled_crs = resample_dem_to_10m(src)
                mem_dataset = create_memory_dataset(resampled_data, resampled_transform, resampled_crs)
                datasets.append(mem_dataset)
                # print(f"File {i+1} resampled and stored in memory.")
            except Exception as e:
                print(f"Error processing {dem_file}: {e}")

    # Merge the in-memory datasets
    print("Merging all resampled DEMs...")
    try:
        mosaic, out_trans = merge(datasets)
        print("DEM merging completed.")
    except Exception as e:
        print(f"Error during merging: {e}")
        return None, None

    # Close all in-memory files
    for dataset in datasets:
        dataset.close()

    return mosaic, out_trans

def calculate_bounds(transform, width, height):
    """
    Calculate the bounds of a raster given its transform, width, and height.
    """
    left = transform.c
    top = transform.f
    right = left + transform.a * width
    bottom = top + transform.e * height
    return (left, bottom, right, top)

def reproject_to_latlon(src_array, src_transform, src_crs):
    """
    Reproject the DEM array to latitude/longitude coordinates (EPSG:4326).
    """
    dst_crs = 'EPSG:4326'
    bounds = calculate_bounds(src_transform, src_array.shape[1], src_array.shape[0])
    dst_transform, width, height = calculate_default_transform(
        src_crs, dst_crs, src_array.shape[1], src_array.shape[0], *bounds)

    # Create an empty array for the reprojected DEM
    dst_array = np.empty((height, width), dtype=np.float32)

    reproject(
        source=src_array,
        destination=dst_array,
        src_transform=src_transform,
        src_crs=src_crs,
        dst_transform=dst_transform,
        dst_crs=dst_crs,
        resampling=Resampling.nearest
    )

    return dst_array, dst_transform

# Find all .tif files in the directory
dem_files = find_all_tif_files(base_directory)

# Extract CRS from any of the loaded DEM files, assuming they all share the same CRS
def extract_crs_from_dem(dem_file):
    with rasterio.open(dem_file) as src:
        return src.crs

if dem_files:
    # Resample all DEM files to 10m resolution and merge them in memory
    merged_dem, merged_transform = resample_and_merge_dems(dem_files)

    # Get the CRS from one of the DEM files
    dem_crs = extract_crs_from_dem(dem_files[0])

    if merged_dem is not None:
        print(f"Merged DEM shape: {merged_dem.shape}")
        print(f"Transform: {merged_transform}")

        # Reproject the merged DEM to latitude/longitude (EPSG:4326)
        reprojected_dem, reprojected_transform = reproject_to_latlon(merged_dem[0], merged_transform, 'EPSG:3067')

        # Plot the reprojected DEM
        plt.figure(figsize=(10, 10))
        plt.imshow(reprojected_dem, cmap='terrain', extent=(reprojected_transform[2], reprojected_transform[2] + reprojected_transform[0] * reprojected_dem.shape[1],
                                                            reprojected_transform[5] + reprojected_transform[4] * reprojected_dem.shape[0], reprojected_transform[5]),
                   aspect='auto')
        plt.colorbar(label='Elevation (meters)')
        plt.xlabel('Longitude')
        plt.ylabel('Latitude')
        plt.title('Merged DEM (Resampled to 10m, Reprojected to Lat/Lon)')
        plt.show()
    else:
        print("Merged DEM could not be created.")
else:
    print("No .tif files found. Check the directory path.")
# Out:
# Searching for .tif files in the directory...
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U52/U5211D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U52/U5211C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U52/U5211B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U52/U5211A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5111A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5112B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5111D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5112A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5122C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5111B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5112C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5122A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5112D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5122D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5122B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5111C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5121D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5121A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5121B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5121C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5222C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5221D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5211D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5212A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5221A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5211B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5222D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5212C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5212B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5222A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5221C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5211A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5221B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5211C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5222B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5212D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4433C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4411C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4413H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4431E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4411D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4411A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4431G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4431H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4431F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4413E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4411G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4413B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4413F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4413C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4413A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4433H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4411F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4411E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4411H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4433F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4431A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4433B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4433D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4433E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4433G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4433A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4431C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4413D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4413G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4431D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4411B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4431B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4333H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4332B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4331G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4323A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4331E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4321D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4343G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4341B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4344G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4344B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4322H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4312E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4322F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4342G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4314F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4323D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4344C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4341E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4333C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4333B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4334H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4331F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4342C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4321E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4332D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4341C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4343D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4322A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4312A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4322G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4314C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4322B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4313C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4324C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4334G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4341F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4311D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4333A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4343A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4324G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4323B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4313A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4331D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4311C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4323H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4332C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4324H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4341G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4343C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4331A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4314D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4312B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4311H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4323C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4321A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4334D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4344H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4314A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4334C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4321C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4344A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4323E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4313B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4332F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4321H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4332H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4311E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4333D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4334F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4322E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4342E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4313G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4313F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4324B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4343H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4341D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4343F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4344D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4324F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4342B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4334B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4332E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4343E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4342D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4321B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4344E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4321F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4342F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4323F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4313E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4332G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4311F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4334A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4333G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4322D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4334E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4324A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4332A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4311A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4322C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4324D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4343B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4321G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4312H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4342H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4342A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4324E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4314E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4314B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4344F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4341H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4313H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4311B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4333F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4314G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4341A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4314H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4333E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4331H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4312C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4312F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4323G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4331B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4313D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4331C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4312D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4312G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4311G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4433G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4422H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4412B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4414F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4431A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4414A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4441E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4431G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4413A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4424A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4443H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4434A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4434E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4443A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4413E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4431D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4444F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4432E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4413H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4433B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4432C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4431F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4434D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4413B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4442C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4432F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4444C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4421C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4411A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4432B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4442A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4442D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4434B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4422E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4414G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4431H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4411C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4422G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4442H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4444D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4434F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4431E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4443E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4412D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4412H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4411D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4421F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4411H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4434G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4434H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4432G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4421D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4421B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4423C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4441H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4421E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4422C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4414E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4424G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4423H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4432D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4423B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4422B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4412G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4441B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4424E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4411G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4413D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4442G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4431B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4441F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4443C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4441C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4433E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4423F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4434C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4422D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4412A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4414D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4442E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4424C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4421A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4423G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4423D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4441D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4443G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4414H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4433H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4421G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4441A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4413G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4431C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4412F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4433A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4411F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4432H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4423E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4442B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4411B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4432A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4413F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4424D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4444H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4414C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4443D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4422A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4424F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4444E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4421H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4424B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4441G.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4412E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4442F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4433F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4433D.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4413C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4443B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4414B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4444B.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4423A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4422F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4433C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4411E.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4412C.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4424H.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4443F.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4444A.tif
# Found: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4444G.tif
# Total .tif files found: 324
# Resampling and merging DEM files...
# Processing file 1/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U52/U5211D.tif
# File 1 resampled and stored in memory.
# Processing file 2/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U52/U5211C.tif
# File 2 resampled and stored in memory.
# Processing file 3/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U52/U5211B.tif
# File 3 resampled and stored in memory.
# Processing file 4/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U52/U5211A.tif
# File 4 resampled and stored in memory.
# Processing file 5/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5111A.tif
# File 5 resampled and stored in memory.
# Processing file 6/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5112B.tif
# File 6 resampled and stored in memory.
# Processing file 7/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5111D.tif
# File 7 resampled and stored in memory.
# Processing file 8/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5112A.tif
# File 8 resampled and stored in memory.
# Processing file 9/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5122C.tif
# File 9 resampled and stored in memory.
# Processing file 10/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5111B.tif
# File 10 resampled and stored in memory.
# Processing file 11/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5112C.tif
# File 11 resampled and stored in memory.
# Processing file 12/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5122A.tif
# File 12 resampled and stored in memory.
# Processing file 13/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5112D.tif
# File 13 resampled and stored in memory.
# Processing file 14/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5122D.tif
# File 14 resampled and stored in memory.
# Processing file 15/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5122B.tif
# File 15 resampled and stored in memory.
# Processing file 16/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5111C.tif
# File 16 resampled and stored in memory.
# Processing file 17/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5121D.tif
# File 17 resampled and stored in memory.
# Processing file 18/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5121A.tif
# File 18 resampled and stored in memory.
# Processing file 19/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5121B.tif
# File 19 resampled and stored in memory.
# Processing file 20/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U5/U51/U5121C.tif
# File 20 resampled and stored in memory.
# Processing file 21/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5222C.tif
# File 21 resampled and stored in memory.
# Processing file 22/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5221D.tif
# File 22 resampled and stored in memory.
# Processing file 23/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5211D.tif
# File 23 resampled and stored in memory.
# Processing file 24/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5212A.tif
# File 24 resampled and stored in memory.
# Processing file 25/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5221A.tif
# File 25 resampled and stored in memory.
# Processing file 26/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5211B.tif
# File 26 resampled and stored in memory.
# Processing file 27/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5222D.tif
# File 27 resampled and stored in memory.
# Processing file 28/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5212C.tif
# File 28 resampled and stored in memory.
# Processing file 29/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5212B.tif
# File 29 resampled and stored in memory.
# Processing file 30/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5222A.tif
# File 30 resampled and stored in memory.
# Processing file 31/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5221C.tif
# File 31 resampled and stored in memory.
# Processing file 32/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5211A.tif
# File 32 resampled and stored in memory.
# Processing file 33/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5221B.tif
# File 33 resampled and stored in memory.
# Processing file 34/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5211C.tif
# File 34 resampled and stored in memory.
# Processing file 35/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5222B.tif
# File 35 resampled and stored in memory.
# Processing file 36/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T5/T52/T5212D.tif
# File 36 resampled and stored in memory.
# Processing file 37/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4433C.tif
# File 37 resampled and stored in memory.
# Processing file 38/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4411C.tif
# File 38 resampled and stored in memory.
# Processing file 39/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4413H.tif
# File 39 resampled and stored in memory.
# Processing file 40/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4431E.tif
# File 40 resampled and stored in memory.
# Processing file 41/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4411D.tif
# File 41 resampled and stored in memory.
# Processing file 42/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4411A.tif
# File 42 resampled and stored in memory.
# Processing file 43/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4431G.tif
# File 43 resampled and stored in memory.
# Processing file 44/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4431H.tif
# File 44 resampled and stored in memory.
# Processing file 45/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4431F.tif
# File 45 resampled and stored in memory.
# Processing file 46/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4413E.tif
# File 46 resampled and stored in memory.
# Processing file 47/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4411G.tif
# File 47 resampled and stored in memory.
# Processing file 48/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4413B.tif
# File 48 resampled and stored in memory.
# Processing file 49/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4413F.tif
# File 49 resampled and stored in memory.
# Processing file 50/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4413C.tif
# File 50 resampled and stored in memory.
# Processing file 51/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4413A.tif
# File 51 resampled and stored in memory.
# Processing file 52/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4433H.tif
# File 52 resampled and stored in memory.
# Processing file 53/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4411F.tif
# File 53 resampled and stored in memory.
# Processing file 54/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4411E.tif
# File 54 resampled and stored in memory.
# Processing file 55/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4411H.tif
# File 55 resampled and stored in memory.
# Processing file 56/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4433F.tif
# File 56 resampled and stored in memory.
# Processing file 57/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4431A.tif
# File 57 resampled and stored in memory.
# Processing file 58/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4433B.tif
# File 58 resampled and stored in memory.
# Processing file 59/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4433D.tif
# File 59 resampled and stored in memory.
# Processing file 60/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4433E.tif
# File 60 resampled and stored in memory.
# Processing file 61/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4433G.tif
# File 61 resampled and stored in memory.
# Processing file 62/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4433A.tif
# File 62 resampled and stored in memory.
# Processing file 63/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4431C.tif
# File 63 resampled and stored in memory.
# Processing file 64/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4413D.tif
# File 64 resampled and stored in memory.
# Processing file 65/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4413G.tif
# File 65 resampled and stored in memory.
# Processing file 66/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4431D.tif
# File 66 resampled and stored in memory.
# Processing file 67/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4411B.tif
# File 67 resampled and stored in memory.
# Processing file 68/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U44/U4431B.tif
# File 68 resampled and stored in memory.
# Processing file 69/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4333H.tif
# File 69 resampled and stored in memory.
# Processing file 70/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4332B.tif
# File 70 resampled and stored in memory.
# Processing file 71/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4331G.tif
# File 71 resampled and stored in memory.
# Processing file 72/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4323A.tif
# File 72 resampled and stored in memory.
# Processing file 73/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4331E.tif
# File 73 resampled and stored in memory.
# Processing file 74/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4321D.tif
# File 74 resampled and stored in memory.
# Processing file 75/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4343G.tif
# File 75 resampled and stored in memory.
# Processing file 76/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4341B.tif
# File 76 resampled and stored in memory.
# Processing file 77/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4344G.tif
# File 77 resampled and stored in memory.
# Processing file 78/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4344B.tif
# File 78 resampled and stored in memory.
# Processing file 79/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4322H.tif
# File 79 resampled and stored in memory.
# Processing file 80/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4312E.tif
# File 80 resampled and stored in memory.
# Processing file 81/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4322F.tif
# File 81 resampled and stored in memory.
# Processing file 82/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4342G.tif
# File 82 resampled and stored in memory.
# Processing file 83/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4314F.tif
# File 83 resampled and stored in memory.
# Processing file 84/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4323D.tif
# File 84 resampled and stored in memory.
# Processing file 85/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4344C.tif
# File 85 resampled and stored in memory.
# Processing file 86/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4341E.tif
# File 86 resampled and stored in memory.
# Processing file 87/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4333C.tif
# File 87 resampled and stored in memory.
# Processing file 88/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4333B.tif
# File 88 resampled and stored in memory.
# Processing file 89/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4334H.tif
# File 89 resampled and stored in memory.
# Processing file 90/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4331F.tif
# File 90 resampled and stored in memory.
# Processing file 91/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4342C.tif
# File 91 resampled and stored in memory.
# Processing file 92/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4321E.tif
# File 92 resampled and stored in memory.
# Processing file 93/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4332D.tif
# File 93 resampled and stored in memory.
# Processing file 94/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4341C.tif
# File 94 resampled and stored in memory.
# Processing file 95/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4343D.tif
# File 95 resampled and stored in memory.
# Processing file 96/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4322A.tif
# File 96 resampled and stored in memory.
# Processing file 97/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4312A.tif
# File 97 resampled and stored in memory.
# Processing file 98/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4322G.tif
# File 98 resampled and stored in memory.
# Processing file 99/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4314C.tif
# File 99 resampled and stored in memory.
# Processing file 100/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4322B.tif
# File 100 resampled and stored in memory.
# Processing file 101/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4313C.tif
# File 101 resampled and stored in memory.
# Processing file 102/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4324C.tif
# File 102 resampled and stored in memory.
# Processing file 103/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4334G.tif
# File 103 resampled and stored in memory.
# Processing file 104/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4341F.tif
# File 104 resampled and stored in memory.
# Processing file 105/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4311D.tif
# File 105 resampled and stored in memory.
# Processing file 106/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4333A.tif
# File 106 resampled and stored in memory.
# Processing file 107/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4343A.tif
# File 107 resampled and stored in memory.
# Processing file 108/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4324G.tif
# File 108 resampled and stored in memory.
# Processing file 109/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4323B.tif
# File 109 resampled and stored in memory.
# Processing file 110/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4313A.tif
# File 110 resampled and stored in memory.
# Processing file 111/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4331D.tif
# File 111 resampled and stored in memory.
# Processing file 112/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4311C.tif
# File 112 resampled and stored in memory.
# Processing file 113/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4323H.tif
# File 113 resampled and stored in memory.
# Processing file 114/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4332C.tif
# File 114 resampled and stored in memory.
# Processing file 115/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4324H.tif
# File 115 resampled and stored in memory.
# Processing file 116/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4341G.tif
# File 116 resampled and stored in memory.
# Processing file 117/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4343C.tif
# File 117 resampled and stored in memory.
# Processing file 118/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4331A.tif
# File 118 resampled and stored in memory.
# Processing file 119/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4314D.tif
# File 119 resampled and stored in memory.
# Processing file 120/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4312B.tif
# File 120 resampled and stored in memory.
# Processing file 121/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4311H.tif
# File 121 resampled and stored in memory.
# Processing file 122/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4323C.tif
# File 122 resampled and stored in memory.
# Processing file 123/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4321A.tif
# File 123 resampled and stored in memory.
# Processing file 124/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4334D.tif
# File 124 resampled and stored in memory.
# Processing file 125/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4344H.tif
# File 125 resampled and stored in memory.
# Processing file 126/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4314A.tif
# File 126 resampled and stored in memory.
# Processing file 127/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4334C.tif
# File 127 resampled and stored in memory.
# Processing file 128/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4321C.tif
# File 128 resampled and stored in memory.
# Processing file 129/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4344A.tif
# File 129 resampled and stored in memory.
# Processing file 130/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4323E.tif
# File 130 resampled and stored in memory.
# Processing file 131/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4313B.tif
# File 131 resampled and stored in memory.
# Processing file 132/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4332F.tif
# File 132 resampled and stored in memory.
# Processing file 133/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4321H.tif
# File 133 resampled and stored in memory.
# Processing file 134/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4332H.tif
# File 134 resampled and stored in memory.
# Processing file 135/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4311E.tif
# File 135 resampled and stored in memory.
# Processing file 136/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4333D.tif
# File 136 resampled and stored in memory.
# Processing file 137/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4334F.tif
# File 137 resampled and stored in memory.
# Processing file 138/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4322E.tif
# File 138 resampled and stored in memory.
# Processing file 139/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4342E.tif
# File 139 resampled and stored in memory.
# Processing file 140/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4313G.tif
# File 140 resampled and stored in memory.
# Processing file 141/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4313F.tif
# File 141 resampled and stored in memory.
# Processing file 142/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4324B.tif
# File 142 resampled and stored in memory.
# Processing file 143/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4343H.tif
# File 143 resampled and stored in memory.
# Processing file 144/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4341D.tif
# File 144 resampled and stored in memory.
# Processing file 145/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4343F.tif
# File 145 resampled and stored in memory.
# Processing file 146/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/U4/U43/U4344D.tif
# File 146 resampled and stored in memory.
# ...
# File 214 resampled and stored in memory.
# Processing file 215/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4413H.tif
# File 215 resampled and stored in memory.
# Processing file 216/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4433B.tif
# File 216 resampled and stored in memory.
# Processing file 217/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4432C.tif
# File 217 resampled and stored in memory.
# Processing file 218/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4431F.tif
# File 218 resampled and stored in memory.
# Processing file 219/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4434D.tif
# File 219 resampled and stored in memory.
# Processing file 220/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4413B.tif
# File 220 resampled and stored in memory.
# Processing file 221/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4442C.tif
# File 221 resampled and stored in memory.
# Processing file 222/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4432F.tif
# File 222 resampled and stored in memory.
# Processing file 223/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4444C.tif
# File 223 resampled and stored in memory.
# Processing file 224/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4421C.tif
# File 224 resampled and stored in memory.
# Processing file 225/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4411A.tif
# File 225 resampled and stored in memory.
# Processing file 226/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4432B.tif
# File 226 resampled and stored in memory.
# Processing file 227/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4442A.tif
# File 227 resampled and stored in memory.
# Processing file 228/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4442D.tif
# File 228 resampled and stored in memory.
# Processing file 229/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4434B.tif
# File 229 resampled and stored in memory.
# Processing file 230/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4422E.tif
# File 230 resampled and stored in memory.
# Processing file 231/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4414G.tif
# File 231 resampled and stored in memory.
# Processing file 232/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4431H.tif
# File 232 resampled and stored in memory.
# Processing file 233/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4411C.tif
# File 233 resampled and stored in memory.
# Processing file 234/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4422G.tif
# File 234 resampled and stored in memory.
# Processing file 235/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4442H.tif
# File 235 resampled and stored in memory.
# Processing file 236/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4444D.tif
# File 236 resampled and stored in memory.
# Processing file 237/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4434F.tif
# File 237 resampled and stored in memory.
# Processing file 238/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4431E.tif
# File 238 resampled and stored in memory.
# Processing file 239/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4443E.tif
# File 239 resampled and stored in memory.
# Processing file 240/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4412D.tif
# File 240 resampled and stored in memory.
# Processing file 241/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4412H.tif
# File 241 resampled and stored in memory.
# Processing file 242/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4411D.tif
# File 242 resampled and stored in memory.
# Processing file 243/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4421F.tif
# File 243 resampled and stored in memory.
# Processing file 244/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4411H.tif
# File 244 resampled and stored in memory.
# Processing file 245/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4434G.tif
# File 245 resampled and stored in memory.
# Processing file 246/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4434H.tif
# File 246 resampled and stored in memory.
# Processing file 247/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4432G.tif
# File 247 resampled and stored in memory.
# Processing file 248/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4421D.tif
# File 248 resampled and stored in memory.
# Processing file 249/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4421B.tif
# File 249 resampled and stored in memory.
# Processing file 250/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4423C.tif
# File 250 resampled and stored in memory.
# Processing file 251/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4441H.tif
# File 251 resampled and stored in memory.
# Processing file 252/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4421E.tif
# File 252 resampled and stored in memory.
# Processing file 253/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4422C.tif
# File 253 resampled and stored in memory.
# Processing file 254/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4414E.tif
# File 254 resampled and stored in memory.
# Processing file 255/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4424G.tif
# File 255 resampled and stored in memory.
# Processing file 256/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4423H.tif
# File 256 resampled and stored in memory.
# Processing file 257/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4432D.tif
# File 257 resampled and stored in memory.
# Processing file 258/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4423B.tif
# File 258 resampled and stored in memory.
# Processing file 259/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4422B.tif
# File 259 resampled and stored in memory.
# Processing file 260/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4412G.tif
# File 260 resampled and stored in memory.
# Processing file 261/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4441B.tif
# File 261 resampled and stored in memory.
# Processing file 262/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4424E.tif
# File 262 resampled and stored in memory.
# Processing file 263/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4411G.tif
# File 263 resampled and stored in memory.
# Processing file 264/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4413D.tif
# File 264 resampled and stored in memory.
# Processing file 265/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4442G.tif
# File 265 resampled and stored in memory.
# Processing file 266/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4431B.tif
# File 266 resampled and stored in memory.
# Processing file 267/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4441F.tif
# File 267 resampled and stored in memory.
# Processing file 268/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4443C.tif
# File 268 resampled and stored in memory.
# Processing file 269/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4441C.tif
# File 269 resampled and stored in memory.
# Processing file 270/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4433E.tif
# File 270 resampled and stored in memory.
# Processing file 271/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4423F.tif
# File 271 resampled and stored in memory.
# Processing file 272/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4434C.tif
# File 272 resampled and stored in memory.
# Processing file 273/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4422D.tif
# File 273 resampled and stored in memory.
# Processing file 274/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4412A.tif
# File 274 resampled and stored in memory.
# Processing file 275/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4414D.tif
# File 275 resampled and stored in memory.
# Processing file 276/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4442E.tif
# File 276 resampled and stored in memory.
# Processing file 277/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4424C.tif
# File 277 resampled and stored in memory.
# Processing file 278/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4421A.tif
# File 278 resampled and stored in memory.
# Processing file 279/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4423G.tif
# File 279 resampled and stored in memory.
# Processing file 280/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4423D.tif
# File 280 resampled and stored in memory.
# Processing file 281/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4441D.tif
# File 281 resampled and stored in memory.
# Processing file 282/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4443G.tif
# File 282 resampled and stored in memory.
# Processing file 283/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4414H.tif
# File 283 resampled and stored in memory.
# Processing file 284/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4433H.tif
# File 284 resampled and stored in memory.
# Processing file 285/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4421G.tif
# File 285 resampled and stored in memory.
# Processing file 286/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4441A.tif
# File 286 resampled and stored in memory.
# Processing file 287/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4413G.tif
# File 287 resampled and stored in memory.
# Processing file 288/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4431C.tif
# File 288 resampled and stored in memory.
# Processing file 289/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4412F.tif
# File 289 resampled and stored in memory.
# Processing file 290/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4433A.tif
# File 290 resampled and stored in memory.
# Processing file 291/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4411F.tif
# File 291 resampled and stored in memory.
# Processing file 292/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4432H.tif
# File 292 resampled and stored in memory.
# Processing file 293/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4423E.tif
# File 293 resampled and stored in memory.
# Processing file 294/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4442B.tif
# File 294 resampled and stored in memory.
# Processing file 295/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4411B.tif
# File 295 resampled and stored in memory.
# Processing file 296/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4432A.tif
# File 296 resampled and stored in memory.
# Processing file 297/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4413F.tif
# File 297 resampled and stored in memory.
# Processing file 298/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4424D.tif
# File 298 resampled and stored in memory.
# Processing file 299/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4444H.tif
# File 299 resampled and stored in memory.
# Processing file 300/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4414C.tif
# File 300 resampled and stored in memory.
# Processing file 301/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4443D.tif
# File 301 resampled and stored in memory.
# Processing file 302/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4422A.tif
# File 302 resampled and stored in memory.
# Processing file 303/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4424F.tif
# File 303 resampled and stored in memory.
# Processing file 304/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4444E.tif
# File 304 resampled and stored in memory.
# Processing file 305/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4421H.tif
# File 305 resampled and stored in memory.
# Processing file 306/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4424B.tif
# File 306 resampled and stored in memory.
# Processing file 307/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4441G.tif
# File 307 resampled and stored in memory.
# Processing file 308/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4412E.tif
# File 308 resampled and stored in memory.
# Processing file 309/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4442F.tif
# File 309 resampled and stored in memory.
# Processing file 310/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4433F.tif
# File 310 resampled and stored in memory.
# Processing file 311/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4433D.tif
# File 311 resampled and stored in memory.
# Processing file 312/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4413C.tif
# File 312 resampled and stored in memory.
# Processing file 313/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4443B.tif
# File 313 resampled and stored in memory.
# Processing file 314/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4414B.tif
# File 314 resampled and stored in memory.
# Processing file 315/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4444B.tif
# File 315 resampled and stored in memory.
# Processing file 316/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4423A.tif
# File 316 resampled and stored in memory.
# Processing file 317/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4422F.tif
# File 317 resampled and stored in memory.
# Processing file 318/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4433C.tif
# File 318 resampled and stored in memory.
# Processing file 319/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4411E.tif
# File 319 resampled and stored in memory.
# Processing file 320/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4412C.tif
# File 320 resampled and stored in memory.
# Processing file 321/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4424H.tif
# File 321 resampled and stored in memory.
# Processing file 322/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4443F.tif
# File 322 resampled and stored in memory.
# Processing file 323/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4444A.tif
# File 323 resampled and stored in memory.
# Processing file 324/324: ../data_store/data/korkeusmalli/hila_2m/etrs-tm35fin-n2000/T4/T44/T4444G.tif
# File 324 resampled and stored in memory.
# Merging all resampled DEMs...
# DEM merging completed.
# Merged DEM shape: (1, 10800, 10800)
# Transform: | 10.00, 0.00, 404000.00|
# | 0.00,-10.00, 7494000.00|
# | 0.00, 0.00, 1.00|

# %% [markdown]
# # Combination

# %%
import numpy as np
import matplotlib.pyplot as plt
import rasterio
from rasterio.coords import BoundingBox
from rasterio.enums import Resampling
from rasterio.warp import reproject, calculate_default_transform
from pyproj import Transformer

def calculate_intersection_bounds(transform1, width1, height1, transform2, width2, height2):
    """
    Calculate the intersection bounds between two raster datasets.
    """
    # Get the bounds of both datasets
    bounds1 = BoundingBox(left=transform1[2],
                          bottom=transform1[5] + transform1[4] * height1,
                          right=transform1[2] + transform1[0] * width1,
                          top=transform1[5])
    
    bounds2 = BoundingBox(left=transform2[2],
                          bottom=transform2[5] + transform2[4] * height2,
                          right=transform2[2] + transform2[0] * width2,
                          top=transform2[5])

    # Find the overlapping area (intersection)
    left = max(bounds1.left, bounds2.left)
    right = min(bounds1.right, bounds2.right)
    bottom = max(bounds1.bottom, bounds2.bottom)
    top = min(bounds1.top, bounds2.top)

    # Ensure that the intersection is valid
    if left < right and bottom < top:
        return BoundingBox(left=left, bottom=bottom, right=right, top=top)
    else:
        raise ValueError("The two rasters do not overlap.")

def reproject_to_common_extent(src_array, src_transform, src_crs, dst_transform, dst_crs, width, height):
    """
    Reprojects a raster to match the common extent and resolution of another dataset.
    """
    reprojected_array = np.empty((height, width), dtype=np.float32)
    reproject(
        source=src_array,
        destination=reprojected_array,
        src_transform=src_transform,
        src_crs=src_crs,
        dst_transform=dst_transform,
        dst_crs=dst_crs,
        resampling=Resampling.nearest
    )
    return reprojected_array

# Calculate the intersection bounds between the Sentinel-2 image (e.g., band3) and the DEM
intersection_bounds = calculate_intersection_bounds(
    transform_band3, band3.shape[1], band3.shape[0],
    merged_transform, merged_dem.shape[2], merged_dem.shape[1]
)

# Calculate the transform and shape for the intersection area
dst_transform, dst_width, dst_height = calculate_default_transform(
    crs_band3, 'EPSG:4326', 
    band3.shape[1], band3.shape[0], 
    left=intersection_bounds.left, bottom=intersection_bounds.bottom, 
    right=intersection_bounds.right, top=intersection_bounds.top
)

# Reproject the DEM to the intersection area
reprojected_dem = reproject_to_common_extent(
    merged_dem[0], merged_transform, dem_crs, 
    dst_transform, 'EPSG:4326', dst_width, dst_height
)

# Reproject the Sentinel-2 snow mask to the intersection area
reprojected_snow_mask = reproject_to_common_extent(
    snow_mask, transform_band3, crs_band3, 
    dst_transform, 'EPSG:4326', dst_width, dst_height
)

# Mask out zero values in the reprojected DEM and calculate fractional snow cover in 1 km x 1 km blocks
reprojected_dem[reprojected_dem == 0] = np.nan

# Plot the DEM reprojected to the intersection area
plt.figure(figsize=(10, 10))
plt.imshow(reprojected_dem, cmap='terrain', extent=(dst_transform[2], dst_transform[2] + dst_transform[0] * dst_width,
                                                    dst_transform[5] + dst_transform[4] * dst_height, dst_transform[5]),
           aspect='auto')
plt.colorbar(label='Elevation (meters)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('DEM Reprojected to Common Intersection Area')
plt.show()

# Plot the averaged snow cover using the reprojected snow mask
averaged_snow_cover = average_snow_cover_in_blocks(reprojected_snow_mask, dst_transform)
plot_averaged_snow_cover_latlon(averaged_snow_cover, dst_transform, 'EPSG:4326', title="Averaged Snow Cover in Common Area")
