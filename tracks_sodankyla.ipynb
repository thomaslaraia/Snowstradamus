# %%
from scripts.track_pairs import *
from scripts.show_tracks import *

dirpath = '../data_store/data/sodankyla_full/'
impath = '../data_store/data/sodankyla_full/'
# all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed = True)
all_ATL03, all_ATL08 = track_pairs(dirpath)
N = len(all_ATL03)

# extent = None
coords = (26.634154,67.361833)
e = .15
extent = (coords[0]-e/np.cos(np.radians(coords[1])), coords[0]+e/np.cos(np.radians(coords[1])), coords[1]-e, coords[1]+e)
fig, ax = map_setup(map_path = impath + '/image.tiff', extent = extent)

# ax = show_tracks_only_atl03(failed_ATL03, ax)
# for i in [0]:
#     print(all_ATL03[i])
#     ax = show_tracks([all_ATL03[i]], [all_ATL08[i]], ax, c='Ev', CBAR = 1)

# i = 5
ax = show_tracks(all_ATL03, all_ATL08, ax, coords=coords, c='Eg', CBAR = 1, w=.1, h=.1, landcover = None)

# Show the plot
# plt.savefig('./images/tracks_vis/sodankyla10_nofilter.png')
plt.show()

# for f in failed_ATL03:
#     print(f)

# %%
from scripts.track_pairs import *
from scripts.show_tracks import *

dirpath = '../data_store/data/sodankyla_full/'
impath = '../data_store/data/sodankyla_full/'
# all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed = True)
all_ATL03, all_ATL08 = track_pairs(dirpath)
N = len(all_ATL03)

# extent = None
coords = (26.634154,67.361833)
e = .15
extent = (coords[0]-e/np.cos(np.radians(coords[1])), coords[0]+e/np.cos(np.radians(coords[1])), coords[1]-e, coords[1]+e)
fig, ax = map_setup(map_path = impath + '/image.tiff', extent = extent)

# ax = show_tracks_only_atl03(failed_ATL03, ax)
# for i in [0]:
#     print(all_ATL03[i])
#     ax = show_tracks([all_ATL03[i]], [all_ATL08[i]], ax, c='Ev', CBAR = 1)

# i = 5
ax = show_tracks(all_ATL03, all_ATL08, ax, coords=coords, c='Eg', CBAR = 1, w=.1, h=.1, landcover = 1, vmax=6)

# Show the plot
plt.savefig('./images/five_sites/sodankyla10.png')
plt.show()

# for f in failed_ATL03:
#     print(f)
