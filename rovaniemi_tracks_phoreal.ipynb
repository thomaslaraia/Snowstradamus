# %%
# %matplotlib ipympl

from scripts.imports import os, glob, pdb, np, h5py, pd, xr, gpd, Proj, Transformer, CRS, \
                        plt, cmap, Model, Data, ODR, datetime, rasterio, show, \
                        ccrs, cfeature

# import sys

from scripts.pvpg_phoreal import *

# from phoreal.reader import get_atl03_struct, get_atl08_struct

from scripts.track_pairs import *
# Out:
# /home/s1803229/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# # Arthur's Seat

# %%
dirpath = '../data/august_2021_arthurs_seat_preprocessed'
ATL03, ATL08 = track_pairs(dirpath)
coefs, means = pvpg_parallel(ATL03[0],ATL08[0],
                  f_scale = 0.1, # Default is 0.1
                  loss = 'arctan', # Default is 'arctan'
                  init = -1, # Default is 1
                  lb = -100, # Default is -100
                  ub = -1/100, # Default is -1/100
                  file_index = 0, # Default is None
                  # model = model, # see script
                  # res = res, # see script
                  # odr = odr, # see script
                  zeros = None, # Default is None, activate to include outliers
                  beam = None, #Default is None, activate a la e.g. [3,4] to show info for only beams 3 and 4
                  y_init = np.max, # Default is np.max, used to choose initial guess for y_intercept
                  graph_detail = 2, # Default is 0, change to 1 to see pv/pg plot, change to 2 to also see all the groundtracks, 3 to only
                                    # see the groundtracks
                  canopy_frac = True, # Default is None, activate to show fraction of segments that contain any canopy photons
                  terrain_frac = True) # Default is None, activate to show fraction of segments that contain any ground photons
# Out:
# /home/s1803229/.local/lib/python3.10/site-packages/traitlets/traitlets.py:1387: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Rovaniemi

# %%
dirpath = '../data/rovaniemi_w'
all_ATL03, all_ATL08 = track_pairs(dirpath)
                             
N = len(all_ATL03)
for i in range(0,1):
    # pvpg(all_ATL03[i], all_ATL08[i],i)
    # atl03 = get_atl03_struct(all_ATL03[i], 'gt1r', all_ATL08[i])
    # atl08 = get_atl08_struct(all_ATL08[i], 'gt1r')

# atl08.df.columns.values.tolist()
# Out:
# ['asr',
#  'atlas_pa',
#  'beam_azimuth',
#  'beam_coelev',
#  'brightness_flag',
#  'can_noise',
#  'canopy_h_metrics_0',
#  'canopy_h_metrics_1',
#  'canopy_h_metrics_2',
#  'canopy_h_metrics_3',
#  'canopy_h_metrics_4',
#  'canopy_h_metrics_5',
#  'canopy_h_metrics_6',
#  'canopy_h_metrics_7',
#  'canopy_h_metrics_8',
#  'canopy_h_metrics_9',
#  'canopy_h_metrics_10',
#  'canopy_h_metrics_11',
#  'canopy_h_metrics_12',
#  'canopy_h_metrics_13',
#  'canopy_h_metrics_14',
#  'canopy_h_metrics_15',
#  'canopy_h_metrics_16',
#  'canopy_h_metrics_17',
#  'canopy_h_metrics_abs_0',
#  'canopy_h_metrics_abs_1',
#  'canopy_h_metrics_abs_2',
#  'canopy_h_metrics_abs_3',
#  'canopy_h_metrics_abs_4',
#  'canopy_h_metrics_abs_5',
#  'canopy_h_metrics_abs_6',
#  'canopy_h_metrics_abs_7',
#  'canopy_h_metrics_abs_8',
#  'canopy_h_metrics_abs_9',
#  'canopy_h_metrics_abs_10',
#  'canopy_h_metrics_abs_11',
#  'canopy_h_metrics_abs_12',
#  'canopy_h_metrics_abs_13',
#  'canopy_h_metrics_abs_14',
#  'canopy_h_metrics_abs_15',
#  'canopy_h_metrics_abs_16',
#  'canopy_h_metrics_abs_17',
#  'canopy_openness',
#  'canopy_rh_conf',
#  'centroid_height',
#  'h_canopy',
#  'h_canopy_20m_0',
#  'h_canopy_20m_1',
#  'h_canopy_20m_2',
#  'h_canopy_20m_3',
#  'h_canopy_20m_4',
#  'h_canopy_abs',
#  'h_canopy_quad',
#  'h_canopy_uncertainty',
#  'h_dif_canopy',
#  'h_max_canopy',
#  'h_max_canopy_abs',
#  'h_mean_canopy',
#  'h_mean_canopy_abs',
#  'h_median_canopy',
#  'h_median_canopy_abs',
#  'h_min_canopy',
#  'h_min_canopy_abs',
#  'n_ca_photons',
#  'n_toc_photons',
#  'photon_rate_can',
#  'photon_rate_can_nr',
#  'segment_cover',
#  'subset_can_flag_0',
#  'subset_can_flag_1',
#  'subset_can_flag_2',
#  'subset_can_flag_3',
#  'subset_can_flag_4',
#  'toc_roughness',
#  'cloud_flag_atm',
#  'cloud_fold_flag',
#  'delta_time',
#  'delta_time_beg',
#  'delta_time_end',
#  'dem_flag',
#  'dem_h',
#  'dem_removal_flag',
#  'h_dif_ref',
#  'last_seg_extend',
#  'latitude',
#  'latitude_20m_0',
#  'latitude_20m_1',
#  'latitude_20m_2',
#  'latitude_20m_3',
#  'latitude_20m_4',
#  'layer_flag',
#  'longitude',
#  'longitude_20m_0',
#  'longitude_20m_1',
#  'longitude_20m_2',
#  'longitude_20m_3',
#  'longitude_20m_4',
#  'msw_flag',
#  'n_seg_ph',
#  'night_flag',
#  'ph_ndx_beg',
#  'ph_removal_flag',
#  'psf_flag',
#  'rgt',
#  'sat_flag',
#  'segment_id_beg',
#  'segment_id_end',
#  'segment_landcover',
#  'segment_snowcover',
#  'segment_watermask',
#  'sigma_across',
#  'sigma_along',
#  'sigma_atlas_land',
#  'sigma_h',
#  'sigma_topo',
#  'snr',
#  'solar_azimuth',
#  'solar_elevation',
#  'surf_type_0',
#  'surf_type_1',
#  'surf_type_2',
#  'surf_type_3',
#  'surf_type_4',
#  'h_te_best_fit',
#  'h_te_best_fit_20m_0',
#  'h_te_best_fit_20m_1',
#  'h_te_best_fit_20m_2',
#  'h_te_best_fit_20m_3',
#  'h_te_best_fit_20m_4',
#  'h_te_interp',
#  'h_te_max',
#  'h_te_mean',
#  'h_te_median',
#  'h_te_min',
#  'h_te_mode',
#  'h_te_rh25',
#  'h_te_skew',
#  'h_te_std',
#  'h_te_uncertainty',
#  'n_te_photons',
#  'photon_rate_te',
#  'subset_te_flag_0',
#  'subset_te_flag_1',
#  'subset_te_flag_2',
#  'subset_te_flag_3',
#  'subset_te_flag_4',
#  'terrain_slope',
#  'terrain_flg',
#  'urban_flag',
#  'time',
#  'easting',
#  'northing',
#  'crosstrack',
#  'alongtrack']
